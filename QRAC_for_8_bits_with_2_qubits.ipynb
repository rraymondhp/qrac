# %% [markdown]
# # Quantum Random Access Coding for 8 bits with 2 qubits.
#
# We first import the libraries.

# %%
import numpy as np
from pprint import pprint
import math
from numpy import array

# %% [markdown]
# ## Encoding Quantum States
#
# We then give the encoding of quantum states for each bitstring $00000000$ to $11111111$ whose decimal representation is $0$ to $2^9-1$. The `encoding[j]` is the mixed state for encoding `j`-th bitstring.

# %%
encoding = [array([[ 0.36287171+2.38726451e-14j,  0.06079613+4.95227704e-02j,
         0.14156643-3.12005498e-01j, -0.11840735-2.11539240e-01j],
       [ 0.06079613-4.95227704e-02j,  0.04035723+1.40211752e-15j,
        -0.05480991-7.82994808e-02j, -0.07814558-3.74775058e-02j],
       [ 0.14156643+3.12005498e-01j, -0.05480991+7.82994808e-02j,
         0.38224394+5.75497284e-14j,  0.1869911 -1.64574422e-01j],
       [-0.11840735+2.11539240e-01j, -0.07814558+3.74775058e-02j,
         0.1869911 +1.64574422e-01j,  0.21452712-8.90958937e-15j]]), array([[ 0.31186355+8.08592561e-15j,  0.13955613-8.29227847e-02j,
        -0.09731114-1.57289706e-01j, -0.33012411-1.34309901e-01j],
       [ 0.13955613+8.29227847e-02j,  0.09616999+6.85882480e-16j,
        -0.01580374-1.01227938e-01j, -0.12484857-1.58397277e-01j],
       [-0.09731114+1.57289706e-01j, -0.01580374+1.01227938e-01j,
         0.14470705-3.24659883e-15j,  0.20090168-1.13457772e-01j],
       [-0.33012411+1.34309901e-01j, -0.12484857+1.58397277e-01j,
         0.20090168+1.13457772e-01j,  0.44725941+1.21794442e-15j]]), array([[ 0.24114711+1.13412378e-16j, -0.05468784-8.71022383e-02j,
         0.22736819-1.84226435e-01j,  0.0388761 -2.15792806e-01j],
       [-0.05468784+8.71022383e-02j,  0.05886766+2.72393004e-16j,
         0.00615593+1.13046729e-01j,  0.05051769+5.40682518e-02j],
       [ 0.22736819+1.84226435e-01j,  0.00615593-1.13046729e-01j,
         0.41197981+1.39473163e-15j,  0.25571208-2.04940071e-01j],
       [ 0.0388761 +2.15792806e-01j,  0.05051769-5.40682518e-02j,
         0.25571208+2.04940071e-01j,  0.28800542-1.67386745e-15j]]), array([[ 0.16497695-2.40173234e-12j, -0.02866073-1.29574843e-01j,
        -0.00824017-1.22321834e-01j, -0.17860558-2.83787392e-02j],
       [-0.02866073+1.29574843e-01j,  0.12673516+1.02645074e-12j,
         0.07686422-2.88344959e-02j, -0.01184907-1.77715056e-01j],
       [-0.00824017+1.22321834e-01j,  0.07686422+2.88344960e-02j,
         0.20764794+2.84391789e-12j,  0.18977089-2.29500412e-01j],
       [-0.17860558+2.83787392e-02j, -0.01184907+1.77715056e-01j,
         0.18977089+2.29500412e-01j,  0.50063995-6.27968300e-12j]]), array([[0.30956179+1.25718426e-15j, 0.1555331 +6.41998576e-03j,
        0.29535688-2.16912615e-01j, 0.09431397-6.53089602e-02j],
       [0.1555331 -6.41998576e-03j, 0.09390217-3.40779348e-16j,
        0.1578801 -1.26062082e-01j, 0.0532635 -3.81445991e-02j],
       [0.29535688+2.16912615e-01j, 0.1578801 +1.26062082e-01j,
        0.52176008-8.14874122e-17j, 0.17666379+1.07417478e-02j],
       [0.09431397+6.53089602e-02j, 0.0532635 +3.81445991e-02j,
        0.17666379-1.07417478e-02j, 0.07477595-5.93915542e-18j]]), array([[ 0.2967337 +1.07788936e-15j,  0.18241038-1.35687095e-01j,
        -0.05993309-2.98974297e-01j, -0.07539566-1.47372438e-01j],
       [ 0.18241038+1.35687095e-01j,  0.19610442-1.90942206e-15j,
         0.11447621-2.30585310e-01j,  0.03676028-1.24137907e-01j],
       [-0.05993309+2.98974297e-01j,  0.11447621+2.30585310e-01j,
         0.36936972-7.22531335e-16j,  0.18462201-1.65106414e-02j],
       [-0.07539566+1.47372438e-01j,  0.03676028+1.24137907e-01j,
         0.18462201+1.65106414e-02j,  0.13779217+2.08248469e-16j]]), array([[0.17116187-9.83929191e-16j, 0.08270903-8.55175554e-02j,
        0.19679896-4.94214232e-02j, 0.1356152 -6.61404214e-02j],
       [0.08270903+8.55175554e-02j, 0.12960003-3.55596721e-16j,
        0.20945553+4.76091011e-02j, 0.1445016 -1.05142991e-02j],
       [0.19679896+4.94214232e-02j, 0.20945553-4.76091011e-02j,
        0.45720371-1.51387592e-15j, 0.30609177-1.08734846e-01j],
       [0.1356152 +6.61404214e-02j, 0.1445016 +1.05142991e-02j,
        0.30609177+1.08734846e-01j, 0.2420344 -4.27261173e-16j]]), array([[ 0.19207082+4.05102162e-16j, -0.0241277 -2.15221683e-01j,
        -0.09371073-1.90564258e-01j, -0.11268319-6.39883570e-02j],
       [-0.0241277 +2.15221683e-01j,  0.28496011+7.77401809e-16j,
         0.27512139-1.03221960e-01j,  0.11247261-1.55096146e-01j],
       [-0.09371073+1.90564258e-01j,  0.27512139+1.03221960e-01j,
         0.34667023+1.29506120e-15j,  0.1960271 -1.26073828e-01j],
       [-0.11268319+6.39883570e-02j,  0.11247261+1.55096146e-01j,
         0.1960271 +1.26073828e-01j,  0.17629884+1.33500524e-15j]]), array([[ 0.16443582+1.09742493e-14j,  0.04639403+9.97260168e-02j,
         0.20211009-2.28318480e-01j, -0.13219307-8.89430088e-02j],
       [ 0.04639403-9.97260168e-02j,  0.0846931 +3.76469374e-15j,
        -0.09549511-1.82179042e-01j, -0.09542614+5.92039212e-02j],
       [ 0.20211009+2.28318480e-01j, -0.09549511+1.82179042e-01j,
         0.59188455-1.61347615e-14j, -0.03178789-2.97556729e-01j],
       [-0.13219307+8.89430088e-02j, -0.09542614-5.92039212e-02j,
        -0.03178789+2.97556729e-01j,  0.15898653+3.47322251e-16j]]), array([[ 0.18711902-8.05121745e-16j,  0.22544837-1.99816684e-02j,
         0.00690967-1.29191435e-01j, -0.24913973-3.29580583e-02j],
       [ 0.22544837+1.99816684e-02j,  0.30267619-5.24445292e-16j,
         0.01435058-1.63977015e-01j, -0.31607246-6.92297870e-02j],
       [ 0.00690967+1.29191435e-01j,  0.01435058+1.63977015e-01j,
         0.13866943+2.32356163e-16j,  0.02227419-1.73841968e-01j],
       [-0.24913973+3.29580583e-02j, -0.31607246+6.92297870e-02j,
         0.02227419+1.73841968e-01j,  0.37153537-1.20456063e-15j]]), array([[ 6.02800294e-02-6.65324888e-16j, -3.50082979e-04-2.44794018e-02j,
         1.52351287e-01-8.38840820e-02j, -5.40466596e-02-1.04678175e-01j],
       [-3.50082979e-04+2.44794018e-02j,  4.78919715e-02-9.09111094e-18j,
         4.51647320e-03+6.29596519e-02j,  2.32936513e-02+8.45041994e-03j],
       [ 1.52351287e-01+8.38840820e-02j,  4.51647320e-03-6.29596519e-02j,
         5.87248833e-01+1.72835036e-15j,  2.85729257e-02-4.06332989e-01j],
       [-5.40466596e-02+1.04678175e-01j,  2.32936513e-02-8.45041994e-03j,
         2.85729257e-02+4.06332989e-01j,  3.04579166e-01+9.20742550e-17j]]), array([[ 0.06196538-1.72514616e-16j,  0.03950403-7.61959017e-02j,
         0.03211018-1.09582704e-01j, -0.13037065+2.53316810e-03j],
       [ 0.03950403+7.61959017e-02j,  0.16148962-5.63246243e-16j,
         0.13819105-7.11371733e-02j, -0.15228935-1.42821928e-01j],
       [ 0.03211018+1.09582704e-01j,  0.13819105+7.11371733e-02j,
         0.31889283-7.98933262e-16j, -0.05352355-3.60884461e-01j],
       [-0.13037065-2.53316810e-03j, -0.15228935+1.42821928e-01j,
        -0.05352355+3.60884461e-01j,  0.45765216-1.66017852e-15j]]), array([[ 0.18666463-5.51365422e-15j,  0.17191046+1.10855345e-03j,
         0.27866641+3.20420015e-03j, -0.02889804-2.70686082e-03j],
       [ 0.17191046-1.10855345e-03j,  0.16979543+1.05115503e-15j,
         0.24389588-4.21511631e-02j, -0.0351128 -2.46039508e-03j],
       [ 0.27866641-3.20420015e-03j,  0.24389588+4.21511631e-02j,
         0.63123806-1.22971679e-14j, -0.03100042-4.00043933e-02j],
       [-0.02889804+2.70686082e-03j, -0.0351128 +2.46039508e-03j,
        -0.03100042+4.00043933e-02j,  0.01230189+3.08680830e-16j]]), array([[ 0.14164937-9.84225181e-17j,  0.19939765-5.52101696e-02j,
         0.03589492-2.12031419e-01j, -0.07679458+3.90643530e-03j],
       [ 0.19939765+5.52101696e-02j,  0.35222287-9.98835879e-16j,
         0.16105627-3.31571751e-01j, -0.117013  -2.06880516e-02j],
       [ 0.03589492+2.12031419e-01j,  0.16105627+3.31571751e-01j,
         0.43956849-2.95535009e-16j, -0.03052168-1.09719226e-01j],
       [-0.07679458-3.90643530e-03j, -0.117013  +2.06880516e-02j,
        -0.03052168+1.09719226e-01j,  0.06655926+7.47954045e-18j]]), array([[0.09440108+6.11029215e-15j, 0.1149536 -8.23843150e-02j,
        0.14093807+2.80894017e-02j, 0.04097573-2.09232881e-02j],
       [0.1149536 +8.23843150e-02j, 0.26384355+3.82349278e-14j,
        0.27426556+1.21520519e-01j, 0.06161695-4.59010938e-02j],
       [0.14093807-2.80894017e-02j, 0.27426556-1.21520519e-01j,
        0.55702573+4.63479764e-14j, 0.07784527-1.86587196e-01j],
       [0.04097573+2.09232881e-02j, 0.06161695+4.59010938e-02j,
        0.07784527+1.86587196e-01j, 0.08472964+6.07917606e-15j]]), array([[ 0.08667851+3.49330827e-16j,  0.04756814-1.79878152e-01j,
        -0.00813135-1.39746904e-01j, -0.0458218 +2.25119649e-02j],
       [ 0.04756814+1.79878152e-01j,  0.47024303+8.19493742e-16j,
         0.36173381-1.09845922e-01j, -0.07896552-1.18864870e-01j],
       [-0.00813135+1.39746904e-01j,  0.36173381+1.09845922e-01j,
         0.36201746+5.92081747e-16j, -0.02550477-1.47431126e-01j],
       [-0.0458218 -2.25119649e-02j, -0.07896552+1.18864870e-01j,
        -0.02550477+1.47431126e-01j,  0.081061  +1.56566556e-16j]]), array([[ 0.15741971+1.42200650e-15j, -0.04069329+9.69512454e-02j,
         0.19046748-1.61373707e-01j,  0.10468995-8.69823570e-02j],
       [-0.04069329-9.69512454e-02j,  0.11797281+4.84767361e-16j,
        -0.21262291-9.72435983e-02j, -0.12242709-8.21491271e-02j],
       [ 0.19046748+1.61373707e-01j, -0.21262291+9.72435983e-02j,
         0.51730376+2.05419281e-15j,  0.30256031+4.22516331e-02j],
       [ 0.10468995+8.69823570e-02j, -0.12242709+8.21491271e-02j,
         0.30256031-4.22516331e-02j,  0.20730373+3.51749502e-16j]]), array([[ 0.0573348 -1.24699390e-17j,  0.04562511-3.86578010e-02j,
        -0.06382451-6.94961258e-03j, -0.09855258-3.25823062e-02j],
       [ 0.04562511+3.86578010e-02j,  0.17132172+3.96475924e-16j,
        -0.1730545 -1.20449996e-01j, -0.15953392-2.15900572e-01j],
       [-0.06382451+6.94961258e-03j, -0.1730545 +1.20449996e-01j,
         0.30737855-7.18644274e-16j,  0.33676034+1.10619020e-01j],
       [-0.09855258+3.25823062e-02j, -0.15953392+2.15900572e-01j,
         0.33676034-1.10619020e-01j,  0.46396493-3.04036413e-15j]]), array([[ 0.18330565-7.30823733e-16j, -0.11327091-1.61040280e-02j,
         0.21660082+4.68630319e-03j,  0.23533327-4.31275350e-02j],
       [-0.11327091+1.61040280e-02j,  0.08998251-1.39785060e-16j,
        -0.13961155+1.00602019e-02j, -0.15336996+3.95572746e-02j],
       [ 0.21660082-4.68630319e-03j, -0.13961155-1.00602019e-02j,
         0.32994809-4.07917916e-16j,  0.33822492-8.06719339e-02j],
       [ 0.23533327+4.31275350e-02j, -0.15336996-3.95572746e-02j,
         0.33822492+8.06719339e-02j,  0.39676374+3.38650878e-16j]]), array([[ 0.06611985+4.95956672e-16j, -0.07306632-3.43076613e-02j,
         0.02171965+6.17858211e-02j,  0.07078367+1.18242843e-01j],
       [-0.07306632+3.43076613e-02j,  0.13986483+5.42263440e-16j,
        -0.06677783-1.12806851e-01j, -0.19650332-1.79152801e-01j],
       [ 0.02171965-6.17858211e-02j, -0.06677783+1.12806851e-01j,
         0.1773205 -1.46660275e-16j,  0.30297092-9.77924494e-02j],
       [ 0.07078367-1.18242843e-01j, -0.19650332+1.79152801e-01j,
         0.30297092+9.77924494e-02j,  0.61669483+1.02349335e-15j]]), array([[ 0.15560545-3.35810501e-16j, -0.01296625+5.48734686e-02j,
         0.22877379+1.39957476e-01j,  0.06999604+9.80044236e-02j],
       [-0.01296625-5.48734686e-02j,  0.03849759-9.76915229e-17j,
         0.0243556 -1.38876314e-01j,  0.0335437 -5.32831952e-02j],
       [ 0.22877379-1.39957476e-01j,  0.0243556 +1.38876314e-01j,
         0.6670341 -2.40299538e-15j,  0.27390823+1.14132672e-01j],
       [ 0.06999604-9.80044236e-02j,  0.0335437 +5.32831952e-02j,
         0.27390823-1.14132672e-01j,  0.13886287-1.17896587e-15j]]), array([[ 0.10945233-6.09005535e-18j,  0.01659394-9.00789408e-02j,
        -0.1643805 -4.13682701e-03j, -0.09074442-2.86189574e-02j],
       [ 0.01659394+9.00789408e-02j,  0.14675257+3.51670949e-16j,
        -0.02936252-2.59955185e-01j,  0.02770431-1.48799747e-01j],
       [-0.1643805 +4.13682701e-03j, -0.02936252+2.59955185e-01j,
         0.54809649-2.65776221e-16j,  0.2918706 +9.82017818e-02j],
       [-0.09074442+2.86189574e-02j,  0.02770431+1.48799747e-01j,
         0.2918706 -9.82017818e-02j,  0.1956986 -7.53888325e-16j]]), array([[ 0.1870301 +1.96756508e-15j, -0.02789137+2.93821883e-02j,
         0.10497461+2.29987322e-01j,  0.16527282+1.54198610e-01j],
       [-0.02789137-2.93821883e-02j,  0.02379018-6.05500402e-17j,
         0.045945  -4.82425956e-02j,  0.01601268-5.16151109e-02j],
       [ 0.10497461-2.29987322e-01j,  0.045945  +4.82425956e-02j,
         0.45630877-2.35081715e-15j,  0.35531593-1.34798423e-01j],
       [ 0.16527282-1.54198610e-01j,  0.01601268+5.16151109e-02j,
         0.35531593+1.34798423e-01j,  0.33287094-9.75807340e-19j]]), array([[ 0.16531778+1.40243445e-16j, -0.12891495-7.66853183e-02j,
        -0.16919217+1.09236223e-01j, -0.06081034+1.60196664e-01j],
       [-0.12891495+7.66853183e-02j,  0.16967098+3.58083821e-16j,
         0.11080542-2.01172713e-01j, -0.01163387-1.92636731e-01j],
       [-0.16919217-1.09236223e-01j,  0.11080542+2.01172713e-01j,
         0.37375163-1.26078929e-16j,  0.27238029-1.46827936e-01j],
       [-0.06081034-1.60196664e-01j, -0.01163387+1.92636731e-01j,
         0.27238029+1.46827936e-01j,  0.29125961+2.38503682e-16j]]), array([[ 0.05879903+8.37892152e-16j,  0.02483602+1.05214379e-01j,
         0.05316691-7.61725272e-02j, -0.02552026-7.33472249e-02j],
       [ 0.02483602-1.05214379e-01j,  0.25776113+2.32356003e-17j,
        -0.26365374-1.14383826e-01j, -0.1783845 +2.39939279e-02j],
       [ 0.05316691+7.61725272e-02j, -0.26365374+1.14383826e-01j,
         0.55562231-5.63254835e-15j,  0.16758903-1.16040672e-01j],
       [-0.02552026+7.33472249e-02j, -0.1783845 -2.39939279e-02j,
         0.16758903+1.16040672e-01j,  0.12781754-2.13721581e-15j]]), array([[ 0.04536691-3.44140369e-11j,  0.11380146-1.47397224e-02j,
        -0.08775692-1.41857859e-02j, -0.10207172-3.25301323e-02j],
       [ 0.11380146+1.47397222e-02j,  0.3536277 -1.80066159e-10j,
        -0.15278557-1.26128517e-01j, -0.2997791 -9.79500594e-02j],
       [-0.08775692+1.41857860e-02j, -0.15278557+1.26128517e-01j,
         0.2970307 -1.45999145e-10j,  0.13739447-5.50029333e-03j],
       [-0.10207172+3.25301324e-02j, -0.2997791 +9.79500597e-02j,
         0.13739447+5.50029308e-03j,  0.30397468+1.09325103e-10j]]), array([[ 0.04993176+3.75806747e-16j, -0.07670965-5.13733835e-03j,
         0.08744922+7.92992184e-02j,  0.10257438-3.69901367e-02j],
       [-0.07670965+5.13733835e-03j,  0.19385904+2.24493615e-16j,
        -0.20135281-3.87221204e-02j, -0.17759761+1.08777003e-01j],
       [ 0.08744922-7.92992184e-02j, -0.20135281+3.87221204e-02j,
         0.4681029 +6.91197455e-16j,  0.19042118-2.64625480e-01j],
       [ 0.10257438+3.69901367e-02j, -0.17759761-1.08777003e-01j,
         0.19042118+2.64625480e-01j,  0.2881063 +6.47538202e-16j]]), array([[ 0.03534506+7.70133135e-17j, -0.05280878-6.32958715e-02j,
        -0.02518649+4.31395782e-02j,  0.05399892+7.34391187e-02j],
       [-0.05280878+6.32958715e-02j,  0.33723486+4.76245326e-16j,
        -0.07589187-1.70119391e-01j, -0.36644072-2.37886881e-02j],
       [-0.02518649-4.31395782e-02j, -0.07589187+1.70119391e-01j,
         0.18846842-3.52426960e-16j,  0.10717097-2.06129078e-01j],
       [ 0.05399892-7.34391187e-02j, -0.36644072+2.37886881e-02j,
         0.10717097+2.06129078e-01j,  0.43895166+4.54548620e-16j]]), array([[ 9.21407581e-02-8.74748426e-16j,  1.82767892e-02+2.04038961e-02j,
         1.27260799e-01+1.91201366e-01j,  3.45973743e-04+6.27830856e-03j],
       [ 1.82767892e-02-2.04038961e-02j,  3.78800675e-02+1.28209692e-16j,
         4.25623744e-02-6.97837491e-02j, -6.48797793e-03-1.38891299e-03j],
       [ 1.27260799e-01-1.91201366e-01j,  4.25623744e-02+6.97837491e-02j,
         8.64193068e-01-5.38969997e-16j,  3.00539889e-02-1.23085211e-02j],
       [ 3.45973743e-04-6.27830856e-03j, -6.48797793e-03+1.38891299e-03j,
         3.00539889e-02+1.23085211e-02j,  5.78610679e-03-2.17314280e-17j]]), array([[ 0.03468338-2.04167558e-17j,  0.03470528-5.10205799e-02j,
        -0.11018201-2.71194342e-02j, -0.01907456+8.29902881e-04j],
       [ 0.03470528+5.10205799e-02j,  0.21482866+4.10046097e-16j,
        -0.0339542 -3.48134227e-01j, -0.05524533-1.96123533e-02j],
       [-0.11018201+2.71194342e-02j, -0.0339542 +3.48134227e-01j,
         0.71035915-1.72179283e-16j,  0.02951457-5.04922612e-02j],
       [-0.01907456-8.29902881e-04j, -0.05524533+1.96123533e-02j,
         0.02951457+5.04922612e-02j,  0.04012881+2.64081563e-17j]]), array([[ 9.64122930e-02+1.26484762e-16j, -2.18376247e-03+9.81327626e-03j,
        -1.75652141e-02+2.31605047e-01j,  9.88472822e-02+5.01637118e-02j],
       [-2.18376247e-03-9.81327626e-03j,  3.81636757e-02+1.23534256e-18j,
         4.91653390e-02+1.77955036e-03j,  8.33084393e-05-1.58621373e-02j],
       [-1.75652141e-02-2.31605047e-01j,  4.91653390e-02-1.77955036e-03j,
         7.03368247e-01+1.83785319e-17j,  1.23794360e-01-2.93297594e-01j],
       [ 9.88472822e-02-5.01637118e-02j,  8.33084393e-05+1.58621373e-02j,
         1.23794360e-01+2.93297594e-01j,  1.62055785e-01-4.36267302e-16j]]), array([[ 0.09788167+8.90503033e-17j, -0.07927465-8.95325846e-02j,
        -0.16666777+7.23302785e-02j,  0.04232168+9.69664141e-02j],
       [-0.07927465+8.95325846e-02j,  0.22402804-2.26801378e-16j,
         0.116643  -2.61176816e-01j, -0.15799819-6.19656458e-02j],
       [-0.16666777-7.23302785e-02j,  0.116643  +2.61176816e-01j,
         0.50222121-6.00455467e-17j,  0.01017595-2.60474107e-01j],
       [ 0.04232168-9.69664141e-02j, -0.15799819+6.19656458e-02j,
         0.01017595+2.60474107e-01j,  0.17586908-5.92563813e-17j]]), array([[ 0.52854598+6.21861115e-13j, -0.009436  -1.19952239e-01j,
         0.30922934-1.19624128e-01j, -0.15797426+1.57912936e-02j],
       [-0.009436  +1.19952239e-01j,  0.05843623+3.43807241e-13j,
        -0.02776483+5.65985922e-02j, -0.03832365-6.41553185e-02j],
       [ 0.30922934+1.19624128e-01j, -0.02776483-5.65985922e-02j,
         0.29456622+4.17570098e-13j, -0.02203428-9.41289133e-04j],
       [-0.15797426-1.57912936e-02j, -0.03832365+6.41553185e-02j,
        -0.02203428+9.41289134e-04j,  0.11845157-1.46013234e-13j]]), array([[ 0.50109359+4.16514032e-15j,  0.06933358-2.35868546e-01j,
         0.02605571-7.60639826e-04j, -0.38489792+8.11708192e-02j],
       [ 0.06933358+2.35868546e-01j,  0.13134417+2.40858882e-15j,
        -0.00846355+6.55167462e-03j, -0.10097192-1.80257224e-01j],
       [ 0.02605571+7.60639826e-04j, -0.00846355-6.55167462e-03j,
         0.02981476-7.90409183e-18j,  0.00268616+1.31964829e-02j],
       [-0.38489792-8.11708192e-02j, -0.10097192+1.80257224e-01j,
         0.00268616-1.31964829e-02j,  0.33774747-1.64735289e-17j]]), array([[ 0.4916113 -3.65509071e-16j, -0.14687834-2.80370856e-01j,
         0.28097075-1.72515863e-01j, -0.01139059-7.09788362e-02j],
       [-0.14687834+2.80370856e-01j,  0.21491386+9.63202046e-16j,
         0.01165662+2.12273856e-01j,  0.04020298+1.42038746e-02j],
       [ 0.28097075+1.72515863e-01j,  0.01165662-2.12273856e-01j,
         0.24609461+3.66511570e-16j,  0.03673303-5.61916650e-02j],
       [-0.01139059+7.09788362e-02j,  0.04020298-1.42038746e-02j,
         0.03673303+5.61916650e-02j,  0.04738023-6.84249867e-17j]]), array([[ 0.44159203+1.01813387e-14j, -0.15027499-3.32742147e-01j,
         0.06365084-1.46823422e-01j, -0.22993851+9.74165550e-02j],
       [-0.15027499+3.32742147e-01j,  0.30616862-9.54752286e-15j,
         0.08639096+9.34996468e-02j, -0.00308177-2.11545488e-01j],
       [ 0.06365084+1.46823422e-01j,  0.08639096-9.34996468e-02j,
         0.07241005+2.05717724e-16j, -0.04657786-7.30834107e-02j],
       [-0.22993851-9.74165550e-02j, -0.00308177+2.11545488e-01j,
        -0.04657786+7.30834107e-02j,  0.17982931+3.81069605e-15j]]), array([[ 0.67644014+7.40350600e-16j,  0.2110447 -1.42278789e-01j,
         0.2546016 -1.10970437e-01j,  0.01009269+4.33090091e-02j],
       [ 0.2110447 +1.42278789e-01j,  0.11081486-2.00742737e-16j,
         0.09772642-2.72370269e-03j, -0.00807642+5.81611758e-03j],
       [ 0.2546016 +1.10970437e-01j,  0.09772642+2.72370269e-03j,
         0.19019073+1.92666224e-15j,  0.02694742+1.97234919e-02j],
       [ 0.01009269-4.33090091e-02j, -0.00807642-5.81611758e-03j,
         0.02694742-1.97234919e-02j,  0.02255426-4.38360980e-17j]]), array([[ 0.62727523-1.52287688e-15j,  0.19610001-2.62210393e-01j,
        -0.12601658-1.68521989e-01j, -0.16605406-2.88120087e-02j],
       [ 0.19610001+2.62210393e-01j,  0.18921246-2.41309540e-16j,
         0.02680122-1.21857930e-01j, -0.02278608-8.71213077e-02j],
       [-0.12601658+1.68521989e-01j,  0.02680122+1.21857930e-01j,
         0.09946093+2.79350141e-16j,  0.04563224-1.25804203e-02j],
       [-0.16605406+2.88120087e-02j, -0.02278608+8.71213077e-02j,
         0.04563224+1.25804203e-02j,  0.08405138-1.82963478e-17j]]), array([[0.53913095-4.13200204e-15j, 0.10674968-2.87298156e-01j,
        0.23413412-2.65720280e-02j, 0.23225248+6.51895858e-03j],
       [0.10674968+2.87298156e-01j, 0.18805639+9.11289079e-16j,
        0.07942029+1.16911354e-01j, 0.05298256+1.17167159e-01j],
       [0.23413412+2.65720280e-02j, 0.07942029-1.16911354e-01j,
        0.1481491 -4.04064809e-17j, 0.12596755-8.39115189e-04j],
       [0.23225248-6.51895858e-03j, 0.05298256-1.17167159e-01j,
        0.12596755+8.39115189e-04j, 0.12466355-6.17088250e-17j]]), array([[ 0.53902403+2.93971803e-16j, -0.01977804-4.15931619e-01j,
        -0.04371761-1.81414089e-01j, -0.00973173-2.44903748e-02j],
       [-0.01977804+4.15931619e-01j,  0.34249637+2.17927986e-15j,
         0.15345812-2.91623407e-02j,  0.03134077-1.30146639e-02j],
       [-0.04371761+1.81414089e-01j,  0.15345812+2.91623407e-02j,
         0.08737681-1.12201628e-16j,  0.02412786-8.99850081e-03j],
       [-0.00973173+2.44903748e-02j,  0.03134077+1.30146639e-02j,
         0.02412786+8.99850081e-03j,  0.0311028 -9.91164657e-18j]]), array([[ 0.30727278-5.36520739e-13j,  0.10972863-1.70178883e-01j,
         0.35469627+6.43864435e-02j, -0.15779666+1.96150066e-02j],
       [ 0.10972863+1.70178883e-01j,  0.15634152-1.10902631e-12j,
         0.06917519+2.33626683e-01j, -0.06403183-7.54134778e-02j],
       [ 0.35469627-6.43864435e-02j,  0.06917519-2.33626683e-01j,
         0.45256034+2.88284761e-12j, -0.17799549+4.89879783e-02j],
       [-0.15779666-1.96150066e-02j, -0.06403183+7.54134778e-02j,
        -0.17799549-4.89879783e-02j,  0.08382536-8.91075486e-14j]]), array([[ 0.30581595-1.90881408e-15j,  0.22647005-2.31840609e-01j,
         0.09446633+2.46659474e-02j, -0.25417056+7.21983529e-02j],
       [ 0.22647005+2.31840609e-01j,  0.37025231+3.92220401e-15j,
         0.02711282+8.74432684e-02j, -0.22973036-1.41329998e-01j],
       [ 0.09446633-2.46659474e-02j,  0.02711282-8.74432684e-02j,
         0.07140631-8.41331918e-17j, -0.09720811+4.72716738e-02j],
       [-0.25417056-7.21983529e-02j, -0.22973036+1.41329998e-01j,
        -0.09720811-4.72716738e-02j,  0.25252542-2.89660012e-16j]]), array([[ 0.19883345-2.42912314e-16j,  0.01746912-2.70285325e-01j,
         0.23918643-1.72695792e-02j, -0.02858317-2.36740457e-02j],
       [ 0.01746912+2.70285325e-01j,  0.40489962+7.68927629e-16j,
         0.01905872+3.34369047e-01j,  0.02463747-1.81605375e-02j],
       [ 0.23918643+1.72695792e-02j,  0.01905872-3.34369047e-01j,
         0.34631591-5.53692503e-16j, -0.02257756-6.90155334e-02j],
       [-0.02858317+2.36740457e-02j,  0.02463747+1.81605375e-02j,
        -0.02257756+6.90155334e-02j,  0.04995101+6.73968520e-18j]]), array([[ 0.19407015+6.66636067e-17j,  0.01630933-3.15908918e-01j,
         0.10935403-9.20585519e-02j, -0.12429502+7.57324522e-02j],
       [ 0.01630933+3.15908918e-01j,  0.53475742-3.99609637e-15j,
         0.15064534+1.75549074e-01j, -0.12683343-1.86926297e-01j],
       [ 0.10935403+9.20585519e-02j,  0.15064534-1.75549074e-01j,
         0.1264541 -1.26404157e-16j, -0.11606705-3.71100372e-02j],
       [-0.12429502-7.57324522e-02j, -0.12683343+1.86926297e-01j,
        -0.11606705+3.71100372e-02j,  0.14471832-8.60369716e-16j]]), array([[ 0.42611663+4.55300054e-15j,  0.33727805-1.38519576e-01j,
         0.1166089 +1.27955418e-01j, -0.05540422+7.97195291e-02j],
       [ 0.33727805+1.38519576e-01j,  0.32287114-2.02936117e-14j,
         0.03756249+1.03129854e-01j, -0.07731022+4.34486175e-02j],
       [ 0.1166089 -1.27955418e-01j,  0.03756249-1.03129854e-01j,
         0.2224628 -4.94415069e-15j,  0.02495068+1.34919100e-02j],
       [-0.05540422-7.97195291e-02j, -0.07731022-4.34486175e-02j,
         0.02495068-1.34919100e-02j,  0.02854944-4.98769829e-16j]]), array([[ 0.36127691+8.15594387e-16j,  0.33634953-2.09666535e-01j,
        -0.09914899-1.19314377e-01j, -0.08441182+7.08551999e-02j],
       [ 0.33634953+2.09666535e-01j,  0.4689862 -2.25408777e-15j,
        -0.03309077-1.85171419e-01j, -0.11802181+1.83450866e-02j],
       [-0.09914899+1.19314377e-01j, -0.03309077+1.85171419e-01j,
         0.11465816+1.27919763e-16j, -0.01163266-4.44388611e-02j],
       [-0.08441182-7.08551999e-02j, -0.11802181-1.83450866e-02j,
        -0.01163266+4.44388611e-02j,  0.05507874-1.12871874e-16j]]), array([[0.27902757+3.59367504e-12j, 0.20698782-2.42033465e-01j,
        0.11172798+1.14122118e-01j, 0.11794819+5.99109183e-02j],
       [0.20698782+2.42033465e-01j, 0.39010561+6.64956934e-12j,
        0.04429594+1.63077659e-01j, 0.03372148+1.20162484e-01j],
       [0.11172798-1.14122118e-01j, 0.04429594-1.63077659e-01j,
        0.24143529-7.70574508e-13j, 0.08611961-8.58896822e-02j],
       [0.11794819-5.99109183e-02j, 0.03372148-1.20162484e-01j,
        0.08611961+8.58896822e-02j, 0.08943153+5.84268786e-13j]]), array([[ 0.27860083-1.42530753e-15j,  0.12592373-3.79236458e-01j,
        -0.02652444-6.11004425e-02j,  0.05404753+7.89112487e-02j],
       [ 0.12592373+3.79236458e-01j,  0.60605231+2.76772454e-15j,
         0.08991355-6.45319351e-02j, -0.08290109+1.02254445e-01j],
       [-0.02652444+6.11004425e-02j,  0.08991355+6.45319351e-02j,
         0.05945484+1.73805300e-16j, -0.02162184-1.83759806e-02j],
       [ 0.05404753-7.89112487e-02j, -0.08290109-1.02254445e-01j,
        -0.02162184+1.83759806e-02j,  0.05589202+3.66326637e-17j]]), array([[ 0.31669818+4.11690904e-15j, -0.13883226-7.04265098e-02j,
         0.33656967+7.96833892e-02j,  0.0152791 +1.53716144e-01j],
       [-0.13883226+7.04265098e-02j,  0.10819836-5.05620310e-17j,
        -0.20480922+2.58952829e-02j, -0.06164033-8.84349585e-02j],
       [ 0.33656967-7.96833892e-02j, -0.20480922-2.58952829e-02j,
         0.45350669+1.64806337e-15j,  0.09987265+1.85013231e-01j],
       [ 0.0152791 -1.53716144e-01j, -0.06164033+8.84349585e-02j,
         0.09987265-1.85013231e-01j,  0.12159677-1.43110286e-15j]]), array([[ 0.26176643-4.68963847e-16j, -0.04815622-1.92980151e-01j,
         0.04799645+1.81793273e-01j, -0.20120425+1.87694830e-01j],
       [-0.04815622+1.92980151e-01j,  0.18249269+4.92907755e-16j,
        -0.17686387-1.35509405e-02j, -0.11601979-2.13527788e-01j],
       [ 0.04799645-1.81793273e-01j, -0.17686387+1.35509405e-02j,
         0.20649265-4.80132007e-17j,  0.13454446+2.09631560e-01j],
       [-0.20120425-1.87694830e-01j, -0.11601979+2.13527788e-01j,
         0.13454446-2.09631560e-01j,  0.34924823+4.21620416e-16j]]), array([[ 0.43008385-1.11738724e-15j, -0.22890286-1.84357712e-01j,
         0.26877663+2.61202052e-02j,  0.18012795+9.50352314e-02j],
       [-0.22890286+1.84357712e-01j,  0.22318275+1.05326471e-17j,
        -0.16175049+1.04107609e-01j, -0.14294438+2.45562738e-02j],
       [ 0.26877663-2.61202052e-02j, -0.16175049-1.04107609e-01j,
         0.20879161-8.56143968e-16j,  0.13991245+3.90185257e-02j],
       [ 0.18012795-9.50352314e-02j, -0.14294438-2.45562738e-02j,
         0.13991245-3.90185257e-02j,  0.13794178-7.96202298e-18j]]), array([[ 0.32212438-6.07209197e-16j, -0.21980594-2.13378158e-01j,
         0.05899606+6.99845270e-02j, -0.00198173+2.66733822e-01j],
       [-0.21980594+2.13378158e-01j,  0.31338228+4.55365260e-16j,
        -0.09119166-2.05962000e-02j, -0.19061316-2.07499615e-01j],
       [ 0.05899606-6.99845270e-02j, -0.09119166+2.05962000e-02j,
         0.05627351+8.64394799e-17j,  0.09441853+3.74037329e-02j],
       [-0.00198173-2.66733822e-01j, -0.19061316+2.07499615e-01j,
         0.09441853-3.74037329e-02j,  0.30821983+2.71184833e-15j]]), array([[ 0.52296852+9.94195369e-13j,  0.02826664-8.99231404e-02j,
         0.10760237+3.21554587e-01j, -0.06872028+2.02758172e-01j],
       [ 0.02826664+8.99231404e-02j,  0.03050204-1.84896309e-13j,
        -0.06108956-2.29842579e-03j, -0.03549097-1.74640998e-02j],
       [ 0.10760237-3.21554587e-01j, -0.06108956+2.29842579e-03j,
         0.33776298-1.84533543e-12j,  0.15481428+1.06978425e-01j],
       [-0.06872028-2.02758172e-01j, -0.03549097+1.74640998e-02j,
         0.15481428-1.06978425e-01j,  0.10876646+2.07131551e-13j]]), array([[ 0.53009091+4.77945926e-15j,  0.04503651-2.28861494e-01j,
        -0.2406518 +1.61804794e-01j, -0.20968371+7.84612681e-02j],
       [ 0.04503651+2.28861494e-01j,  0.11801747-2.15714739e-15j,
        -0.1099495 -1.08586314e-01j, -0.0446919 -1.01720838e-01j],
       [-0.2406518 -1.61804794e-01j, -0.1099495 +1.08586314e-01j,
         0.22275117+5.82401456e-15j,  0.13451701+6.87748281e-02j],
       [-0.20968371-7.84612681e-02j, -0.0446919 +1.01720838e-01j,
         0.13451701-6.87748281e-02j,  0.12914045+2.28332380e-15j]]), array([[ 0.53781635-3.90687356e-16j, -0.03091311-1.34783311e-01j,
         0.11776489+2.56242422e-01j,  0.22267331+2.26672068e-01j],
       [-0.03091311+1.34783311e-01j,  0.05021731-2.59073807e-16j,
        -0.06217973+1.54555885e-02j, -0.06483688+4.08572328e-02j],
       [ 0.11776489-2.56242422e-01j, -0.06217973-1.54555885e-02j,
         0.19910129-1.22372964e-15j,  0.18090819-6.68852299e-02j],
       [ 0.22267331-2.26672068e-01j, -0.06483688-4.08572328e-02j,
         0.18090819+6.68852299e-02j,  0.21286506-1.23136130e-15j]]), array([[ 0.53659473+9.57698161e-16j, -0.1636524 -2.71361338e-01j,
        -0.16999611+1.11425458e-01j, -0.01651011+2.09304755e-01j],
       [-0.1636524 +2.71361338e-01j,  0.21505336+2.57145505e-16j,
         0.00463648-1.35975716e-01j, -0.09475945-8.79637150e-02j],
       [-0.16999611-1.11425458e-01j,  0.00463648+1.35975716e-01j,
         0.12457763+1.15261580e-16j,  0.07673091-6.69051038e-02j],
       [-0.01651011-2.09304755e-01j, -0.09475945+8.79637150e-02j,
         0.07673091+6.69051038e-02j,  0.12377428+2.99826832e-17j]]), array([[ 0.12207182+5.18698951e-16j,  0.00522211-1.18908534e-01j,
         0.13060047+1.57772233e-01j, -0.04053599+3.15748381e-02j],
       [ 0.00522211+1.18908534e-01j,  0.24050694-1.59873567e-15j,
        -0.30566907+1.53621199e-01j, -0.06398445-4.75519240e-02j],
       [ 0.13060047-1.57772233e-01j, -0.30566907-1.53621199e-01j,
         0.59311878+9.01313383e-16j,  0.03550019+1.03115095e-01j],
       [-0.04053599-3.15748381e-02j, -0.06398445+4.75519240e-02j,
         0.03550019-1.03115095e-01j,  0.04430246+3.80229659e-17j]]), array([[ 0.15275914+4.69253264e-16j,  0.13953466-2.08225702e-01j,
        -0.06274176+1.13610004e-01j, -0.14555852+6.52423211e-02j],
       [ 0.13953466+2.08225702e-01j,  0.44253616+5.45664648e-16j,
        -0.24104267+3.02811339e-02j, -0.22701387-1.57876396e-01j],
       [-0.06274176-1.13610004e-01j, -0.24104267-3.02811339e-02j,
         0.19528556+4.14869360e-16j,  0.07742881+1.13640246e-01j],
       [-0.14555852-6.52423211e-02j, -0.22701387+1.57876396e-01j,
         0.07742881-1.13640246e-01j,  0.20941913-5.33227981e-16j]]), array([[ 0.15340447-1.43135520e-16j, -0.08258794-2.04342654e-01j,
         0.12156642+1.36531669e-01j,  0.10151738+4.94994717e-02j],
       [-0.08258794+2.04342654e-01j,  0.40629991-1.24664818e-16j,
        -0.29576052+1.42332202e-01j, -0.1251425 +1.18681361e-01j],
       [ 0.12156642-1.36531669e-01j, -0.29576052-1.42332202e-01j,
         0.32647872-8.14781539e-16j,  0.1311179 -7.23149689e-02j],
       [ 0.10151738-4.94994717e-02j, -0.1251425 -1.18681361e-01j,
         0.1311179 +7.23149689e-02j,  0.1138169 -1.84800342e-16j]]), array([[ 0.15708371+1.49979172e-16j, -0.07921826-2.69566556e-01j,
         0.00869975+6.43551482e-02j,  0.0260906 +1.50541166e-01j],
       [-0.07921826+2.69566556e-01j,  0.56919396+1.78202411e-16j,
        -0.13588517+5.48861758e-03j, -0.28417587-5.08097265e-02j],
       [ 0.00869975-6.43551482e-02j, -0.13588517-5.48861758e-03j,
         0.08065979+1.56548994e-18j,  0.04011883-3.31924009e-03j],
       [ 0.0260906 -1.50541166e-01j, -0.28417587+5.08097265e-02j,
         0.04011883+3.31924009e-03j,  0.19306254-3.36467259e-16j]]), array([[ 0.36986278+6.62622146e-15j,  0.20525775-1.21661872e-01j,
        -0.08417295+3.15960921e-01j, -0.04698058+6.90153098e-02j],
       [ 0.20525775+1.21661872e-01j,  0.17287026+2.20151486e-15j,
        -0.16820956+1.05234637e-01j, -0.05328939+1.94391814e-02j],
       [-0.08417295-3.15960921e-01j, -0.16820956-1.05234637e-01j,
         0.4341809 -2.43304574e-15j,  0.08446724+1.68388773e-02j],
       [-0.04698058-6.90153098e-02j, -0.05328939-1.94391814e-02j,
         0.08446724-1.68388773e-02j,  0.02308606-7.01428109e-17j]]), array([[ 0.25430887+3.71422664e-16j,  0.18005758-1.98713364e-01j,
        -0.27576106+4.56474272e-02j, -0.04123995+3.98175082e-02j],
       [ 0.18005758+1.98713364e-01j,  0.31592943+5.42457115e-16j,
        -0.25295915-1.97944546e-01j, -0.06212418-9.23718416e-03j],
       [-0.27576106-4.56474272e-02j, -0.25295915+1.97944546e-01j,
         0.3938718 -2.31556964e-16j,  0.04304733-2.19161399e-02j],
       [-0.04123995-3.98175082e-02j, -0.06212418+9.23718416e-03j,
         0.04304733+2.19161399e-02j,  0.0358899 +2.20452323e-17j]]), array([[ 0.30713723-3.66456367e-16j,  0.08941244-1.56274748e-01j,
        -0.06366279+3.17136543e-01j,  0.16066434+1.27198233e-01j],
       [ 0.08941244+1.56274748e-01j,  0.1358737 +2.17926323e-16j,
        -0.17879965+7.02228800e-02j, -0.01716987+1.20515494e-01j],
       [-0.06366279-3.17136543e-01j, -0.17879965-7.02228800e-02j,
         0.40156891+9.69048979e-16j,  0.10359755-2.09474682e-01j],
       [ 0.16066434-1.27198233e-01j, -0.01716987-1.20515494e-01j,
         0.10359755+2.09474682e-01j,  0.15542016-4.52671601e-16j]]), array([[ 0.30366158+2.03558675e-16j, -0.00247143-2.80340923e-01j,
        -0.19783924+1.37257453e-01j,  0.11394971+1.46203336e-01j],
       [-0.00247143+2.80340923e-01j,  0.30707364-2.54634165e-16j,
        -0.12499677-1.87392897e-01j, -0.14349986+1.00099118e-01j],
       [-0.19783924-1.37257453e-01j, -0.12499677+1.87392897e-01j,
         0.2459043 +3.08530381e-16j, -0.01462136-1.61138147e-01j],
       [ 0.11394971-1.46203336e-01j, -0.14349986-1.00099118e-01j,
        -0.01462136+1.61138147e-01j,  0.14336048-2.46830812e-16j]]), array([[ 0.57838201-5.17265612e-16j,  0.03073021+1.25426157e-01j,
         0.16471765-1.00445486e-01j, -0.13053649-3.43006875e-01j],
       [ 0.03073021-1.25426157e-01j,  0.05480341+1.89879806e-18j,
        -0.01477275-4.96636203e-02j, -0.07437618-1.03162296e-03j],
       [ 0.16471765+1.00445486e-01j, -0.01477275+4.96636203e-02j,
         0.09099431+1.20000681e-16j,  0.03518212-1.11015336e-01j],
       [-0.13053649+3.43006875e-01j, -0.07437618+1.03162296e-03j,
         0.03518212+1.11015336e-01j,  0.27582026-1.52356356e-16j]]), array([[ 0.34594596-3.63989662e-16j,  0.11822245-4.78683048e-02j,
        -0.0149603 -3.33691796e-02j, -0.21551009-3.45604094e-01j],
       [ 0.11822245+4.78683048e-02j,  0.08513873+2.25701634e-17j,
         0.00125781-3.58707724e-02j, -0.00606525-1.60839210e-01j],
       [-0.0149603 +3.33691796e-02j,  0.00125781+3.58707724e-02j,
         0.03706096+5.55971211e-19j,  0.05286252+1.45405888e-02j],
       [-0.21551009+3.45604094e-01j, -0.00606525+1.60839210e-01j,
         0.05286252-1.45405888e-02j,  0.53185435-1.15635704e-15j]]), array([[ 0.39229792+1.02983399e-16j, -0.10641989-3.15867078e-02j,
         0.18634641-5.48110835e-02j,  0.05287188-3.62522130e-01j],
       [-0.10641989+3.15867078e-02j,  0.08375305-1.32984262e-17j,
        -0.02497885+4.19348694e-02j,  0.05349045+1.00059227e-01j],
       [ 0.18634641+5.48110835e-02j, -0.02497885-4.19348694e-02j,
         0.12434896-2.08985072e-16j,  0.09829743-1.81800522e-01j],
       [ 0.05287188+3.62522130e-01j,  0.05349045-1.00059227e-01j,
         0.09829743+1.81800522e-01j,  0.39960008-6.13879501e-16j]]), array([[ 0.12020952+1.95610848e-16j,  0.0301248 -7.07386390e-02j,
         0.04690504-4.11722073e-02j, -0.03212062-2.37143235e-01j],
       [ 0.0301248 +7.07386390e-02j,  0.13496254-1.64653159e-16j,
         0.06688678-2.79642903e-03j,  0.14884051-1.79266348e-01j],
       [ 0.04690504+4.11722073e-02j,  0.06688678+2.79642903e-03j,
         0.06816427-2.60762759e-16j,  0.10834734-1.49582703e-01j],
       [-0.03212062+2.37143235e-01j,  0.14884051+1.79266348e-01j,
         0.10834734+1.49582703e-01j,  0.67666368+1.17902370e-15j]]), array([[0.40397804+1.16721084e-15j, 0.16953004+1.71795743e-01j,
        0.21522249-5.52160730e-02j, 0.08341565-1.22843518e-01j],
       [0.16953004-1.71795743e-01j, 0.22832586+1.36515704e-15j,
        0.12979905-1.57682936e-01j, 0.07278037-8.75290969e-02j],
       [0.21522249+5.52160730e-02j, 0.12979905+1.57682936e-01j,
        0.20129071+1.13914637e-15j, 0.13394988-5.67654211e-03j],
       [0.08341565+1.22843518e-01j, 0.07278037+8.75290969e-02j,
        0.13394988+5.67654211e-03j, 0.16640539-9.54407065e-17j]]), array([[0.18278413+2.19123630e-16j, 0.15664031-4.06551750e-04j,
        0.03145928-9.11011041e-02j, 0.00146351-1.62704196e-01j],
       [0.15664031+4.06551750e-04j, 0.32174093+1.85507564e-15j,
        0.09863974-2.32033896e-01j, 0.16294793-1.24762860e-01j],
       [0.03145928+9.11011041e-02j, 0.09863974+2.32033896e-01j,
        0.2068441 -1.32387434e-15j, 0.13085772+1.11990477e-01j],
       [0.00146351+1.62704196e-01j, 0.16294793+1.24762860e-01j,
        0.13085772-1.11990477e-01j, 0.28863084+3.71354989e-15j]]), array([[0.25566585+1.60374081e-15j, 0.10700089+7.75176224e-02j,
        0.16789932+5.18855869e-02j, 0.19733597-9.66144932e-02j],
       [0.10700089-7.75176224e-02j, 0.21330152+9.14964846e-16j,
        0.17753173-3.32307877e-04j, 0.19726513-9.47824051e-02j],
       [0.16789932-5.18855869e-02j, 0.17753173+3.32307877e-04j,
        0.19001489+1.22683258e-15j, 0.20485131-1.30259441e-01j],
       [0.19733597+9.66144932e-02j, 0.19726513+9.47824051e-02j,
        0.20485131+1.30259441e-01j, 0.34101773+2.87852886e-15j]]), array([[ 5.51392665e-02+1.36883997e-17j,  3.33880632e-04-6.56880898e-02j,
        -1.32626997e-02-2.51199582e-02j, -7.35134725e-03-7.06226234e-02j],
       [ 3.33880632e-04+6.56880898e-02j,  4.51549576e-01-6.65374212e-16j,
         2.25275665e-01-1.30601564e-01j,  2.83244675e-01-1.94236012e-01j],
       [-1.32626997e-02+2.51199582e-02j,  2.25275665e-01+1.30601564e-01j,
         1.69413347e-01-2.44902548e-16j,  1.99752350e-01-2.72784758e-02j],
       [-7.35134725e-03+7.06226234e-02j,  2.83244675e-01+1.94236012e-01j,
         1.99752350e-01+2.72784758e-02j,  3.23897811e-01+2.98134231e-16j]]), array([[ 0.31105992+6.46233536e-16j,  0.04540742+1.95754457e-01j,
         0.24893061+1.63302610e-02j, -0.14166686-2.06036275e-01j],
       [ 0.04540742-1.95754457e-01j,  0.21230625-2.68841104e-16j,
         0.01257517-1.36782353e-01j, -0.14784744+7.02023343e-02j],
       [ 0.24893061-1.63302610e-02j,  0.01257517+1.36782353e-01j,
         0.25050657+1.14460550e-15j, -0.12936319-1.71502567e-01j],
       [-0.14166686+2.06036275e-01j, -0.14784744-7.02023343e-02j,
        -0.12936319+1.71502567e-01j,  0.22612726-1.23716749e-15j]]), array([[ 0.20524758-1.64810388e-15j,  0.17286669+2.35778810e-02j,
         0.09684228+5.35273155e-02j, -0.19583713-2.31069662e-01j],
       [ 0.17286669-2.35778810e-02j,  0.21083041-3.24998307e-16j,
         0.09100899-6.83062901e-03j, -0.18206104-1.56645390e-01j],
       [ 0.09684228-5.35273155e-02j,  0.09100899+6.83062901e-03j,
         0.10220151-7.36061851e-17j, -0.17478625-4.76976657e-02j],
       [-0.19583713+2.31069662e-01j, -0.18206104+1.56645390e-01j,
        -0.17478625+4.76976657e-02j,  0.4817205 +2.53723173e-15j]]), array([[ 0.16371692-6.82883836e-16j, -0.01937329+5.24378622e-02j,
         0.17181497+6.62218273e-02j,  0.01322308-2.18496605e-01j],
       [-0.01937329-5.24378622e-02j,  0.22081558-1.04427728e-16j,
         0.01313429+3.99957075e-02j,  0.01268446+6.80103200e-02j],
       [ 0.17181497-6.62218273e-02j,  0.01313429-3.99957075e-02j,
         0.26819729+2.47091604e-15j, -0.04636936-2.80243541e-01j],
       [ 0.01322308+2.18496605e-01j,  0.01268446-6.80103200e-02j,
        -0.04636936+2.80243541e-01j,  0.34727021-6.80524827e-17j]]), array([[ 0.06072947-1.42393312e-16j,  0.05586621-1.20055207e-02j,
         0.0816813 +2.96539866e-02j, -0.02549297-1.70140392e-01j],
       [ 0.05586621+1.20055207e-02j,  0.20096793-4.75390683e-16j,
         0.12972421+1.04515675e-02j, -0.03274139-1.74839710e-01j],
       [ 0.0816813 -2.96539866e-02j,  0.12972421-1.04515675e-02j,
         0.17573655-6.44305727e-16j, -0.14818508-2.52452339e-01j],
       [-0.02549297+1.70140392e-01j, -0.03274139+1.74839710e-01j,
        -0.14818508+2.52452339e-01j,  0.56256605+2.84300060e-17j]]), array([[ 0.31060047-2.93538449e-17j,  0.24225636+2.18009713e-01j,
         0.20901745+9.38342641e-02j, -0.01491141-7.87497230e-02j],
       [ 0.24225636-2.18009713e-01j,  0.41544524-9.33164142e-16j,
         0.23925568-9.94199938e-02j, -0.06466453-4.60878473e-02j],
       [ 0.20901745-9.38342641e-02j,  0.23925568+9.94199938e-02j,
         0.22752301-1.83469242e-17j, -0.03867025-5.31381191e-02j],
       [-0.01491141+7.87497230e-02j, -0.06466453+4.60878473e-02j,
        -0.03867025+5.31381191e-02j,  0.04643129-1.09255085e-17j]]), array([[ 0.08536415-3.42029536e-13j,  0.13120216+4.65931925e-02j,
         0.061083  -2.99108407e-02j, -0.04085304-6.89428202e-02j],
       [ 0.13120216-4.65931925e-02j,  0.52406555+5.66680553e-13j,
         0.12323817-3.17044640e-01j,  0.0077914 +1.41008236e-03j],
       [ 0.061083  +2.99108407e-02j,  0.12323817+3.17044640e-01j,
         0.25152646+3.33053944e-14j, -0.05653716+3.60644434e-02j],
       [-0.04085304+6.89428202e-02j,  0.0077914 -1.41008236e-03j,
        -0.05653716-3.60644434e-02j,  0.13904384+3.49656570e-14j]]), array([[0.1260933 +7.86779173e-17j, 0.16913336+9.83157606e-02j,
        0.11608216+1.30070559e-01j, 0.09861258-6.64483424e-02j],
       [0.16913336-9.83157606e-02j, 0.43598989+3.33685047e-16j,
        0.30013657+1.11474506e-01j, 0.12101295-1.61976161e-01j],
       [0.11608216-1.30070559e-01j, 0.30013657-1.11474506e-01j,
        0.28638079+3.95942471e-16j, 0.03587569-1.85051356e-01j],
       [0.09861258+6.64483424e-02j, 0.12101295+1.61976161e-01j,
        0.03587569+1.85051356e-01j, 0.15153603-4.58113508e-16j]]), array([[1.83332430e-02+4.54714756e-18j, 1.01817045e-02-4.46386374e-02j,
        5.14740645e-04-7.33048545e-03j, 1.84978127e-03-3.21378374e-02j],
       [1.01817045e-02+4.46386374e-02j, 7.42154833e-01+3.49603902e-15j,
        2.71357583e-01-1.51239674e-01j, 5.31969219e-02-7.90923405e-02j],
       [5.14740645e-04+7.33048545e-03j, 2.71357583e-01+1.51239674e-01j,
        1.49358563e-01+1.25743695e-16j, 1.14539612e-02-4.01615293e-02j],
       [1.84978127e-03+3.21378374e-02j, 5.31969219e-02+7.90923405e-02j,
        1.14539612e-02+4.01615293e-02j, 9.01533609e-02-3.87013354e-17j]]), array([[ 0.35245543+1.35770163e-15j, -0.01812931+2.66217498e-01j,
         0.15258822-1.44924813e-01j,  0.15187156-1.93308422e-01j],
       [-0.01812931-2.66217498e-01j,  0.24879475+5.71300027e-16j,
        -0.15363416-1.23736461e-01j, -0.15683856-1.52537588e-01j],
       [ 0.15258822+1.44924813e-01j, -0.15363416+1.23736461e-01j,
         0.16741093+2.81165929e-18j,  0.16524328+1.84160608e-02j],
       [ 0.15187156+1.93308422e-01j, -0.15683856+1.52537588e-01j,
         0.16524328-1.84160608e-02j,  0.23133889-5.62760646e-16j]]), array([[ 0.1326228 -1.84700879e-17j,  0.09929243+9.94252510e-02j,
        -0.01412534-7.92827481e-02j,  0.08588145-2.02694699e-01j],
       [ 0.09929243-9.94252510e-02j,  0.25047912+5.82835650e-16j,
        -0.12365738-1.03375619e-01j, -0.082155  -3.22734050e-01j],
       [-0.01412534+7.92827481e-02j, -0.12365738+1.03375619e-01j,
         0.12012672+1.04810721e-16j,  0.16909441+1.37944124e-01j],
       [ 0.08588145+2.02694699e-01j, -0.082155  +3.22734050e-01j,
         0.16909441-1.37944124e-01j,  0.49677135+1.30571292e-16j]]), array([[ 0.43952132+9.31410424e-16j, -0.21228735+1.08391726e-01j,
         0.17454108+6.27237026e-03j,  0.26026141-2.23298794e-01j],
       [-0.21228735-1.08391726e-01j,  0.154592  -5.46898051e-16j,
        -0.07882114-4.87847956e-02j, -0.17561727+2.90634591e-02j],
       [ 0.17454108-6.27237026e-03j, -0.07882114+4.87847956e-02j,
         0.08945086-7.64485885e-18j,  0.11462288-9.94485241e-02j],
       [ 0.26026141+2.23298794e-01j, -0.17561727-2.90634591e-02j,
         0.11462288+9.94485241e-02j,  0.31643582-2.74143753e-16j]]), array([[ 0.12100514-3.20102085e-16j, -0.05260163+9.81541904e-02j,
         0.05597814+1.90912141e-02j,  0.20430692-4.93445515e-02j],
       [-0.05260163-9.81541904e-02j,  0.20990368-4.27911848e-17j,
         0.00096532-8.35090442e-02j, -0.09817143-3.02586337e-01j],
       [ 0.05597814-1.90912141e-02j,  0.00096532+8.35090442e-02j,
         0.04283444+2.33021816e-16j,  0.13607647-6.23261901e-02j],
       [ 0.20430692+4.93445515e-02j, -0.09817143+3.02586337e-01j,
         0.13607647+6.23261901e-02j,  0.62625674+6.53356037e-15j]]), array([[ 0.34667569+4.72208898e-15j, -0.0740889 +2.18483661e-01j,
         0.15603052+1.58491790e-01j,  0.06020357+5.36153136e-03j],
       [-0.0740889 -2.18483661e-01j,  0.18855288+3.38235806e-16j,
         0.04202256-2.13485320e-01j,  0.0159884 -8.84717333e-02j],
       [ 0.15603052-1.58491790e-01j,  0.04202256+2.13485320e-01j,
         0.36008491-6.93519503e-15j,  0.1304599 +7.39461360e-02j],
       [ 0.06020357-5.36153136e-03j,  0.0159884 +8.84717333e-02j,
         0.1304599 -7.39461360e-02j,  0.10468653-1.00374017e-15j]]), array([[ 0.1547323 -3.08822490e-16j, -0.0824213 +3.85802385e-02j,
        -0.03042136+1.31135553e-01j, -0.03353192-5.31178905e-02j],
       [-0.0824213 -3.85802385e-02j,  0.26372577+1.99556042e-15j,
         0.01509229-2.89270462e-01j,  0.10586324-1.30031211e-01j],
       [-0.03042136-1.31135553e-01j,  0.01509229+2.89270462e-01j,
         0.37139274-1.63312279e-15j,  0.12606152+1.76716442e-01j],
       [-0.03353192+5.31178905e-02j,  0.10586324+1.30031211e-01j,
         0.12606152-1.76716442e-01j,  0.21014919+2.92449127e-15j]]), array([[ 0.35642594+2.04445102e-16j, -0.08505615+1.95522421e-01j,
         0.11714485+1.92067331e-01j,  0.24987544+3.95185105e-02j],
       [-0.08505615-1.95522421e-01j,  0.1667766 -7.91562354e-16j,
         0.12158748-1.10946756e-01j,  0.00457133-1.55790691e-01j],
       [ 0.11714485-1.92067331e-01j,  0.12158748+1.10946756e-01j,
         0.21726277-3.18201071e-16j,  0.17093981-1.35369153e-01j],
       [ 0.24987544-3.95185105e-02j,  0.00457133+1.55790691e-01j,
         0.17093981+1.35369153e-01j,  0.25953469+9.91960401e-16j]]), array([[ 0.18391895+7.78399984e-16j, -0.22722429+3.43433952e-02j,
        -0.07988051+1.42703255e-01j,  0.01011906+6.43988540e-02j],
       [-0.22722429-3.43433952e-02j,  0.39639515+1.71268385e-15j,
         0.15365511-2.33705744e-01j,  0.06790911-1.99297193e-01j],
       [-0.07988051-1.42703255e-01j,  0.15365511+2.33705744e-01j,
         0.20767203+9.81591719e-16j,  0.14482375-1.87055651e-02j],
       [ 0.01011906-6.43988540e-02j,  0.06790911+1.99297193e-01j,
         0.14482375+1.87055651e-02j,  0.21201387-5.93334195e-17j]]), array([[ 0.18891109-2.53870690e-13j,  0.01351386+2.49355701e-01j,
         0.07404935-2.51015419e-03j,  0.02665011-1.40328202e-01j],
       [ 0.01351386-2.49355701e-01j,  0.45975248-5.36987453e-13j,
        -0.16062064-9.84761374e-02j, -0.21445302-6.42826154e-02j],
       [ 0.07404935+2.51015419e-03j, -0.16062064+9.84761374e-02j,
         0.23304788-6.42330679e-13j,  0.05143529-3.08708381e-02j],
       [ 0.02665011+1.40328202e-01j, -0.21445302+6.42826154e-02j,
         0.05143529+3.08708381e-02j,  0.11828855+1.61366173e-13j]]), array([[ 0.10989501-9.29418194e-16j,  0.10651297+8.31478823e-02j,
        -0.04686554+6.36869575e-02j, -0.02213652-1.81924349e-01j],
       [ 0.10651297-8.31478823e-02j,  0.37132592+1.97780114e-15j,
        -0.05201328-4.86474632e-02j, -0.21465246-2.19600831e-01j],
       [-0.04686554-6.36869575e-02j, -0.05201328+4.86474632e-02j,
         0.17856396+1.90248596e-15j, -0.03954497+6.77678458e-02j],
       [-0.02213652+1.81924349e-01j, -0.21465246+2.19600831e-01j,
        -0.03954497-6.77678458e-02j,  0.34021511+7.35327696e-15j]]), array([[ 0.20164698-2.21774118e-15j, -0.18252658+1.23481076e-01j,
         0.1056261 +1.04467573e-01j,  0.12862738-1.41523238e-01j],
       [-0.18252658-1.23481076e-01j,  0.38515365+9.17380679e-16j,
        -0.09076241-5.48270699e-02j, -0.1872721 +7.69620345e-02j],
       [ 0.1056261 -1.04467573e-01j, -0.09076241+5.48270699e-02j,
         0.21935968+1.19350064e-15j,  0.00702364-1.67947558e-01j],
       [ 0.12862738+1.41523238e-01j, -0.1872721 -7.69620345e-02j,
         0.00702364+1.67947558e-01j,  0.19383969+2.51764020e-15j]]), array([[ 0.08467476+4.70517888e-17j, -0.07675871+9.86943805e-02j,
         0.01066106+7.29276620e-02j,  0.12582971-8.63837606e-02j],
       [-0.07675871-9.86943805e-02j,  0.39988865-9.88901038e-17j,
         0.08626008-8.65621455e-02j, -0.28887125-1.99430896e-01j],
       [ 0.01066106-7.29276620e-02j,  0.08626008+8.65621455e-02j,
         0.09032155+2.30562799e-17j, -0.07032124-1.38241149e-01j],
       [ 0.12582971+8.63837606e-02j, -0.28887125+1.99430896e-01j,
        -0.07032124+1.38241149e-01j,  0.42511503-7.41513826e-16j]]), array([[ 0.33292614-7.72838431e-16j,  0.00149068+1.32423466e-01j,
         0.08739298+3.78080473e-01j, -0.02235903-1.08873238e-01j],
       [ 0.00149068-1.32423466e-01j,  0.08879753-1.42723988e-16j,
         0.12060612-5.87207678e-02j, -0.04720787+2.74296989e-04j],
       [ 0.08739298-3.78080473e-01j,  0.12060612+5.87207678e-02j,
         0.53096958-1.10099876e-15j, -0.12206052+5.19232576e-03j],
       [-0.02235903+1.08873238e-01j, -0.04720787-2.74296989e-04j,
        -0.12206052-5.19232576e-03j,  0.04730675+1.00241548e-16j]]), array([[ 0.10096235-1.92973316e-17j, -0.08301201+1.89605503e-02j,
        -0.01918786+1.89819793e-01j, -0.02694318-9.11699121e-02j],
       [-0.08301201-1.89605503e-02j,  0.26917528+4.55261824e-15j,
         0.02116093-3.29843418e-01j,  0.00412484+3.70938348e-02j],
       [-0.01918786-1.89819793e-01j,  0.02116093+3.29843418e-01j,
         0.52830213+3.24339381e-15j, -0.12858918+7.48406105e-02j],
       [-0.02694318+9.11699121e-02j,  0.00412484-3.70938348e-02j,
        -0.12858918-7.48406105e-02j,  0.10156024-9.54792580e-17j]]), array([[ 0.27680861-2.68211707e-16j, -0.00520154+1.56046917e-01j,
         0.01945847+3.11870093e-01j,  0.19089842-6.02618070e-02j],
       [-0.00520154-1.56046917e-01j,  0.1503923 +3.90088074e-17j,
         0.17776044+2.60120398e-03j, -0.03449388-1.04150489e-01j],
       [ 0.01945847-3.11870093e-01j,  0.17776044-2.60120398e-03j,
         0.40394064+3.35186735e-16j, -0.05235341-2.36874608e-01j],
       [ 0.19089842+6.02618070e-02j, -0.03449388+1.04150489e-01j,
        -0.05235341+2.36874608e-01j,  0.16885845+7.91058564e-17j]]), array([[ 0.16465724+1.57526821e-16j, -0.20312092+2.31953330e-03j,
        -0.088288  +1.82519692e-01j,  0.09902342-4.60228778e-02j],
       [-0.20312092-2.31953330e-03j,  0.42277308+4.71746479e-16j,
         0.15245195-2.80636577e-01j, -0.12147674+1.72894827e-02j],
       [-0.088288  -1.82519692e-01j,  0.15245195+2.80636577e-01j,
         0.30221813+4.32389868e-16j, -0.09864872-9.93247339e-02j],
       [ 0.09902342+4.60228778e-02j, -0.12147674-1.72894827e-02j,
        -0.09864872+9.93247339e-02j,  0.11035155+3.27479768e-16j]]), array([[ 0.62053822-2.59232921e-16j, -0.13261988-1.91070474e-02j,
         0.27721657+6.08829806e-02j, -0.25221214-9.65763449e-02j],
       [-0.13261988+1.91070474e-02j,  0.07718821-4.44881213e-17j,
        -0.07798873-9.05363954e-03j,  0.07967921-2.67619086e-05j],
       [ 0.27721657-6.08829806e-02j, -0.07798873+9.05363954e-03j,
         0.15056312+1.83655904e-16j, -0.13027971-1.01805334e-02j],
       [-0.25221214+9.65763449e-02j,  0.07967921+2.67619086e-05j,
        -0.13027971+1.01805334e-02j,  0.15171044+2.95767281e-16j]]), array([[ 0.40398513+4.32735116e-16j, -0.04048051-1.76457389e-01j,
         0.07733758+1.00472169e-01j, -0.34185269-1.18783978e-01j],
       [-0.04048051+1.76457389e-01j,  0.13555923+3.77258313e-16j,
        -0.07234108+8.55439343e-04j,  0.13074144-1.56587884e-01j],
       [ 0.07733758-1.00472169e-01j, -0.07234108-8.55439343e-04j,
         0.07033757+1.42025146e-16j, -0.10689874+9.38366206e-02j],
       [-0.34185269+1.18783978e-01j,  0.13074144+1.56587884e-01j,
        -0.10689874-9.38366206e-02j,  0.39011807+1.27065342e-17j]]), array([[ 0.48734206-7.05904406e-16j, -0.2658105 -1.63112074e-01j,
         0.19640412-2.87076157e-02j, -0.10326428-1.85822276e-01j],
       [-0.2658105 +1.63112074e-01j,  0.26894213-3.68783977e-16j,
        -0.09923772+9.87138743e-02j,  0.16826427+6.41701737e-02j],
       [ 0.19640412+2.87076157e-02j, -0.09923772-9.87138743e-02j,
         0.09666604-6.66245906e-17j, -0.03111026-9.65406262e-02j],
       [-0.10326428+1.85822276e-01j,  0.16826427-6.41701737e-02j,
        -0.03111026+9.65406262e-02j,  0.14704978+2.61801044e-16j]]), array([[ 0.2492353 -3.42626499e-17j, -0.17751886-2.30133582e-01j,
         0.03429937-1.62845904e-02j, -0.21912548-7.08348644e-02j],
       [-0.17751886+2.30133582e-01j,  0.39689759+3.50678380e-17j,
        -0.00726251+4.49423242e-02j,  0.25910858-1.94618167e-01j],
       [ 0.03429937+1.62845904e-02j, -0.00726251-4.49423242e-02j,
         0.02269609+2.17480735e-17j, -0.02400454-3.38303782e-02j],
       [-0.21912548+7.08348644e-02j,  0.25910858+1.94618167e-01j,
        -0.02400454+3.38303782e-02j,  0.33117103+2.27426052e-16j]]), array([[ 0.69406571-1.41151848e-16j,  0.2030883 +1.82818874e-02j,
         0.13027038+6.66916457e-03j,  0.04853674-9.38824265e-02j],
       [ 0.2030883 -1.82818874e-02j,  0.16910638+1.38893778e-16j,
         0.01594146-2.57239674e-02j,  0.09547601-4.89290682e-02j],
       [ 0.13027038-6.66916457e-03j,  0.01594146+2.57239674e-02j,
         0.04181472-3.82343326e-17j, -0.00540649+5.50283793e-03j],
       [ 0.04853674+9.38824265e-02j,  0.09547601+4.89290682e-02j,
        -0.00540649-5.50283793e-03j,  0.09501318-6.36666186e-17j]]), array([[ 4.22417353e-01-4.42563095e-12j,  1.95383585e-01-1.46827509e-01j,
        -3.87669583e-02-7.14620808e-02j,  2.75035436e-04-1.38398549e-01j],
       [ 1.95383585e-01+1.46827509e-01j,  2.78436158e-01+7.40251591e-12j,
        -3.44074980e-02-1.26272703e-01j,  1.99350340e-01-1.05517045e-01j],
       [-3.87669583e-02+7.14620808e-02j, -3.44074980e-02+1.26272703e-01j,
         7.45143881e-02+2.16820892e-13j,  2.03209560e-03+1.13234625e-01j],
       [ 2.75035436e-04+1.38398549e-01j,  1.99350340e-01+1.05517045e-01j,
         2.03209560e-03-1.13234625e-01j,  2.24632101e-01-1.48963637e-12j]]), array([[0.51622689-1.07889031e-12j, 0.10242726-1.02828000e-01j,
        0.13104428+5.31928786e-02j, 0.2283723 -9.95479459e-02j],
       [0.10242726+1.02828000e-01j, 0.19448263+5.35952050e-13j,
        0.0249717 +6.83053907e-02j, 0.2027229 +2.37767668e-02j],
       [0.13104428-5.31928786e-02j, 0.0249717 -6.83053907e-02j,
        0.04586304+5.80888517e-13j, 0.05587542-7.72584272e-02j],
       [0.2283723 +9.95479459e-02j, 0.2027229 -2.37767668e-02j,
        0.05587542+7.72584272e-02j, 0.24342744-3.21455196e-12j]]), array([[ 0.42835827-1.86870813e-15j,  0.01073993-3.26782884e-01j,
        -0.05472854-2.15234435e-02j,  0.1007937 -2.00410597e-01j],
       [ 0.01073993+3.26782884e-01j,  0.33900922-8.42475020e-17j,
         0.02311192-5.27530156e-02j,  0.24144415+4.88102482e-02j],
       [-0.05472854+2.15234435e-02j,  0.02311192+5.27530156e-02j,
         0.01542719+4.42888413e-17j,  0.00794402+3.85983025e-02j],
       [ 0.1007937 +2.00410597e-01j,  0.24144415-4.88102482e-02j,
         0.00794402-3.85983025e-02j,  0.21720532+2.35820081e-16j]]), array([[ 0.30698665-5.91196976e-15j,  0.05391799+8.43909564e-03j,
         0.21809011+7.20780753e-02j, -0.14678556-9.86829789e-02j],
       [ 0.05391799-8.43909564e-03j,  0.25536831+2.18337852e-16j,
        -0.12570802+4.28263638e-02j,  0.07412694+2.05576480e-04j],
       [ 0.21809011-7.20780753e-02j, -0.12570802-4.28263638e-02j,
         0.29089143+7.56862727e-15j, -0.19535427-6.00375806e-02j],
       [-0.14678556+9.86829789e-02j,  0.07412694-2.05576480e-04j,
        -0.19535427+6.00375806e-02j,  0.1467536 -2.12514992e-15j]]), array([[ 0.19343015+1.84351642e-13j,  0.15113208-1.16895278e-01j,
         0.07414361+5.77601645e-02j, -0.16751966-1.05720150e-01j],
       [ 0.15113208+1.16895278e-01j,  0.31683233-6.97051676e-13j,
        -0.0740489 +1.76968151e-02j,  0.04947805-1.32048600e-01j],
       [ 0.07414361-5.77601645e-02j, -0.0740489 -1.76968151e-02j,
         0.15999236+6.98294534e-14j, -0.21327394+3.59392558e-02j],
       [-0.16751966+1.05720150e-01j,  0.04947805+1.32048600e-01j,
        -0.21327394-3.59392558e-02j,  0.32974517-6.22644956e-14j]]), array([[ 0.15990916+2.08370151e-16j, -0.03185592-1.44872865e-01j,
         0.15477632+7.99057796e-02j, -0.00303027-1.56291698e-01j],
       [-0.03185592+1.44872865e-01j,  0.36223857+2.08524362e-16j,
        -0.16450308+1.94957579e-01j,  0.2285523 +4.71000769e-02j],
       [ 0.15477632-7.99057796e-02j, -0.16450308-1.94957579e-01j,
         0.2581685 +3.67570707e-16j, -0.10453768-1.94441895e-01j],
       [-0.00303027+1.56291698e-01j,  0.2285523 -4.71000769e-02j,
        -0.10453768+1.94441895e-01j,  0.21968376+6.75034461e-17j]]), array([[ 0.07474573-1.33046928e-16j,  0.02596112-1.77382506e-01j,
         0.04185671+1.80423790e-02j, -0.05999303-7.29777419e-02j],
       [ 0.02596112+1.77382506e-01j,  0.47438304+1.66882960e-16j,
        -0.01552855+1.05329387e-01j,  0.13591086-1.82767868e-01j],
       [ 0.04185671-1.80423790e-02j, -0.01552855-1.05329387e-01j,
         0.10973364-3.11125837e-17j, -0.15657716-9.92183042e-02j],
       [-0.05999303+7.29777419e-02j,  0.13591086+1.82767868e-01j,
        -0.15657716+9.92183042e-02j,  0.34113759+1.28919560e-15j]]), array([[ 0.43692875-4.94491588e-16j,  0.40598558+3.05392417e-02j,
         0.03020768+9.59700739e-02j,  0.04173299-7.56848774e-02j],
       [ 0.40598558-3.05392417e-02j,  0.45893511-9.45320303e-16j,
        -0.00081655+8.06763562e-02j,  0.05976456-7.05988708e-02j],
       [ 0.03020768-9.59700739e-02j, -0.00081655-8.06763562e-02j,
         0.06224507+8.99037361e-18j, -0.031546  -1.52341126e-02j],
       [ 0.04173299+7.56848774e-02j,  0.05976456+7.05988708e-02j,
        -0.031546  +1.52341126e-02j,  0.04189106+4.34065459e-18j]]), array([[ 0.1592984 +4.96811696e-16j,  0.28127776-8.40891959e-02j,
        -0.060247  -7.74807812e-02j,  0.03951015-4.32559319e-02j],
       [ 0.28127776+8.40891959e-02j,  0.63263334-1.27910079e-15j,
        -0.09885212-2.26577973e-01j,  0.1475673 -2.78137579e-02j],
       [-0.060247  +7.74807812e-02j, -0.09885212+2.26577973e-01j,
         0.12465299+9.27280919e-17j, -0.04247866+6.26723373e-02j],
       [ 0.03951015+4.32559319e-02j,  0.1475673 +2.78137579e-02j,
        -0.04247866-6.26723373e-02j,  0.08341527+1.21032472e-16j]]), array([[ 0.25803682+3.19696265e-17j,  0.26600096-9.22509233e-02j,
         0.05895593+1.65675481e-01j,  0.18283354-7.54085412e-02j],
       [ 0.26600096+9.22509233e-02j,  0.40956774-2.40454785e-16j,
         0.0121147 +1.97399470e-01j,  0.24196941-1.43308619e-02j],
       [ 0.05895593-1.65675481e-01j,  0.0121147 -1.97399470e-01j,
         0.15084376-1.53510576e-18j, -0.00744755-1.47648278e-01j],
       [ 0.18283354+7.54085412e-02j,  0.24196941+1.43308619e-02j,
        -0.00744755+1.47648278e-01j,  0.18155168+2.32738122e-16j]]), array([[ 0.14360625+2.41969813e-16j,  0.07609926-2.66363007e-01j,
        -0.05673121+2.57251249e-02j,  0.09296331-6.95330332e-02j],
       [ 0.07609926+2.66363007e-01j,  0.67773414+6.67293513e-16j,
        -0.03810656-1.10786773e-01j,  0.19231646+1.19168918e-01j],
       [-0.05673121-2.57251249e-02j, -0.03810656+1.10786773e-01j,
         0.05972521+4.40259070e-17j, -0.04969173-1.03788001e-03j],
       [ 0.09296331+6.95330332e-02j,  0.19231646-1.19168918e-01j,
        -0.04969173+1.03788001e-03j,  0.1189344 +2.15764041e-17j]]), array([[ 0.34488291-3.13950519e-15j, -0.25668004+1.20277259e-01j,
         0.28977808+4.20510249e-02j, -0.02119446+8.79828709e-02j],
       [-0.25668004-1.20277259e-01j,  0.2902586 +1.03973251e-15j,
        -0.24398563-1.43918430e-01j,  0.05216152-1.04052218e-01j],
       [ 0.28977808-4.20510249e-02j, -0.24398563+1.43918430e-01j,
         0.29249342-1.40474499e-15j, -0.00195695+1.15627755e-01j],
       [-0.02119446-8.79828709e-02j,  0.05216152+1.04052218e-01j,
        -0.00195695-1.15627755e-01j,  0.07236507-1.10019319e-16j]]), array([[ 0.12948495-8.38791893e-17j, -0.1306833 -6.60958784e-02j,
         0.06875071+1.01577270e-01j, -0.11427304+5.95551350e-02j],
       [-0.1306833 +6.60958784e-02j,  0.32902479-1.16597312e-15j,
        -0.22349376-1.19319204e-01j,  0.12180111-2.84274979e-01j],
       [ 0.06875071-1.01577270e-01j, -0.22349376+1.19319204e-01j,
         0.21198313-5.65829383e-16j,  0.01668381+2.43466033e-01j],
       [-0.11427304-5.95551350e-02j,  0.12180111+2.84274979e-01j,
         0.01668381-2.43466033e-01j,  0.32950714+1.98642292e-15j]]), array([[ 0.49658687+1.28955623e-15j, -0.40747435-2.64742592e-02j,
         0.17786177+5.00656223e-02j,  0.0493042 -4.83631015e-03j],
       [-0.40747435+2.64742592e-02j,  0.38233492+5.48375006e-16j,
        -0.1582171 -2.18483382e-02j, -0.02261102-6.99579189e-03j],
       [ 0.17786177-5.00656223e-02j, -0.1582171 +2.18483382e-02j,
         0.08555027+9.71900681e-17j,  0.01048086-1.07287546e-02j],
       [ 0.0493042 +4.83631015e-03j, -0.02261102+6.99579189e-03j,
         0.01048086+1.07287546e-02j,  0.03552793+5.87364288e-18j]]), array([[ 0.20154364-1.02233139e-15j, -0.29661509-5.06296114e-02j,
         0.04006718+4.56336063e-02j, -0.04240037+1.60622459e-01j],
       [-0.29661509+5.06296114e-02j,  0.51651525+1.07112250e-15j,
        -0.07484258-6.03569984e-02j,  0.04566172-3.23935315e-01j],
       [ 0.04006718-4.56336063e-02j, -0.07484258+6.03569984e-02j,
         0.02518245+1.93959000e-16j,  0.03045203+4.65117161e-02j],
       [-0.04240037-1.60622459e-01j,  0.04566172+3.23935315e-01j,
         0.03045203-4.65117161e-02j,  0.25675866-2.82951880e-16j]]), array([[ 0.67540399-8.13838811e-15j, -0.03891411+2.70534178e-02j,
         0.02856372+2.63193069e-01j, -0.0215018 -9.63424054e-03j],
       [-0.03891411-2.70534178e-02j,  0.08310143+6.87412388e-16j,
        -0.06824523-5.20336808e-02j,  0.03367893-4.67128418e-02j],
       [ 0.02856372-2.63193069e-01j, -0.06824523+5.20336808e-02j,
         0.19666249-4.95501101e-16j, -0.015084  +6.99942446e-02j],
       [-0.0215018 +9.63424054e-03j,  0.03367893+4.67128418e-02j,
        -0.015084  -6.99942446e-02j,  0.0448321 -1.34742445e-16j]]), array([[ 0.48328519+2.99830830e-13j, -0.0175601 -1.48131288e-01j,
        -0.15917908+1.66200680e-01j, -0.0528576 -1.06292666e-01j],
       [-0.0175601 +1.48131288e-01j,  0.15880763+7.77932404e-14j,
        -0.11660846-1.32924216e-01j,  0.12061026-9.03661657e-02j],
       [-0.15917908-1.66200680e-01j, -0.11660846+1.32924216e-01j,
         0.20897202+3.09812000e-13j, -0.01966927+1.62276016e-01j],
       [-0.0528576 +1.06292666e-01j,  0.12061026+9.03661657e-02j,
        -0.01966927-1.62276016e-01j,  0.14893516-3.74515051e-13j]]), array([[ 6.91566675e-01-5.71788565e-16j, -9.76174302e-02-2.98092153e-02j,
         4.29266895e-02+2.02252732e-01j,  2.61549617e-01-2.12073001e-02j],
       [-9.76174302e-02+2.98092153e-02j,  9.45065751e-02-6.69334255e-17j,
        -2.74120961e-02-1.29121895e-02j,  9.50147481e-03+4.47698934e-04j],
       [ 4.29266895e-02-2.02252732e-01j, -2.74120961e-02+1.29121895e-02j,
         7.47478707e-02-2.11416018e-16j, -4.36601129e-04-8.54208967e-02j],
       [ 2.61549617e-01+2.12073001e-02j,  9.50147481e-03-4.47698934e-04j,
        -4.36601129e-04+8.54208967e-02j,  1.39178879e-01+7.57637958e-17j]]), array([[ 0.52839391-1.78790524e-14j, -0.22964787-2.21547025e-01j,
        -0.14117336+1.45078682e-01j,  0.05417966-5.93221571e-02j],
       [-0.22964787+2.21547025e-01j,  0.27775382-3.79073238e-17j,
        -0.02257169-1.38813552e-01j,  0.07469623+1.13784517e-04j],
       [-0.14117336-1.45078682e-01j, -0.02257169+1.38813552e-01j,
         0.08825071-1.26788162e-16j, -0.04165385+2.87040038e-02j],
       [ 0.05417966+5.93221571e-02j,  0.07469623-1.13784517e-04j,
        -0.04165385-2.87040038e-02j,  0.10560157-5.07168343e-16j]]), array([[ 0.17207611-4.63011656e-16j, -0.04948707+9.10231081e-02j,
         0.10657581+5.15294701e-02j, -0.00115154-4.80267476e-02j],
       [-0.04948707-9.10231081e-02j,  0.43303099+5.79984854e-15j,
        -0.3191337 -3.03065001e-02j,  0.01777413-6.08613777e-02j],
       [ 0.10657581-5.15294701e-02j, -0.3191337 +3.03065001e-02j,
         0.35906257-1.45843909e-15j, -0.06057206+3.00946921e-02j],
       [-0.00115154+4.80267476e-02j,  0.01777413+6.08613777e-02j,
        -0.06057206-3.00946921e-02j,  0.03583033+1.29007501e-16j]]), array([[ 0.08174086+9.87620885e-17j,  0.094914  -1.02850555e-01j,
        -0.05283137+1.15073039e-01j, -0.05259161-1.03258031e-01j],
       [ 0.094914  +1.02850555e-01j,  0.41118076+6.18676400e-16j,
        -0.26615959+6.02383936e-02j,  0.0386335 -2.60400293e-01j],
       [-0.05283137-1.15073039e-01j, -0.26615959-6.02383936e-02j,
         0.26131964-3.07862275e-16j, -0.12495555+1.67057659e-01j],
       [-0.05259161+1.03258031e-01j,  0.0386335 +2.60400293e-01j,
        -0.12495555-1.67057659e-01j,  0.24575874-1.12138587e-16j]]), array([[ 0.20518459-3.35564940e-15j, -0.17679059-1.20523750e-02j,
         0.07138969+1.05997063e-01j,  0.09654079-4.35656919e-02j],
       [-0.17679059+1.20523750e-02j,  0.49179691+2.06536778e-14j,
        -0.22442222+6.93916723e-02j,  0.0005397 +5.49958374e-03j],
       [ 0.07138969-1.05997063e-01j, -0.22442222-6.93916723e-02j,
         0.2245647 -1.44675652e-14j, -0.04391549-8.51404611e-02j],
       [ 0.09654079+4.35656919e-02j,  0.0005397 -5.49958374e-03j,
        -0.04391549+8.51404611e-02j,  0.0784538 -2.33613964e-15j]]), array([[ 0.09510488-5.89605742e-11j, -0.11741405-9.36097758e-02j,
        -0.02253597+6.68218325e-02j,  0.06196401+1.23735744e-02j],
       [-0.11741405+9.36097758e-02j,  0.55582323+3.24570028e-10j,
        -0.11309228+2.13268105e-02j, -0.03750598-1.93179126e-01j],
       [-0.02253597-6.68218324e-02j, -0.11309228-2.13268107e-02j,
         0.11982003+7.17120326e-12j, -0.11249653-1.03777133e-02j],
       [ 0.06196401-1.23735745e-02j, -0.03750598+1.93179126e-01j,
        -0.11249653+1.03777133e-02j,  0.22925186+3.42618193e-11j]]), array([[ 0.49439745+1.93524200e-15j,  0.21657228-1.41144828e-02j,
        -0.10090047+3.43744699e-01j,  0.03442622-1.35103209e-01j],
       [ 0.21657228+1.41144828e-02j,  0.14621813-6.11139552e-17j,
        -0.09625442+1.41717421e-01j,  0.02691278-6.90882517e-02j],
       [-0.10090047-3.43744699e-01j, -0.09625442-1.41717421e-01j,
         0.31003389-3.39781634e-16j, -0.10814658+1.48074361e-02j],
       [ 0.03442622+1.35103209e-01j,  0.02691278+6.90882517e-02j,
        -0.10814658-1.48074361e-02j,  0.04935052-3.75855546e-17j]]), array([[ 0.23048073+8.75113300e-17j,  0.11605425-1.60375501e-01j,
        -0.20204921+1.59745768e-01j,  0.04827632-1.32346759e-01j],
       [ 0.11605425+1.60375501e-01j,  0.2899862 +1.59939935e-17j,
        -0.23403122-1.44229561e-01j,  0.13645027-3.18911912e-02j],
       [-0.20204921-1.59745768e-01j, -0.23403122+1.44229561e-01j,
         0.37610217-3.44913734e-16j, -0.14543904+9.83657911e-02j],
       [ 0.04827632+1.32346759e-01j,  0.13645027+3.18911912e-02j,
        -0.14543904-9.83657911e-02j,  0.1034309 -6.53817343e-17j]]), array([[ 0.4137714 -1.16023591e-15j,  0.09494584-4.02095327e-02j,
        -0.06164049+3.28981560e-01j,  0.25367475-6.58347727e-02j],
       [ 0.09494584+4.02095327e-02j,  0.10246555-4.20831305e-16j,
        -0.07687235+9.68784755e-02j,  0.08586272+2.32274105e-03j],
       [-0.06164049-3.28981560e-01j, -0.07687235-9.68784755e-02j,
         0.30315325-9.70955530e-16j, -0.10296205-1.98955668e-01j],
       [ 0.25367475+6.58347727e-02j,  0.08586272-2.32274105e-03j,
        -0.10296205+1.98955668e-01j,  0.18060981-1.47400979e-15j]]), array([[ 0.32076522+7.41700368e-16j, -0.06235724-2.29374720e-01j,
        -0.1578023 +2.25752591e-01j,  0.19760811-1.12734236e-01j],
       [-0.06235724+2.29374720e-01j,  0.23894129-8.87172144e-16j,
        -0.13656147-1.57999898e-01j,  0.05562908+1.45698479e-01j],
       [-0.1578023 -2.25752591e-01j, -0.13656147+1.57999898e-01j,
         0.25214479-2.82812037e-16j, -0.18428471-8.51513424e-02j],
       [ 0.19760811+1.12734236e-01j,  0.05562908-1.45698479e-01j,
        -0.18428471+8.51513424e-02j,  0.1881487 +5.59437748e-16j]]), array([[ 0.40709469-6.04883593e-16j,  0.02726584+1.53350190e-01j,
        -0.12613929-2.30870406e-01j, -0.3106359 -1.12510746e-01j],
       [ 0.02726584-1.53350190e-01j,  0.0689025 +1.45368474e-15j,
        -0.0949324 +4.58659984e-02j, -0.07222365+1.20000529e-01j],
       [-0.12613929+2.30870406e-01j, -0.0949324 -4.58659984e-02j,
         0.21382525+3.67246254e-15j,  0.1866478 -1.15081037e-01j],
       [-0.3106359 +1.12510746e-01j, -0.07222365-1.20000529e-01j,
         0.1866478 +1.15081037e-01j,  0.31017756+1.10066025e-15j]]), array([[ 0.20393661-1.04069304e-15j,  0.07642597+1.11964489e-02j,
        -0.06285142+4.97722141e-03j, -0.33021629+3.37667939e-02j],
       [ 0.07642597-1.11964489e-02j,  0.04294244+1.24042851e-15j,
         0.00675755+5.98765377e-03j, -0.11024419+6.33181881e-02j],
       [-0.06285142-4.97722141e-03j,  0.00675755-5.98765377e-03j,
         0.10137358+2.35621216e-16j,  0.13887403+8.19720643e-02j],
       [-0.33021629-3.37667939e-02j, -0.11024419-6.33181881e-02j,
         0.13887403-8.19720643e-02j,  0.65174736-2.95737069e-15j]]), array([[ 0.16773506-2.79427252e-16j, -0.13051798+1.95639829e-02j,
        -0.03085485-1.95759145e-01j, -0.12286275-1.35467858e-01j],
       [-0.13051798-1.95639829e-02j,  0.15598839-1.72818599e-16j,
         0.00428403+2.01649831e-01j,  0.08057568+1.86885678e-01j],
       [-0.03085485+1.95759145e-01j,  0.00428403-2.01649831e-01j,
         0.30971166+4.00734972e-16j,  0.26689883-1.18952735e-01j],
       [-0.12286275+1.35467858e-01j,  0.08057568-1.86885678e-01j,
         0.26689883+1.18952735e-01j,  0.3665649 -2.97350557e-16j]]), array([[ 0.05902625-7.20961892e-17j, -0.00411123-1.61071066e-02j,
        -0.04951649-2.61518695e-02j, -0.11393702+8.81595690e-02j],
       [-0.00411123+1.61071066e-02j,  0.04342701-3.63057057e-17j,
         0.02269567+2.29349661e-02j, -0.01172397+7.76297106e-02j],
       [-0.04951649+2.61518695e-02j,  0.02269567-2.29349661e-02j,
         0.10378685-7.26662559e-16j,  0.18717074-1.00206215e-01j],
       [-0.11393702-8.81595690e-02j, -0.01172397-7.76297106e-02j,
         0.18717074+1.00206215e-01j,  0.79375988+8.73977344e-16j]]), array([[ 0.25773831-3.62183018e-14j,  0.101006  +9.07951851e-02j,
         0.11853716-1.30900126e-02j, -0.07089885+7.83176999e-02j],
       [ 0.101006  -9.07951851e-02j,  0.13062331+1.73587133e-14j,
         0.16153352+1.98418824e-02j,  0.05489611+1.47597126e-01j],
       [ 0.11853716+1.30900126e-02j,  0.16153352-1.98418824e-02j,
         0.37358273+4.85607992e-14j,  0.17918177+1.56590798e-01j],
       [-0.07089885-7.83176999e-02j,  0.05489611-1.47597126e-01j,
         0.17918177-1.56590798e-01j,  0.23805566-2.21880241e-13j]]), array([[ 0.1494217 +3.56565541e-16j,  0.09409078-5.01218112e-02j,
         0.03326266-1.46783460e-01j, -0.03207955+1.92479962e-02j],
       [ 0.09409078+5.01218112e-02j,  0.13433745+2.44836102e-14j,
         0.17810967-1.19049416e-01j,  0.06281971+1.06606228e-01j],
       [ 0.03326266+1.46783460e-01j,  0.17810967+1.19049416e-01j,
         0.37715371+2.55272767e-14j,  0.07206779+2.26778775e-01j],
       [-0.03207955-1.92479962e-02j,  0.06281971-1.06606228e-01j,
         0.07206779-2.26778775e-01j,  0.33908714+4.11885994e-15j]]), array([[0.08909092-2.00519041e-17j, 0.02459345+1.66169827e-02j,
        0.01089141+1.77066907e-02j, 0.01476386+5.70765157e-02j],
       [0.02459345-1.66169827e-02j, 0.20619937-1.64439426e-16j,
        0.2025352 +1.58628051e-01j, 0.18873113+1.63608096e-01j],
       [0.01089141-1.77066907e-02j, 0.2025352 -1.58628051e-01j,
        0.3627477 -4.84608452e-16j, 0.32714817+1.43554267e-02j],
       [0.01476386-5.70765157e-02j, 0.18873113-1.63608096e-01j,
        0.32714817-1.43554267e-02j, 0.34196201-4.13095481e-16j]]), array([[ 0.1671759 +5.53660917e-16j, -0.04735042-1.90721995e-01j,
        -0.05829611-1.94551036e-01j,  0.07438854-5.60361217e-02j],
       [-0.04735042+1.90721995e-01j,  0.27510223-1.56315294e-15j,
         0.27218938+8.39874579e-04j,  0.09258296+1.66892301e-01j],
       [-0.05829611+1.94551036e-01j,  0.27218938-8.39874579e-04j,
         0.28809433-9.16570206e-17j,  0.10793561+1.42257604e-01j],
       [ 0.07438854+5.60361217e-02j,  0.09258296-1.66892301e-01j,
         0.10793561-1.42257604e-01j,  0.26962754-1.01152472e-15j]]), array([[ 0.18474048+5.67975236e-13j,  0.16466781+1.67464318e-01j,
        -0.05471351-6.23246716e-02j, -0.23384022-5.43048202e-03j],
       [ 0.16466781-1.67464318e-01j,  0.32921717-2.48667950e-12j,
        -0.09866194+5.69939779e-02j, -0.21383786+2.32930401e-01j],
       [-0.05471351+6.23246716e-02j, -0.09866194-5.69939779e-02j,
         0.16813375-4.03732229e-13j,  0.12402186-7.07499851e-02j],
       [-0.23384022+5.43048202e-03j, -0.21383786-2.32930401e-01j,
         0.12402186+7.07499851e-02j,  0.31790861-3.06329156e-14j]]), array([[ 0.11014091-3.42254492e-16j,  0.14824968+1.83038626e-02j,
         0.05381768-1.82770980e-03j, -0.2090223 +5.70975596e-02j],
       [ 0.14824968-1.83038626e-02j,  0.2379803 +1.59486879e-15j,
         0.11421558+1.09752293e-02j, -0.30014357+1.46073747e-01j],
       [ 0.05381768+1.82770980e-03j,  0.11421558-1.09752293e-02j,
         0.14241732-4.22390108e-16j, -0.10119157+1.02010703e-01j],
       [-0.2090223 -5.70975596e-02j, -0.30014357-1.46073747e-01j,
        -0.10119157-1.02010703e-01j,  0.50946147-2.85464853e-15j]]), array([[ 0.01765449+8.76305180e-18j,  0.01526342+3.72058665e-02j,
        -0.00060571-3.18016404e-02j, -0.06136267-1.31405500e-02j],
       [ 0.01526342-3.72058665e-02j,  0.38101658-2.83948607e-15j,
        -0.04479528+1.66649922e-01j, -0.08839472+3.09902391e-01j],
       [-0.00060571+3.18016404e-02j, -0.04479528-1.66649922e-01j,
         0.22437029+8.66616153e-16j,  0.15570256-1.16275333e-01j],
       [-0.06136267+1.31405500e-02j, -0.08839472-3.09902391e-01j,
         0.15570256+1.16275333e-01j,  0.37695864+1.37504499e-15j]]), array([[ 0.02175653-1.48084613e-16j,  0.02604318-3.83743046e-02j,
        -0.00867735-4.20204073e-02j, -0.03376124+5.74910334e-02j],
       [ 0.02604318+3.83743046e-02j,  0.26949796-4.55374499e-15j,
         0.05000422-1.71857510e-02j, -0.20922196+2.49661177e-01j],
       [-0.00867735+4.20204073e-02j,  0.05000422+1.71857510e-02j,
         0.1122397 -2.93969263e-16j, -0.0196005 -1.03609672e-01j],
       [-0.03376124-5.74910334e-02j, -0.20922196-2.49661177e-01j,
        -0.0196005 +1.03609672e-01j,  0.59650581-3.37042485e-15j]]), array([[ 0.15004134+7.40531511e-16j,  0.20296074+6.02351103e-02j,
         0.15055525+1.42938103e-01j, -0.09132562+1.00694882e-01j],
       [ 0.20296074-6.02351103e-02j,  0.32009481+2.78710951e-15j,
         0.2869488 +1.57093909e-01j, -0.08636874+1.83390216e-01j],
       [ 0.15055525-1.42938103e-01j,  0.2869488 -1.57093909e-01j,
         0.39480829+8.42345301e-17j,  0.01636784+2.05604431e-01j],
       [-0.09132562-1.00694882e-01j, -0.08636874-1.83390216e-01j,
         0.01636784-2.05604431e-01j,  0.13505556-1.01024763e-15j]]), array([[ 0.06842372-3.01240539e-16j,  0.11083124-2.45236224e-02j,
         0.10240364-9.83337000e-02j, -0.0292745 +8.29029670e-02j],
       [ 0.11083124+2.45236224e-02j,  0.25653055+6.86558294e-16j,
         0.29614559-1.43739586e-01j, -0.09033635+1.81507411e-01j],
       [ 0.10240364+9.83337000e-02j,  0.29614559+1.43739586e-01j,
         0.48240514-1.61309056e-15j, -0.19518287+1.75895309e-01j],
       [-0.0292745 -8.29029670e-02j, -0.09033635-1.81507411e-01j,
        -0.19518287-1.75895309e-01j,  0.19264059-1.22532835e-16j]]), array([[0.0321065 -6.22619232e-17j, 0.07518861-1.67248613e-02j,
        0.03021879+2.63884794e-02j, 0.01378281+4.10413081e-02j],
       [0.07518861+1.67248613e-02j, 0.47832227+2.00223166e-15j,
        0.29976142+2.63974915e-01j, 0.04100147+1.63568122e-01j],
       [0.03021879-2.63884794e-02j, 0.29976142-2.63974915e-01j,
        0.40155865+2.44636374e-17j, 0.10854636+4.64233294e-02j],
       [0.01378281-4.10413081e-02j, 0.04100147-1.63568122e-01j,
        0.10854636-4.64233294e-02j, 0.08801258-2.51226983e-16j]]), array([[ 0.05820513-1.49134724e-17j,  0.00249311-1.56773286e-01j,
        -0.00406092-1.10036365e-01j,  0.06231049+4.16041084e-02j],
       [ 0.00249311+1.56773286e-01j,  0.52615808+2.11361344e-15j,
         0.35262537+7.20337149e-03j, -0.10438616+2.20238967e-01j],
       [-0.00406092+1.10036365e-01j,  0.35262537-7.20337149e-03j,
         0.26525918+2.83826192e-16j, -0.06941462+1.27236889e-01j],
       [ 0.06231049-4.16041084e-02j, -0.10438616-2.20238967e-01j,
        -0.06941462-1.27236889e-01j,  0.15037761+5.05279683e-16j]]), array([[ 0.24540504+2.86513113e-16j, -0.04734978+1.45935390e-01j,
        -0.07274168-2.67119138e-01j,  0.02364571-1.65564387e-01j],
       [-0.04734978-1.45935390e-01j,  0.12005202-2.76145359e-16j,
        -0.16516458+1.22744165e-01j, -0.1312277 +1.88905592e-02j],
       [-0.07274168+2.67119138e-01j, -0.16516458-1.22744165e-01j,
         0.43085204+2.87570394e-16j,  0.22444221+1.45864275e-01j],
       [ 0.02364571+1.65564387e-01j, -0.1312277 -1.88905592e-02j,
         0.22444221-1.45864275e-01j,  0.20369091+1.05773124e-15j]]), array([[ 0.03942395+1.08377728e-17j,  0.00485181+2.19439146e-03j,
        -0.03642294-1.62161924e-02j, -0.02204695-2.81619567e-02j],
       [ 0.00485181-2.19439146e-03j,  0.05943042+7.81454617e-17j,
        -0.06237601+7.53520701e-02j, -0.14363777-3.42578869e-02j],
       [-0.03642294+1.62161924e-02j, -0.06237601-7.53520701e-02j,
         0.33082369+1.02742622e-15j,  0.17524549+3.50653666e-01j],
       [-0.02204695+2.81619567e-02j, -0.14363777+3.42578869e-02j,
         0.17524549-3.50653666e-01j,  0.57032194+1.12576032e-16j]]), array([[ 0.2378745 +1.07690345e-16j, -0.2222598 +1.12909828e-02j,
         0.03237313-2.02333295e-01j,  0.16516457-1.27602167e-01j],
       [-0.2222598 -1.12909828e-02j,  0.23230994-2.12412524e-16j,
        -0.04095292+2.20474425e-01j, -0.16270875+1.35003947e-01j],
       [ 0.03237313+2.02333295e-01j, -0.04095292-2.20474425e-01j,
         0.27813885+1.93146681e-16j,  0.20140092+1.16635549e-01j],
       [ 0.16516457+1.27602167e-01j, -0.16270875-1.35003947e-01j,
         0.20140092-1.16635549e-01j,  0.25167671-8.93155900e-16j]]), array([[ 0.11229913+1.22179314e-16j, -0.10201586-4.25533533e-02j,
         0.00916362-6.66378829e-02j,  0.20362864+2.01462644e-02j],
       [-0.10201586+4.25533533e-02j,  0.12192397-1.43907071e-16j,
         0.00562716+6.69476869e-02j, -0.22351264+5.85897218e-02j],
       [ 0.00916362+6.66378829e-02j,  0.00562716-6.69476869e-02j,
         0.12966014+2.19755537e-16j,  0.14122959+1.47042353e-01j],
       [ 0.20362864-2.01462644e-02j, -0.22351264-5.85897218e-02j,
         0.14122959-1.47042353e-01j,  0.63611676+1.06528192e-15j]]), array([[ 0.3228004 -1.68483618e-15j,  0.00469131+1.19662679e-01j,
        -0.1480817 +6.17075177e-02j, -0.08145236+1.09467414e-02j],
       [ 0.00469131-1.19662679e-01j,  0.04905863+3.01352932e-17j,
         0.03292836+7.83632766e-02j,  0.00096041+4.42971114e-02j],
       [-0.1480817 -6.17075177e-02j,  0.03292836-7.83632766e-02j,
         0.48519021-2.07418357e-16j,  0.21591839+1.40876757e-01j],
       [-0.08145236-1.09467414e-02j,  0.00096041-4.42971114e-02j,
         0.21591839-1.40876757e-01j,  0.14295076-2.03347325e-15j]]), array([[ 0.15191146+1.61491985e-16j, -0.00959166-4.44468018e-02j,
        -0.20962252-1.30755370e-01j,  0.02648484-1.07185166e-01j],
       [-0.00959166+4.44468018e-02j,  0.03827121-3.24235403e-17j,
         0.06728343-6.87641656e-02j,  0.03896045+1.93991342e-02j],
       [-0.20962252+1.30755370e-01j,  0.06728343+6.87641656e-02j,
         0.59051694-9.50423394e-16j,  0.11116358+2.93744504e-01j],
       [ 0.02648484+1.07185166e-01j,  0.03896045-1.93991342e-02j,
         0.11116358-2.93744504e-01j,  0.21930039-9.77298824e-17j]]), array([[ 0.2956592 -1.11059972e-11j, -0.14140978+8.20792665e-02j,
        -0.16526772+2.74439880e-02j,  0.02709432+6.42320282e-02j],
       [-0.14140978-8.20792664e-02j,  0.11882895-3.33113964e-11j,
         0.11764385+1.23607850e-01j,  0.02683645+2.31807927e-02j],
       [-0.16526772-2.74439880e-02j,  0.11764385-1.23607850e-01j,
         0.41928006+2.73264180e-11j,  0.21121477-4.16781385e-02j],
       [ 0.02709432-6.42320282e-02j,  0.02683645-2.31807927e-02j,
         0.21121477+4.16781384e-02j,  0.1662318 -2.05914765e-11j]]), array([[ 0.29842477-1.79298656e-15j, -0.19296875-9.20803083e-02j,
        -0.26607432-1.20061945e-01j,  0.0533495 -1.59976839e-02j],
       [-0.19296875+9.20803083e-02j,  0.1629459 -4.58223610e-16j,
         0.21155773-1.01958626e-02j, -0.03039636+1.93032042e-02j],
       [-0.26607432+1.20061945e-01j,  0.21155773+1.01958626e-02j,
         0.37652185+1.80147795e-16j,  0.05886098+6.91351315e-02j],
       [ 0.0533495 +1.59976839e-02j, -0.03039636-1.93032042e-02j,
         0.05886098-6.91351315e-02j,  0.16210748+1.27006786e-16j]]), array([[ 0.0901697 +1.34930888e-16j,  0.09285954+1.33358674e-01j,
        -0.13269285+2.89789111e-02j, -0.10008686-7.52377378e-02j],
       [ 0.09285954-1.33358674e-01j,  0.34179612+2.32155035e-16j,
        -0.11860898+2.75172021e-01j, -0.24243904+7.99412108e-02j],
       [-0.13269285-2.89789111e-02j, -0.11860898-2.75172021e-01j,
         0.36187259-1.18506430e-15j,  0.14841108+1.67431420e-01j],
       [-0.10008686+7.52377378e-02j, -0.24243904-7.99412108e-02j,
         0.14841108-1.67431420e-01j,  0.20616159-1.41625126e-15j]]), array([[ 0.02235398+1.95329150e-16j,  0.04868727+1.79346702e-03j,
        -0.04015171+2.94067298e-02j, -0.06117822-1.76835705e-02j],
       [ 0.04868727-1.79346702e-03j,  0.20621683+6.64037011e-16j,
         0.05192641+1.31740921e-01j, -0.2708281 -6.38022006e-03j],
       [-0.04015171-2.94067298e-02j,  0.05192641-1.31740921e-01j,
         0.38950614-2.85902801e-15j, -0.08700996+2.50728106e-01j],
       [-0.06117822+1.76835705e-02j, -0.2708281 +6.38022006e-03j,
        -0.08700996-2.50728106e-01j,  0.38192305-8.01850483e-16j]]), array([[ 0.0482817 +4.19828976e-16j, -0.11267567+4.82798904e-02j,
        -0.04719352-3.44986453e-02j,  0.060015  -3.79268688e-02j],
       [-0.11267567-4.82798904e-02j,  0.41516982-3.62635016e-15j,
         0.00358204+2.76123037e-01j, -0.19315312+1.04514861e-01j],
       [-0.04719352+3.44986453e-02j,  0.00358204-2.76123037e-01j,
         0.36373241-1.04973070e-15j,  0.09337139+3.48197910e-02j],
       [ 0.060015  +3.79268688e-02j, -0.19315312-1.04514861e-01j,
         0.09337139-3.48197910e-02j,  0.17281607-3.64326594e-16j]]), array([[ 0.04840395+1.01945046e-16j, -0.10531828-4.36946987e-02j,
        -0.04573713-4.96956783e-02j,  0.10429794+3.32580026e-02j],
       [-0.10531828+4.36946987e-02j,  0.37151596+7.46604922e-16j,
         0.12270549+1.17027790e-01j, -0.35784763+5.71993547e-02j],
       [-0.04573713+4.96956783e-02j,  0.12270549-1.17027790e-01j,
         0.19560977-3.61385346e-16j, -0.07769384+1.00543732e-01j],
       [ 0.10429794-3.32580026e-02j, -0.35784763-5.71993547e-02j,
        -0.07769384-1.00543732e-01j,  0.38447032+9.35998521e-16j]]), array([[ 0.136446  +1.66480587e-16j,  0.08232094+9.14034864e-02j,
        -0.13277102+2.03340160e-01j, -0.07053769-5.20775649e-03j],
       [ 0.08232094-9.14034864e-02j,  0.13386875-1.79363001e-17j,
         0.10245346+2.11310309e-01j, -0.05222231+5.65783364e-02j],
       [-0.13277102-2.03340160e-01j,  0.10245346-2.11310309e-01j,
         0.67273054+1.85652922e-15j,  0.04063206+1.56591065e-01j],
       [-0.07053769+5.20775649e-03j, -0.05222231-5.65783364e-02j,
         0.04063206-1.56591065e-01j,  0.05695471-4.74821282e-17j]]), array([[ 0.036573  +2.62338076e-19j, -0.00721456-1.75123877e-02j,
        -0.11866565-3.04185069e-02j,  0.02575844-1.75041307e-02j],
       [-0.00721456+1.75123877e-02j,  0.07134078-8.56777556e-17j,
         0.14883471-7.50714654e-02j, -0.04167621+5.86556298e-02j],
       [-0.11866565+3.04185069e-02j,  0.14883471+7.50714654e-02j,
         0.76955332+2.62634638e-16j, -0.18844926+1.81186072e-01j],
       [ 0.02575844+1.75041307e-02j, -0.04167621-5.86556298e-02j,
        -0.18844926-1.81186072e-01j,  0.1225329 +5.35695077e-16j]]), array([[ 0.10206748+1.96615293e-17j, -0.04748251+9.68448827e-02j,
        -0.22000931+7.47609974e-02j,  0.0188313 +4.55860819e-02j],
       [-0.04748251-9.68448827e-02j,  0.1760898 +1.91638261e-17j,
         0.18714679+2.37659666e-01j,  0.03268186-1.81309043e-02j],
       [-0.22000931-7.47609974e-02j,  0.18714679-2.37659666e-01j,
         0.66587437-1.57456537e-16j,  0.02496915-1.26092884e-01j],
       [ 0.0188313 -4.55860819e-02j,  0.03268186+1.81309043e-02j,
         0.02496915+1.26092884e-01j,  0.05596834-1.48483704e-17j]]), array([[ 0.12655074-6.50395557e-17j, -0.12751536-4.56314684e-02j,
        -0.22720584-6.23366805e-02j,  0.08715101+4.71907807e-02j],
       [-0.12751536+4.56314684e-02j,  0.20718348+1.63180321e-17j,
         0.2912668 -1.22761804e-03j, -0.13156801-7.45791410e-04j],
       [-0.22720584+6.23366805e-02j,  0.2912668 +1.22761804e-03j,
         0.53912814+3.64061562e-16j, -0.18594451-3.37187854e-02j],
       [ 0.08715101-4.71907807e-02j, -0.13156801+7.45791410e-04j,
        -0.18594451+3.37187854e-02j,  0.12713764-3.16775501e-17j]]), array([[ 0.49426012+5.08860017e-15j, -0.07699171+7.76592580e-02j,
         0.16569112-3.12151119e-01j, -0.17897686+1.41408132e-01j],
       [-0.07699171-7.76592580e-02j,  0.04455513+3.35045068e-16j,
        -0.08375558+4.39255499e-02j,  0.02917524+1.46924424e-02j],
       [ 0.16569112+3.12151119e-01j, -0.08375558-4.39255499e-02j,
         0.30160233+8.08699030e-16j, -0.12368803-3.51707753e-02j],
       [-0.17897686-1.41408132e-01j,  0.02917524-1.46924424e-02j,
        -0.12368803+3.51707753e-02j,  0.15958242-4.20410463e-16j]]), array([[ 0.33042056+1.80420767e-15j,  0.01913219-4.54425478e-02j,
         0.12239997-2.35355557e-02j, -0.26880013+2.89436313e-01j],
       [ 0.01913219+4.54425478e-02j,  0.02209867+1.04278200e-18j,
         0.00723325+1.22797648e-02j, -0.05280051-2.44848048e-02j],
       [ 0.12239997+2.35355557e-02j,  0.00723325-1.22797648e-02j,
         0.08852408-6.60264672e-17j, -0.11181106+1.29919758e-01j],
       [-0.26880013-2.89436313e-01j, -0.05280051+2.44848048e-02j,
        -0.11181106-1.29919758e-01j,  0.55895669+1.68573869e-15j]]), array([[ 0.40126728+2.02600452e-15j, -0.226073  -3.20923715e-02j,
         0.02825323-3.07649187e-01j, -0.16477999+7.57809449e-02j],
       [-0.226073  +3.20923715e-02j,  0.18084235+7.41584548e-16j,
         0.00659783+2.16528176e-01j,  0.11667868-2.02312857e-02j],
       [ 0.02825323+3.07649187e-01j,  0.00659783-2.16528176e-01j,
         0.28035651-1.00958690e-15j, -0.03964775-1.49561831e-01j],
       [-0.16477999-7.57809449e-02j,  0.11667868+2.02312857e-02j,
        -0.03964775+1.49561831e-01j,  0.13753385-1.27541866e-16j]]), array([[ 0.28928054+9.66684110e-16j, -0.12074762-5.56852887e-02j,
        -0.04810354-1.49328923e-01j, -0.21989895+2.76687357e-01j],
       [-0.12074762+5.56852887e-02j,  0.07921241+2.69029010e-16j,
         0.05023126+6.28386938e-02j,  0.05011929-1.35215296e-01j],
       [-0.04810354+1.49328923e-01j,  0.05023126-6.28386938e-02j,
         0.1014637 -1.43060917e-16j, -0.08420754-1.70245164e-01j],
       [-0.21989895-2.76687357e-01j,  0.05011929+1.35215296e-01j,
        -0.08420754+1.70245164e-01j,  0.53004335-2.31367371e-15j]]), array([[ 0.60184946-3.29937200e-16j,  0.16715692+7.15905938e-02j,
         0.10036449-9.36383744e-02j, -0.03877506+2.76263365e-01j],
       [ 0.16715692-7.15905938e-02j,  0.08955127-1.69475251e-17j,
         0.03168038-4.23582373e-03j,  0.02570862+1.05552575e-01j],
       [ 0.10036449+9.36383744e-02j,  0.03168038+4.23582373e-03j,
         0.13268163+3.51945870e-17j, -0.00427246+5.52118840e-02j],
       [-0.03877506-2.76263365e-01j,  0.02570862-1.05552575e-01j,
        -0.00427246-5.52118840e-02j,  0.17591764+6.28155910e-17j]]), array([[ 0.36185555-2.84104874e-16j,  0.13731   -7.60823213e-02j,
         0.04231686-2.13945665e-01j,  0.03927317+1.85767899e-01j],
       [ 0.13731   +7.60823213e-02j,  0.10957449-1.22843530e-15j,
         0.06567772-1.27713821e-01j,  0.05973453+7.22242472e-02j],
       [ 0.04231686+2.13945665e-01j,  0.06567772+1.27713821e-01j,
         0.22126651+3.42721869e-16j, -0.0860299 +1.73291963e-01j],
       [ 0.03927317-1.85767899e-01j,  0.05973453-7.22242472e-02j,
        -0.0860299 -1.73291963e-01j,  0.30730344+4.32080850e-16j]]), array([[0.38038673+4.65171247e-15j, 0.0856687 -3.33213611e-02j,
        0.05961885+6.23980668e-03j, 0.11997641+2.33204137e-01j],
       [0.0856687 +3.33213611e-02j, 0.15607129+5.50396885e-15j,
        0.04844151+1.22716555e-01j, 0.11800423+1.56491836e-01j],
       [0.05961885-6.23980668e-03j, 0.04844151-1.22716555e-01j,
        0.12186906-3.08654586e-16j, 0.1342328 -3.79033840e-02j],
       [0.11997641-2.33204137e-01j, 0.11800423-1.56491836e-01j,
        0.1342328 +3.79033840e-02j, 0.34167293+8.86306553e-15j]]), array([[ 0.35781873+3.19736687e-15j,  0.03860359-1.92657945e-01j,
        -0.01803164-1.48104964e-01j,  0.14131973+1.61760549e-01j],
       [ 0.03860359+1.92657945e-01j,  0.1928879 -3.47248912e-15j,
         0.11127993-1.69223576e-02j,  0.06250077+1.34194096e-01j],
       [-0.01803164+1.48104964e-01j,  0.11127993+1.69223576e-02j,
         0.07858526-2.77682645e-16j, -0.01620527+5.19803728e-02j],
       [ 0.14131973-1.61760549e-01j,  0.06250077-1.34194096e-01j,
        -0.01620527-5.19803728e-02j,  0.37070811+4.84855005e-15j]]), array([[ 0.19699722+1.06865711e-12j,  0.01870451+1.37479603e-01j,
         0.04831538-3.04152339e-01j, -0.15177065+9.71430639e-02j],
       [ 0.01870451-1.37479603e-01j,  0.12016792-3.59882829e-13j,
        -0.22944211-4.43289248e-02j,  0.05446718+1.18492049e-01j],
       [ 0.04831538+3.04152339e-01j, -0.22944211+4.43289248e-02j,
         0.51744094-1.58189443e-12j, -0.1855361 -2.14633007e-01j],
       [-0.15177065-9.71430639e-02j,  0.05446718-1.18492049e-01j,
        -0.1855361 +2.14633007e-01j,  0.16539391-1.32836335e-12j]]), array([[ 0.16025038+2.38829613e-16j,  0.06571213-3.92552837e-02j,
         0.1333284 -1.41630303e-01j, -0.15341829+1.78451823e-01j],
       [ 0.06571213+3.92552837e-02j,  0.08909364-5.17236876e-17j,
         0.02127409-1.63076394e-03j, -0.07774161+1.72782961e-02j],
       [ 0.1333284 +1.41630303e-01j,  0.02127409+1.63076394e-03j,
         0.36267787-2.02995410e-15j, -0.34975083+2.59037784e-02j],
       [-0.15341829-1.78451823e-01j, -0.07774161-1.72782961e-02j,
        -0.34975083-2.59037784e-02j,  0.3879781 -4.18504171e-16j]]), array([[ 0.11686733+5.18194070e-16j, -0.0198095 +1.91699623e-03j,
        -0.00895709-1.34739331e-01j, -0.0840518 +1.10939365e-01j],
       [-0.0198095 -1.91699623e-03j,  0.23919434+1.51313660e-15j,
        -0.12775334+2.03923857e-01j,  0.10139916+1.12552849e-01j],
       [-0.00895709+1.34739331e-01j, -0.12775334-2.03923857e-01j,
         0.36930353-1.50899405e-15j, -0.06918798-2.43689265e-01j],
       [-0.0840518 -1.10939365e-01j,  0.10139916-1.12552849e-01j,
        -0.06918798+2.43689265e-01j,  0.2746348 -7.94499582e-17j]]), array([[ 0.117259  -1.90111216e-14j, -0.00305372-6.35956828e-02j,
        -0.02316275-1.34470376e-01j, -0.07798706+1.95713634e-01j],
       [-0.00305372+6.35956828e-02j,  0.13302269-8.35915192e-16j,
        -0.00236639+5.36080769e-02j, -0.01495056+6.75985434e-03j],
       [-0.02316275+1.34470376e-01j, -0.00236639-5.36080769e-02j,
         0.25845918+3.50284583e-14j, -0.24419767-2.27599998e-01j],
       [-0.07798706-1.95713634e-01j, -0.01495056-6.75985434e-03j,
        -0.24419767+2.27599998e-01j,  0.49125914+3.80213834e-14j]]), array([[ 0.38051024-1.77111628e-15j,  0.33978737+8.23033181e-02j,
        -0.11006772+3.37523253e-03j, -0.09717178+2.10947061e-01j],
       [ 0.33978737-8.23033181e-02j,  0.34678992-8.68009601e-16j,
        -0.09498324+4.75717047e-02j, -0.04505931+2.15765109e-01j],
       [-0.11006772-3.37523253e-03j, -0.09498324-4.75717047e-02j,
         0.11636312-9.13185333e-17j,  0.02939293-5.39798772e-02j],
       [-0.09717178-2.10947061e-01j, -0.04505931-2.15765109e-01j,
         0.02939293+5.39798772e-02j,  0.15633673+9.61096274e-17j]]), array([[ 0.23951316+2.06490794e-16j,  0.21940285-3.75121363e-02j,
        -0.04641863-2.27036898e-01j,  0.01133912+2.02681587e-01j],
       [ 0.21940285+3.75121363e-02j,  0.23880704+1.02064158e-16j,
        -0.00999114-2.27905802e-01j, -0.01950598+1.96802515e-01j],
       [-0.04641863+2.27036898e-01j, -0.00999114+2.27905802e-01j,
         0.30257978-2.24996564e-16j, -0.23100002-9.03472226e-03j],
       [ 0.01133912-2.02681587e-01j, -0.01950598-1.96802515e-01j,
        -0.23100002+9.03472226e-03j,  0.21910002+1.75680611e-16j]]), array([[ 0.19996396+8.50575751e-16j,  0.2283163 -2.82757850e-02j,
        -0.07826902+1.01591995e-01j,  0.08700868+2.21688088e-01j],
       [ 0.2283163 +2.82757850e-02j,  0.33381559+1.30615590e-15j,
        -0.07738184+1.54554447e-01j,  0.08458639+2.86128725e-01j],
       [-0.07826902-1.01591995e-01j, -0.07738184-1.54554447e-01j,
         0.15707615+4.32490265e-16j,  0.09854978-1.44444548e-01j],
       [ 0.08700868-2.21688088e-01j,  0.08458639-2.86128725e-01j,
         0.09854978+1.44444548e-01j,  0.3091443 -1.84989600e-15j]]), array([[ 0.2025598 -1.01097126e-15j,  0.15128832-1.82036057e-01j,
        -0.07597569-5.27178932e-02j,  0.1630132 +2.05856276e-01j],
       [ 0.15128832+1.82036057e-01j,  0.34190878+3.74204015e-16j,
         0.00683917-8.77149497e-02j, -0.04680097+3.21849911e-01j],
       [-0.07597569+5.27178932e-02j,  0.00683917+8.77149497e-02j,
         0.07691883-2.86207750e-17j, -0.11060846-4.63549455e-02j],
       [ 0.1630132 -2.05856276e-01j, -0.04680097-3.21849911e-01j,
        -0.11060846+4.63549455e-02j,  0.37861259+2.71850230e-16j]]), array([[ 0.31841602-1.04426751e-16j, -0.13029837+9.74785092e-02j,
         0.15793241-3.02313564e-01j,  0.09935396+1.02383014e-01j],
       [-0.13029837-9.74785092e-02j,  0.11504334+1.13736567e-16j,
        -0.18753518+1.02876359e-01j, -0.0296147 -7.88415348e-02j],
       [ 0.15793241+3.02313564e-01j, -0.18753518-1.02876359e-01j,
         0.46080379+4.59677249e-16j, -0.02759262+1.86275221e-01j],
       [ 0.09935396-1.02383014e-01j, -0.0296147 +7.88415348e-02j,
        -0.02759262-1.86275221e-01j,  0.10573686+7.21698960e-17j]]), array([[ 0.15474726+2.28038008e-16j, -0.06362178-3.71942743e-02j,
         0.13842768-6.68557789e-02j,  0.02663471+2.23765241e-01j],
       [-0.06362178+3.71942743e-02j,  0.07139327+1.25450656e-16j,
        -0.09696563+6.94459162e-02j, -0.07934682-1.36970339e-01j],
       [ 0.13842768+6.68557789e-02j, -0.09696563-6.94459162e-02j,
         0.30573881-1.12642302e-15j, -0.06514939+3.42050869e-01j],
       [ 0.02663471-2.23765241e-01j, -0.07934682+1.36970339e-01j,
        -0.06514939-3.42050869e-01j,  0.46812066+4.25284433e-16j]]), array([[ 0.40649157+1.13194199e-15j, -0.29927373-2.42538995e-02j,
         0.07722071-2.61173218e-01j,  0.11584308+8.50550814e-02j],
       [-0.29927373+2.42538995e-02j,  0.26622191-2.22048328e-16j,
        -0.05764593+2.40969686e-01j, -0.08843227-3.58401929e-02j],
       [ 0.07722071+2.61173218e-01j, -0.05764593-2.40969686e-01j,
         0.25284292+1.55901396e-17j, -0.00891766+7.81133904e-02j],
       [ 0.11584308-8.50550814e-02j, -0.08843227+3.58401929e-02j,
        -0.00891766-7.81133904e-02j,  0.0744436 +1.95677011e-16j]]), array([[ 0.29522151-4.13493231e-16j, -0.18840271-7.70991201e-02j,
         0.0415265 -1.19426130e-01j,  0.15184895+2.85750685e-01j],
       [-0.18840271+7.70991201e-02j,  0.16513407-8.30381126e-17j,
         0.00099374+9.50415962e-02j, -0.18237944-1.42417377e-01j],
       [ 0.0415265 +1.19426130e-01j,  0.00099374-9.50415962e-02j,
         0.08255635-4.11496578e-17j, -0.08051811+1.13104497e-01j],
       [ 0.15184895-2.85750685e-01j, -0.18237944+1.42417377e-01j,
        -0.08051811-1.13104497e-01j,  0.45708807+1.99295508e-16j]]), array([[ 0.54855118-3.49876245e-14j,  0.0467544 +8.62107714e-02j,
        -0.13455008-8.96212428e-02j,  0.03710471+1.15819663e-01j],
       [ 0.0467544 -8.62107714e-02j,  0.0408479 +2.22651102e-15j,
        -0.09847621+5.12351591e-02j, -0.00746002-7.72343469e-03j],
       [-0.13455008+8.96212428e-02j, -0.09847621-5.12351591e-02j,
         0.34117881+3.46660366e-16j,  0.04407468+6.22968732e-02j],
       [ 0.03710471-1.15819663e-01j, -0.00746002+7.72343469e-03j,
         0.04407468-6.22968732e-02j,  0.06942211-4.67527351e-16j]]), array([[ 0.37979616-4.76159839e-15j,  0.04274118-6.05605923e-02j,
        -0.14997845-1.90257555e-01j,  0.11816208+9.10140344e-02j],
       [ 0.04274118+6.05605923e-02j,  0.05071399-1.01561543e-16j,
        -0.06444942-7.93387903e-02j,  0.0143246 -3.87686674e-02j],
       [-0.14997845+1.90257555e-01j, -0.06444942+7.93387903e-02j,
         0.36734416+1.75799937e-15j, -0.06126262+1.93021694e-01j],
       [ 0.11816208-9.10140344e-02j,  0.0143246 +3.87686674e-02j,
        -0.06126262-1.93021694e-01j,  0.20214569-4.14058355e-16j]]), array([[ 0.50583143-5.24760619e-15j, -0.08347306+4.27561290e-02j,
        -0.12404569+2.05942445e-02j,  0.1146101 +2.31444767e-01j],
       [-0.08347306-4.27561290e-02j,  0.0835929 -1.29776462e-15j,
         0.00127711+1.20038907e-01j,  0.00247129+4.99311800e-03j],
       [-0.12404569-2.05942445e-02j,  0.00127711-1.20038907e-01j,
         0.23467376-1.64701825e-15j,  0.07236506-8.17219864e-02j],
       [ 0.1146101 -2.31444767e-01j,  0.00247129-4.99311800e-03j,
         0.07236506+8.17219864e-02j,  0.17590191+1.72194917e-14j]]), array([[ 0.53511948+2.97688520e-17j, -0.13132136-1.26469609e-01j,
        -0.19348633-1.37329023e-01j,  0.19796144+2.10929957e-01j],
       [-0.13132136+1.26469609e-01j,  0.08646931+4.35603880e-17j,
         0.08386076-1.95614740e-02j, -0.08977585-9.23145657e-03j],
       [-0.19348633+1.37329023e-01j,  0.08386076+1.95614740e-02j,
         0.15267427-1.50183192e-16j, -0.10936253+1.96991399e-03j],
       [ 0.19796144-2.10929957e-01j, -0.08977585+9.23145657e-03j,
        -0.10936253-1.96991399e-03j,  0.22573694+5.06781103e-16j]]), array([[ 0.08318553-2.67688639e-18j, -0.01334886+8.57723806e-02j,
        -0.03800395-1.62597123e-01j,  0.00672947+3.77341783e-02j],
       [-0.01334886-8.57723806e-02j,  0.21723307+4.45994429e-18j,
        -0.28195486+2.03587623e-01j,  0.00436304-4.56897705e-02j],
       [-0.03800395+1.62597123e-01j, -0.28195486-2.03587623e-01j,
         0.64493949+2.72271334e-15j, -0.09171094+7.28709400e-02j],
       [ 0.00672947-3.77341783e-02j,  0.00436304+4.56897705e-02j,
        -0.09171094-7.28709400e-02j,  0.05464192+8.96022760e-17j]]), array([[ 0.07282199+1.88127479e-15j,  0.01719778-6.29497845e-02j,
         0.00600514-6.39471602e-02j, -0.01193856+1.04569684e-01j],
       [ 0.01719778+6.29497845e-02j,  0.14409331-1.16788041e-14j,
        -0.08779867+1.16897019e-01j, -0.09650926-9.55567249e-02j],
       [ 0.00600514+6.39471602e-02j, -0.08779867-1.16897019e-01j,
         0.48925718+4.54109474e-14j, -0.25055063+1.88786883e-01j],
       [-0.01193856-1.04569684e-01j, -0.09650926+9.55567249e-02j,
        -0.25055063-1.88786883e-01j,  0.29382752+1.14365671e-14j]]), array([[ 0.13096544-2.14486888e-15j, -0.11491161-9.37488019e-03j,
        -0.04619443-9.66462023e-02j,  0.0620873 +8.80215183e-02j],
       [-0.11491161+9.37488019e-03j,  0.35094009+3.31632567e-15j,
        -0.10121556+3.26995333e-01j, -0.03686032-3.99445349e-02j],
       [-0.04619443+9.66462023e-02j, -0.10121556-3.26995333e-01j,
         0.42101084-8.89923902e-15j, -0.06920868-2.91575767e-02j],
       [ 0.0620873 -8.80215183e-02j, -0.03686032+3.99445349e-02j,
        -0.06920868+2.91575767e-02j,  0.09708363-5.08124324e-16j]]), array([[ 0.12487986-8.06120088e-16j, -0.09947613-8.35245026e-02j,
        -0.05375285-1.04460507e-01j,  0.08141483+1.68041840e-01j],
       [-0.09947613+8.35245026e-02j,  0.27805125-7.22963243e-15j,
         0.018767  +1.78140436e-01j, -0.1579983 -1.25621599e-01j],
       [-0.05375285+1.04460507e-01j,  0.018767  -1.78140436e-01j,
         0.29692647+3.70789833e-15j, -0.23318144+7.43065127e-03j],
       [ 0.08141483-1.68041840e-01j, -0.1579983 +1.25621599e-01j,
        -0.23318144-7.43065127e-03j,  0.30014242-5.63024001e-16j]]), array([[ 0.33009013-4.62973474e-16j,  0.20959721+9.95259116e-02j,
        -0.34114795-6.09145965e-03j, -0.0190505 +7.45550663e-02j],
       [ 0.20959721-9.95259116e-02j,  0.18471609-5.31897325e-16j,
        -0.2342846 +1.17961680e-01j,  0.00588659+5.26700189e-02j],
       [-0.34114795+6.09145965e-03j, -0.2342846 -1.17961680e-01j,
         0.4529393 -1.19342244e-15j,  0.01712323-6.08147515e-02j],
       [-0.0190505 -7.45550663e-02j,  0.00588659-5.26700189e-02j,
         0.01712323+6.08147515e-02j,  0.03225448+5.91483859e-17j]]), array([[ 0.19602961+5.22806641e-16j,  0.10930763-3.61378069e-02j,
        -0.26427513-1.64692234e-01j,  0.0970915 +7.20319900e-02j],
       [ 0.10930763+3.61378069e-02j,  0.08979706+1.89194953e-16j,
        -0.14078248-1.28175615e-01j,  0.03686082+4.48583218e-02j],
       [-0.26427513+1.64692234e-01j, -0.14078248+1.28175615e-01j,
         0.59994443+5.27848169e-16j, -0.21983903+2.61419012e-02j],
       [ 0.0970915 -7.20319900e-02j,  0.03686082-4.48583218e-02j,
        -0.21983903-2.61419012e-02j,  0.11422891+8.66639367e-17j]]), array([[ 0.27084777+1.08393526e-15j,  0.07377785+5.81250741e-02j,
        -0.28456952+9.96164264e-02j,  0.09716215+1.86197512e-01j],
       [ 0.07377785-5.81250741e-02j,  0.10450064+2.13253542e-16j,
        -0.09591732+1.64197009e-01j,  0.06863154+4.63714248e-02j],
       [-0.28456952-9.96164264e-02j, -0.09591732-1.64197009e-01j,
         0.45148768+6.14943290e-16j, -0.01714659-2.45245309e-01j],
       [ 0.09716215-1.86197512e-01j,  0.06863154-4.63714248e-02j,
        -0.01714659+2.45245309e-01j,  0.17316391-9.76634543e-16j]]), array([[ 0.2767581 -2.72763537e-16j,  0.01060992-7.62887294e-02j,
        -0.29448064-3.77960340e-02j,  0.1791356 +1.94246512e-01j],
       [ 0.01060992+7.62887294e-02j,  0.06534149+7.02196872e-18j,
        -0.01033945-6.05949076e-02j, -0.05264385+5.50555389e-02j],
       [-0.29448064+3.77960340e-02j, -0.01033945+6.05949076e-02j,
         0.37853456-1.91119546e-18j, -0.23193717-1.82595498e-01j],
       [ 0.1791356 -1.94246512e-01j, -0.05264385-5.50555389e-02j,
        -0.23193717+1.82595498e-01j,  0.27936586+5.24702967e-16j]]), array([[ 0.49106988+4.15416322e-17j, -0.09678292+2.40700019e-01j,
        -0.01524456-2.95607495e-02j, -0.31914789-1.88238496e-01j],
       [-0.09678292-2.40700019e-01j,  0.15280894-7.62636536e-16j,
        -0.01190668+1.28005418e-02j, -0.02467981+1.94384147e-01j],
       [-0.01524456+2.95607495e-02j, -0.01190668-1.28005418e-02j,
         0.02632689+9.05413532e-18j,  0.02599074+5.68359221e-03j],
       [-0.31914789+1.88238496e-01j, -0.02467981-1.94384147e-01j,
         0.02599074-5.68359221e-03j,  0.32979429+1.54369610e-15j]]), array([[ 0.21068061-8.12865256e-16j, -0.05333508+5.43017038e-02j,
        -0.02328658+8.87575577e-02j, -0.29578752-1.61874633e-01j],
       [-0.05333508-5.43017038e-02j,  0.05659786-4.84604418e-17j,
         0.03151987-3.20428437e-02j,  0.0599125 +1.21580301e-01j],
       [-0.02328658-8.87575577e-02j,  0.03151987+3.20428437e-02j,
         0.08088434+1.97965115e-17j, -0.03889951+1.90184343e-01j],
       [-0.29578752+1.61874633e-01j,  0.0599125 -1.21580301e-01j,
        -0.03889951-1.90184343e-01j,  0.65183719-5.06748910e-16j]]), array([[ 0.30960095+2.65982140e-16j, -0.27948944+1.01640196e-01j,
        -0.02654611-8.95110616e-02j, -0.16215774-2.18228335e-01j],
       [-0.27948944-1.01640196e-01j,  0.33139594+1.20709989e-16j,
         0.00723951+1.03492487e-01j,  0.10888075+2.61772070e-01j],
       [-0.02654611+8.95110616e-02j,  0.00723951-1.03492487e-01j,
         0.05278997-1.30975997e-16j,  0.09681563-3.97040178e-02j],
       [-0.16215774+2.18228335e-01j,  0.10888075-2.61772070e-01j,
         0.09681563+3.97040178e-02j,  0.30621314-6.89375286e-16j]]), array([[ 0.08603327-1.67873355e-17j, -0.0848271 -2.66603925e-02j,
        -0.01815611-1.54959970e-02j, -0.03412753-1.97117260e-01j],
       [-0.0848271 +2.66603925e-02j,  0.13009446+5.16185020e-16j,
         0.02673028+1.36508497e-02j,  0.1545123 +1.93321270e-01j],
       [-0.01815611+1.54959970e-02j,  0.02673028-1.36508497e-02j,
         0.02136494+1.25782168e-17j,  0.04262506+2.89465777e-02j],
       [-0.03412753+1.97117260e-01j,  0.1545123 -1.93321270e-01j,
         0.04262506-2.89465777e-02j,  0.76250733+1.28972170e-16j]]), array([[ 0.35550353-1.12069601e-15j, -0.0305939 +2.61614063e-01j,
         0.040731  +1.46413297e-01j, -0.19978606+4.89649337e-02j],
       [-0.0305939 -2.61614063e-01j,  0.25499655-1.69443600e-15j,
         0.1699621 -6.49298459e-02j,  0.12457214+1.62331251e-01j],
       [ 0.040731  -1.46413297e-01j,  0.1699621 +6.49298459e-02j,
         0.16037554+1.09333842e-15j,  0.07709894+1.40798076e-01j],
       [-0.19978606-4.89649337e-02j,  0.12457214-1.62331251e-01j,
         0.07709894-1.40798076e-01j,  0.22912438+2.19052277e-16j]]), array([[ 0.07850886+1.37007101e-16j, -0.04241418+7.44894579e-02j,
         0.02093607+8.31891154e-02j, -0.1226149 +4.82582203e-03j],
       [-0.04241418-7.44894579e-02j,  0.25307777+4.09150838e-15j,
         0.15279709-1.96983883e-01j,  0.23511433+1.69410239e-01j],
       [ 0.02093607-8.31891154e-02j,  0.15279709+1.96983883e-01j,
         0.2635187 -1.06674070e-15j,  0.01513772+3.06097797e-01j],
       [-0.1226149 -4.82582203e-03j,  0.23511433-1.69410239e-01j,
         0.01513772-3.06097797e-01j,  0.40489467+2.00847471e-15j]]), array([[ 0.20762351+5.26431814e-16j, -0.14276433+2.00850224e-01j,
        -0.08027141+7.28926414e-02j, -0.11564872+5.26453804e-02j],
       [-0.14276433-2.00850224e-01j,  0.42009488-1.39653373e-15j,
         0.21526903+6.56937913e-02j,  0.25819914+1.04884428e-01j],
       [-0.08027141-7.28926414e-02j,  0.21526903-6.56937913e-02j,
         0.14279096+1.25983002e-16j,  0.16816844+2.07898281e-04j],
       [-0.11564872-5.26453804e-02j,  0.25819914-1.04884428e-01j,
         0.16816844-2.07898281e-04j,  0.22949066-5.97124733e-16j]]), array([[ 0.09564554+8.90291260e-17j, -0.13838667-6.91001702e-02j,
        -0.0975129 -1.06484896e-02j, -0.02705374-1.19947964e-01j],
       [-0.13838667+6.91001702e-02j,  0.40353258+1.77749233e-15j,
         0.20742068-7.53454338e-02j,  0.27400454+2.10689659e-01j],
       [-0.0975129 +1.06484896e-02j,  0.20742068+7.53454338e-02j,
         0.1384499 -6.67201292e-17j,  0.08842748+1.61871030e-01j],
       [-0.02705374+1.19947964e-01j,  0.27400454-2.10689659e-01j,
         0.08842748-1.61871030e-01j,  0.36237197+1.36160118e-15j]]), array([[ 0.24316005+3.72359373e-16j,  0.03001202+3.12261508e-01j,
         0.03414772-8.69123529e-03j, -0.2176143 -1.08791865e-01j],
       [ 0.03001202-3.12261508e-01j,  0.43919111-6.51534880e-16j,
        -0.01921549-3.32545158e-02j, -0.16473369+2.65544521e-01j],
       [ 0.03414772+8.69123529e-03j, -0.01921549+3.32545158e-02j,
         0.04029282-1.23954852e-17j, -0.04644743-1.92198951e-02j],
       [-0.2176143 +1.08791865e-01j, -0.16473369-2.65544521e-01j,
        -0.04644743+1.92198951e-02j,  0.27735603+7.73177985e-16j]]), array([[ 0.11107466-1.23241926e-16j,  0.00216159+1.09036025e-01j,
         0.08216882+9.30045791e-02j, -0.19394069-1.15900090e-01j],
       [ 0.00216159-1.09036025e-01j,  0.14560593-6.01694124e-17j,
         0.09152857-9.45623421e-02j, -0.10998266+2.09849656e-01j],
       [ 0.08216882-9.30045791e-02j,  0.09152857+9.45623421e-02j,
         0.18897548-5.11230795e-16j, -0.29244299+9.55421743e-02j],
       [-0.19394069+1.15900090e-01j, -0.10998266-2.09849656e-01j,
        -0.29244299-9.55421743e-02j,  0.55434393-8.88117688e-16j]]), array([[ 0.08905007-3.33769523e-16j, -0.15213146+1.52452053e-01j,
         0.00435099-1.54046245e-02j, -0.07431552-1.15142727e-01j],
       [-0.15213146-1.52452053e-01j,  0.62336059-1.49354343e-15j,
        -0.02761965+6.28898302e-02j, -0.03697583+3.51769922e-01j],
       [ 0.00435099+1.54046245e-02j, -0.02761965-6.28898302e-02j,
         0.03719945+2.67028791e-17j,  0.02722205-4.25002139e-02j],
       [-0.07431552+1.15142727e-01j, -0.03697583-3.51769922e-01j,
         0.02722205+4.25002139e-02j,  0.2503899 +1.62001800e-16j]]), array([[ 4.19230691e-02-1.32644040e-16j, -9.57482974e-02+1.08015744e-02j,
         3.35034663e-03+4.03269592e-02j,  1.59405222e-02-1.42843626e-01j],
       [-9.57482974e-02-1.08015744e-02j,  2.81581398e-01-4.94597964e-16j,
        -2.04900616e-04-9.59126952e-02j, -6.21230134e-02+3.69237460e-01j],
       [ 3.35034663e-03-4.03269592e-02j, -2.04900616e-04+9.59126952e-02j,
         6.22702375e-02+1.37615442e-16j, -1.67795221e-01-4.91244663e-02j],
       [ 1.59405222e-02+1.42843626e-01j, -6.21230134e-02-3.69237460e-01j,
        -1.67795221e-01+4.91244663e-02j,  6.14225296e-01+9.14546326e-18j]]), array([[ 0.24566015-4.38959592e-16j,  0.13838925+3.05743835e-01j,
         0.05525838+1.31483733e-01j, -0.12885325+2.85124095e-02j],
       [ 0.13838925-3.05743835e-01j,  0.50902942+3.49521744e-16j,
         0.21361911-1.18176481e-02j, -0.03405601+2.01005380e-01j],
       [ 0.05525838-1.31483733e-01j,  0.21361911+1.18176481e-02j,
         0.13652958+6.03752625e-17j, -0.034517  +9.20980749e-02j],
       [-0.12885325-2.85124095e-02j, -0.03405601-2.01005380e-01j,
        -0.034517  -9.20980749e-02j,  0.10878086-1.47064157e-16j]]), array([[ 0.04116729-1.36513220e-16j, -0.00564689+9.83394128e-02j,
         0.06049896+5.87369047e-02j, -0.0749232 -3.61700072e-03j],
       [-0.00564689-9.83394128e-02j,  0.37684862+3.65664117e-15j,
         0.17331838-2.80236563e-01j,  0.04928697+2.91491583e-01j],
       [ 0.06049896-5.87369047e-02j,  0.17331838+2.80236563e-01j,
         0.31996741+1.02933380e-16j, -0.21434112+1.84040498e-01j],
       [-0.0749232 +3.61700072e-03j,  0.04928697-2.91491583e-01j,
        -0.21434112-1.84040498e-01j,  0.26201669+6.00212030e-16j]]), array([[ 0.06795062+2.40984563e-17j, -0.00338394+1.91813185e-01j,
        -0.04133725+7.77740515e-02j, -0.02664913+2.45398552e-02j],
       [-0.00338394-1.91813185e-01j,  0.70971992-7.20955143e-16j,
         0.26445965+1.39555931e-01j,  0.11090154+1.24910843e-01j],
       [-0.04133725-7.77740515e-02j,  0.26445965-1.39555931e-01j,
         0.15120704-1.06130785e-16j,  0.05616225+1.20466604e-02j],
       [-0.02664913-2.45398552e-02j,  0.11090154-1.24910843e-01j,
         0.05616225-1.20466604e-02j,  0.07112243-1.85304075e-17j]]), array([[ 0.04089995-2.26920038e-14j, -0.09520504-2.11765193e-02j,
        -0.06406874+2.46744181e-02j,  0.03911765-5.15364755e-02j],
       [-0.09520504+2.11765193e-02j,  0.60088291+5.92132415e-13j,
         0.19462679-1.36781053e-01j,  0.04767762+3.23658782e-01j],
       [-0.06406874-2.46744181e-02j,  0.19462679+1.36781053e-01j,
         0.13031501+2.64404120e-13j, -0.09768192+1.00180868e-01j],
       [ 0.03911765+5.15364755e-02j,  0.04767762-3.23658782e-01j,
        -0.09768192-1.00180868e-01j,  0.22790213-1.96043514e-13j]]), array([[ 0.44397864-6.80115119e-13j, -0.07071414+2.81884025e-01j,
        -0.08834249-1.42094778e-01j,  0.01888213-2.36802658e-01j],
       [-0.07071414-2.81884025e-01j,  0.20272955+6.73255357e-12j,
        -0.09966103+7.72293557e-02j, -0.14137628-1.08655502e-02j],
       [-0.08834249+1.42094778e-01j, -0.09966103-7.72293557e-02j,
         0.10749957-1.28301000e-12j,  0.05385535+1.23474813e-01j],
       [ 0.01888213+2.36802658e-01j, -0.14137628+1.08655501e-02j,
         0.05385535-1.23474813e-01j,  0.24579224+4.45499411e-12j]]), array([[ 0.17781201+5.19512089e-16j,  0.00989999+6.70535053e-02j,
        -0.13426384-2.27015790e-02j,  0.04780518-2.71452854e-01j],
       [ 0.00989999-6.70535053e-02j,  0.05036157+1.18155875e-16j,
        -0.0430758 +3.80996597e-02j, -0.06644497-7.70286690e-02j],
       [-0.13426384+2.27015790e-02j, -0.0430758 -3.80996597e-02j,
         0.15931672-5.37297831e-16j, -0.02260474+3.02873563e-01j],
       [ 0.04780518+2.71452854e-01j, -0.06644497+7.70286690e-02j,
        -0.02260474-3.02873563e-01j,  0.6125097 -2.38351592e-16j]]), array([[ 4.51613126e-01+1.01095871e-15j, -3.41531641e-01+1.75412213e-01j,
        -5.79990075e-02-1.14834506e-01j,  9.23990558e-02-2.17331508e-01j],
       [-3.41531641e-01-1.75412213e-01j,  3.39513243e-01-1.33198556e-15j,
        -2.80661648e-04+1.11662238e-01j, -1.47371933e-01+1.27478525e-01j],
       [-5.79990075e-02+1.14834506e-01j, -2.80661648e-04-1.11662238e-01j,
         4.50308655e-02+1.02709633e-16j,  4.59686607e-02+5.23817868e-02j],
       [ 9.23990558e-02+2.17331508e-01j, -1.47371933e-01-1.27478525e-01j,
         4.59686607e-02-5.23817868e-02j,  1.63842766e-01-1.60690129e-15j]]), array([[ 0.24355999-5.05530614e-13j, -0.13659169+6.31662739e-02j,
        -0.05779551-5.36154294e-02j,  0.24341557-1.82082919e-01j],
       [-0.13659169-6.31662739e-02j,  0.11562887+1.90198635e-13j,
         0.013226  +4.31427043e-02j, -0.114792  +1.54065800e-02j],
       [-0.05779551+5.36154294e-02j,  0.013226  -4.31427043e-02j,
         0.02691457+2.33339591e-13j, -0.03176766+1.08124763e-01j],
       [ 0.24341557+1.82082919e-01j, -0.114792  -1.54065800e-02j,
        -0.03176766-1.08124763e-01j,  0.61389658-2.07336160e-12j]]), array([[ 0.60971607+3.40037381e-15j, -0.07075754+2.29078122e-01j,
        -0.24413242+1.45008455e-01j, -0.12004396-1.63532685e-01j],
       [-0.07075754-2.29078122e-01j,  0.10302929-1.40982233e-15j,
         0.08547855+6.14947245e-02j, -0.0390746 +5.94708147e-02j],
       [-0.24413242-1.45008455e-01j,  0.08547855-6.14947245e-02j,
         0.18828913-2.31944097e-15j,  0.03177454+1.23522602e-01j],
       [-0.12004396+1.63532685e-01j, -0.0390746 -5.94708147e-02j,
         0.03177454-1.23522602e-01j,  0.0989655 +1.26714567e-15j]]), array([[ 0.32986121+8.13834457e-16j, -0.08128045+2.71114388e-02j,
        -0.25266081+1.02326003e-01j, -0.04694828-2.25948980e-01j],
       [-0.08128045-2.71114388e-02j,  0.07343755-1.22312759e-16j,
         0.07704977-6.62300909e-02j,  0.06623359+6.60302375e-02j],
       [-0.25266081-1.02326003e-01j,  0.07704977+6.62300909e-02j,
         0.31359494-8.17114868e-16j, -0.03378052+2.86977837e-01j],
       [-0.04694828+2.25948980e-01j,  0.06623359-6.60302375e-02j,
        -0.03378052-2.86977837e-01j,  0.2831063 -6.16059181e-16j]]), array([[ 0.46310712-2.15194877e-15j, -0.28327629+2.28457084e-01j,
        -0.19487335+8.50317046e-02j, -0.00446362-1.63973031e-02j],
       [-0.28327629-2.28457084e-01j,  0.31112953-9.76184702e-16j,
         0.19130608+5.76644776e-02j,  0.02270294+2.15143266e-02j],
       [-0.19487335-8.50317046e-02j,  0.19130608-5.76644776e-02j,
         0.16489848-1.28677194e-15j,  0.05552338+1.27291678e-03j],
       [-0.00446362+1.63973031e-02j,  0.02270294-2.15143266e-02j,
         0.05552338-1.27291678e-03j,  0.06086487+4.26069026e-17j]]), array([[ 0.41686216-3.07043323e-15j, -0.26673522-4.69579876e-02j,
        -0.25245586+1.65610195e-02j,  0.10628992-2.22560070e-01j],
       [-0.26673522+4.69579876e-02j,  0.20582235+6.68335460e-16j,
         0.1673201 -4.93294560e-02j, -0.00309585+1.55382556e-01j],
       [-0.25245586-1.65610195e-02j,  0.1673201 +4.93294560e-02j,
         0.16327252-9.49950196e-16j, -0.06359531+1.47116401e-01j],
       [ 0.10628992+2.22560070e-01j, -0.00309585-1.55382556e-01j,
        -0.06359531-1.47116401e-01j,  0.21404297-2.15135220e-15j]]), array([[ 0.24852679-6.23391150e-16j,  0.06360986+3.22313619e-01j,
        -0.1377696 +2.68456593e-03j, -0.02952038-1.94208372e-01j],
       [ 0.06360986-3.22313619e-01j,  0.4585278 +1.68996953e-16j,
        -0.04623692+1.91023329e-01j, -0.25904896-2.12832151e-02j],
       [-0.1377696 -2.68456593e-03j, -0.04623692-1.91023329e-01j,
         0.11089817-2.92365430e-16j, -0.0032305 +1.20826020e-01j],
       [-0.02952038+1.94208372e-01j, -0.25904896+2.12832151e-02j,
        -0.0032305 -1.20826020e-01j,  0.18204725+3.04776963e-16j]]), array([[ 0.12473208-2.07896734e-17j,  0.03795882+1.07730428e-01j,
        -0.10074042+1.25068440e-01j, -0.02073458-2.21902044e-01j],
       [ 0.03795882-1.07730428e-01j,  0.1328852 +1.98892119e-16j,
         0.06753514+1.30738375e-01j, -0.19932445-5.78757186e-02j],
       [-0.10074042-1.25068440e-01j,  0.06753514-1.30738375e-01j,
         0.26735442+6.20189785e-16j, -0.2520189 +2.30540097e-01j],
       [-0.02073458+2.21902044e-01j, -0.19932445+5.78757186e-02j,
        -0.2520189 -2.30540097e-01j,  0.4750283 +2.14577884e-15j]]), array([[ 0.15773195-5.59236202e-16j, -0.20553945+2.38863074e-01j,
        -0.07950169-3.41110420e-02j,  0.05590265-9.03844800e-02j],
       [-0.20553945-2.38863074e-01j,  0.67760652-2.74589741e-15j,
         0.04475832+1.90348333e-01j, -0.20599481+3.90471239e-02j],
       [-0.07950169+3.41110420e-02j,  0.04475832-1.90348333e-01j,
         0.07665403+1.27523875e-16j, -0.00915973+4.74869372e-02j],
       [ 0.05590265+9.03844800e-02j, -0.20599481-3.90471239e-02j,
        -0.00915973-4.74869372e-02j,  0.08800749-3.37348112e-16j]]), array([[ 0.11368385+8.55448674e-16j, -0.12114549+1.10483086e-01j,
        -0.094642  +3.27297529e-02j,  0.15235593-1.26207171e-01j],
       [-0.12114549-1.10483086e-01j,  0.27864709-1.61346239e-17j,
         0.11147808+7.29745369e-02j, -0.23668992-7.43667364e-03j],
       [-0.094642  -3.27297529e-02j,  0.11147808-7.29745369e-02j,
         0.12476469+3.90456085e-16j, -0.21852258+3.08144747e-02j],
       [ 0.15235593+1.26207171e-01j, -0.23668992+7.43667364e-03j,
        -0.21852258-3.08144747e-02j,  0.48290437-5.18968419e-16j]]), array([[ 0.36314251+1.23866300e-15j,  0.08958528+2.73256592e-01j,
        -0.18347367+2.52048193e-01j, -0.04973893-1.24113070e-01j],
       [ 0.08958528-2.73256592e-01j,  0.24898113-1.51982273e-15j,
         0.14973423+1.84175860e-01j, -0.1014766 +1.70809980e-02j],
       [-0.18347367-2.52048193e-01j,  0.14973423-1.84175860e-01j,
         0.31660024-1.93493751e-15j, -0.07932697+1.14079486e-01j],
       [-0.04973893+1.24113070e-01j, -0.1014766 -1.70809980e-02j,
        -0.07932697-1.14079486e-01j,  0.07127612-1.92551101e-16j]]), array([[ 0.15122842+7.11336604e-15j, -0.06167036+8.16670816e-02j,
        -0.13049859+2.07213442e-01j, -0.02486254-1.55297630e-01j],
       [-0.06167036-8.16670816e-02j,  0.12732101+2.09837826e-15j,
         0.17599379-8.66931178e-02j, -0.04060515+1.28749944e-01j],
       [-0.13049859-2.07213442e-01j,  0.17599379+8.66931178e-02j,
         0.49125345+3.71800599e-14j, -0.25108475+2.19898219e-01j],
       [-0.02486254+1.55297630e-01j, -0.04060515-1.28749944e-01j,
        -0.25108475-2.19898219e-01j,  0.23019712-9.66010959e-16j]]), array([[ 0.22864083+4.34553309e-16j, -0.07880397+2.76540141e-01j,
        -0.19314452+1.49760740e-01j,  0.08007795-6.01009000e-03j],
       [-0.07880397-2.76540141e-01j,  0.41990265-1.05748648e-15j,
         0.25778188+1.99534422e-01j, -0.0299837 -8.41626178e-02j],
       [-0.19314452-1.49760740e-01j,  0.25778188-1.99534422e-01j,
         0.29747838+5.75895791e-16j, -0.07229136-5.47155028e-02j],
       [ 0.08007795+6.01009000e-03j, -0.0299837 +8.41626178e-02j,
        -0.07229136+5.47155028e-02j,  0.05397815+6.54977984e-17j]]), array([[ 0.22154441+1.93544682e-15j, -0.16482051+7.79496779e-02j,
        -0.22521142+1.23183335e-01j,  0.16789977-1.08841519e-01j],
       [-0.16482051-7.79496779e-02j,  0.23754445+5.23550461e-16j,
         0.22182302-3.35146737e-02j, -0.12612412+6.84616086e-02j],
       [-0.22521142-1.23183335e-01j,  0.22182302+3.35146737e-02j,
         0.30992776+2.71373687e-15j, -0.24226948+3.18343536e-02j],
       [ 0.16789977+1.08841519e-01j, -0.12612412-6.84616086e-02j,
        -0.24226948-3.18343536e-02j,  0.23098337-1.90475773e-15j]]), array([[ 0.44016103-4.36544098e-16j, -0.16627744+2.24622257e-01j,
         0.16552395-9.58049652e-02j, -0.26568163+1.14728832e-01j],
       [-0.16627744-2.24622257e-01j,  0.20267621+8.25227774e-16j,
        -0.12337722-4.62985576e-02j,  0.16920934+8.24570843e-02j],
       [ 0.16552395+9.58049652e-02j, -0.12337722+4.62985576e-02j,
         0.11102081+8.70079124e-17j, -0.13621546+5.23593999e-03j],
       [-0.26568163-1.14728832e-01j,  0.16920934-8.24570843e-02j,
        -0.13621546-5.23593999e-03j,  0.24614194+9.24897741e-16j]]), array([[ 0.16886311+5.05737250e-16j, -0.0927499 +5.26680787e-02j,
         0.11746651+2.28112950e-02j, -0.23332598+1.27627443e-01j],
       [-0.0927499 -5.26680787e-02j,  0.11723099+1.32080086e-16j,
        -0.0835931 -7.01382758e-02j,  0.22918586-1.85085800e-02j],
       [ 0.11746651-2.28112950e-02j, -0.0835931 +7.01382758e-02j,
         0.13587046+9.56660838e-17j, -0.18181495+1.82905112e-01j],
       [-0.23332598-1.27627443e-01j,  0.22918586+1.85085800e-02j,
        -0.18181495-1.82905112e-01j,  0.57803544+5.67551067e-16j]]), array([[ 0.31784786+4.60475510e-17j, -0.2989326 +1.21032590e-01j,
         0.01739446-1.25572530e-01j, -0.20241805+6.92414952e-02j],
       [-0.2989326 -1.21032590e-01j,  0.39011134-3.12575821e-16j,
        -0.06719742+1.31956615e-01j,  0.26755039+2.28871501e-02j],
       [ 0.01739446+1.25572530e-01j, -0.06719742-1.31956615e-01j,
         0.07173308-8.66939667e-17j, -0.03621046-9.56583732e-02j],
       [-0.20241805-6.92414952e-02j,  0.26755039-2.28871501e-02j,
        -0.03621046+9.56583732e-02j,  0.22030773-1.69644702e-16j]]), array([[ 9.52870058e-02+8.76935540e-17j, -1.09382093e-01+3.97754772e-02j,
        -3.12036412e-04-4.09484997e-02j, -1.12119500e-01+1.51886550e-01j],
       [-1.09382093e-01-3.97754772e-02j,  2.04566190e-01+3.83808986e-16j,
        -2.67210548e-02+5.42501429e-02j,  3.00395533e-01-1.34901680e-01j],
       [-3.12036412e-04+4.09484997e-02j, -2.67210548e-02-5.42501429e-02j,
         3.28767626e-02-7.86411484e-17j, -9.30208770e-02-5.78612793e-02j],
       [-1.12119500e-01-1.51886550e-01j,  3.00395533e-01+1.34901680e-01j,
        -9.30208770e-02+5.78612793e-02j,  6.67270041e-01-8.35291348e-17j]]), array([[ 0.46445077+2.29591155e-16j,  0.08324657+3.04694757e-01j,
         0.11036571-3.30807045e-02j, -0.01105179+2.35442145e-01j],
       [ 0.08324657-3.04694757e-01j,  0.28259984-3.29999084e-16j,
        -0.00300994-9.45780127e-02j,  0.20357009+5.49906634e-02j],
       [ 0.11036571+3.30807045e-02j, -0.00300994+9.45780127e-02j,
         0.05804409-3.84479537e-17j, -0.02383827+7.50752683e-02j],
       [-0.01105179-2.35442145e-01j,  0.20357009-5.49906634e-02j,
        -0.02383827-7.50752683e-02j,  0.1949053 +1.29450855e-16j]]), array([[ 0.13823175+5.94794855e-16j,  0.10981234+8.26111737e-02j,
         0.05626006-9.91641374e-02j,  0.10084383+1.37822495e-01j],
       [ 0.10981234-8.26111737e-02j,  0.2584555 -1.91760753e-16j,
        -0.03438372-1.95767597e-01j,  0.31664998+4.17187235e-02j],
       [ 0.05626006+9.91641374e-02j, -0.03438372+1.95767597e-01j,
         0.16873686+1.99889481e-17j, -0.08124025+2.44363372e-01j],
       [ 0.10084383-1.37822495e-01j,  0.31664998-4.17187235e-02j,
        -0.08124025-2.44363372e-01j,  0.43457589-2.09207368e-16j]]), array([[ 0.29234786-2.82775731e-16j,  0.00256116+2.13466700e-01j,
        -0.03188485+3.68061795e-02j,  0.04619507+2.42079122e-01j],
       [ 0.00256116-2.13466700e-01j,  0.31591812+6.54962835e-16j,
         0.04935778+7.89059687e-02j,  0.32161872-4.00036402e-03j],
       [-0.03188485-3.68061795e-02j,  0.04935778-7.89059687e-02j,
         0.03748934-2.16788324e-16j,  0.0569964 -8.00589809e-02j],
       [ 0.04619507-2.42079122e-01j,  0.32161872+4.00036402e-03j,
         0.0569964 +8.00589809e-02j,  0.35424468+4.81271457e-16j]]), array([[ 0.19121559-5.92089782e-16j,  0.11270827-3.33385993e-02j,
        -0.02647774-3.55463627e-02j,  0.26722156+6.49582542e-02j],
       [ 0.11270827+3.33385993e-02j,  0.1912413 +1.63866904e-16j,
         0.00428439-3.77449161e-02j,  0.29761054+7.08710170e-02j],
       [-0.02647774+3.55463627e-02j,  0.00428439+3.77449161e-02j,
         0.01658293+2.41005982e-17j, -0.03059595+5.48246916e-02j],
       [ 0.26722156-6.49582542e-02j,  0.29761054-7.08710170e-02j,
        -0.03059595-5.48246916e-02j,  0.60096018-4.77124902e-15j]]), array([[ 0.15909315-5.19341722e-16j, -0.01907452+2.39614681e-01j,
         0.07981572-1.32868758e-01j, -0.1421299 +5.82794445e-02j],
       [-0.01907452-2.39614681e-01j,  0.40586655+3.36780683e-15j,
        -0.25619854-7.85311349e-02j,  0.12987781+1.79433269e-01j],
       [ 0.07981572+1.32868758e-01j, -0.25619854+7.85311349e-02j,
         0.23431209+2.21464593e-15j, -0.17824795-6.93746677e-02j],
       [-0.1421299 -5.82794445e-02j,  0.12987781-1.79433269e-01j,
        -0.17824795+6.93746677e-02j,  0.20072821+4.08548861e-16j]]), array([[ 0.04769467+1.89058202e-16j, -0.02100344+4.84384072e-02j,
         0.10229511-1.88788955e-02j, -0.12338684+3.41806601e-02j],
       [-0.02100344-4.84384072e-02j,  0.12505394+2.11511720e-16j,
        -0.13626618-1.13285471e-01j,  0.16389012+1.17653576e-01j],
       [ 0.10229511+1.88788955e-02j, -0.13626618+1.13285471e-01j,
         0.34687615+9.23729675e-16j, -0.39757065+4.49386595e-02j],
       [-0.12338684-3.41806601e-02j,  0.16389012-1.17653576e-01j,
        -0.39757065-4.49386595e-02j,  0.48037524+5.33022249e-16j]]), array([[ 0.05224568-9.64304719e-18j, -0.076191  +1.09998559e-01j,
        -0.00859108-6.63890896e-02j, -0.06859499+3.22875692e-02j],
       [-0.076191  -1.09998559e-01j,  0.52443171-1.25170948e-16j,
        -0.19884623+1.83758573e-01j,  0.27214272+1.38390393e-01j],
       [-0.00859108+6.63890896e-02j, -0.19884623-1.83758573e-01j,
         0.17416961+1.10996914e-16j, -0.08565165-1.59570858e-01j],
       [-0.06859499-3.22875692e-02j,  0.27214272-1.38390393e-01j,
        -0.08565165+1.59570858e-01j,  0.249153  +1.45261741e-16j]]), array([[ 0.0116883 -6.99176865e-18j,  0.00591496+3.21926207e-03j,
        -0.02130791-5.10447187e-03j,  0.03030609+2.45079167e-02j],
       [ 0.00591496-3.21926207e-03j,  0.12286549-4.03477813e-16j,
        -0.11560796+3.50018940e-02j,  0.20998498+6.70356303e-02j],
       [-0.02130791+5.10447187e-03j, -0.11560796-3.50018940e-02j,
         0.20237635-8.54191779e-16j, -0.30914542-1.73520826e-01j],
       [ 0.03030609-2.45079167e-02j,  0.20998498-6.70356303e-02j,
        -0.30914542+1.73520826e-01j,  0.66306985+2.20092434e-15j]]), array([[ 0.27960759+2.41850042e-16j,  0.26573362+2.67528708e-01j,
        -0.04287743-5.39295558e-02j,  0.00344155+1.25683584e-01j],
       [ 0.26573362-2.67528708e-01j,  0.557363  +1.18151732e-15j,
        -0.10445434-2.54572322e-02j,  0.14081118+1.32452000e-01j],
       [-0.04287743+5.39295558e-02j, -0.10445434+2.54572322e-02j,
         0.06600245+1.77412530e-17j, -0.05458911-1.06329317e-02j],
       [ 0.00344155-1.25683584e-01j,  0.14081118-1.32452000e-01j,
        -0.05458911+1.06329317e-02j,  0.09702696-1.06638808e-16j]]), array([[ 0.06230256-1.00049981e-16j,  0.13000652+4.88838726e-02j,
        -0.01625925-9.16873523e-02j,  0.05138102+8.69098288e-02j],
       [ 0.13000652-4.88838726e-02j,  0.40206608-1.09833162e-15j,
        -0.11527996-2.70675649e-01j,  0.22574575+2.17730535e-01j],
       [-0.01625925+9.16873523e-02j, -0.11527996+2.70675649e-01j,
         0.25781889-4.12806118e-17j, -0.24030144+1.02386914e-01j],
       [ 0.05138102-8.69098288e-02j,  0.22574575-2.17730535e-01j,
        -0.24030144-1.02386914e-01j,  0.27781247-2.13210476e-15j]]), array([[ 0.14041792-1.93807008e-16j,  0.17848708+1.49983482e-01j,
        -0.08636705+6.75477147e-02j,  0.09989801+1.21708471e-01j],
       [ 0.17848708-1.49983482e-01j,  0.5159454 +6.05240454e-16j,
        -0.02938942+1.93996600e-01j,  0.29912612+8.52084652e-02j],
       [-0.08636705-6.75477147e-02j, -0.02938942-1.93996600e-01j,
         0.11508943-4.96074922e-17j, -0.00678145-1.32300578e-01j],
       [ 0.09989801-1.21708471e-01j,  0.29912612-8.52084652e-02j,
        -0.00678145+1.32300578e-01j,  0.22854725+3.52555985e-16j]]), array([[ 0.10248467-1.57369874e-15j,  0.08745266-6.54885320e-02j,
        -0.10345795+1.66767350e-02j,  0.18617941+2.77918302e-02j],
       [ 0.08745266+6.54885320e-02j,  0.36138977-1.07385510e-13j,
        -0.04987169-8.52013504e-02j,  0.20815823+2.53418615e-01j],
       [-0.10345795-1.66767350e-02j, -0.04987169+8.52013504e-02j,
         0.12170146+1.79021974e-14j, -0.1851723 -2.70852829e-02j],
       [ 0.18617941-2.77918302e-02j,  0.20815823-2.53418615e-01j,
        -0.1851723 +2.70852829e-02j,  0.4144241 -8.07535002e-14j]]), array([[ 0.34488877+1.48478708e-12j, -0.12731486+2.83128562e-01j,
         0.06030433-1.91581516e-01j,  0.07053053+5.31886474e-02j],
       [-0.12731486-2.83128562e-01j,  0.29892292+9.69296106e-13j,
        -0.21413607+2.24783317e-02j,  0.03388866-1.30049666e-01j],
       [ 0.06030433+1.91581516e-01j, -0.21413607-2.24783317e-02j,
         0.17847805+7.28692636e-14j, -0.04948015+1.40658756e-01j],
       [ 0.07053053-5.31886474e-02j,  0.03388866+1.30049666e-01j,
        -0.04948015-1.40658756e-01j,  0.17771025+3.29198421e-13j]]), array([[ 0.0842097 -1.24921500e-17j, -0.03004057+9.69453725e-02j,
         0.02145618-8.89121002e-02j,  0.10482029+7.94794468e-02j],
       [-0.03004057-9.69453725e-02j,  0.17674134+1.13414125e-15j,
        -0.17819026-7.74436069e-03j,  0.12454005-2.48033425e-01j],
       [ 0.02145618+8.89121002e-02j, -0.17819026+7.74436069e-03j,
         0.20813084-3.62842689e-16j, -0.12627264+2.98509765e-01j],
       [ 0.10482029-7.94794468e-02j,  0.12454005+2.48033425e-01j,
        -0.12627264-2.98509765e-01j,  0.53091811-2.08994224e-16j]]), array([[ 3.98271182e-01+9.72110080e-16j, -3.60932297e-01+2.08902649e-01j,
        -2.52701322e-04-1.46126031e-01j,  4.38608496e-02+1.17325960e-01j],
       [-3.60932297e-01-2.08902649e-01j,  4.56921158e-01+6.03384361e-16j,
        -8.05612109e-02+1.37567426e-01j,  3.43109901e-02-1.34859525e-01j],
       [-2.52701322e-04+1.46126031e-01j, -8.05612109e-02-1.37567426e-01j,
         6.39652944e-02-2.93816994e-16j, -4.92893784e-02+1.54614909e-02j],
       [ 4.38608496e-02-1.17325960e-01j,  3.43109901e-02+1.34859525e-01j,
        -4.92893784e-02-1.54614909e-02j,  8.08423657e-02-3.63818360e-17j]]), array([[ 0.16931529-2.60695543e-15j, -0.15267181+1.35089571e-01j,
        -0.01791039-7.13519433e-02j,  0.14548276+2.18491139e-01j],
       [-0.15267181-1.35089571e-01j,  0.25960152+1.79003592e-16j,
        -0.04523557+7.93232314e-02j,  0.07649534-3.31396064e-01j],
       [-0.01791039+7.13519433e-02j, -0.04523557-7.93232314e-02j,
         0.03531542+9.29187259e-16j, -0.12070595+4.46916443e-02j],
       [ 0.14548276-2.18491139e-01j,  0.07649534+3.31396064e-01j,
        -0.12070595-4.46916443e-02j,  0.53576777+1.54288759e-14j]]), array([[ 0.61657796-4.58601164e-16j,  0.09435777+2.82862856e-01j,
        -0.13628192-1.38775242e-01j,  0.20896007+2.86679343e-03j],
       [ 0.09435777-2.82862856e-01j,  0.16774007-4.24289681e-16j,
        -0.10298362+2.79081921e-02j,  0.04515514-1.08271497e-01j],
       [-0.13628192+1.38775242e-01j, -0.10298362-2.79081921e-02j,
         0.11185322-3.93172443e-16j, -0.05054891+7.78919144e-02j],
       [ 0.20896007-2.86679343e-03j,  0.04515514+1.08271497e-01j,
        -0.05054891-7.78919144e-02j,  0.10382876-8.16096998e-17j]]), array([[ 0.33938114+1.48464704e-15j,  0.14520315+7.06152787e-02j,
        -0.16676472-1.70222263e-01j,  0.30430031-7.88835789e-02j],
       [ 0.14520315-7.06152787e-02j,  0.10741324+1.16476070e-15j,
        -0.12319489-6.34594022e-02j,  0.14500057-1.16098155e-01j],
       [-0.16676472+1.70222263e-01j, -0.12319489+6.34594022e-02j,
         0.20667087+3.31847502e-15j, -0.11181971+2.33819354e-01j],
       [ 0.30430031+7.88835789e-02j,  0.14500057+1.16098155e-01j,
        -0.11181971-2.33819354e-01j,  0.34653474+9.45057278e-16j]]), array([[ 0.53134564+1.94102905e-15j, -0.12119472+2.70173426e-01j,
        -0.1276129 +4.04331395e-02j,  0.18920903+2.18664709e-01j],
       [-0.12119472-2.70173426e-01j,  0.21972302+5.53556975e-17j,
         0.04461953+7.26781283e-02j,  0.09558326-1.43934118e-01j],
       [-0.1276129 -4.04331395e-02j,  0.04461953-7.26781283e-02j,
         0.05645551+1.00294682e-16j, -0.03130795-7.83359403e-02j],
       [ 0.18920903-2.18664709e-01j,  0.09558326+1.43934118e-01j,
        -0.03130795+7.83359403e-02j,  0.19247584-6.60590792e-17j]]), array([[ 0.40570198-3.36829995e-13j,  0.03218422+1.42518465e-02j,
        -0.13089718-3.50619719e-02j,  0.42181325+3.83128633e-03j],
       [ 0.03218422-1.42518465e-02j,  0.04085933-9.99867024e-15j,
        -0.01656664-1.05776585e-02j,  0.07700859-3.82552489e-02j],
       [-0.13089718+3.50619719e-02j, -0.01656664+1.05776585e-02j,
         0.05000071+1.31738546e-14j, -0.13433283+5.25745012e-02j],
       [ 0.42181325-3.83128633e-03j,  0.07700859+3.82552489e-02j,
        -0.13433283-5.25745012e-02j,  0.50343798-5.08147395e-13j]]), array([[ 0.15663961-5.54358364e-16j,  0.03917864+2.59130311e-01j,
        -0.09498712-1.12279221e-01j,  0.03485969-1.77379094e-02j],
       [ 0.03917864-2.59130311e-01j,  0.47998181-1.13830741e-14j,
        -0.26870532+1.57214993e-01j,  0.01433166-1.12689982e-01j],
       [-0.09498712+1.12279221e-01j, -0.26870532-1.57214993e-01j,
         0.25033624-5.38972430e-15j, -0.10021256+8.87520308e-02j],
       [ 0.03485969+1.77379094e-02j,  0.01433166+1.12689982e-01j,
        -0.10021256-8.87520308e-02j,  0.11304233+3.50735238e-16j]]), array([[ 0.03769267-1.22099363e-16j,  0.03836812+4.00243710e-02j,
        -0.07931579+1.20581093e-02j,  0.0540762 -5.46022992e-02j],
       [ 0.03836812-4.00243710e-02j,  0.1406948 -7.78903885e-16j,
        -0.16261348+1.18174433e-01j,  0.07654796-1.71388929e-01j],
       [-0.07931579-1.20581093e-02j, -0.16261348-1.18174433e-01j,
         0.40027278-1.95060781e-15j, -0.34847588+1.96556416e-01j],
       [ 0.0540762 +5.46022992e-02j,  0.07654796+1.71388929e-01j,
        -0.34847588-1.96556416e-01j,  0.42133976+1.11197849e-15j]]), array([[ 0.11465398-2.29991407e-16j, -0.13034321+1.97345987e-01j,
        -0.09339572-8.08927465e-02j,  0.07282594+5.72089948e-02j],
       [-0.13034321-1.97345987e-01j,  0.59780985+2.31255231e-15j,
        -0.07936661+3.13811459e-01j,  0.04620882-2.00667614e-01j],
       [-0.09339572+8.08927465e-02j, -0.07936661-3.13811459e-01j,
         0.19512119+1.04001018e-15j, -0.12064383-1.05677664e-02j],
       [ 0.07282594-5.72089948e-02j,  0.04620882+2.00667614e-01j,
        -0.12064383+1.05677664e-02j,  0.09241498+6.79995095e-16j]]), array([[ 0.06249086-1.52015670e-16j, -0.03433052+9.50169657e-02j,
        -0.10745455-2.58779520e-02j,  0.14998662+6.06885360e-02j],
       [-0.03433052-9.50169657e-02j,  0.22796314+2.47058488e-15j,
        -0.0045782 +2.13913450e-01j,  0.03731101-3.01395869e-01j],
       [-0.10745455+2.58779520e-02j, -0.0045782 -2.13913450e-01j,
         0.23530383-9.95350948e-16j, -0.32534417-4.56454131e-02j],
       [ 0.14998662-6.06885360e-02j,  0.03731101+3.01395869e-01j,
        -0.32534417+4.56454131e-02j,  0.47424218-1.83866050e-15j]]), array([[ 0.3891265 -6.98329600e-16j,  0.23861467+2.44388458e-01j,
        -0.27289573+3.38212879e-02j,  0.11393354-3.31169221e-02j],
       [ 0.23861467-2.44388458e-01j,  0.32043323+1.45830332e-15j,
        -0.15185174+1.80466795e-01j,  0.05730471-8.59943991e-02j],
       [-0.27289573-3.38212879e-02j, -0.15185174-1.80466795e-01j,
         0.23252849+4.29846284e-16j, -0.10096126+2.52847717e-02j],
       [ 0.11393354+3.31169221e-02j,  0.05730471+8.59943991e-02j,
        -0.10096126-2.52847717e-02j,  0.05791178-2.07747675e-17j]]), array([[ 0.18648997+4.47028260e-14j,  0.11952763+4.03379621e-02j,
        -0.22108987+1.45593649e-02j,  0.14868559-6.43500214e-02j],
       [ 0.11952763-4.03379621e-02j,  0.16947952+1.83942269e-13j,
        -0.12918803-4.93455476e-02j,  0.1302143 +6.40498738e-03j],
       [-0.22108987-1.45593649e-02j, -0.12918803+4.93455476e-02j,
         0.39917256+7.16986508e-13j, -0.276924  +1.35407255e-01j],
       [ 0.14868559+6.43500214e-02j,  0.1302143 -6.40498737e-03j,
        -0.276924  -1.35407255e-01j,  0.24485795+8.03109030e-13j]]), array([[ 0.28558021+5.52106541e-16j,  0.08723864+2.12855263e-01j,
        -0.23767736+1.13358077e-01j,  0.21083068+8.15711976e-02j],
       [ 0.08723864-2.12855263e-01j,  0.24349265-3.85056957e-16j,
        -0.00576436+2.35488211e-01j,  0.1417701 -1.32364695e-01j],
       [-0.23767736-1.13358077e-01j, -0.00576436-2.35488211e-01j,
         0.27390249+6.99037667e-16j, -0.15221953-1.61575296e-01j],
       [ 0.21083068-8.15711976e-02j,  0.1417701 +1.32364695e-01j,
        -0.15221953+1.61575296e-01j,  0.19702466+8.36830349e-16j]]), array([[ 0.25283005-1.69515054e-15j,  0.05766822+1.55367608e-02j,
        -0.24608238+7.87951177e-02j,  0.31806976-5.11189817e-03j],
       [ 0.05766822-1.55367608e-02j,  0.05440641+1.70952250e-16j,
        -0.04825722+2.55060216e-02j,  0.08778093-5.06398872e-03j],
       [-0.24608238-7.87951177e-02j, -0.04825722-2.55060216e-02j,
         0.27186199-4.31823993e-15j, -0.31696979-9.05317216e-02j],
       [ 0.31806976+5.11189817e-03j,  0.08778093+5.06398872e-03j,
        -0.31696979+9.05317216e-02j,  0.42090154-1.90412054e-15j]])]

# %% [markdown]
# ## Decoding with Projective Measurements
#
# The decoding is performed by measuring the encoding states with the POVMs defined as below. The `decoding[j]` is a positive semidefinite matrix which representes the POVM used to decode the `j`-th bit from the encoding state.

# %%
decoding = [array([[ 0.56511925+1.80589027e-09j,  0.06408139-2.65317867e-01j,
         0.25632532+2.27331433e-01j,  0.0058657 -2.31499800e-01j],
       [ 0.06408139+2.65317871e-01j,  0.64136922-1.28780905e-09j,
        -0.09698309-2.42182676e-01j, -0.05597357-2.90111279e-01j],
       [ 0.25632532-2.27331439e-01j, -0.09698309+2.42182677e-01j,
         0.50436918-9.32390273e-10j,  0.11895617-2.23269831e-01j],
       [ 0.0058657 +2.31499797e-01j, -0.05597357+2.90111272e-01j,
         0.11895617+2.23269828e-01j,  0.28821116-6.71144104e-10j]]), array([[ 0.44992402+5.91329463e-12j,  0.08884955-2.67223097e-01j,
        -0.04415954-2.30473764e-01j, -0.07423909+3.25530019e-01j],
       [ 0.08884955+2.67223097e-01j,  0.24716704+1.33027064e-11j,
         0.0316127 +1.29658274e-01j, -0.27115046+1.17729924e-01j],
       [-0.04415954+2.30473764e-01j,  0.0316127 -1.29658274e-01j,
         0.8592538 +1.27993762e-11j,  0.21622322-2.56804165e-02j],
       [-0.07423909-3.25530019e-01j, -0.27115046-1.17729924e-01j,
         0.21622322+2.56804165e-02j,  0.44314769-7.78365698e-12j]]), array([[ 0.20496743-1.26825862e-12j, -0.07056618+2.18123930e-01j,
        -0.03125375+2.02404229e-02j, -0.05079752-3.25135251e-01j],
       [-0.07056618-2.18123930e-01j,  0.44083198-1.45694988e-11j,
         0.35544081-1.22644404e-01j, -0.21221934+6.85288884e-02j],
       [-0.03125375-2.02404229e-02j,  0.35544081+1.22644404e-01j,
         0.693306  -2.93610708e-11j,  0.25816589-2.22769789e-02j],
       [-0.05079752+3.25135251e-01j, -0.21221934-6.85288885e-02j,
         0.25816589+2.22769789e-02j,  0.65323718-8.94425157e-12j]]), array([[ 0.49888285-1.19481326e-10j,  0.25128533-6.86650373e-02j,
         0.251052  -2.03259031e-01j, -0.27393499-2.84475153e-02j],
       [ 0.25128533+6.86650372e-02j,  0.62018411-1.72369868e-12j,
         0.20824423+7.90178841e-03j,  0.27174511+2.23398160e-01j],
       [ 0.251052  +2.03259031e-01j,  0.20824423-7.90178845e-03j,
         0.24108408-6.13526080e-12j, -0.03724868-1.62529202e-01j],
       [-0.27393499+2.84475155e-02j,  0.27174511-2.23398160e-01j,
        -0.03724868+1.62529203e-01j,  0.6499121 +1.35894181e-11j]]), array([[ 0.91432998+2.06935254e-11j, -0.22298893-2.01895254e-04j,
         0.03578453-1.59592925e-01j, -0.0009792 +3.75560719e-02j],
       [-0.22298893+2.01895213e-04j,  0.13416923+3.31081319e-11j,
         0.06607989-7.62377792e-02j,  0.20871936-1.09119068e-01j],
       [ 0.03578453+1.59592926e-01j,  0.06607989+7.62377793e-02j,
         0.28199853+8.95041808e-11j,  0.33602245+2.17810870e-01j],
       [-0.0009792 -3.75560719e-02j,  0.20871936+1.09119068e-01j,
         0.33602245-2.17810869e-01j,  0.67731542+2.70042367e-10j]]), array([[ 0.25660391+4.67241692e-12j, -0.21017811+3.40898457e-03j,
         0.24014789-1.30197739e-01j, -0.21060563-1.45510600e-01j],
       [-0.21017811-3.40898458e-03j,  0.52626467+5.30989594e-12j,
        -0.30318048+2.23545354e-01j, -0.22449037-9.38354628e-02j],
       [ 0.24014789+1.30197739e-01j, -0.30318048-2.23545354e-01j,
         0.36253571-2.10522583e-12j, -0.07959498-4.51929050e-02j],
       [-0.21060563+1.45510600e-01j, -0.22449037+9.38354628e-02j,
        -0.07959498+4.51929050e-02j,  0.82772566+4.23587862e-11j]]), array([[ 0.63878412-5.29364464e-10j,  0.32094462+1.98874752e-01j,
         0.08237048-3.02785546e-02j, -0.27383634-5.97832215e-02j],
       [ 0.32094462-1.98874752e-01j,  0.3205516 -9.89716808e-11j,
        -0.18075179-1.83983195e-01j, -0.06585909-5.57900778e-02j],
       [ 0.08237048+3.02785548e-02j, -0.18075179+1.83983193e-01j,
         0.68703116+8.30851807e-10j, -0.06664792+3.54553607e-01j],
       [-0.27383634+5.97832207e-02j, -0.06585909+5.57900777e-02j,
        -0.06664792-3.54553608e-01j,  0.33332548+4.33648854e-11j]]), array([[ 0.77118028+1.96814805e-11j,  0.0284094 +3.31327299e-01j,
         0.2476933 +6.02470693e-02j,  0.02592874-1.28998819e-02j],
       [ 0.0284094 -3.31327299e-01j,  0.49586312-1.70015567e-11j,
        -0.10472638+3.10621483e-01j,  0.06856488+1.64722821e-01j],
       [ 0.2476933 -6.02470693e-02j, -0.10472638-3.10621483e-01j,
         0.62866444+3.57340439e-12j,  0.18585399-1.62428513e-01j],
       [ 0.02592874+1.28998819e-02j,  0.06856488-1.64722821e-01j,
         0.18585399+1.62428513e-01j,  0.10458147-2.05801408e-12j]])]

# %% [markdown]
# ## Exploring the success probabilities
#
# Now we can test the success probabilities of the newly-found $(8,2)$-QRACs.

# %%
# function to compute the success probability of observing zero
def get_prob_observe_zero(encoding, decoding):
    prob = np.abs(np.trace(np.dot(encoding, decoding))) #the probability of observing zero computed by trace
    return prob

probabilities = []
for i in range(len(decoding)):
    for j in range(len(encoding)):
        prob = get_prob_observe_zero(encoding[j], decoding[i])
        print('[Obtaining zero at {0}-th bit of {1} with. prob. {2}]'.format(format(i+1,'2'), format(j,'08b'), prob))
        probabilities.append(np.abs(prob - 1.0/2.0))
# Out:
# [Obtaining zero at  1-th bit of 00000000 with. prob. 0.6913811888242437]
# [Obtaining zero at  1-th bit of 00000001 with. prob. 0.6950505886026912]
# [Obtaining zero at  1-th bit of 00000010 with. prob. 0.6965813083353747]
# [Obtaining zero at  1-th bit of 00000011 with. prob. 0.6909532496036327]
# [Obtaining zero at  1-th bit of 00000100 with. prob. 0.704380618257736]
# [Obtaining zero at  1-th bit of 00000101 with. prob. 0.7242394226920454]
# [Obtaining zero at  1-th bit of 00000110 with. prob. 0.694430709594724]
# [Obtaining zero at  1-th bit of 00000111 with. prob. 0.6986683916383694]
# [Obtaining zero at  1-th bit of 00001000 with. prob. 0.6924603300164853]
# [Obtaining zero at  1-th bit of 00001001 with. prob. 0.7086505506577268]
# [Obtaining zero at  1-th bit of 00001010 with. prob. 0.6988552103818056]
# [Obtaining zero at  1-th bit of 00001011 with. prob. 0.6967476856575876]
# [Obtaining zero at  1-th bit of 00001100 with. prob. 0.6919413233241365]
# ...

# %% [markdown]
# ## Computing the worst case of the success probability

# %%
#QRAC success prob.
1/2 + np.min(probabilities)
# Out:
# 0.690950258952292

# %% [markdown]
# ## Computing the maximum success probability

# %%
#max success prob.
1/2 + np.max(probabilities)
# Out:
# 0.7982071013538582

# %% [markdown]
# ## Computing the average success probability

# %%
#min success prob
1/2 + np.mean(probabilities)
# Out:
# 0.704700143454131

# %% [markdown]
# # Quantum Random Access Coding for 9 bits with 2 qubits.
#
# We first import the libraries.

# %%
import numpy as np
from pprint import pprint
import math
from numpy import array

# %% [markdown]
# ## Encoding Quantum States
#
# We then give the encoding of quantum states for each bitstring $000000000$ to $111111111$ whose decimal representation is $0$ to $2^{10}-1$. The `encoding[j]` is the mixed state for encoding `j`-th bitstring.

# %%
encoding = [array([[ 0.06312388-4.78386891e-16j,  0.07820762-8.05578444e-03j,
        -0.11184163+7.22424821e-02j, -0.03879841+9.01368840e-02j],
       [ 0.07820762+8.05578444e-03j,  0.25086823+4.08671090e-16j,
        -0.10207093+1.04440969e-01j,  0.07947027+8.04484848e-02j],
       [-0.11184163-7.22424821e-02j, -0.10207093-1.04440969e-01j,
         0.34771737+1.56275764e-15j,  0.24911651-1.67151387e-01j],
       [-0.03879841-9.01368840e-02j,  0.07947027-8.04484848e-02j,
         0.24911651+1.67151387e-01j,  0.33829053+1.13975265e-15j]]), array([[ 0.12658363-2.64369327e-16j,  0.03400007+8.39011537e-04j,
        -0.16346841-2.31377058e-02j, -0.20940547-2.20729786e-02j],
       [ 0.03400007-8.39011537e-04j,  0.18096502+4.57993103e-16j,
        -0.10226638+8.90403211e-02j, -0.04399782+9.28155053e-03j],
       [-0.16346841+2.31377058e-02j, -0.10226638-8.90403211e-02j,
         0.30982679+1.57339468e-15j,  0.29527624-2.38293437e-02j],
       [-0.20940547+2.20729786e-02j, -0.04399782-9.28155053e-03j,
         0.29527624+2.38293437e-02j,  0.38262456-7.12923432e-17j]]), array([[ 0.08914106-2.12014341e-16j, -0.00081763+1.11212483e-01j,
        -0.10776061+3.28864198e-02j, -0.06580082+1.10929025e-01j],
       [-0.00081763-1.11212483e-01j,  0.33271786+1.47630361e-15j,
        -0.08401735+2.33426710e-01j,  0.23744655+1.16322238e-01j],
       [-0.10776061-3.28864198e-02j, -0.08401735-2.33426710e-01j,
         0.31447726-5.97688010e-16j,  0.08498017-1.86098825e-01j],
       [-0.06580082-1.10929025e-01j,  0.23744655-1.16322238e-01j,
         0.08498017+1.86098825e-01j,  0.26366382+1.27228140e-15j]]), array([[ 0.19500035+3.75136299e-15j, -0.05190286+1.02575755e-01j,
        -0.14608628-3.72172720e-02j, -0.22072815+2.28388694e-02j],
       [-0.05190286-1.02575755e-01j,  0.27015645+2.32298789e-15j,
        -0.08056445+2.25549042e-01j,  0.09476151+5.34920273e-02j],
       [-0.14608628+3.72172720e-02j, -0.08056445-2.25549042e-01j,
         0.26220498+4.17506353e-16j,  0.1106409 -4.76035657e-02j],
       [-0.22072815-2.28388694e-02j,  0.09476151-5.34920273e-02j,
         0.1106409 +4.76035657e-02j,  0.27263821+7.93729556e-15j]]), array([[ 0.13724416+4.02073530e-16j,  0.10204302+7.50621955e-02j,
        -0.10924336-2.89808286e-02j, -0.04789599+1.30825858e-01j],
       [ 0.10204302-7.50621955e-02j,  0.14442107+2.41435404e-16j,
        -0.08626804-1.63793446e-02j,  0.00290801+6.72789105e-02j],
       [-0.10924336+2.89808286e-02j, -0.08626804+1.63793446e-02j,
         0.29167103-1.17551554e-15j,  0.17404936-2.78385660e-01j],
       [-0.04789599-1.30825858e-01j,  0.00290801-6.72789105e-02j,
         0.17404936+2.78385660e-01j,  0.42666374+6.76077698e-15j]]), array([[ 0.24778733+4.25270943e-16j,  0.09285377+4.67178860e-02j,
        -0.15762683-1.50381958e-01j, -0.28292061+2.43377258e-02j],
       [ 0.09285377-4.67178860e-02j,  0.08396865-7.91027825e-17j,
        -0.09833178-3.06284966e-02j, -0.11552699+4.31637289e-02j],
       [-0.15762683+1.50381958e-01j, -0.09833178+3.06284966e-02j,
         0.24200445+3.02824054e-16j,  0.2021066 -2.09426321e-01j],
       [-0.28292061-2.43377258e-02j, -0.11552699-4.31637289e-02j,
         0.2021066 +2.09426321e-01j,  0.42623958+3.19571195e-16j]]), array([[ 0.20015037-6.37877552e-16j,  0.00679134+2.09548414e-01j,
        -0.09740636-7.24014507e-02j, -0.0729133 +1.84219433e-01j],
       [ 0.00679134-2.09548414e-01j,  0.24037064+4.26338908e-16j,
        -0.07800344+9.23431652e-02j,  0.189478  +7.54545619e-02j],
       [-0.09740636+7.24014507e-02j, -0.07800344-9.23431652e-02j,
         0.20701938-1.15708781e-16j,  0.01204292-2.41966566e-01j],
       [-0.0729133 -1.84219433e-01j,  0.189478  -7.54545619e-02j,
         0.01204292+2.41966566e-01j,  0.35245961+1.48062871e-15j]]), array([[ 0.32243475-1.48244389e-15j, -0.03814841+1.73088097e-01j,
        -0.12842177-1.88878554e-01j, -0.26762428+8.08863658e-02j],
       [-0.03814841-1.73088097e-01j,  0.16092158+1.78070627e-16j,
        -0.08562519+1.17779781e-01j,  0.08191403+7.75424593e-02j],
       [-0.12842177+1.88878554e-01j, -0.08562519-1.17779781e-01j,
         0.18800654-1.41507454e-16j,  0.0351035 -2.00930781e-01j],
       [-0.26762428-8.08863658e-02j,  0.08191403-7.75424593e-02j,
         0.0351035 +2.00930781e-01j,  0.32863713-6.71551439e-16j]]), array([[ 0.00774538-7.97327529e-17j, -0.01902234-2.61913278e-02j,
        -0.02008538+1.50835375e-02j, -0.01372444+9.13635039e-03j],
       [-0.01902234+2.61913278e-02j,  0.36384391+2.50382755e-17j,
        -0.16425729-3.71797811e-02j, -0.00644282+1.90568851e-03j],
       [-0.02008538-1.50835375e-02j, -0.16425729+3.71797811e-02j,
         0.46815346-3.60849281e-16j,  0.21879429-1.19985157e-01j],
       [-0.01372444-9.13635039e-03j, -0.00644282-1.90568851e-03j,
         0.21879429+1.19985157e-01j,  0.16025726-9.98285426e-16j]]), array([[ 0.08381644-2.15283981e-16j, -0.0562568 -4.06023603e-02j,
        -0.0449383 -1.09115573e-01j, -0.07565772-3.18299408e-02j],
       [-0.0562568 +4.06023603e-02j,  0.30547182+2.31079141e-15j,
        -0.16079928+1.09831565e-01j, -0.08891713-2.87161381e-02j],
       [-0.0449383 +1.09115573e-01j, -0.16079928-1.09831565e-01j,
         0.42791595-5.12894811e-16j,  0.23594599-3.28875698e-02j],
       [-0.07565772+3.18299408e-02j, -0.08891713+2.87161381e-02j,
         0.23594599+3.28875698e-02j,  0.18279579-2.35596380e-15j]]), array([[ 0.03964979+9.73095767e-16j, -0.09150189+6.90141992e-02j,
        -0.00133542-7.94439226e-03j, -0.03073501+2.69243768e-02j],
       [-0.09150189-6.90141992e-02j,  0.39728128-7.93680794e-17j,
        -0.14483306+1.04848732e-01j,  0.13378549+4.04542191e-02j],
       [-0.00133542+7.94439226e-03j, -0.14483306-1.04848732e-01j,
         0.46962855+5.87586878e-15j,  0.04278328-1.50241647e-01j],
       [-0.03073501-2.69243768e-02j,  0.13378549-4.04542191e-02j,
         0.04278328+1.50241647e-01j,  0.09344038+9.28449599e-17j]]), array([[ 0.10930104+4.92434736e-17j, -0.14837183+5.68279779e-02j,
        -0.02046853-1.67784196e-01j, -0.06786729+9.06171743e-04j],
       [-0.14837183-5.68279779e-02j,  0.36544136+3.38059071e-16j,
        -0.15376932+3.28931438e-01j,  0.07607244+3.27418245e-02j],
       [-0.02046853+1.67784196e-01j, -0.15376932-3.28931438e-01j,
         0.45213783-1.17318295e-15j,  0.04159939-9.58812627e-02j],
       [-0.06786729-9.06171743e-04j,  0.07607244-3.27418245e-02j,
         0.04159939+9.58812627e-02j,  0.07311977+2.13451303e-17j]]), array([[ 0.03813123+4.47513963e-17j,  0.02979656+3.36692385e-02j,
        -0.02839592-6.64571699e-02j, -0.04191098+9.25939056e-03j],
       [ 0.02979656-3.36692385e-02j,  0.19723439+1.03208073e-15j,
        -0.16433735-1.90151998e-01j, -0.14737622+1.00112865e-02j],
       [-0.02839592+6.64571699e-02j, -0.16433735+1.90151998e-01j,
         0.50025157-2.06003337e-16j,  0.16913   -2.88768442e-01j],
       [-0.04191098-9.25939056e-03j, -0.14737622-1.00112865e-02j,
         0.16913   +2.88768442e-01j,  0.26438282+2.89658904e-16j]]), array([[ 0.17305587+3.46114573e-16j, -0.01325298+3.22776378e-02j,
        -0.02787662-2.19620016e-01j, -0.11776176-1.50246773e-02j],
       [-0.01325298-3.22776378e-02j,  0.20026202+8.34163189e-16j,
        -0.15409414-3.59907577e-02j, -0.15158227-4.48087325e-02j],
       [-0.02787662+2.19620016e-01j, -0.15409414+3.59907577e-02j,
         0.38196198-8.07489303e-16j,  0.15619243-1.58270675e-01j],
       [-0.11776176+1.50246773e-02j, -0.15158227+4.48087325e-02j,
         0.15619243+1.58270675e-01j,  0.24472013+3.36647346e-16j]]), array([[ 0.11753175-2.99604108e-15j, -0.07017122+1.66938084e-01j,
         0.01244325-9.97990481e-02j, -0.03932213+5.78509222e-02j],
       [-0.07017122-1.66938084e-01j,  0.29844383-5.21057567e-16j,
        -0.13948402-3.16657554e-02j,  0.05956312+6.68623364e-03j],
       [ 0.01244325+9.97990481e-02j, -0.13948402+3.16657554e-02j,
         0.40501478+5.33044210e-15j, -0.01916105-2.32935051e-01j],
       [-0.03932213-5.78509222e-02j,  0.05956312-6.68623364e-03j,
        -0.01916105+2.32935051e-01j,  0.17900964-4.77646300e-15j]]), array([[ 0.23720013+5.18932402e-16j, -0.12135512+1.55629249e-01j,
        -0.01138984-2.68884613e-01j, -0.11393618+2.73391427e-02j],
       [-0.12135512-1.55629249e-01j,  0.27086114+6.98485018e-17j,
        -0.16463242+1.24733581e-01j,  0.01860457-1.03012469e-03j],
       [-0.01138984+2.68884613e-01j, -0.16463242-1.24733581e-01j,
         0.33770768+6.24457179e-16j, -0.01586522-1.62012801e-01j],
       [-0.11393618-2.73391427e-02j,  0.01860457+1.03012469e-03j,
        -0.01586522+1.62012801e-01j,  0.15423106+1.43481371e-16j]]), array([[ 0.23183203-8.61247564e-16j,  0.08894361+2.21088252e-03j,
        -0.16235022+2.26125334e-01j, -0.03893022+1.79413742e-01j],
       [ 0.08894361-2.21088252e-03j,  0.07214431-1.38717513e-16j,
        -0.05173297+5.96956184e-02j,  0.00674221+5.56494512e-02j],
       [-0.16235022-2.26125334e-01j, -0.05173297-5.96956184e-02j,
         0.47939124+7.48510010e-16j,  0.27710685-7.29184274e-02j],
       [-0.03893022-1.79413742e-01j,  0.00674221-5.56494512e-02j,
         0.27710685+7.29184274e-02j,  0.21663242+8.27948329e-16j]]), array([[ 0.30893026-5.52160496e-16j,  0.05706038-8.91059116e-03j,
        -0.23331228+6.91312583e-02j, -0.21540781+4.34952516e-02j],
       [ 0.05706038+8.91059116e-03j,  0.0323401 -3.46009910e-17j,
        -0.06887935+3.91414376e-02j, -0.06222952+1.02634720e-02j],
       [-0.23331228-6.91312583e-02j, -0.06887935-3.91414376e-02j,
         0.41399185+7.71439679e-17j,  0.27967883+7.82509357e-02j],
       [-0.21540781-4.34952516e-02j, -0.06222952-1.02634720e-02j,
         0.27967883-7.82509357e-02j,  0.2447378 -4.23155535e-16j]]), array([[ 0.25391715+3.72389343e-15j,  0.0132133 +1.31429785e-01j,
        -0.14007551+1.95492038e-01j, -0.08289187+1.56259645e-01j],
       [ 0.0132133 -1.31429785e-01j,  0.14948191+2.97394713e-16j,
        -0.02776403+1.05629662e-01j,  0.12748222+4.85641085e-02j],
       [-0.14007551-1.95492038e-01j, -0.02776403-1.05629662e-01j,
         0.43621488-5.85397365e-16j,  0.08761607-3.21719747e-02j],
       [-0.08289187-1.56259645e-01j,  0.12748222-4.85641085e-02j,
         0.08761607+3.21719747e-02j,  0.16038605+9.45820014e-16j]]), array([[ 0.35307734-1.67376420e-14j, -0.03428853+1.14903226e-01j,
        -0.19672211+7.03559851e-02j, -0.2185022 +7.11807006e-02j],
       [-0.03428853-1.14903226e-01j,  0.10191588+2.31423790e-15j,
        -0.0390957 +1.50246100e-01j,  0.03439953+3.44158975e-02j],
       [-0.19672211-7.03559851e-02j, -0.0390957 -1.50246100e-01j,
         0.37764048-7.49637387e-15j,  0.1037509 +5.98325299e-02j],
       [-0.2185022 -7.11807006e-02j,  0.03439953-3.44158975e-02j,
         0.1037509 -5.98325299e-02j,  0.1673663 -4.69015320e-15j]]), array([[ 0.3749587 +6.72668174e-15j,  0.11774401+7.40198530e-02j,
        -0.11926946+1.78140251e-02j,  0.00716874+2.44131600e-01j],
       [ 0.11774401-7.40198530e-02j,  0.07277686+1.54156379e-15j,
        -0.05579164-3.80181092e-02j,  0.02231803+4.55425266e-02j],
       [-0.11926946-1.78140251e-02j, -0.05579164+3.80181092e-02j,
         0.30144142+2.26276027e-18j,  0.14681752-1.44136137e-01j],
       [ 0.00716874-2.44131600e-01j,  0.02231803-4.55425266e-02j,
         0.14681752+1.44136137e-01j,  0.25082302+2.55645903e-15j]]), array([[ 0.5121875 -3.74527543e-15j,  0.1055806 +2.74549086e-02j,
        -0.15896925-1.16065459e-01j, -0.19595951+1.59630455e-01j],
       [ 0.1055806 -2.74549086e-02j,  0.03406657-1.31082225e-16j,
        -0.0697983 -1.81413085e-02j, -0.05364044+4.06280183e-02j],
       [-0.15896925+1.16065459e-01j, -0.0697983 +1.81413085e-02j,
         0.24163626+4.85313375e-16j,  0.13871579-8.97803980e-02j],
       [-0.19595951-1.59630455e-01j, -0.05364044-4.06280183e-02j,
         0.13871579+8.97803980e-02j,  0.21210968+1.41497804e-15j]]), array([[ 0.42752927+1.12917816e-15j,  0.01881628+2.33480101e-01j,
        -0.11494952+2.64333066e-02j, -0.02729748+2.86135610e-01j],
       [ 0.01881628-2.33480101e-01j,  0.1477951 -4.81784207e-16j,
        -0.03228033+4.07731562e-02j,  0.15649439+3.12215921e-02j],
       [-0.11494952-2.64333066e-02j, -0.03228033-4.07731562e-02j,
         0.22183613+1.23849481e-16j,  0.02042445-8.96344637e-02j],
       [-0.02729748-2.86135610e-01j,  0.15649439-3.12215921e-02j,
         0.02042445+8.96344637e-02j,  0.20283949+1.28724750e-16j]]), array([[ 0.58446049-2.30596638e-16j, -0.00670822+1.98634707e-01j,
        -0.16460528-1.45464051e-01j, -0.19246464+1.94858767e-01j],
       [-0.00670822-1.98634707e-01j,  0.08683468-1.59216251e-16j,
        -0.06746356+7.74295526e-02j,  0.06519674+5.42050955e-02j],
       [-0.16460528+1.45464051e-01j, -0.06746356-7.74295526e-02j,
         0.17573591+5.11326821e-16j, -0.00337349-7.64716474e-02j],
       [-0.19246464-1.94858767e-01j,  0.06519674-5.42050955e-02j,
        -0.00337349+7.64716474e-02j,  0.15296893-1.06097070e-15j]]), array([[ 0.06401341+2.65111173e-18j, -0.00674613-2.95382197e-02j,
        -0.05639015+9.24482104e-02j, -0.01601267+4.26964958e-02j],
       [-0.00674613+2.95382197e-02j,  0.09637641-5.26864809e-17j,
        -0.10687212-1.44161857e-01j, -0.02699456-4.53841685e-02j],
       [-0.05639015-9.24482104e-02j, -0.10687212+1.44161857e-01j,
         0.72830699+1.96871815e-16j,  0.23568773+4.44086740e-03j],
       [-0.01601267-4.26964958e-02j, -0.02699456+4.53841685e-02j,
         0.23568773-4.44086740e-03j,  0.11130319+1.42950169e-17j]]), array([[ 0.18686608-4.84655968e-16j, -0.03566914-5.18139947e-02j,
        -0.09372679-1.08902206e-01j, -0.06318731+6.44301613e-03j],
       [-0.03566914+5.18139947e-02j,  0.07865209+9.63143644e-17j,
        -0.09579936+4.87221731e-02j, -0.05744643-3.40381075e-02j],
       [-0.09372679+1.08902206e-01j, -0.09579936-4.87221731e-02j,
         0.60779068+5.69948657e-16j,  0.21340469+7.53202035e-02j],
       [-0.06318731-6.44301613e-03j, -0.05744643+3.40381075e-02j,
         0.21340469-7.53202035e-02j,  0.12669115+4.28044128e-17j]]), array([[ 0.10149031-2.46149542e-16j, -0.04892808+5.83314739e-02j,
        -0.03000623+1.05133878e-01j, -0.02574038+4.66437226e-02j],
       [-0.04892808-5.83314739e-02j,  0.12203569-1.03225419e-16j,
        -0.07392409+5.45686686e-02j,  0.06618379+8.19392840e-03j],
       [-0.03000623-1.05133878e-01j, -0.07392409-5.45686686e-02j,
         0.72435325-6.74259206e-16j,  0.01859959-7.40622981e-02j],
       [-0.02574038-4.66437226e-02j,  0.06618379-8.19392840e-03j,
         0.01859959+7.40622981e-02j,  0.05212075+8.71739436e-17j]]), array([[ 0.21069871+5.94332687e-16j, -0.11002553+4.17888469e-02j,
        -0.06566765-7.68902687e-02j, -0.08332347+3.83214074e-02j],
       [-0.11002553-4.17888469e-02j,  0.12021031-2.78592751e-16j,
        -0.06255254+1.96785225e-01j,  0.02937606-8.30819723e-03j],
       [-0.06566765+7.68902687e-02j, -0.06255254-1.96785225e-01j,
         0.61278703-2.06090355e-15j,  0.0372565 +3.17357303e-02j],
       [-0.08332347-3.83214074e-02j,  0.02937606+8.30819723e-03j,
         0.0372565 -3.17357303e-02j,  0.05630395+7.64750827e-18j]]), array([[ 0.23321965+5.00658688e-17j,  0.03162797+3.25972153e-02j,
        -0.02944355-7.27965984e-02j,  0.01919834+1.28793534e-01j],
       [ 0.03162797-3.25972153e-02j,  0.08066948-1.91259166e-15j,
        -0.09179468-1.74389570e-01j, -0.04316149-1.50600738e-02j],
       [-0.02944355+7.27965984e-02j, -0.09179468+1.74389570e-01j,
         0.53539381+1.68726197e-15j,  0.10381789-1.34883859e-01j],
       [ 0.01919834-1.28793534e-01j, -0.04316149+1.50600738e-02j,
         0.10381789+1.34883859e-01j,  0.15071706-7.29363375e-17j]]), array([[ 0.35419662-5.20621043e-16j,  0.00930684-9.14888801e-03j,
        -0.04931712-2.62351801e-01j, -0.07685787+8.63339807e-02j],
       [ 0.00930684+9.14888801e-03j,  0.04714856+2.64679643e-16j,
        -0.09402501-4.48551874e-02j, -0.06166215-2.13926779e-02j],
       [-0.04931712+2.62351801e-01j, -0.09402501+4.48551874e-02j,
         0.46958761-1.92424752e-15j,  0.09762614-6.85080851e-02j],
       [-0.07685787-8.63339807e-02j, -0.06166215+2.13926779e-02j,
         0.09762614+6.85080851e-02j,  0.12906721+2.57972104e-16j]]), array([[ 0.25822826-1.97427271e-13j, -0.05262381+1.57912044e-01j,
        -0.0112133 -5.72604142e-02j, -0.00477833+1.37828913e-01j],
       [-0.05262381-1.57912044e-01j,  0.12475243-3.11457440e-14j,
        -0.07549862-6.48883356e-02j,  0.06759947-1.32922841e-02j],
       [-0.0112133 +5.72604142e-02j, -0.07549862+6.48883356e-02j,
         0.51733932+1.60965215e-13j, -0.04384781-1.20729512e-01j],
       [-0.00477833-1.37828913e-01j,  0.06759947+1.32922841e-02j,
        -0.04384781+1.20729512e-01j,  0.09967999+1.82234731e-13j]]), array([[ 0.40361147-7.57052822e-16j, -0.10419181+1.25230281e-01j,
        -0.03392402-3.08559760e-01j, -0.06923148+1.15641151e-01j],
       [-0.10419181-1.25230281e-01j,  0.0843051 -1.66073022e-16j,
        -0.10475036+9.64330881e-02j,  0.05272441-1.00461649e-02j],
       [-0.03392402+3.08559760e-01j, -0.10475036-9.64330881e-02j,
         0.44878425+5.30981523e-16j, -0.06776353-6.04648337e-02j],
       [-0.06923148-1.15641151e-01j,  0.05272441+1.00461649e-02j,
        -0.06776353+6.04648337e-02j,  0.06329918-1.38201976e-16j]]), array([[0.05063488+6.13262743e-17j, 0.06629871+2.03666464e-02j,
        0.03321483+3.94943577e-02j, 0.04302013+4.91822796e-02j],
       [0.06629871-2.03666464e-02j, 0.25516393-1.51065643e-16j,
        0.07006702+1.68037369e-01j, 0.15713287+2.11262703e-01j],
       [0.03321483-3.94943577e-02j, 0.07006702-1.68037369e-01j,
        0.27542556+1.16385496e-16j, 0.30207593-8.46840394e-02j],
       [0.04302013-4.91822796e-02j, 0.15713287-2.11262703e-01j,
        0.30207593+8.46840394e-02j, 0.41877564+4.33101994e-16j]]), array([[ 0.1142216 +1.85751797e-16j, -0.01839071+5.21687965e-02j,
        -0.07847409-8.35573689e-02j, -0.11209576-1.25072849e-01j],
       [-0.01839071-5.21687965e-02j,  0.13329247-1.36530705e-16j,
         0.01131151+1.48151990e-01j, -0.01123331+1.90271563e-01j],
       [-0.07847409+8.35573689e-02j,  0.01131151-1.48151990e-01j,
         0.27927476+1.14029537e-16j,  0.34216824+2.71857250e-02j],
       [-0.11209576+1.25072849e-01j, -0.01123331-1.90271563e-01j,
         0.34216824-2.71857250e-02j,  0.47321117+3.35922317e-16j]]), array([[ 0.14010928+2.44838487e-17j, -0.0524538 +1.98176538e-01j,
        -0.0259292 +5.52190030e-02j, -0.12854678+8.02911116e-02j],
       [-0.0524538 -1.98176538e-01j,  0.41166414+1.82572718e-15j,
         0.10976398+9.20792967e-02j,  0.24186034+2.29281639e-01j],
       [-0.0259292 -5.52190030e-02j,  0.10976398-9.20792967e-02j,
         0.13277565+1.36413951e-16j,  0.14740459-1.56447710e-02j],
       [-0.12854678-8.02911116e-02j,  0.24186034-2.29281639e-01j,
         0.14740459+1.56447710e-02j,  0.31545093-9.67442438e-16j]]), array([[ 0.23437121-3.67301920e-16j, -0.10974166+2.00758561e-01j,
        -0.13538732-3.32607742e-02j, -0.23364141-8.08433022e-02j],
       [-0.10974166-2.00758561e-01j,  0.29628877+1.64475712e-16j,
         0.04325408+1.79994322e-01j,  0.05145468+2.67514155e-01j],
       [-0.13538732+3.32607742e-02j,  0.04325408-1.79994322e-01j,
         0.154609  -5.68434751e-17j,  0.17966088+1.62344400e-02j],
       [-0.23364141+8.08433022e-02j,  0.05145468-2.67514155e-01j,
         0.17966088-1.62344400e-02j,  0.31473102-8.14668415e-19j]]), array([[ 0.20165821-1.47549000e-14j,  0.10698269+1.46704260e-01j,
         0.09232286-2.81974722e-02j,  0.03191153+1.87354123e-02j],
       [ 0.10698269-1.46704260e-01j,  0.19151958+6.20886159e-15j,
        -0.01419098-3.55151215e-02j,  0.02752912+9.23186927e-02j],
       [ 0.09232286+2.81974722e-02j, -0.01419098+3.55151215e-02j,
         0.19272534-1.16096215e-14j,  0.19679452-1.46065441e-01j],
       [ 0.03191153-1.87354123e-02j,  0.02752912-9.23186927e-02j,
         0.19679452+1.46065441e-01j,  0.41409687+4.12140952e-14j]]), array([[ 0.29392897+1.00947982e-15j,  0.07567934+1.30682983e-01j,
         0.01931152-1.42359219e-01j, -0.1438508 -1.43027068e-01j],
       [ 0.07567934-1.30682983e-01j,  0.10812171-3.18999438e-16j,
        -0.06839347-3.40749377e-03j, -0.10748596+1.01420182e-01j],
       [ 0.01931152+1.42359219e-01j, -0.06839347+3.40749377e-03j,
         0.1744333 -1.12134281e-15j,  0.22017758-1.03444737e-01j],
       [-0.1438508 +1.43027068e-01j, -0.10748596-1.01420182e-01j,
         0.22017758+1.03444737e-01j,  0.42351602-1.62290403e-16j]]), array([[ 0.28620029-1.10775674e-14j,  0.0070046 +2.81646946e-01j,
         0.07197936+1.96721206e-03j, -0.07226622+4.16891797e-02j],
       [ 0.0070046 -2.81646946e-01j,  0.30654426+4.34142638e-14j,
         0.00218869-2.05894773e-02j,  0.11508858+1.19672357e-01j],
       [ 0.07197936-1.96721206e-03j,  0.00218869+2.05894773e-02j,
         0.10573113-8.33552371e-15j,  0.06073576-1.23315914e-01j],
       [-0.07226622-4.16891797e-02j,  0.11508858-1.19672357e-01j,
         0.06073576+1.23315914e-01j,  0.30152433-2.39397583e-14j]]), array([[ 0.43229571+4.84365834e-16j, -0.0271383 +2.78786091e-01j,
        -0.02312306-1.21624303e-01j, -0.27111678-1.11718201e-01j],
       [-0.0271383 -2.78786091e-01j,  0.21586397-4.64410079e-16j,
        -0.06902473+3.74305006e-02j, -0.03450672+1.85709106e-01j],
       [-0.02312306+1.21624303e-01j, -0.06902473-3.74305006e-02j,
         0.0764421 +1.25384400e-16j,  0.06888316-9.64082660e-02j],
       [-0.27111678+1.11718201e-01j, -0.03450672-1.85709106e-01j,
         0.06888316+9.64082660e-02j,  0.27539822+8.54194848e-16j]]), array([[ 0.04032866+1.28788630e-17j, -0.01844307+7.96149469e-04j,
         0.12094627-1.99701708e-02j,  0.06175486-3.92923799e-02j],
       [-0.01844307-7.96149469e-04j,  0.37275052-6.14053459e-16j,
        -0.02183682+1.50168430e-02j,  0.02388409+1.34262595e-01j],
       [ 0.12094627+1.99701708e-02j, -0.02183682-1.50168430e-02j,
         0.39876616+1.05582126e-15j,  0.22409165-8.12428550e-02j],
       [ 0.06175486+3.92923799e-02j,  0.02388409-1.34262595e-01j,
         0.22409165+8.12428550e-02j,  0.18815466+4.41822166e-16j]]), array([[ 0.10770017+1.17011903e-16j, -0.1016988 -7.15638551e-03j,
         0.06775089-1.76924470e-01j,  0.03541216-1.30241955e-01j],
       [-0.1016988 +7.15638551e-03j,  0.24169996-3.71999783e-16j,
        -0.06879151+2.14164470e-01j, -0.06012527+1.62736749e-01j],
       [ 0.06775089+1.76924470e-01j, -0.06879151-2.14164470e-01j,
         0.41813114+1.29393579e-16j,  0.29005251-2.08749785e-02j],
       [ 0.03541216+1.30241955e-01j, -0.06012527-1.62736749e-01j,
         0.29005251+2.08749785e-02j,  0.23246873+9.93998560e-17j]]), array([[ 0.10647799-8.31385469e-11j, -0.12927929+1.47657454e-01j,
         0.08432028+1.19947845e-02j, -0.04858869-1.70908864e-02j],
       [-0.12927929-1.47657454e-01j,  0.4793998 +5.65456202e-11j,
         0.00830438+9.30272141e-03j,  0.10417317+1.54235564e-01j],
       [ 0.08432028-1.19947846e-02j,  0.00830438-9.30272128e-03j,
         0.31175229+1.39887387e-10j,  0.09374213-3.76435503e-02j],
       [-0.04858869+1.70908865e-02j,  0.10417317-1.54235564e-01j,
         0.09374213+3.76435505e-02j,  0.10236992-6.37322919e-12j]]), array([[ 0.17998615+3.25223084e-16j, -0.20029429+1.34121650e-01j,
        -0.00249708-1.38110643e-01j, -0.06328203-9.88239212e-02j],
       [-0.20029429-1.34121650e-01j,  0.42388368-1.13881831e-15j,
        -0.0388846 +2.43241121e-01j, -0.00399988+2.05421955e-01j],
       [-0.00249708+1.38110643e-01j, -0.0388846 -2.43241121e-01j,
         0.2804354 +3.25325208e-16j,  0.12712735-9.64279388e-03j],
       [-0.06328203+9.88239212e-02j, -0.00399988-2.05421955e-01j,
         0.12712735+9.64279388e-03j,  0.11569477+2.02279230e-16j]]), array([[ 0.13564652+2.35837022e-17j,  0.00700148+1.38959218e-01j,
         0.19257921-6.32684202e-02j,  0.05948304-9.61473279e-02j],
       [ 0.00700148-1.38959218e-01j,  0.25385168+6.93947507e-17j,
        -0.09980012-1.83139079e-01j, -0.11153601+2.45925607e-02j],
       [ 0.19257921+6.32684202e-02j, -0.09980012+1.83139079e-01j,
         0.38048937+2.72110697e-15j,  0.18846758-1.64896194e-01j],
       [ 0.05948304+9.61473279e-02j, -0.11153601-2.45925607e-02j,
         0.18846758+1.64896194e-01j,  0.23001242-9.03572853e-16j]]), array([[ 0.25413059+5.06558708e-17j, -0.05175851+1.38360272e-01j,
         0.12703937-2.37552510e-01j,  0.02107906-2.04545655e-01j],
       [-0.05175851-1.38360272e-01j,  0.16608365+1.97112023e-16j,
        -0.17142273-1.74237919e-02j, -0.164299  +4.29668776e-02j],
       [ 0.12703937+2.37552510e-01j, -0.17142273+1.74237919e-02j,
         0.33511537+5.42652797e-16j,  0.23291996-8.76123065e-02j],
       [ 0.02107906+2.04545655e-01j, -0.164299  -4.29668776e-02j,
         0.23291996+8.76123065e-02j,  0.24467038+3.57058053e-16j]]), array([[ 0.24393504+1.56094631e-15j, -0.09630488+2.88270455e-01j,
         0.1639692 -3.31646561e-02j, -0.03258879-4.54891373e-02j],
       [-0.09630488-2.88270455e-01j,  0.42082934+9.84593823e-17j,
        -0.0829751 -1.47752606e-01j, -0.00290316+6.31756929e-02j],
       [ 0.1639692 +3.31646561e-02j, -0.0829751 +1.47752606e-01j,
         0.23403904+5.05608181e-16j,  0.0402834 -1.08076283e-01j],
       [-0.03258879+4.54891373e-02j, -0.00290316-6.31756929e-02j,
         0.0402834 +1.08076283e-01j,  0.10119657+3.13255593e-17j]]), array([[ 0.37746828-1.69415219e-17j, -0.15870632+2.81687803e-01j,
         0.08415409-2.05368525e-01j, -0.07026252-1.41645411e-01j],
       [-0.15870632-2.81687803e-01j,  0.33684507+5.56435750e-17j,
        -0.1687045 +3.84250140e-02j, -0.08436518+1.13885194e-01j],
       [ 0.08415409+2.05368525e-01j, -0.1687045 -3.84250140e-02j,
         0.19033258+1.87903040e-17j,  0.06270939-7.32732367e-02j],
       [-0.07026252+1.41645411e-01j, -0.08436518-1.13885194e-01j,
         0.06270939+7.32732367e-02j,  0.09535407+2.04099013e-16j]]), array([[0.21490538+2.55258355e-16j, 0.12306876+5.04073841e-02j,
        0.11043209+1.75006651e-01j, 0.06375819+1.69487537e-01j],
       [0.12306876-5.04073841e-02j, 0.12982888+2.25985037e-16j,
        0.14736968+8.18084813e-02j, 0.1138782 +1.04106504e-01j],
       [0.11043209-1.75006651e-01j, 0.14736968-8.18084813e-02j,
        0.37887918+5.10547100e-17j, 0.28793269+6.66107140e-02j],
       [0.06375819-1.69487537e-01j, 0.1138782 -1.04106504e-01j,
        0.28793269-6.66107140e-02j, 0.27638656-2.99140684e-16j]]), array([[ 0.34274014-4.04807457e-16j,  0.06075089+2.34985891e-02j,
        -0.01621432+2.87671237e-03j, -0.09465736-1.05451087e-02j],
       [ 0.06075089-2.34985891e-02j,  0.052745  +1.27862821e-16j,
         0.06210508+9.49337166e-02j, -0.00509176+1.00868160e-01j],
       [-0.01621432-2.87671237e-03j,  0.06210508-9.49337166e-02j,
         0.33424719-1.14412398e-14j,  0.25618864+1.31837321e-01j],
       [-0.09465736+1.05451087e-02j, -0.00509176-1.00868160e-01j,
         0.25618864-1.31837321e-01j,  0.27026767-3.93731284e-15j]]), array([[ 0.29374003-2.87259180e-16j,  0.00368174+2.24429065e-01j,
         0.01831281+2.49145919e-01j, -0.12983431+1.54912018e-01j],
       [ 0.00368174-2.24429065e-01j,  0.21908956+3.66867576e-16j,
         0.19714925+7.26745669e-03j,  0.13812701+1.19877701e-01j],
       [ 0.01831281-2.49145919e-01j,  0.19714925-7.26745669e-03j,
         0.29898732+1.17164367e-16j,  0.14774051+1.19351581e-01j],
       [-0.12983431-1.54912018e-01j,  0.13812701-1.19877701e-01j,
         0.14774051-1.19351581e-01j,  0.18818309+3.69352075e-16j]]), array([[ 0.39574267-6.12697744e-16j, -0.0355132 +1.76870574e-01j,
        -0.07859123+1.03351168e-01j, -0.2207655 -5.18949380e-03j],
       [-0.0355132 -1.76870574e-01j,  0.1245987 -2.55243411e-16j,
         0.0972717 +1.10736163e-01j,  0.00909722+1.46011432e-01j],
       [-0.07859123-1.03351168e-01j,  0.0972717 -1.10736163e-01j,
         0.29158972+1.76516220e-15j,  0.1373463 +1.33385749e-01j],
       [-0.2207655 +5.18949380e-03j,  0.00909722-1.46011432e-01j,
         0.1373463 -1.33385749e-01j,  0.18806891+6.54987166e-16j]]), array([[0.42944656-4.67263076e-16j, 0.14330392+1.50921129e-01j,
        0.15531384+2.06873241e-02j, 0.1087541 +1.71317813e-01j],
       [0.14330392-1.50921129e-01j, 0.1120581 -5.80763642e-16j,
        0.04733468-4.76930984e-02j, 0.08679489+2.55413553e-02j],
       [0.15531384-2.06873241e-02j, 0.04733468+4.76930984e-02j,
        0.20670184+4.00522909e-17j, 0.18029063+3.67250714e-03j],
       [0.1087541 -1.71317813e-01j, 0.08679489-2.55413553e-02j,
        0.18029063-3.67250714e-03j, 0.2517935 -1.28532437e-16j]]), array([[ 0.55122605-4.98156980e-14j,  0.12736813+8.24135833e-02j,
         0.07550879-1.05837258e-01j, -0.09426252+3.54092282e-02j],
       [ 0.12736813-8.24135833e-02j,  0.0511346 +2.11939380e-14j,
        -0.00495205+2.10734172e-03j, -0.02791036+6.24519087e-02j],
       [ 0.07550879+1.05837258e-01j, -0.00495205-2.10734172e-03j,
         0.19048674-1.56032588e-14j,  0.15288109+4.91968229e-03j],
       [-0.09426252-3.54092282e-02j, -0.02791036-6.24519087e-02j,
         0.15288109-4.91968229e-03j,  0.20715261-3.22541969e-15j]]), array([[ 0.53459423-4.87669438e-16j,  0.0413861 +3.28335581e-01j,
         0.12046574+1.08110920e-01j, -0.03971873+1.99950021e-01j],
       [ 0.0413861 -3.28335581e-01j,  0.2285259 +1.54295924e-16j,
         0.0769468 -6.16326480e-02j,  0.12883563+4.65446213e-02j],
       [ 0.12046574-1.08110920e-01j,  0.0769468 +6.16326480e-02j,
         0.11133761-4.30703397e-17j,  0.05095695+3.48217266e-02j],
       [-0.03971873-1.99950021e-01j,  0.12883563-4.65446213e-02j,
         0.05095695-3.48217266e-02j,  0.12554226-1.32802204e-16j]]), array([[ 0.68283943-1.05925393e-15j,  0.03318957+2.70181639e-01j,
         0.04201921-5.19757942e-02j, -0.20658183+4.22993457e-02j],
       [ 0.03318957-2.70181639e-01j,  0.12796743+2.01273807e-16j,
        -0.00824722+9.91736978e-04j,  0.0069202 +9.53992749e-02j],
       [ 0.04201921+5.19757942e-02j, -0.00824722-9.91736978e-04j,
         0.09262983-2.90069843e-17j,  0.01405005+2.99959108e-03j],
       [-0.20658183-4.22993457e-02j,  0.0069202 -9.53992749e-02j,
         0.01405005-2.99959108e-03j,  0.09656331-1.97110790e-16j]]), array([[0.10392193+3.96439630e-18j, 0.02786769+1.12552793e-02j,
        0.19621955+4.02727967e-02j, 0.07800274+4.50999069e-02j],
       [0.02786769-1.12552793e-02j, 0.10010988-2.10394368e-17j,
        0.10546866-5.88358291e-02j, 0.05480361+1.85924922e-02j],
       [0.19621955-4.02727967e-02j, 0.10546866+5.88358291e-02j,
        0.64928069-2.58557711e-16j, 0.24632267+9.41863249e-02j],
       [0.07800274-4.50999069e-02j, 0.05480361-1.85924922e-02j,
        0.24632267-9.41863249e-02j, 0.1466875 +5.18370287e-17j]]), array([[ 0.17521317+2.78311086e-16j, -0.03801405-5.44045322e-02j,
         0.13716534-1.82950680e-01j,  0.07751776-3.66515502e-02j],
       [-0.03801405+5.44045322e-02j,  0.07455265-9.38632946e-18j,
         0.05165203+1.51810439e-01j, -0.01718146+7.25817472e-02j],
       [ 0.13716534+1.82950680e-01j,  0.05165203-1.51810439e-01j,
         0.60337556+5.94432383e-17j,  0.22718302+1.36052397e-01j],
       [ 0.07751776+3.66515502e-02j, -0.01718146-7.25817472e-02j,
         0.22718302-1.36052397e-01j,  0.14685861+1.15288279e-16j]]), array([[ 0.16888988-4.62883599e-16j, -0.05931404+1.37960850e-01j,
         0.13475142+1.47444846e-01j, -0.05476909+3.58319123e-02j],
       [-0.05931404-1.37960850e-01j,  0.19655844+1.13618207e-16j,
         0.1231598 -5.85352910e-02j,  0.06426573+6.03627762e-02j],
       [ 0.13475142-1.47444846e-01j,  0.1231598 +5.85352910e-02j,
         0.58053039-1.91612452e-16j,  0.06308719+7.64685058e-02j],
       [-0.05476909-3.58319123e-02j,  0.06426573-6.03627762e-02j,
         0.06308719-7.64685058e-02j,  0.05402128+1.60177342e-17j]]), array([[ 0.26546427-2.23009998e-15j, -0.10738852+9.50323262e-02j,
         0.06615463-4.14256960e-02j, -0.07889362-2.55826670e-02j],
       [-0.10738852-9.50323262e-02j,  0.16201352-1.01171180e-15j,
         0.0758939 +1.54012976e-01j,  0.00273681+9.54109713e-02j],
       [ 0.06615463+4.14256960e-02j,  0.0758939 -1.54012976e-01j,
         0.50203732+2.32493082e-15j,  0.06551402+1.00328190e-01j],
       [-0.07889362+2.55826670e-02j,  0.00273681-9.54109713e-02j,
         0.06551402-1.00328190e-01j,  0.07048488+3.04791987e-16j]]), array([[0.30015919-6.02551792e-16j, 0.05242431+1.34940132e-01j,
        0.29986584-8.51864345e-02j, 0.13384276+2.57038442e-02j],
       [0.05242431-1.34940132e-01j, 0.11995213+5.55331263e-17j,
        0.00068897-1.96345404e-01j, 0.01662993-5.77039098e-02j],
       [0.29986584+8.51864345e-02j, 0.00068897+1.96345404e-01j,
        0.46233831-2.06071799e-16j, 0.16379222+3.03324560e-02j],
       [0.13384276-2.57038442e-02j, 0.01662993+5.77039098e-02j,
        0.16379222-3.03324560e-02j, 0.11755038-2.01896550e-16j]]), array([[ 0.42581508-9.13125048e-16j,  0.00276286+5.29251752e-02j,
         0.22049004-3.17946665e-01j,  0.07661677-4.76328167e-02j],
       [ 0.00276286-5.29251752e-02j,  0.04262824+2.28780477e-17j,
        -0.05301011-1.96467390e-02j, -0.02781144-4.94557447e-04j],
       [ 0.22049004+3.17946665e-01j, -0.05301011+1.96467390e-02j,
         0.44269661+4.72642869e-16j,  0.12472293+4.37024627e-02j],
       [ 0.07661677+4.76328167e-02j, -0.02781144+4.94557447e-04j,
         0.12472293-4.37024627e-02j,  0.08886008-3.97568773e-17j]]), array([[ 0.36985091-6.04339323e-16j, -0.03094763+2.68417627e-01j,
         0.24995239+2.29833065e-02j, -0.0169387 +4.33075584e-02j],
       [-0.03094763-2.68417627e-01j,  0.22429801+4.61577414e-16j,
         0.02634673-1.89367123e-01j,  0.03566385+6.73711387e-03j],
       [ 0.24995239-2.29833065e-02j,  0.02634673+1.89367123e-01j,
         0.38127401-5.88388320e-16j, -0.00152903+8.56433939e-03j],
       [-0.0169387 -4.33075584e-02j,  0.03566385-6.73711387e-03j,
        -0.00152903-8.56433939e-03j,  0.02457707+1.26566777e-17j]]), array([[ 0.49528918+9.57277211e-17j, -0.07180434+2.01354610e-01j,
         0.15259077-1.95146664e-01j, -0.06465192-1.06395222e-02j],
       [-0.07180434-2.01354610e-01j,  0.1353844 -4.23115868e-16j,
        -0.03171339+9.99451183e-03j, -0.00680139+4.17910072e-02j],
       [ 0.15259077+1.95146664e-01j, -0.03171339-9.99451183e-03j,
         0.34266698-1.14748694e-15j, -0.02301805+1.47854467e-02j],
       [-0.06465192+1.06395222e-02j, -0.00680139-4.17910072e-02j,
        -0.02301805-1.47854467e-02j,  0.02665944+2.43219045e-18j]]), array([[ 0.07434702+5.07771247e-17j,  0.00346257-5.98993940e-02j,
        -0.08938935+2.31551659e-02j, -0.06608585+5.30399050e-03j],
       [ 0.00346257+5.98993940e-02j,  0.30579586-4.99246479e-15j,
         0.11588523-8.63680061e-02j,  0.23403229-1.86148444e-01j],
       [-0.08938935-2.31551659e-02j,  0.11588523+8.63680061e-02j,
         0.22876018+7.28576440e-18j,  0.24276449-5.37242230e-02j],
       [-0.06608585-5.30399050e-03j,  0.23403229+1.86148444e-01j,
         0.24276449+5.37242230e-02j,  0.39109693-8.62811370e-17j]]), array([[ 0.21065243+5.58503983e-16j, -0.00605045-1.24318513e-01j,
        -0.15972436-9.53805255e-02j, -0.23024965-1.19087490e-01j],
       [-0.00605045+1.24318513e-01j,  0.2065361 -6.11464904e-16j,
         0.07589314-2.80057877e-02j,  0.11740028-1.52093701e-01j],
       [-0.15972436+9.53805255e-02j,  0.07589314+2.80057877e-02j,
         0.22306103-7.56361734e-16j,  0.23846717-3.71183446e-02j],
       [-0.23024965+1.19087490e-01j,  0.11740028+1.52093701e-01j,
         0.23846717+3.71183446e-02j,  0.35975045-5.99357559e-16j]]), array([[ 0.08144089-3.01664988e-16j, -0.07018604+5.42115004e-02j,
        -0.08439065+3.40246408e-02j, -0.05193086+6.46647210e-02j],
       [-0.07018604-5.42115004e-02j,  0.42968753+1.43514384e-15j,
         0.12968201+1.48928215e-01j,  0.33093297-1.10256125e-01j],
       [-0.08439065-3.40246408e-02j,  0.12968201-1.48928215e-01j,
         0.18086578-7.83894175e-16j,  0.07725935-1.48313832e-01j],
       [-0.05193086-6.46647210e-02j,  0.33093297+1.10256125e-01j,
         0.07725935+1.48313832e-01j,  0.3080058 +1.86376996e-15j]]), array([[ 0.24904276-6.09788634e-15j, -0.08616811+1.97739713e-02j,
        -0.16492575-3.43286264e-02j, -0.18993573-5.22535917e-02j],
       [-0.08616811-1.97739713e-02j,  0.2924438 +1.13415657e-14j,
         0.08252049+1.75017908e-01j,  0.1636949 -9.03023242e-02j],
       [-0.16492575+3.43286264e-02j,  0.08252049-1.75017908e-01j,
         0.20375244+1.21403290e-15j,  0.07310928-6.36195156e-02j],
       [-0.18993573+5.22535917e-02j,  0.1636949 +9.03023242e-02j,
         0.07310928+6.36195156e-02j,  0.25476099-4.44967525e-15j]]), array([[ 0.12367495+4.87144947e-17j,  0.05159819+3.97870319e-02j,
        -0.05688099+1.15888624e-02j,  0.03628019+5.31397195e-02j],
       [ 0.05159819-3.97870319e-02j,  0.1749545 -2.19720279e-16j,
         0.10153606-6.17541501e-02j,  0.07560516-2.15183104e-01j],
       [-0.05688099-1.15888624e-02j,  0.10153606+6.17541501e-02j,
         0.22689948-1.72831708e-15j,  0.18627746-2.29520587e-01j],
       [ 0.03628019-5.31397195e-02j,  0.07560516+2.15183104e-01j,
         0.18627746+2.29520587e-01j,  0.47447106-8.38964792e-16j]]), array([[ 0.27211913+2.71355055e-16j,  0.07293013-5.17317483e-02j,
        -0.09616313-1.51071813e-01j, -0.21289246-7.28479660e-02j],
       [ 0.07293013+5.17317483e-02j,  0.11862562-3.03138805e-16j,
         0.06721704-6.41891019e-02j, -0.01286853-1.84927578e-01j],
       [-0.09616313+1.51071813e-01j,  0.06721704+6.41891019e-02j,
         0.19088644+6.89205951e-16j,  0.15583964-1.99897183e-01j],
       [-0.21289246+7.28479660e-02j, -0.01286853+1.84927578e-01j,
         0.15583964+1.99897183e-01j,  0.41836881+9.71294405e-16j]]), array([[ 0.17324338-2.21595539e-16j, -0.04215456+1.77247769e-01j,
        -0.09869367+5.37721692e-02j,  0.07389311+1.49607100e-01j],
       [-0.04215456-1.77247769e-01j,  0.26528404+8.24485298e-16j,
         0.13425326+1.10460825e-01j,  0.18608727-1.92713742e-01j],
       [-0.09869367-5.37721692e-02j,  0.13425326-1.10460825e-01j,
         0.18276905-7.66783412e-17j,  0.02590817-2.40779405e-01j],
       [ 0.07389311-1.49607100e-01j,  0.18608727+1.92713742e-01j,
         0.02590817+2.40779405e-01j,  0.37870353+9.95388104e-16j]]), array([[ 0.33360298+4.34288914e-15j, -0.04693658+1.13785584e-01j,
        -0.12219609-1.01833940e-01j, -0.14161273-9.24491728e-03j],
       [-0.04693658-1.13785584e-01j,  0.19522578+6.79041034e-16j,
         0.0687134 +1.19841566e-01j,  0.07525382-1.36409507e-01j],
       [-0.12219609+1.01833940e-01j,  0.0687134 -1.19841566e-01j,
         0.15416534-3.64765182e-15j,  0.0091015 -1.72874437e-01j],
       [-0.14161273+9.24491728e-03j,  0.07525382+1.36409507e-01j,
         0.0091015 +1.72874437e-01j,  0.31700589-2.25496292e-15j]]), array([[ 0.05114037+4.77982320e-16j, -0.09822243-1.02025796e-01j,
        -0.06965643+4.10983551e-03j, -0.06222191+1.37417115e-02j],
       [-0.09822243+1.02025796e-01j,  0.46763022-3.68855693e-15j,
         0.13240287-1.94174795e-01j,  0.09435539-1.85669758e-01j],
       [-0.06965643-4.10983551e-03j,  0.13240287+1.94174795e-01j,
         0.3093515 +1.85444110e-15j,  0.20525316-6.77868723e-02j],
       [-0.06222191-1.37417115e-02j,  0.09435539+1.85669758e-01j,
         0.20525316+6.77868723e-02j,  0.1718779 -2.41128255e-16j]]), array([[ 0.15593501+1.16971515e-15j, -0.08673341-1.75469476e-01j,
        -0.07425734-1.56207512e-01j, -0.12344525-3.37745174e-02j],
       [-0.08673341+1.75469476e-01j,  0.37361992-9.70827529e-16j,
         0.09731798+3.27078934e-02j,  0.03107568-1.29666110e-01j],
       [-0.07425734+1.56207512e-01j,  0.09731798-3.27078934e-02j,
         0.31713296-9.82585840e-15j,  0.16443513-8.19098357e-02j],
       [-0.12344525+3.37745174e-02j,  0.03107568+1.29666110e-01j,
         0.16443513+8.19098357e-02j,  0.15331211+7.01993150e-16j]]), array([[ 0.09193353-2.31414779e-16j, -0.20228355+4.12089762e-02j,
        -0.08933665+4.14165289e-02j, -0.04923093+7.13989586e-02j],
       [-0.20228355-4.12089762e-02j,  0.54142672-2.67843869e-15j,
         0.14903435-2.15541309e-02j,  0.16193126-1.32224626e-01j],
       [-0.08933665-4.14165289e-02j,  0.14903435+2.15541309e-02j,
         0.2685972 -5.64473145e-16j,  0.06995435-7.74046899e-02j],
       [-0.04923093-7.13989586e-02j,  0.16193126+1.32224626e-01j,
         0.06995435+7.74046899e-02j,  0.09804255+1.13792099e-15j]]), array([[ 0.15015539+2.66211563e-16j, -0.21432143-4.24768614e-02j,
        -0.08693472-1.53524724e-01j, -0.09369314+2.94767725e-02j],
       [-0.21432143+4.24768614e-02j,  0.44157631+8.48408022e-17j,
         0.15412266+2.65412732e-01j,  0.1358995 -9.67808861e-02j],
       [-0.08693472+1.53524724e-01j,  0.15412266-2.65412732e-01j,
         0.31416929-1.61792457e-15j,  0.01764893-1.19315586e-01j],
       [-0.09369314-2.94767725e-02j,  0.1358995 +9.67808861e-02j,
         0.01764893+1.19315586e-01j,  0.09409901+2.89442452e-16j]]), array([[ 0.04263332-2.99302814e-18j, -0.03142559-1.11726411e-02j,
        -0.03892619+2.55093948e-03j, -0.00459757+3.70617022e-02j],
       [-0.03142559+1.11726411e-02j,  0.27721916-3.24395221e-16j,
         0.13789273-2.32980055e-01j, -0.09999044-2.26813971e-01j],
       [-0.03892619-2.55093948e-03j,  0.13789273+2.32980055e-01j,
         0.384131  -1.97340391e-16j,  0.16515665-2.62758930e-01j],
       [-0.00459757-3.70617022e-02j, -0.09999044+2.26813971e-01j,
         0.16515665+2.62758930e-01j,  0.29601652+1.11664650e-15j]]), array([[ 0.18851185+4.49438430e-18j, -0.01946063-1.15378456e-01j,
        -0.03398571-2.27126109e-01j, -0.15667506-6.36622783e-03j],
       [-0.01946063+1.15378456e-01j,  0.21925101+1.25861362e-16j,
         0.13836035-6.74916842e-02j, -0.07461246-1.72853593e-01j],
       [-0.03398571+2.27126109e-01j,  0.13836035+6.74916842e-02j,
         0.33960092+5.70736512e-16j,  0.08377248-2.41599742e-01j],
       [-0.15667506+6.36622783e-03j, -0.07461246+1.72853593e-01j,
         0.08377248+2.41599742e-01j,  0.25263622+6.27249820e-16j]]), array([[ 0.1424787 -9.65452201e-16j, -0.17254521+1.47731284e-01j,
        -0.06523506+4.45420154e-02j,  0.05629472+1.03329806e-01j],
       [-0.17254521-1.47731284e-01j,  0.41222538+7.34550985e-16j,
         0.17957671-4.14809694e-02j,  0.0098757 -2.27696799e-01j],
       [-0.06523506-4.45420154e-02j,  0.17957671+4.14809694e-02j,
         0.25405851+3.26727402e-16j,  0.02354549-1.96654572e-01j],
       [ 0.05629472-1.03329806e-01j,  0.0098757 +2.27696799e-01j,
         0.02354549+1.96654572e-01j,  0.19123741-1.92109176e-16j]]), array([[ 0.22149702+5.72629091e-16j, -0.15194478+5.79638429e-02j,
        -0.06037221-1.91416723e-01j, -0.07603977+3.93215919e-02j],
       [-0.15194478-5.79638429e-02j,  0.29060514+4.86208197e-16j,
         0.11663392+1.23376723e-01j,  0.00740786-1.54034595e-01j],
       [-0.06037221+1.91416723e-01j,  0.11663392-1.23376723e-01j,
         0.29534601+3.94435988e-16j, -0.03248067-2.02131472e-01j],
       [-0.07603977-3.93215919e-02j,  0.00740786+1.54034595e-01j,
        -0.03248067+2.02131472e-01j,  0.19255183+1.98774571e-16j]]), array([[ 0.32281991-1.16235538e-14j,  0.03956244-7.41412610e-02j,
        -0.20617159+1.39519017e-01j, -0.01383676+3.65298295e-02j],
       [ 0.03956244+7.41412610e-02j,  0.14041715+2.19738186e-15j,
         0.07192529-7.44147793e-02j,  0.11831415-6.75464172e-02j],
       [-0.20617159-1.39519017e-01j,  0.07192529+7.44147793e-02j,
         0.35139196+1.32202521e-14j,  0.1913213 -4.48497445e-02j],
       [-0.01383676-3.65298295e-02j,  0.11831415+6.75464172e-02j,
         0.1913213 +4.48497445e-02j,  0.18537097+7.19891379e-15j]]), array([[ 0.45149738+1.46003705e-15j, -0.01392308-1.17547054e-01j,
        -0.32495247-2.97808972e-02j, -0.22153689-8.68686483e-02j],
       [-0.01392308+1.17547054e-01j,  0.06104278-1.30020783e-16j,
         0.0423158 -8.19721111e-02j,  0.05189514-6.13369061e-02j],
       [-0.32495247+2.97808972e-02j,  0.0423158 +8.19721111e-02j,
         0.3069829 +4.84667504e-16j,  0.21103555+4.36770471e-02j],
       [-0.22153689+8.68686483e-02j,  0.05189514+6.13369061e-02j,
         0.21103555-4.36770471e-02j,  0.18047694-5.76906764e-17j]]), array([[ 0.32444354+2.79797667e-15j, -0.04668372+7.48007336e-02j,
        -0.23920802+2.42726798e-01j, -0.0288865 +6.20715868e-02j],
       [-0.04668372-7.48007336e-02j,  0.16044963-4.36166174e-16j,
         0.11382458+6.24830045e-02j,  0.13066984-4.67606398e-02j],
       [-0.23920802-2.42726798e-01j,  0.11382458-6.24830045e-02j,
         0.38569184+1.24248897e-15j,  0.07346405-6.75542735e-02j],
       [-0.0288865 -6.20715868e-02j,  0.13066984+4.67606398e-02j,
         0.07346405+6.75542735e-02j,  0.12941499-7.22093041e-16j]]), array([[ 0.45760008+5.87515818e-16j, -0.11234384+5.27847861e-02j,
        -0.32917846+7.34563350e-02j, -0.18000922-3.17428652e-02j],
       [-0.11234384-5.27847861e-02j,  0.11795405+8.63163622e-16j,
         0.08572395+7.97855177e-02j,  0.07167905-2.35832168e-02j],
       [-0.32917846-7.34563350e-02j,  0.08572395-7.97855177e-02j,
         0.30033063+2.22216491e-16j,  0.0851028 +3.24721034e-02j],
       [-0.18000922+3.17428652e-02j,  0.07167905+2.35832168e-02j,
         0.0851028 -3.24721034e-02j,  0.12411524-6.68595004e-17j]]), array([[ 0.43320676-6.70739310e-14j,  0.06917111+1.51358125e-02j,
        -0.16933573+5.34189533e-02j,  0.08960332+1.29939864e-01j],
       [ 0.06917111-1.51358125e-02j,  0.07992086-1.02375797e-14j,
         0.06081347-5.94018619e-02j,  0.04524996-8.62815842e-02j],
       [-0.16933573-5.34189533e-02j,  0.06081347+5.94018619e-02j,
         0.26100098+8.74640164e-14j,  0.12660352-1.64137426e-01j],
       [ 0.08960332-1.29939864e-01j,  0.04524996+8.62815842e-02j,
         0.12660352+1.64137426e-01j,  0.2258714 +4.47326818e-14j]]), array([[ 0.6107047 +2.16287325e-15j,  0.05169325-5.23047144e-02j,
        -0.21827987-1.33828267e-01j, -0.13463561+3.04823110e-02j],
       [ 0.05169325+5.23047144e-02j,  0.04388963-9.86905193e-17j,
         0.03311845-5.02901691e-02j,  0.00237206-6.93627824e-02j],
       [-0.21827987+1.33828267e-01j,  0.03311845+5.02901691e-02j,
         0.18042637-4.48343298e-16j,  0.10412065-1.09555501e-01j],
       [-0.13463561-3.04823110e-02j,  0.00237206+6.93627824e-02j,
         0.10412065+1.09555501e-01j,  0.16497929+7.57625200e-16j]]), array([[ 0.46758688+1.91641653e-16j, -0.04848916+2.06418178e-01j,
        -0.2307703 +1.59773027e-01j,  0.11628592+2.05494712e-01j],
       [-0.04848916-2.06418178e-01j,  0.13006125+6.07572021e-18j,
         0.10958423+8.40761866e-02j,  0.090531  -8.93275447e-02j],
       [-0.2307703 -1.59773027e-01j,  0.10958423-8.40761866e-02j,
         0.23266374-4.40508207e-16j,  0.01874636-1.67366924e-01j],
       [ 0.11628592-2.05494712e-01j,  0.090531  +8.93275447e-02j,
         0.01874636+1.67366924e-01j,  0.16968813+3.50531035e-16j]]), array([[ 0.64779327-7.55567535e-17j, -0.0856112 +1.45054709e-01j,
        -0.28729976-4.53906671e-02j, -0.06890521+7.76373496e-02j],
       [-0.0856112 -1.45054709e-01j,  0.08697021+3.28448259e-17j,
         0.04645239+8.83649039e-02j,  0.04076654-4.52569887e-02j],
       [-0.28729976+4.53906671e-02j,  0.04645239-8.83649039e-02j,
         0.16059146-3.18964898e-17j,  0.00831068-7.28086381e-02j],
       [-0.06890521-7.76373496e-02j,  0.04076654+4.52569887e-02j,
         0.00831068+7.28086381e-02j,  0.10464506+1.68542492e-16j]]), array([[ 0.15865518-1.39557188e-16j, -0.08921655-1.15474592e-01j,
        -0.21573038+5.89345388e-02j, -0.05979258+3.06629123e-02j],
       [-0.08921655+1.15474592e-01j,  0.20453119-5.40192761e-17j,
         0.14358673-2.56438933e-01j,  0.0405668 -9.52921833e-02j],
       [-0.21573038-5.89345388e-02j,  0.14358673+2.56438933e-01j,
         0.54757658-2.01655617e-17j,  0.18736911-3.00919255e-02j],
       [-0.05979258-3.06629123e-02j,  0.0405668 +9.52921833e-02j,
         0.18736911+3.00919255e-02j,  0.08923705+4.41500125e-17j]]), array([[ 0.30828765-2.79715567e-16j, -0.10526157-1.74475533e-01j,
        -0.22689473-1.58805165e-01j, -0.10472215-2.34398024e-02j],
       [-0.10526157+1.74475533e-01j,  0.15672648+2.67988859e-16j,
         0.12883877-5.11904893e-02j,  0.0318896 -5.44355818e-02j],
       [-0.22689473+1.58805165e-01j,  0.12883877+5.11904893e-02j,
         0.46186837-3.12467440e-16j,  0.15343143+5.01944248e-03j],
       [-0.10472215+2.34398024e-02j,  0.0318896 +5.44355818e-02j,
         0.15343143-5.01944248e-03j,  0.0731175 +1.94081692e-16j]]), array([[ 0.18255043-2.95172314e-16j, -0.16567594+2.93965994e-02j,
        -0.21389127+1.53932417e-01j, -0.02707578+5.36038084e-02j],
       [-0.16567594-2.93965994e-02j,  0.21142314+4.30300225e-17j,
         0.17904151-5.49154636e-02j,  0.05633764-5.58063465e-02j],
       [-0.21389127-1.53932417e-01j,  0.17904151+5.49154636e-02j,
         0.56361404-1.47794420e-15j,  0.0414004 -6.02510135e-02j],
       [-0.02707578-5.36038084e-02j,  0.05633764+5.58063465e-02j,
         0.0414004 +6.02510135e-02j,  0.04241239-2.29226257e-17j]]), array([[ 0.29121548-1.29295518e-15j, -0.2067305 -5.34695018e-03j,
        -0.26533972-7.67392720e-02j, -0.07706567+1.51188402e-02j],
       [-0.2067305 +5.34695018e-03j,  0.18771672-1.61209679e-15j,
         0.16400009+1.26197158e-01j,  0.0481909 -2.60426756e-02j],
       [-0.26533972+7.67392720e-02j,  0.16400009-1.26197158e-01j,
         0.48599567-8.46940360e-16j,  0.04324644-3.89467823e-03j],
       [-0.07706567-1.51188402e-02j,  0.0481909 +2.60426756e-02j,
         0.04324644+3.89467823e-03j,  0.03507212+1.57094422e-17j]]), array([[ 0.27920014-7.37344530e-16j, -0.02840034-4.09287539e-02j,
        -0.13907725-1.79071746e-02j,  0.0562186 +1.02570818e-01j],
       [-0.02840034+4.09287539e-02j,  0.11255389-5.42581151e-16j,
         0.1140255 -1.90433927e-01j, -0.0528314 -9.15482778e-02j],
       [-0.13907725+1.79071746e-02j,  0.1140255 +1.90433927e-01j,
         0.46504406-1.43980148e-15j,  0.08741269-1.89888395e-01j],
       [ 0.0562186 -1.02570818e-01j, -0.0528314 +9.15482778e-02j,
         0.08741269+1.89888395e-01j,  0.14320191+1.83400165e-15j]]), array([[ 0.44159104-9.32445312e-17j, -0.04566073-1.32785226e-01j,
        -0.15972581-2.84170988e-01j, -0.09352393+6.83665266e-02j],
       [-0.04566073+1.32785226e-01j,  0.08254499+7.90943771e-17j,
         0.12261747-7.12247542e-02j, -0.02703048-7.08284361e-02j],
       [-0.15972581+2.84170988e-01j,  0.12261747+7.12247542e-02j,
         0.38005055+4.63854062e-17j,  0.0482247 -1.43246389e-01j],
       [-0.09352393-6.83665266e-02j, -0.02703048+7.08284361e-02j,
         0.0482247 +1.43246389e-01j,  0.09581342-1.44039395e-16j]]), array([[ 0.27532825+2.79328091e-16j, -0.12852041+1.09677945e-01j,
        -0.15652236+6.11307968e-02j,  0.07204569+1.18587972e-01j],
       [-0.12852041-1.09677945e-01j,  0.138141  -5.78553160e-16j,
         0.15450965-4.81963892e-02j, -0.01203685-9.68031152e-02j],
       [-0.15652236-6.11307968e-02j,  0.15450965+4.81963892e-02j,
         0.47972965-9.08949773e-16j, -0.03536094-1.88624746e-01j],
       [ 0.07204569-1.18587972e-01j, -0.01203685+9.68031152e-02j,
        -0.03536094+1.88624746e-01j,  0.1068011 +6.66004996e-16j]]), array([[ 0.46075824+2.20058956e-16j, -0.20483626+6.02854266e-02j,
        -0.23357323-2.23585411e-01j, -0.0087047 +1.17112940e-01j],
       [-0.20483626-6.02854266e-02j,  0.13460723-1.03976009e-17j,
         0.11256964+1.17771457e-01j,  0.01423258-6.84942453e-02j],
       [-0.23357323+2.23585411e-01j,  0.11256964-1.17771457e-01j,
         0.34540486+2.01041093e-16j, -0.05248421-9.96133680e-02j],
       [-0.0087047 -1.17112940e-01j,  0.01423258+6.84942453e-02j,
        -0.05248421+9.96133680e-02j,  0.05922967-3.68786606e-17j]]), array([[0.10605463-2.63293694e-16j, 0.07460664-7.50053739e-02j,
        0.08633595-2.44073264e-02j, 0.09362079-1.03383256e-01j],
       [0.07460664+7.50053739e-02j, 0.27915802+3.99871578e-16j,
        0.19702635+7.19242457e-02j, 0.29003449-5.19215715e-03j],
       [0.08633595+2.44073264e-02j, 0.19702635-7.19242457e-02j,
        0.22430871-2.36246546e-16j, 0.2426126 -1.02984383e-01j],
       [0.09362079+1.03383256e-01j, 0.29003449+5.19215715e-03j,
        0.2426126 +1.02984383e-01j, 0.39047864+3.04077167e-16j]]), array([[ 0.24563865-1.34227174e-16j, -0.02435787-9.35815288e-02j,
        -0.04447316-1.68361329e-01j, -0.08927592-2.68181781e-01j],
       [-0.02435787+9.35815288e-02j,  0.14578995+1.35782940e-16j,
         0.12476195+5.04488698e-02j,  0.16120482+2.53119287e-02j],
       [-0.04447316+1.68361329e-01j,  0.12476195-5.04488698e-02j,
         0.20787266+1.74455745e-16j,  0.26186673-1.80236212e-02j],
       [-0.08927592+2.68181781e-01j,  0.16120482-2.53119287e-02j,
         0.26186673+1.80236212e-02j,  0.40069873+6.00356188e-16j]]), array([[ 0.20037392-2.00968222e-16j, -0.06667603+1.09662610e-01j,
        -0.01307161+9.90263821e-02j, -0.0291253 -6.42960937e-02j],
       [-0.06667603-1.09662610e-01j,  0.38080316-2.29654398e-15j,
         0.20167757+7.31156533e-02j,  0.23718293+4.29965239e-02j],
       [-0.01307161-9.90263821e-02j,  0.20167757-7.31156533e-02j,
         0.15575588-7.44341059e-16j,  0.0985274 -6.73659168e-02j],
       [-0.0291253 +6.42960937e-02j,  0.23718293-4.29965239e-02j,
         0.0985274 +6.73659168e-02j,  0.26306703+9.13773002e-16j]]), array([[ 0.31100148-4.51101389e-15j, -0.11738747+9.10239166e-02j,
        -0.1134367 -2.20934125e-02j, -0.14549126-1.92514452e-01j],
       [-0.11738747-9.10239166e-02j,  0.29213685-1.78382480e-15j,
         0.14515168+1.31391859e-01j,  0.12013662+7.55699341e-02j],
       [-0.1134367 +2.20934125e-02j,  0.14515168-1.31391859e-01j,
         0.13405173-1.35864072e-15j,  0.11064418-9.22038796e-03j],
       [-0.14549126+1.92514452e-01j,  0.12013662-7.55699341e-02j,
         0.11064418+9.22038796e-03j,  0.26280994+7.89968535e-16j]]), array([[0.21564455+1.65193410e-16j, 0.11750004+7.08428584e-02j,
        0.1588264 +1.56495766e-02j, 0.1861771 -1.45968363e-01j],
       [0.11750004-7.08428584e-02j, 0.14294945-1.52787277e-16j,
        0.12300587-3.93748591e-02j, 0.09553876-1.59567357e-01j],
       [0.1588264 -1.56495766e-02j, 0.12300587+3.93748591e-02j,
        0.20364735+2.67108819e-16j, 0.19762493-1.89092715e-01j],
       [0.1861771 +1.45968363e-01j, 0.09553876+1.59567357e-01j,
        0.19762493+1.89092715e-01j, 0.43775865+1.01431362e-16j]]), array([[ 0.37582931+5.97205229e-17j,  0.09620566+1.34855311e-02j,
         0.08385065-1.71294438e-01j, -0.0653909 -3.17824140e-01j],
       [ 0.09620566-1.34855311e-02j,  0.06970417+3.13369777e-17j,
         0.04059873-4.23038362e-02j, -0.00426049-9.93293842e-02j],
       [ 0.08385065+1.71294438e-01j,  0.04059873+4.23038362e-02j,
         0.15915217-1.71099509e-16j,  0.17694373-1.40988865e-01j],
       [-0.0653909 +3.17824140e-01j, -0.00426049+9.93293842e-02j,
         0.17694373+1.40988865e-01j,  0.39531435-2.97684507e-16j]]), array([[ 0.30168074+6.25386536e-17j, -0.00530978+2.25895944e-01j,
         0.06863438+1.01135388e-01j,  0.04855304-8.06395568e-02j],
       [-0.00530978-2.25895944e-01j,  0.265608  +1.36569703e-15j,
         0.12430857+2.09697731e-02j,  0.09305654-6.10494076e-02j],
       [ 0.06863438-1.01135388e-01j,  0.12430857-2.09697731e-02j,
         0.13747929+1.86824070e-15j,  0.04486362-1.72173779e-01j],
       [ 0.04855304+8.06395568e-02j,  0.09305654+6.10494076e-02j,
         0.04486362+1.72173779e-01j,  0.29523197-2.89998367e-16j]]), array([[ 0.43475177-7.36466855e-15j, -0.04293537+1.91456532e-01j,
        -0.00913095-4.06229591e-02j, -0.09989375-2.04361997e-01j],
       [-0.04293537-1.91456532e-01j,  0.20349935+1.09982302e-15j,
         0.06839309+6.18523453e-02j,  0.00860918-2.93060343e-02j],
       [-0.00913095+4.06229591e-02j,  0.06839309-6.18523453e-02j,
         0.09462812+9.14794738e-16j,  0.04375985-1.17467161e-01j],
       [-0.09989375+2.04361997e-01j,  0.00860918+2.93060343e-02j,
         0.04375985+1.17467161e-01j,  0.26712077+4.91442830e-15j]]), array([[ 0.09300081-3.97281388e-16j, -0.05856051-8.46376510e-02j,
         0.08340496-3.33690737e-02j,  0.06085219-8.30447101e-02j],
       [-0.05856051+8.46376510e-02j,  0.42113515-3.56192493e-15j,
         0.18292631-5.74090462e-02j,  0.10466977+4.54717599e-03j],
       [ 0.08340496+3.33690737e-02j,  0.18292631+5.74090462e-02j,
         0.31413815-4.71199646e-15j,  0.18742594-9.20379825e-02j],
       [ 0.06085219+8.30447101e-02j,  0.10466977-4.54717599e-03j,
         0.18742594+9.20379825e-02j,  0.17172588+1.73613429e-16j]]), array([[ 0.19800404-4.12985427e-16j, -0.0862037 -1.70943822e-01j,
         0.06929998-2.19562959e-01j, -0.00613911-1.49295154e-01j],
       [-0.0862037 +1.70943822e-01j,  0.34377386+4.17495492e-16j,
         0.17784981+1.38041110e-01j,  0.08614237+3.29721768e-02j],
       [ 0.06929998+2.19562959e-01j,  0.17784981-1.38041110e-01j,
         0.30156055-9.57687687e-16j,  0.17620019-7.43487763e-02j],
       [-0.00613911+1.49295154e-01j,  0.08614237-3.29721768e-02j,
         0.17620019+7.43487763e-02j,  0.15666155+5.68507882e-17j]]), array([[ 0.14878544-6.76282609e-16j, -0.20388602+9.63124527e-02j,
        -0.00132764+5.65972812e-02j, -0.02271293-4.01234407e-02j],
       [-0.20388602-9.63124527e-02j,  0.54401878+1.67377687e-15j,
         0.22421179-4.25345433e-02j,  0.12083831+4.20720988e-02j],
       [-0.00132764-5.65972812e-02j,  0.22421179+4.25345433e-02j,
         0.21372022-3.12348897e-16j,  0.09159393-4.16060722e-02j],
       [-0.02271293+4.01234407e-02j,  0.12083831-4.20720988e-02j,
         0.09159393+4.16060722e-02j,  0.09347556-1.19790489e-16j]]), array([[ 0.22923651-7.33905315e-16j, -0.26872456+3.18081529e-02j,
        -0.09408888-1.20265507e-01j, -0.05210248-1.12760282e-01j],
       [-0.26872456-3.18081529e-02j,  0.47201188-2.43579322e-15j,
         0.2008947 +1.87378093e-01j,  0.07241951+1.18482070e-01j],
       [-0.09408888+1.20265507e-01j,  0.2008947 -1.87378093e-01j,
         0.20742384-7.23371433e-16j,  0.09912041-6.22311200e-03j],
       [-0.05210248+1.12760282e-01j,  0.07241951-1.18482070e-01j,
         0.09912041+6.22311200e-03j,  0.09132778-2.62490003e-17j]]), array([[ 0.14895359-1.96832467e-16j,  0.02010566+7.96451699e-02j,
         0.17482559-7.81475639e-03j,  0.10253455-1.31986093e-01j],
       [ 0.02010566-7.96451699e-02j,  0.25722359-3.58482006e-16j,
         0.13279906-1.94507502e-01j, -0.08596834-1.45474649e-01j],
       [ 0.17482559+7.81475639e-03j,  0.13279906+1.94507502e-01j,
         0.34700576-1.21411021e-16j,  0.15691302-2.16311230e-01j],
       [ 0.10253455+1.31986093e-01j, -0.08596834+1.45474649e-01j,
         0.15691302+2.16311230e-01j,  0.24681706-3.66839725e-18j]]), array([[ 0.28575548-7.06036531e-16j, -0.02231562-2.71610845e-02j,
         0.12259754-2.11794224e-01j, -0.00903424-1.86595816e-01j],
       [-0.02231562+2.71610845e-02j,  0.22225799-7.28703554e-17j,
         0.10305941-3.38241216e-02j, -0.08258105-7.62060498e-02j],
       [ 0.12259754+2.11794224e-01j,  0.10305941+3.38241216e-02j,
         0.27625576+8.36243992e-16j,  0.11945383-1.57212098e-01j],
       [-0.00903424+1.86595816e-01j, -0.08258105+7.62060498e-02j,
         0.11945383+1.57212098e-01j,  0.21573076+9.72717528e-17j]]), array([[ 0.24281385+1.06129285e-15j, -0.14155251+2.36998097e-01j,
         0.09078006+8.55471495e-02j,  0.06445067-7.06577828e-02j],
       [-0.14155251-2.36998097e-01j,  0.42448358-2.68202690e-16j,
         0.13907331-1.13888974e-01j, -0.04769758-8.71056444e-02j],
       [ 0.09078006-8.55471495e-02j,  0.13907331+1.13888974e-01j,
         0.20294034+2.88375934e-16j,  0.0487479 -1.42694118e-01j],
       [ 0.06445067+7.06577828e-02j, -0.04769758+8.71056444e-02j,
         0.0487479 +1.42694118e-01j,  0.12976223-5.24393436e-16j]]), array([[ 0.36241856+1.10865100e-14j, -0.18531212+1.80618963e-01j,
         0.01239819-1.10240706e-01j,  0.01186249-1.48887682e-01j],
       [-0.18531212-1.80618963e-01j,  0.3493424 +2.06256503e-14j,
         0.08337137+5.28702995e-02j, -0.08163903-3.19210176e-02j],
       [ 0.01239819+1.10240706e-01j,  0.08337137-5.28702995e-02j,
         0.16232371-2.88432517e-16j,  0.04299576-9.17604146e-02j],
       [ 0.01186249+1.48887682e-01j, -0.08163903+3.19210176e-02j,
         0.04299576+9.17604146e-02j,  0.12591532+5.65915186e-15j]]), array([[0.36996807+7.58653893e-16j, 0.07906584-5.29190715e-02j,
        0.01145425+1.20530487e-01j, 0.09230575-3.88256266e-02j],
       [0.07906584+5.29190715e-02j, 0.14801205-3.67398286e-16j,
        0.16393137+8.79957958e-03j, 0.15995798+6.63052022e-03j],
       [0.01145425-1.20530487e-01j, 0.16393137-8.79957958e-03j,
        0.30536801+2.21340383e-15j, 0.18681491-8.34581849e-03j],
       [0.09230575+3.88256266e-02j, 0.15995798-6.63052022e-03j,
        0.18681491+8.34581849e-03j, 0.17665187+9.48458530e-16j]]), array([[ 0.47122852+1.25282612e-13j,  0.00835862-6.69808419e-02j,
        -0.0992424 -5.41402004e-02j, -0.0505264 -1.68809876e-01j],
       [ 0.00835862+6.69808419e-02j,  0.06931415+3.00983888e-14j,
         0.11948385+1.60272580e-02j,  0.09758886+3.91985810e-02j],
       [-0.0992424 +5.41402004e-02j,  0.11948385-1.60272580e-02j,
         0.25959577-3.06957262e-13j,  0.1976427 +8.49316410e-02j],
       [-0.0505264 +1.68809876e-01j,  0.09758886-3.91985810e-02j,
         0.1976427 -8.49316410e-02j,  0.19986156-5.86980946e-13j]]), array([[ 0.37720183+3.09036045e-15j, -0.03102883+1.22679902e-01j,
        -0.06045978+2.60014551e-01j, -0.01156241-3.49856041e-02j],
       [-0.03102883-1.22679902e-01j,  0.19990508+9.79511151e-16j,
         0.21494801+2.56175835e-02j,  0.12366313+2.70305576e-02j],
       [-0.06045978-2.60014551e-01j,  0.21494801-2.56175835e-02j,
         0.29814491+4.24575832e-15j,  0.08923841+6.42307160e-03j],
       [-0.01156241+3.49856041e-02j,  0.12366313-2.70305576e-02j,
         0.08923841-6.42307160e-03j,  0.12474818+1.74165653e-16j]]), array([[ 0.50007528-2.12690487e-15j, -0.12102396+1.15297145e-01j,
        -0.206745  +8.23984815e-02j, -0.13554939-1.57719388e-01j],
       [-0.12102396-1.15297145e-01j,  0.1341297 +1.30821580e-15j,
         0.16264727+5.55239694e-02j,  0.05195305+9.24220712e-02j],
       [-0.206745  -8.23984815e-02j,  0.16264727-5.55239694e-02j,
         0.22822164-1.56201413e-15j,  0.10722207+9.59458469e-02j],
       [-0.13554939+1.57719388e-01j,  0.05195305-9.24220712e-02j,
         0.10722207-9.59458469e-02j,  0.13757339-2.37221538e-15j]]), array([[0.5305303 +3.00159560e-16j, 0.13727491+8.52751225e-02j,
        0.14924689+8.28030116e-02j, 0.23807775-2.11651966e-02j],
       [0.13727491-8.52751225e-02j, 0.09279108+5.78582833e-16j,
        0.11091877-2.69067818e-02j, 0.08917712-7.76244447e-02j],
       [0.14924689-8.28030116e-02j, 0.11091877+2.69067818e-02j,
        0.19152761+9.56240810e-16j, 0.14463528-8.27702636e-02j],
       [0.23807775+2.11651966e-02j, 0.08917712+7.76244447e-02j,
        0.14463528+8.27702636e-02j, 0.185151  -3.73827390e-16j]]), array([[0.70002982-8.05790419e-16j, 0.09192351+9.13329560e-03j,
        0.02636277-1.32116438e-01j, 0.00357732-1.49911761e-01j],
       [0.09192351-9.13329560e-03j, 0.03571883-3.59874098e-17j,
        0.03946959-1.99960187e-02j, 0.03092871-3.48215543e-02j],
       [0.02636277+1.32116438e-01j, 0.03946959+1.99960187e-02j,
        0.13273282-9.03293678e-17j, 0.11591171-3.76636970e-02j],
       [0.00357732+1.49911761e-01j, 0.03092871+3.48215543e-02j,
        0.11591171+3.76636970e-02j, 0.13151853+9.24713927e-17j]]), array([[0.57400563-2.62895538e-16j, 0.01526514+2.76231190e-01j,
        0.03202175+2.53456150e-01j, 0.13305569+2.70121989e-02j],
       [0.01526514-2.76231190e-01j, 0.16966221+2.21620611e-16j,
        0.14685719-2.81059240e-03j, 0.03940922-7.24043473e-02j],
       [0.03202175-2.53456150e-01j, 0.14685719+2.81059240e-03j,
        0.16911043-2.21001650e-17j, 0.039526  -8.10832787e-02j],
       [0.13305569-2.70121989e-02j, 0.03940922+7.24043473e-02j,
        0.039526  +8.10832787e-02j, 0.08722173+1.12687984e-18j]]), array([[ 0.74578642-9.82601637e-16j, -0.05622884+2.25341885e-01j,
        -0.09457957+1.57036535e-02j, -0.03739795-1.26630735e-01j],
       [-0.05622884-2.25341885e-01j,  0.11097341-1.56803578e-17j,
         0.05113937+3.68684571e-02j, -0.01300264+7.17993880e-03j],
       [-0.09457957-1.57036535e-02j,  0.05113937-3.68684571e-02j,
         0.08137173+6.37878854e-17j,  0.02921608-8.69051550e-03j],
       [-0.03739795+1.26630735e-01j, -0.01300264-7.17993880e-03j,
         0.02921608+8.69051550e-03j,  0.06186844-6.61018758e-17j]]), array([[ 0.21328875+2.94617490e-16j, -0.03640573-8.01867550e-02j,
         0.02782774+8.91179915e-03j,  0.07355289-3.95909815e-02j],
       [-0.03640573+8.01867550e-02j,  0.21605323+1.08567563e-16j,
         0.2461424 -1.20603267e-01j,  0.09776338-6.48912889e-04j],
       [ 0.02782774-8.91179915e-03j,  0.2461424 +1.20603267e-01j,
         0.47429107-1.32687905e-15j,  0.17313409+1.04625034e-02j],
       [ 0.07355289+3.95909815e-02j,  0.09776338+6.48912889e-04j,
         0.17313409-1.04625034e-02j,  0.09636696+9.85385663e-17j]]), array([[ 0.3476365 +5.85809132e-16j, -0.09414247-1.58108948e-01j,
        -0.03222283-2.28884931e-01j,  0.031254  -1.17805148e-01j],
       [-0.09414247+1.58108948e-01j,  0.14508364+1.27942224e-18j,
         0.20443401+4.56546908e-02j,  0.076669  +5.66747583e-02j],
       [-0.03222283+2.28884931e-01j,  0.20443401-4.56546908e-02j,
         0.418156  -1.06004799e-16j,  0.16246982+6.31224820e-02j],
       [ 0.031254  +1.17805148e-01j,  0.076669  -5.66747583e-02j,
         0.16246982-6.31224820e-02j,  0.08912386+1.00061386e-16j]]), array([[ 0.23042629+9.43815095e-17j, -0.16527302+9.95091821e-02j,
        -0.04677362+1.83515720e-01j, -0.01487243-1.94874528e-02j],
       [-0.16527302-9.95091821e-02j,  0.28950288-1.37591139e-16j,
         0.29254454-1.10753474e-01j,  0.05497752+2.88943832e-02j],
       [-0.04677362-1.83515720e-01j,  0.29254454+1.10753474e-01j,
         0.44458483+9.57600352e-17j,  0.06781604+2.64336563e-02j],
       [-0.01487243+1.94874528e-02j,  0.05497752-2.88943832e-02j,
         0.06781604-2.64336563e-02j,  0.035486  +7.33758389e-18j]]), array([[ 0.3669406 -1.43741373e-17j, -0.22546959+4.89438676e-02j,
        -0.13366186-4.67817594e-02j, -0.03201734-9.67029435e-02j],
       [-0.22546959-4.89438676e-02j,  0.21795257+7.70619824e-16j,
         0.22046619+8.09956358e-02j,  0.02054083+9.04751508e-02j],
       [-0.13366186+4.67817594e-02j,  0.22046619-8.09956358e-02j,
         0.37177587+6.84493750e-16j,  0.06536906+7.93048416e-02j],
       [-0.03201734+9.67029435e-02j,  0.02054083-9.04751508e-02j,
         0.06536906-7.93048416e-02j,  0.04333096-4.81994818e-16j]]), array([[ 0.35979138+2.43650735e-16j,  0.0058803 +1.93055299e-02j,
         0.10927286-1.42659242e-02j,  0.16080548-2.41666302e-02j],
       [ 0.0058803 -1.93055299e-02j,  0.1424878 -9.44052280e-16j,
         0.15546766-1.62939557e-01j, -0.0159812 -7.41766722e-02j],
       [ 0.10927286+1.42659242e-02j,  0.15546766+1.62939557e-01j,
         0.38763699+1.24135437e-15j,  0.10468688-9.35614456e-02j],
       [ 0.16080548+2.41666302e-02j, -0.0159812 +7.41766722e-02j,
         0.10468688+9.35614456e-02j,  0.11008383+2.51053267e-16j]]), array([[ 0.53749696+1.69406996e-15j, -0.02210296-6.82264403e-02j,
         0.07714781-2.87365413e-01j,  0.06033025-1.02890093e-01j],
       [-0.02210296+6.82264403e-02j,  0.08618227+3.28636489e-17j,
         0.1144622 -2.55121101e-02j, -0.00335005-2.99017188e-02j],
       [ 0.07714781+2.87365413e-01j,  0.1144622 +2.55121101e-02j,
         0.30973269-4.61122170e-16j,  0.07856009-4.28166015e-02j],
       [ 0.06033025+1.02890093e-01j, -0.00335005+2.99017188e-02j,
         0.07856009+4.28166015e-02j,  0.06658808-1.73161853e-16j]]), array([[ 3.57534357e-01+1.57555612e-15j, -8.93291642e-02+2.01411519e-01j,
         7.37975796e-02+1.67482303e-01j,  9.55042968e-02-1.44479370e-02j],
       [-8.93291642e-02-2.01411519e-01j,  2.05490316e-01+3.02974148e-16j,
         1.98341814e-01-1.39330175e-01j, -4.69492607e-02-6.96576835e-02j],
       [ 7.37975796e-02-1.67482303e-01j,  1.98341814e-01+1.39330175e-01j,
         3.94132291e-01+1.19182908e-15j,  9.73012479e-05-9.95729678e-02j],
       [ 9.55042968e-02+1.44479370e-02j, -4.69492607e-02+6.96576835e-02j,
         9.73012479e-05+9.95729678e-02j,  4.28430350e-02-1.06986060e-16j]]), array([[ 0.53772585-1.34094185e-14j, -0.17234351+1.56761768e-01j,
        -0.03484998-1.06023732e-01j,  0.05638315-7.73340038e-02j],
       [-0.17234351-1.56761768e-01j,  0.18178853-4.83061213e-15j,
         0.11762783+3.15273137e-02j, -0.04680389-3.41888936e-03j],
       [-0.03484998+1.06023732e-01j,  0.11762783-3.15273137e-02j,
         0.26074697-2.79208721e-15j,  0.0029271 -4.98042892e-03j],
       [ 0.05638315+7.73340038e-02j, -0.04680389+3.41888936e-03j,
         0.0029271 +4.98042892e-03j,  0.01973865-9.71450822e-16j]]), array([[ 0.1422212 +1.64583334e-15j,  0.25844635-3.47249828e-02j,
        -0.11976137+5.57621188e-02j,  0.0074414 +6.25346872e-02j],
       [ 0.25844635+3.47249828e-02j,  0.53093731+1.69095932e-15j,
        -0.2139453 +7.17305527e-02j,  0.04182195+1.04167058e-01j],
       [-0.11976137-5.57621188e-02j, -0.2139453 -7.17305527e-02j,
         0.18195673-2.14892288e-15j,  0.08615445-7.49195060e-02j],
       [ 0.0074414 -6.25346872e-02j,  0.04182195-1.04167058e-01j,
         0.08615445+7.49195060e-02j,  0.14488476+1.72431695e-17j]]), array([[ 0.15951948+4.32726722e-16j,  0.22819309+5.91679715e-05j,
        -0.14399874+4.90086947e-02j, -0.14080165-3.78933134e-02j],
       [ 0.22819309-5.91679715e-05j,  0.43039339+1.42995028e-15j,
        -0.20460972+1.17760744e-01j, -0.16903916-2.45324393e-02j],
       [-0.14399874-4.90086947e-02j, -0.20460972-1.17760744e-01j,
         0.20001986-1.80538338e-15j,  0.15834516+6.54054531e-02j],
       [-0.14080165+3.78933134e-02j, -0.16903916+2.45324393e-02j,
         0.15834516-6.54054531e-02j,  0.21006727+3.54414529e-16j]]), array([[ 0.10000167+5.34256386e-17j,  0.15970852+1.14781066e-01j,
        -0.108953  +4.13630159e-02j,  0.01840325+6.21769959e-02j],
       [ 0.15970852-1.14781066e-01j,  0.54697179-4.72202838e-16j,
        -0.20345185+2.10754234e-01j,  0.19282606+8.50070493e-02j],
       [-0.108953  -4.13630159e-02j, -0.20345185-2.10754234e-01j,
         0.21770238-2.42961150e-16j, -0.04499071-7.63355889e-02j],
       [ 0.01840325-6.21769959e-02j,  0.19282606-8.50070493e-02j,
        -0.04499071+7.63355889e-02j,  0.13532416-3.22720923e-16j]]), array([[ 0.14345909+1.76394461e-15j,  0.12314714+1.31300618e-01j,
        -0.13347704+4.60751242e-02j, -0.11162964-2.83856722e-02j],
       [ 0.12314714-1.31300618e-01j,  0.42973213+8.07625092e-16j,
        -0.15663025+2.67241385e-01j, -0.03581587-1.19214589e-02j],
       [-0.13347704-4.60751242e-02j, -0.15663025-2.67241385e-01j,
         0.23712984+1.04232908e-15j,  0.01091362+5.71693346e-02j],
       [-0.11162964+2.83856722e-02j, -0.03581587+1.19214589e-02j,
         0.01091362-5.71693346e-02j,  0.18967895+3.22434905e-17j]]), array([[ 0.18296008+1.09798960e-15j,  0.24351652+6.60996926e-02j,
        -0.11522602-6.35351033e-02j, -0.01149302+1.01783170e-01j],
       [ 0.24351652-6.60996926e-02j,  0.37940835-1.49951365e-16j,
        -0.16190981-7.57193776e-02j, -0.0141573 +6.96710719e-02j],
       [-0.11522602+6.35351033e-02j, -0.16190981+7.57193776e-02j,
         0.14496215+1.25737153e-15j,  0.03574071-1.52868335e-01j],
       [-0.01149302-1.01783170e-01j, -0.0141573 -6.96710719e-02j,
         0.03574071+1.52868335e-01j,  0.29266942-1.02265999e-15j]]), array([[ 0.26333875+7.87309642e-16j,  0.25995573+5.67377016e-02j,
        -0.13807347-9.12772313e-02j, -0.20260246+3.92185941e-03j],
       [ 0.25995573-5.67377016e-02j,  0.32710198-6.31894364e-16j,
        -0.16332946-5.14731764e-02j, -0.21765357-1.14961096e-02j],
       [-0.13807347+9.12772313e-02j, -0.16332946+5.14731764e-02j,
         0.12431974-6.63392092e-16j,  0.09284793-7.19645262e-02j],
       [-0.20260246-3.92185941e-03j, -0.21765357+1.14961096e-02j,
         0.09284793+7.19645262e-02j,  0.28523953+4.77621179e-16j]]), array([[ 0.19213012+9.00686155e-16j,  0.14476213+2.35934101e-01j,
        -0.08576894-9.13310934e-02j,  0.02144544+1.21377591e-01j],
       [ 0.14476213-2.35934101e-01j,  0.43978227-2.04913312e-15j,
        -0.17402786+4.15066378e-02j,  0.16085203+3.13345990e-02j],
       [-0.08576894+9.13310934e-02j, -0.17402786-4.15066378e-02j,
         0.11639724+1.94272000e-17j, -0.10237287-8.99983775e-02j],
       [ 0.02144544-1.21377591e-01j,  0.16085203-3.13345990e-02j,
        -0.10237287+8.99983775e-02j,  0.25169037-2.76604493e-16j]]), array([[ 0.2436616 +5.89647251e-14j,  0.12028527+2.11985224e-01j,
        -0.11099085-9.49405526e-02j, -0.11680139+1.72626279e-02j],
       [ 0.12028527-2.11985224e-01j,  0.33222834-7.71304152e-14j,
        -0.15111795+1.17784780e-01j, -0.05564046-2.98973192e-02j],
       [-0.11099085+9.49405526e-02j, -0.15111795-1.17784780e-01j,
         0.14235672+2.68670869e-14j, -0.05959871-2.16717031e-02j],
       [-0.11680139-1.72626279e-02j, -0.05564046+2.98973192e-02j,
        -0.05959871+2.16717031e-02j,  0.28175334-4.41184235e-15j]]), array([[ 0.03163343-2.59779097e-16j,  0.1143927 -3.51783598e-02j,
        -0.05767347-2.21400775e-02j, -0.00637191-2.48350850e-03j],
       [ 0.1143927 +3.51783598e-02j,  0.60887267-1.14215094e-15j,
        -0.23249122-1.29570557e-01j, -0.02558828+3.96376294e-03j],
       [-0.05767347+2.21400775e-02j, -0.23249122+1.29570557e-01j,
         0.31636227+1.50610249e-15j,  0.08907977+3.77801553e-03j],
       [-0.00637191+2.48350850e-03j, -0.02558828-3.96376294e-03j,
         0.08907977-3.77801553e-03j,  0.04313163-1.30895158e-17j]]), array([[ 0.05897348-6.48766066e-16j,  0.08095951-2.52096587e-02j,
        -0.06289723-6.90346403e-02j, -0.02997468-3.34513841e-02j],
       [ 0.08095951+2.52096587e-02j,  0.50730161+1.10451293e-15j,
        -0.19670161+8.14396676e-02j, -0.18505187-5.51805722e-02j],
       [-0.06289723+6.90346403e-02j, -0.19670161-8.14396676e-02j,
         0.32812467+3.60525315e-16j,  0.13653589+8.62328888e-02j],
       [-0.02997468+3.34513841e-02j, -0.18505187+5.51805722e-02j,
         0.13653589-8.62328888e-02j,  0.10560024-2.49756730e-16j]]), array([[ 0.02333233+4.82480268e-17j,  0.01790395+9.81459828e-02j,
        -0.03283188-2.51122002e-02j,  0.00241715+1.32573091e-02j],
       [ 0.01790395-9.81459828e-02j,  0.62690493-5.85280190e-16j,
        -0.20006213+2.06860485e-02j,  0.09629277+1.37564526e-02j],
       [-0.03283188+2.51122002e-02j, -0.20006213-2.06860485e-02j,
         0.32543835+5.85808197e-16j, -0.0551041 +1.14188357e-02j],
       [ 0.00241715-1.32573091e-02j,  0.09629277-1.37564526e-02j,
        -0.0551041 -1.14188357e-02j,  0.0243244 -8.91055743e-18j]]), array([[ 0.04560106-9.49972176e-18j, -0.01540964+1.07821733e-01j,
        -0.0620136 -6.51405260e-02j,  0.01194196-1.47320334e-02j],
       [-0.01540964-1.07821733e-01j,  0.5513307 +2.77425018e-16j,
        -0.19909469+3.15023131e-01j, -0.08844204-5.70733129e-02j],
       [-0.0620136 +6.51405260e-02j, -0.19909469-3.15023131e-01j,
         0.35491462+8.95469705e-16j, -0.01240532+8.40036195e-02j],
       [ 0.01194196+1.47320334e-02j, -0.08844204+5.70733129e-02j,
        -0.01240532-8.40036195e-02j,  0.04815362-1.27142493e-16j]]), array([[ 0.08346419+2.64928038e-16j,  0.15978672+4.27058946e-02j,
        -0.06352178-1.17858016e-01j, -0.04604245+2.50987837e-02j],
       [ 0.15978672-4.27058946e-02j,  0.48691164+3.64291766e-16j,
        -0.20829755-2.76076439e-01j, -0.14791378+3.55518632e-02j],
       [-0.06352178+1.17858016e-01j, -0.20829755+2.76076439e-01j,
         0.30500206-3.66048780e-16j,  0.02522785-1.42031835e-01j],
       [-0.04604245-2.50987837e-02j, -0.14791378-3.55518632e-02j,
         0.02522785+1.42031835e-01j,  0.12462212+3.56834672e-17j]]), array([[ 0.14228284+3.00165508e-16j,  0.10620601+5.95852949e-02j,
        -0.04901315-1.76413723e-01j, -0.0531968 -1.13521339e-02j],
       [ 0.10620601-5.95852949e-02j,  0.40521495+8.69913226e-16j,
        -0.17979172-6.85248107e-02j, -0.24326994-8.28514306e-02j],
       [-0.04901315+1.76413723e-01j, -0.17979172+6.85248107e-02j,
         0.26465784-2.42732471e-15j,  0.06344955-1.13842688e-02j],
       [-0.0531968 +1.13521339e-02j, -0.24326994+8.28514306e-02j,
         0.06344955+1.13842688e-02j,  0.18784437-8.72889666e-17j]]), array([[ 0.11174508-9.91640812e-16j,  0.03389669+2.16030643e-01j,
        -0.00510569-1.27173586e-01j,  0.025097  +5.09024688e-02j],
       [ 0.03389669-2.16030643e-01j,  0.5276649 +5.88133636e-16j,
        -0.21003274-1.04035197e-01j,  0.03433516-3.34216340e-02j],
       [-0.00510569+1.27173586e-01j, -0.21003274+1.04035197e-01j,
         0.25337724+6.73363415e-16j, -0.10748129-4.35542636e-02j],
       [ 0.025097  -5.09024688e-02j,  0.03433516+3.34216340e-02j,
        -0.10748129+4.35542636e-02j,  0.10721279-6.03599853e-17j]]), array([[ 0.17319686-6.14129374e-16j, -0.0194258 +2.40422013e-01j,
        -0.03951895-1.83086431e-01j,  0.04710509-4.71303290e-03j],
       [-0.0194258 -2.40422013e-01j,  0.46124111+7.89963229e-16j,
        -0.22072166+1.03414818e-01j, -0.11423636-1.16413960e-01j],
       [-0.03951895+1.83086431e-01j, -0.22072166-1.03414818e-01j,
         0.23108864+5.24995583e-17j, -0.05052181+6.04289473e-02j],
       [ 0.04710509+4.71303290e-03j, -0.11423636+1.16413960e-01j,
        -0.05052181-6.04289473e-02j,  0.13447339-2.04279087e-16j]]), array([[ 0.27322157-5.75803556e-16j,  0.26079851-4.38595894e-02j,
        -0.16839867+1.04635281e-01j,  0.02553149+9.62842272e-02j],
       [ 0.26079851+4.38595894e-02j,  0.28451477+5.09122132e-17j,
        -0.16539437+1.55637260e-02j,  0.03790665+9.01737273e-02j],
       [-0.16839867-1.04635281e-01j, -0.16539437-1.55637260e-02j,
         0.3519371 +8.33339203e-16j,  0.06967683+1.47713651e-02j],
       [ 0.02553149-9.62842272e-02j,  0.03790665-9.01737273e-02j,
         0.06967683-1.47713651e-02j,  0.09032656-3.54795034e-16j]]), array([[ 0.30813958+4.60872315e-16j,  0.22652234-2.78002646e-02j,
        -0.21328464+5.53605870e-02j, -0.11785962-8.55485285e-03j],
       [ 0.22652234+2.78002646e-02j,  0.19149312+1.53396109e-16j,
        -0.16963485+5.89170366e-02j, -0.11195628-1.15933569e-02j],
       [-0.21328464-5.53605870e-02j, -0.16963485-5.89170366e-02j,
         0.35849826+1.31950520e-15j,  0.12372509+1.46985020e-01j],
       [-0.11785962+8.55485285e-03j, -0.11195628+1.15933569e-02j,
         0.12372509-1.46985020e-01j,  0.14186904+3.03112756e-16j]]), array([[ 0.20893908+4.13909414e-16j,  0.16872906+1.02922108e-01j,
        -0.14764866+1.45384515e-01j,  0.00598253+6.66498622e-02j],
       [ 0.16872906-1.02922108e-01j,  0.24882197-8.83892872e-16j,
        -0.12403265+1.09428712e-01j,  0.10919058+5.95544093e-02j],
       [-0.14764866-1.45384515e-01j, -0.12403265-1.09428712e-01j,
         0.42924867-6.23448400e-15j, -0.06291705+3.96845297e-02j],
       [ 0.00598253-6.66498622e-02j,  0.10919058-5.95544093e-02j,
        -0.06291705-3.96845297e-02j,  0.11299028+8.01239475e-16j]]), array([[ 0.24023644-1.00423636e-15j,  0.14130201+1.13138981e-01j,
        -0.20443753+1.35969372e-01j, -0.10364286-2.80089877e-02j],
       [ 0.14130201-1.13138981e-01j,  0.1820648 -2.51753146e-16j,
        -0.11695426+2.23197382e-01j, -0.06777065-9.11245428e-03j],
       [-0.20443753-1.35969372e-01j, -0.11695426-2.23197382e-01j,
         0.44913467+6.81034853e-17j, -0.00191709+1.63303546e-01j],
       [-0.10364286+2.80089877e-02j, -0.06777065+9.11245428e-03j,
        -0.00191709-1.63303546e-01j,  0.12856409-3.24951023e-16j]]), array([[ 0.40899436-9.00273647e-17j,  0.3014283 +2.93408374e-02j,
        -0.18443598-1.00202565e-01j,  0.05089267+2.00903021e-01j],
       [ 0.3014283 -2.93408374e-02j,  0.25469187+2.32728021e-16j,
        -0.15719976-8.67170078e-02j,  0.04926746+1.35665604e-01j],
       [-0.18443598+1.00202565e-01j, -0.15719976+8.67170078e-02j,
         0.19494763+6.92935872e-16j, -0.04250211-7.78959208e-02j],
       [ 0.05089267-2.00903021e-01j,  0.04926746-1.35665604e-01j,
        -0.04250211+7.78959208e-02j,  0.14136614-3.74068756e-18j]]), array([[ 0.48824209-3.93422934e-16j,  0.27132853+1.81791028e-02j,
        -0.17387914-1.34962625e-01j, -0.13714318+1.14184963e-01j],
       [ 0.27132853-1.81791028e-02j,  0.1824512 +3.20092309e-16j,
        -0.12575893-3.46946384e-02j, -0.10222979+4.67416541e-02j],
       [-0.17387914+1.34962625e-01j, -0.12575893+3.46946384e-02j,
         0.19081661+1.28822482e-17j,  0.01171219-8.02300938e-03j],
       [-0.13714318-1.14184963e-01j, -0.10222979-4.67416541e-02j,
         0.01171219+8.02300938e-03j,  0.1384901 +1.93711383e-16j]]), array([[ 0.35987585-2.17362871e-15j,  0.16478437+2.12841319e-01j,
        -0.14200326-9.02307585e-02j,  0.0778183 +1.90168651e-01j],
       [ 0.16478437-2.12841319e-01j,  0.22503361-7.17618304e-16j,
        -0.14239693+1.76302608e-02j,  0.16893303+4.74032078e-02j],
       [-0.14200326+9.02307585e-02j, -0.14239693-1.76302608e-02j,
         0.23922928-5.55396066e-16j, -0.14761549-1.38275513e-02j],
       [ 0.0778183 -1.90168651e-01j,  0.16893303-4.74032078e-02j,
        -0.14761549+1.38275513e-02j,  0.17586127+6.04963824e-17j]]), array([[ 0.41542348-8.10458572e-15j,  0.13601473+1.86426693e-01j,
        -0.1587898 -1.01552632e-01j, -0.06973237+8.32030626e-02j],
       [ 0.13601473-1.86426693e-01j,  0.1559937 +1.49197468e-15j,
        -0.12036628+9.98691798e-02j, -0.01214978+1.46636277e-03j],
       [-0.1587898 +1.01552632e-01j, -0.12036628-9.98691798e-02j,
         0.24946956+3.51603578e-15j, -0.10387548+6.16282891e-02j],
       [-0.06973237-8.32030626e-02j, -0.01214978-1.46636277e-03j,
        -0.10387548-6.16282891e-02j,  0.17911326+5.50748258e-16j]]), array([[ 0.07338671+1.25068051e-16j,  0.11607491-5.27534261e-02j,
        -0.11681428-6.16564631e-02j,  0.01612969-1.40292788e-02j],
       [ 0.11607491+5.27534261e-02j,  0.28111024+1.50867903e-15j,
        -0.18443063-2.37275177e-01j,  0.04539865-2.52495478e-02j],
       [-0.11681428+6.16564631e-02j, -0.18443063+2.37275177e-01j,
         0.57783292-3.47861752e-16j,  0.04901034+1.40884698e-01j],
       [ 0.01612969+1.40292788e-02j,  0.04539865+2.52495478e-02j,
         0.04901034-1.40884698e-01j,  0.06767014+1.32634488e-16j]]), array([[ 0.1235535 -3.83979491e-16j,  0.07914762-4.96672308e-02j,
        -0.11845526-1.35068761e-01j,  0.01362888-3.60272173e-02j],
       [ 0.07914762+4.96672308e-02j,  0.20546741-3.76302533e-16j,
        -0.13584489+8.34513467e-03j, -0.09092151-5.34283842e-02j],
       [-0.11845526+1.35068761e-01j, -0.13584489-8.34513467e-03j,
         0.54209065-4.28481581e-15j,  0.08872203+2.13816117e-01j],
       [ 0.01362888+3.60272173e-02j, -0.09092151+5.34283842e-02j,
         0.08872203-2.13816117e-01j,  0.12888844-7.15974244e-17j]]), array([[ 0.0490474 -1.09059560e-16j,  0.05673451+6.09107963e-02j,
        -0.09437956+1.92555684e-02j,  0.0144135 +6.22967034e-03j],
       [ 0.05673451-6.09107963e-02j,  0.25637977+2.59488700e-16j,
        -0.11629109-3.09652472e-02j,  0.07499214+1.87350394e-02j],
       [-0.09437956-1.92555684e-02j, -0.11629109+3.09652472e-02j,
         0.64603243+5.85108342e-16j, -0.10736626+7.66765417e-02j],
       [ 0.0144135 -6.22967034e-03j,  0.07499214-1.87350394e-02j,
        -0.10736626-7.66765417e-02j,  0.04854039+5.30188863e-16j]]), array([[ 0.06937111+8.82816450e-17j,  0.00937178+6.68146502e-02j,
        -0.12678301-7.16069033e-02j,  0.0251807 -2.36659844e-02j],
       [ 0.00937178-6.68146502e-02j,  0.16640106-2.47548982e-16j,
        -0.11157004+2.30400638e-01j, -0.05659438-4.98735519e-02j],
       [-0.12678301+7.16069033e-02j, -0.11157004-2.30400638e-01j,
         0.6798624 +4.02481168e-16j, -0.07225437+1.85001931e-01j],
       [ 0.0251807 +2.36659844e-02j, -0.05659438+4.98735519e-02j,
        -0.07225437-1.85001931e-01j,  0.08436543+1.06222156e-16j]]), array([[ 0.20387491+5.47412237e-16j,  0.18846995-6.78357914e-03j,
        -0.11259173-2.23308800e-01j,  0.01406169+8.71146565e-02j],
       [ 0.18846995+6.78357914e-03j,  0.24538385+5.92244807e-16j,
        -0.13840437-2.84879263e-01j, -0.00938897+7.15890294e-02j],
       [-0.11259173+2.23308800e-01j, -0.13840437+2.84879263e-01j,
         0.4778577 -5.51875150e-16j, -0.07263963-5.02559359e-02j],
       [ 0.01406169-8.71146565e-02j, -0.00938897-7.15890294e-02j,
        -0.07263963+5.02559359e-02j,  0.07288355+2.12719556e-17j]]), array([[ 0.28569189-2.36407299e-16j,  0.13208063-1.42481343e-02j,
        -0.08616292-2.84006270e-01j, -0.01684939+7.17597996e-02j],
       [ 0.13208063+1.42481343e-02j,  0.18007789-1.02755842e-15j,
        -0.10879181-7.35229287e-02j, -0.10726987-1.51441403e-02j],
       [-0.08616292+2.84006270e-01j, -0.10879181+7.35229287e-02j,
         0.41138712-3.95182904e-15j, -0.02416774+4.92941355e-02j],
       [-0.01684939-7.17597996e-02j, -0.10726987+1.51441403e-02j,
        -0.02416774-4.92941355e-02j,  0.1228431 -2.92033787e-16j]]), array([[ 0.17078443+7.62760786e-16j,  0.0798885 +1.44718872e-01j,
        -0.06189134-1.71886350e-01j,  0.03879445+9.46280480e-02j],
       [ 0.0798885 -1.44718872e-01j,  0.21332806+1.46887960e-16j,
        -0.14246251-1.19548719e-01j,  0.08516991+3.33219975e-02j],
       [-0.06189134+1.71886350e-01j, -0.14246251+1.19548719e-01j,
         0.51704773-7.57735754e-16j, -0.1978374 -1.67979148e-02j],
       [ 0.03879445-9.46280480e-02j,  0.08516991-3.33219975e-02j,
        -0.1978374 +1.67979148e-02j,  0.09883978+4.35958441e-17j]]), array([[ 2.59585957e-01+4.50309654e-16j,  6.80210390e-03+1.55477325e-01j,
        -1.04931417e-01-2.92392936e-01j,  7.97364290e-02+6.55918672e-02j],
       [ 6.80210390e-03-1.55477325e-01j,  1.51967224e-01-1.55205618e-16j,
        -1.58750278e-01+9.81326943e-02j,  5.95712949e-05-6.12721079e-02j],
       [-1.04931417e-01+2.92392936e-01j, -1.58750278e-01-9.81326943e-02j,
         4.78443990e-01-7.33180624e-16j, -1.57709543e-01+1.05866964e-01j],
       [ 7.97364290e-02-6.55918672e-02j,  5.95712949e-05+6.12721079e-02j,
        -1.57709543e-01-1.05866964e-01j,  1.10002829e-01+1.50033894e-16j]]), array([[0.12345288-2.20593191e-16j, 0.24112111-2.84416280e-03j,
        0.01964965+3.01244038e-02j, 0.04470011+8.64429743e-02j],
       [0.24112111+2.84416280e-03j, 0.56062331+2.28193653e-16j,
        0.02958121+1.03300268e-01j, 0.08736961+2.46533978e-01j],
       [0.01964965-3.01244038e-02j, 0.02958121-1.03300268e-01j,
        0.08887849-1.88155895e-17j, 0.11959886-8.84868494e-03j],
       [0.04470011-8.64429743e-02j, 0.08736961-2.46533978e-01j,
        0.11959886+8.84868494e-03j, 0.22704533-3.83724106e-17j]]), array([[ 0.15697747+7.93176678e-17j,  0.19132767+2.47270679e-02j,
        -0.03071293+6.76503014e-03j, -0.08505439-4.62956824e-02j],
       [ 0.19132767-2.47270679e-02j,  0.4148408 +1.42945169e-15j,
         0.0136444 +1.53322310e-01j, -0.13098358+1.50199876e-01j],
       [-0.03071293-6.76503014e-03j,  0.0136444 -1.53322310e-01j,
         0.14019379-2.44552682e-15j,  0.1695244 +8.59311469e-02j],
       [-0.08505439+4.62956824e-02j, -0.13098358-1.50199876e-01j,
         0.1695244 -8.59311469e-02j,  0.28798794+6.97920685e-17j]]), array([[ 0.11656406+4.09700970e-16j,  0.12246225+1.92818698e-01j,
        -0.02033915+6.85815412e-02j, -0.06197583+6.68406400e-02j],
       [ 0.12246225-1.92818698e-01j,  0.60657852-8.55603687e-16j,
         0.07132066+9.43850391e-02j,  0.13947785+2.35855360e-01j],
       [-0.02033915-6.85815412e-02j,  0.07132066-9.43850391e-02j,
         0.0816759 -1.80395431e-16j,  0.01785078+3.71187365e-02j],
       [-0.06197583-6.68406400e-02j,  0.13947785-2.35855360e-01j,
         0.01785078-3.71187365e-02j,  0.19518152-3.17951250e-16j]]), array([[ 0.16102922+1.51200022e-16j,  0.09136964+2.10344897e-01j,
        -0.09567519+8.31362406e-02j, -0.15578622-5.85366412e-02j],
       [ 0.09136964-2.10344897e-01j,  0.46667948-3.52977477e-16j,
         0.0517031 +2.21469890e-01j, -0.1226303 +1.96885937e-01j],
       [-0.09567519-8.31362406e-02j,  0.0517031 -2.21469890e-01j,
         0.13788651+7.95915917e-17j,  0.06738383+1.08535647e-01j],
       [-0.15578622+5.85366412e-02j, -0.1226303 -1.96885937e-01j,
         0.06738383-1.08535647e-01j,  0.23440479+6.36498363e-16j]]), array([[ 0.20876438-3.39991147e-15j,  0.24683487+1.16546922e-01j,
         0.04908748-5.43881217e-02j,  0.02034646+4.45185507e-02j],
       [ 0.24683487-1.16546922e-01j,  0.40640918-2.60035954e-15j,
        -0.01560408-8.74465794e-02j, -0.01355987+1.44651920e-01j],
       [ 0.04908748+5.43881217e-02j, -0.01560408+8.74465794e-02j,
         0.06646639+1.07371266e-15j,  0.06011356-7.21593912e-02j],
       [ 0.02034646-4.45185507e-02j, -0.01355987-1.44651920e-01j,
         0.06011356+7.21593912e-02j,  0.31836006-6.60278700e-15j]]), array([[ 0.2892368 +4.29389239e-16j,  0.25238149+1.14009511e-01j,
         0.01688216-7.61127692e-02j, -0.15097681-6.50751659e-02j],
       [ 0.25238149-1.14009511e-01j,  0.33667297-1.11145329e-15j,
        -0.02482214-3.21463060e-02j, -0.21443071+9.71420802e-02j],
       [ 0.01688216+7.61127692e-02j, -0.02482214+3.21463060e-02j,
         0.0628003 -5.95762120e-17j,  0.08779464-2.00298386e-02j],
       [-0.15097681+6.50751659e-02j, -0.21443071-9.71420802e-02j,
         0.08779464+2.00298386e-02j,  0.31128993-1.52136905e-15j]]), array([[ 0.24447763+5.76408013e-16j,  0.16029541+2.91040818e-01j,
         0.03473494-6.25142777e-03j, -0.0550536 +4.56062348e-02j],
       [ 0.16029541-2.91040818e-01j,  0.48844159-1.65242470e-17j,
        -0.0034326 -5.06890491e-02j,  0.05357972+1.49284011e-01j],
       [ 0.03473494+6.25142777e-03j, -0.0034326 +5.06890491e-02j,
         0.03273481+3.33490994e-17j, -0.0564325 -3.93528978e-02j],
       [-0.0550536 -4.56062348e-02j,  0.05357972-1.49284011e-01j,
        -0.0564325 +3.93528978e-02j,  0.23434597+1.28055540e-16j]]), array([[ 0.3282464 -7.84508485e-16j,  0.15094967+3.05193641e-01j,
        -0.01351299+3.04651825e-03j, -0.2071374 -1.02298195e-01j],
       [ 0.15094967-3.05193641e-01j,  0.39429222+1.20166888e-15j,
        -0.00391778+2.70067726e-02j, -0.19620785+1.38937984e-01j],
       [-0.01351299-3.04651825e-03j, -0.00391778-2.70067726e-02j,
         0.03572893-4.41564859e-18j, -0.01898008+8.76941386e-03j],
       [-0.2071374 +1.02298195e-01j, -0.19620785-1.38937984e-01j,
        -0.01898008-8.76941386e-03j,  0.24173245+3.18750916e-17j]]), array([[ 0.03635677-8.10323992e-15j,  0.10217573-1.69114320e-02j,
         0.05725617-4.50612216e-02j,  0.03197483+1.90399114e-02j],
       [ 0.10217573+1.69114320e-02j,  0.60684012+1.31925128e-14j,
         0.01496545-6.16483124e-02j, -0.02215116+1.82163666e-01j],
       [ 0.05725617+4.50612216e-02j,  0.01496545+6.16483124e-02j,
         0.24235091-1.14733508e-14j,  0.09700592+2.15605795e-02j],
       [ 0.03197483-1.90399114e-02j, -0.02215116-1.82163666e-01j,
         0.09700592-2.15605795e-02j,  0.1144522 +8.17092723e-16j]]), array([[ 0.07365814-8.66020519e-16j,  0.07473323-2.01213957e-02j,
         0.03138131-9.58842081e-02j,  0.00719779-2.69222548e-02j],
       [ 0.07473323+2.01213957e-02j,  0.51648431+2.32651742e-14j,
         0.02579394+1.34162367e-01j, -0.17743905+1.32329601e-01j],
       [ 0.03138131+9.58842081e-02j,  0.02579394-1.34162367e-01j,
         0.25651978-2.20269979e-15j,  0.13381394+8.49151539e-02j],
       [ 0.00719779+2.69222548e-02j, -0.17743905-1.32329601e-01j,
         0.13381394-8.49151539e-02j,  0.15333776+1.14050793e-14j]]), array([[ 0.0383761 -7.18469710e-17j, -0.0056255 +1.44766878e-01j,
         0.03051909+1.00441831e-02j, -0.04353547+1.02040508e-02j],
       [-0.0056255 -1.44766878e-01j,  0.67027208+1.60194512e-15j,
         0.04430773-3.78440421e-02j,  0.03409925+1.93084236e-01j],
       [ 0.03051909-1.00441831e-02j,  0.04430773+3.78440421e-02j,
         0.21953987+1.14573083e-16j, -0.02056808+5.76005197e-02j],
       [-0.04353547-1.02040508e-02j,  0.03409925-1.93084236e-01j,
        -0.02056808-5.76005197e-02j,  0.07181195+1.55830148e-18j]]), array([[ 0.06419595+9.77264986e-17j, -0.04260302+1.45166662e-01j,
        -0.02455487-3.10822280e-02j, -0.03226605-4.11850221e-02j],
       [-0.04260302-1.45166662e-01j,  0.57204375-1.03782187e-15j,
         0.04641366+2.29398230e-01j, -0.15812787+1.64688528e-01j],
       [-0.02455487+3.10822280e-02j,  0.04641366-2.29398230e-01j,
         0.25022905-3.41058958e-17j,  0.02834138+1.09550624e-01j],
       [-0.03226605+4.11850221e-02j, -0.15812787-1.64688528e-01j,
         0.02834138-1.09550624e-01j,  0.11353124+1.24353415e-16j]]), array([[ 0.11813756-1.86115703e-16j,  0.15830579+9.32428808e-02j,
         0.09768046-9.90471607e-02j, -0.00672039-7.78549578e-03j],
       [ 0.15830579-9.32428808e-02j,  0.507129  +1.14651991e-15j,
        -0.02033754-2.44925927e-01j, -0.13740774+1.21625516e-01j],
       [ 0.09768046+9.90471607e-02j, -0.02033754+2.44925927e-01j,
         0.21159853-1.29165374e-16j,  0.03227283-7.59018041e-02j],
       [-0.00672039+7.78549578e-03j, -0.13740774-1.21625516e-01j,
         0.03227283+7.59018041e-02j,  0.16313492+3.96179368e-17j]]), array([[ 0.1766781 -1.76353206e-14j,  0.11484663+8.13536694e-02j,
         0.07050034-1.65694581e-01j, -0.03416451-6.21701859e-02j],
       [ 0.11484663-8.13536694e-02j,  0.41115253-1.72489674e-14j,
        -0.02389542-5.50394881e-02j, -0.25969763+6.90082910e-02j],
       [ 0.07050034+1.65694581e-01j, -0.02389542+5.50394881e-02j,
         0.20822292+1.07997678e-14j,  0.06682007+4.73384457e-03j],
       [-0.03416451+6.21701859e-02j, -0.25969763-6.90082910e-02j,
         0.06682007-4.73384457e-03j,  0.20394644+5.83508101e-15j]]), array([[ 0.15387072-1.45767242e-16j,  0.05312235+2.77178654e-01j,
         0.10552596-3.30027570e-02j, -0.07160054-2.06201507e-02j],
       [ 0.05312235-2.77178654e-01j,  0.6016235 -5.60626257e-16j,
        -0.00722438-2.23345231e-01j, -0.08069584+1.40804045e-01j],
       [ 0.10552596+3.30027570e-02j, -0.00722438+2.23345231e-01j,
         0.15735318+1.56762861e-16j, -0.08525932-3.67223874e-02j],
       [-0.07160054+2.06201507e-02j, -0.08069584-1.40804045e-01j,
        -0.08525932+3.67223874e-02j,  0.08715259-2.70956528e-16j]]), array([[ 0.20000732-8.76311333e-16j,  0.00290193+2.51676278e-01j,
         0.03665219-1.08149950e-01j, -0.05177506-7.75320623e-02j],
       [ 0.00290193-2.51676278e-01j,  0.46913669+9.70521575e-16j,
        -0.03271012+2.55504065e-02j, -0.21788145+8.19189977e-02j],
       [ 0.03665219+1.08149950e-01j, -0.03271012-2.55504065e-02j,
         0.18438419-6.11073307e-16j, -0.04463556+3.01740748e-02j],
       [-0.05177506+7.75320623e-02j, -0.21788145-8.19189977e-02j,
        -0.04463556-3.01740748e-02j,  0.1464718 -1.19020057e-15j]]), array([[0.25075406-3.01597612e-16j, 0.2741498 -2.76915310e-03j,
        0.07765939+6.61063103e-02j, 0.06504998+1.42007794e-01j],
       [0.2741498 +2.76915310e-03j, 0.33980307+9.37257195e-16j,
        0.13274463+4.21438475e-02j, 0.10040245+1.82804571e-01j],
       [0.07765939-6.61063103e-02j, 0.13274463-4.21438475e-02j,
        0.23127874-4.92366603e-16j, 0.09419606+1.30854307e-01j],
       [0.06504998-1.42007794e-01j, 0.10040245-1.82804571e-01j,
        0.09419606-1.30854307e-01j, 0.17816413-5.38541138e-16j]]), array([[ 0.3216333 +2.88539246e-15j,  0.24359975-1.76063600e-02j,
         0.00532272+3.55921543e-02j, -0.06885927+2.98713565e-02j],
       [ 0.24359975+1.76063600e-02j,  0.24435806+1.90289668e-15j,
         0.07261139+1.25078604e-01j, -0.08605633+1.06064282e-01j],
       [ 0.00532272-3.55921543e-02j,  0.07261139-1.25078604e-01j,
         0.26247257-4.17263801e-15j,  0.11274402+1.72273730e-01j],
       [-0.06885927-2.98713565e-02j, -0.08605633-1.06064282e-01j,
         0.11274402-1.72273730e-01j,  0.17153607-3.79929656e-16j]]), array([[ 0.2137438 +7.74973635e-16j,  0.16162594+1.63340059e-01j,
         0.00548327+1.71761868e-01j, -0.05153276+7.81607828e-02j],
       [ 0.16162594-1.63340059e-01j,  0.31995366-7.85609153e-16j,
         0.1316574 +2.96851344e-02j,  0.0913016 +1.51479903e-01j],
       [ 0.00548327-1.71761868e-01j,  0.1316574 -2.96851344e-02j,
         0.30134986-1.80830976e-16j, -0.02376024+1.48712170e-01j],
       [-0.05153276-7.81607828e-02j,  0.0913016 -1.51479903e-01j,
        -0.02376024-1.48712170e-01j,  0.16495268+4.48768746e-16j]]), array([[ 0.25852387+2.69358882e-16j,  0.1524358 +1.62349849e-01j,
        -0.05497646+2.07538187e-01j, -0.16463199-1.35924092e-02j],
       [ 0.1524358 -1.62349849e-01j,  0.23442257+1.41791805e-16j,
         0.13417815+1.94439025e-01j, -0.12482852+1.18091320e-01j],
       [-0.05497646-2.07538187e-01j,  0.13417815-1.94439025e-01j,
         0.33890825-2.72797196e-16j,  0.01964031+2.15005742e-01j],
       [-0.16463199+1.35924092e-02j, -0.12482852-1.18091320e-01j,
         0.01964031-2.15005742e-01j,  0.1681453 -1.06260913e-16j]]), array([[ 0.44004088+2.09973706e-16j,  0.32377983+9.52663498e-02j,
         0.10042598-9.48675701e-02j,  0.10058549+1.93530200e-01j],
       [ 0.32377983-9.52663498e-02j,  0.29508898-2.00828081e-17j,
         0.0500266 -9.93846510e-02j,  0.11097415+1.31712434e-01j],
       [ 0.10042598+9.48675701e-02j,  0.0500266 +9.93846510e-02j,
         0.09579301-2.88144928e-16j, -0.0007178 +6.67434813e-02j],
       [ 0.10058549-1.93530200e-01j,  0.11097415-1.31712434e-01j,
        -0.0007178 -6.67434813e-02j,  0.16907714+2.28865793e-16j]]), array([[ 0.53953148+6.36038948e-16j,  0.32750342+3.80631210e-02j,
         0.0829197 -9.87655534e-02j, -0.13842252+9.26353235e-02j],
       [ 0.32750342-3.80631210e-02j,  0.23306096-1.07375070e-16j,
         0.04724046-3.14984273e-02j, -0.10663706+9.04849196e-02j],
       [ 0.0829197 +9.87655534e-02j,  0.04724046+3.14984273e-02j,
         0.10135678+4.13320167e-17j, -0.00316518+3.99739530e-02j],
       [-0.13842252-9.26353235e-02j, -0.10663706-9.04849196e-02j,
        -0.00316518-3.99739530e-02j,  0.12605078-1.09269218e-16j]]), array([[ 0.39256648+1.03921091e-15j,  0.19571049+2.62089287e-01j,
         0.06002211+2.55415367e-02j, -0.01104709+1.29709965e-01j],
       [ 0.19571049-2.62089287e-01j,  0.29802953-1.25051313e-15j,
         0.05794337-6.92184555e-02j,  0.089137  +1.10435134e-01j],
       [ 0.06002211-2.55415367e-02j,  0.05794337+6.92184555e-02j,
         0.15387851-1.06866201e-16j, -0.10132035+6.89852023e-02j],
       [-0.01104709-1.29709965e-01j,  0.089137  -1.10435134e-01j,
        -0.10132035-6.89852023e-02j,  0.15552548+1.03177594e-16j]]), array([[ 0.47531628-5.26250191e-16j,  0.19172199+2.23424513e-01j,
         0.02451928+8.29251984e-04j, -0.15386408+2.13729382e-02j],
       [ 0.19172199-2.23424513e-01j,  0.20702213-1.90964311e-15j,
         0.04859406+3.03401215e-02j, -0.09396049+8.16262596e-02j],
       [ 0.02451928-8.29251984e-04j,  0.04859406-3.03401215e-02j,
         0.17201739-5.28980904e-16j, -0.09109213+9.14156818e-02j],
       [-0.15386408-2.13729382e-02j, -0.09396049-8.16262596e-02j,
        -0.09109213-9.14156818e-02j,  0.1456442 +7.05963279e-16j]]), array([[0.07389496+2.94358631e-16j, 0.1266836 -3.17842619e-02j,
        0.083105  -9.29242098e-02j, 0.06435243+5.63054006e-02j],
       [0.1266836 +3.17842619e-02j, 0.30413796+1.19397771e-15j,
        0.13911502-1.60807230e-01j, 0.08372904+1.25531339e-01j],
       [0.083105  +9.29242098e-02j, 0.13911502+1.60807230e-01j,
        0.4740994 +7.35809158e-16j, 0.05668332+2.12414538e-01j],
       [0.06435243-5.63054006e-02j, 0.08372904-1.25531339e-01j,
        0.05668332-2.12414538e-01j, 0.14786768+1.32497919e-17j]]), array([[ 0.13288073+3.13174385e-16j,  0.09842102-5.60294211e-02j,
         0.04374874-1.50170210e-01j,  0.04715343+1.47076007e-02j],
       [ 0.09842102+5.60294211e-02j,  0.24345429-5.01519293e-16j,
         0.11745483+8.99487240e-02j, -0.08237083+1.03427495e-01j],
       [ 0.04374874+1.50170210e-01j,  0.11745483-8.99487240e-02j,
         0.46595554-1.22356833e-15j,  0.08377291+2.27661893e-01j],
       [ 0.04715343-1.47076007e-02j, -0.08237083-1.03427495e-01j,
         0.08377291-2.27661893e-01j,  0.15770943+1.53254727e-16j]]), array([[ 0.05904655-2.25712216e-16j,  0.05228772+1.16112882e-01j,
         0.06487936+6.17746820e-02j, -0.04509669+3.42209461e-02j],
       [ 0.05228772-1.16112882e-01j,  0.32984037-1.58210729e-16j,
         0.18209849-1.03457109e-01j,  0.04019558+1.36347858e-01j],
       [ 0.06487936-6.17746820e-02j,  0.18209849+1.03457109e-01j,
         0.5140308 -1.31038848e-15j, -0.0700488 +1.76390983e-01j],
       [-0.04509669-3.42209461e-02j,  0.04019558-1.36347858e-01j,
        -0.0700488 -1.76390983e-01j,  0.09708228+7.36198322e-16j]]), array([[ 0.07457799+2.41400625e-17j,  0.02865812+7.56520493e-02j,
         0.02236082+9.37661039e-03j, -0.03822623+1.53451595e-03j],
       [ 0.02865812-7.56520493e-02j,  0.24841305+5.22043443e-16j,
         0.1792229 +1.93699165e-01j, -0.10716655+1.00438936e-01j],
       [ 0.02236082-9.37661039e-03j,  0.1792229 -1.93699165e-01j,
         0.55779844-6.02813864e-16j, -0.03567913+2.20692902e-01j],
       [-0.03822623-1.53451595e-03j, -0.10716655-1.00438936e-01j,
        -0.03567913-2.20692902e-01j,  0.11921052-3.72535187e-17j]]), array([[ 0.24903053+2.58647560e-17j,  0.2194044 +6.19499116e-02j,
         0.15567514-2.19779760e-01j,  0.05564767+8.10068023e-02j],
       [ 0.2194044 -6.19499116e-02j,  0.28696844+1.39430071e-16j,
         0.0709603 -2.81800033e-01j,  0.04409268+7.40744709e-02j],
       [ 0.15567514+2.19779760e-01j,  0.0709603 +2.81800033e-01j,
         0.37969695+2.30825166e-17j, -0.03333078+8.28283511e-02j],
       [ 0.05564767-8.10068023e-02j,  0.04409268-7.40744709e-02j,
        -0.03333078-8.28283511e-02j,  0.08430408-3.17319078e-17j]]), array([[ 0.33119976+1.13182649e-15j,  0.17672887-5.86001147e-03j,
         0.12536671-2.70254501e-01j, -0.01146005+6.09813671e-02j],
       [ 0.17672887+5.86001147e-03j,  0.20488155+6.66150850e-16j,
         0.07900026-6.16614273e-02j, -0.10275335+6.73308395e-02j],
       [ 0.12536671+2.70254501e-01j,  0.07900026+6.16614273e-02j,
         0.34641019+1.43028780e-15j, -0.03289051+9.28341676e-02j],
       [-0.01146005-6.09813671e-02j, -0.10275335-6.73308395e-02j,
        -0.03289051-9.28341676e-02j,  0.1175085 -3.33338407e-16j]]), array([[ 0.21027521-7.74295637e-16j,  0.1110835 +1.98529006e-01j,
         0.14611459-5.81510596e-02j, -0.04302278+5.45955239e-02j],
       [ 0.1110835 -1.98529006e-01j,  0.29597021-5.95989200e-16j,
         0.09666782-2.17347589e-01j,  0.00253837+9.77382520e-02j],
       [ 0.14611459+5.81510596e-02j,  0.09666782+2.17347589e-01j,
         0.40736952-2.75778705e-16j, -0.16291667+5.20830223e-02j],
       [-0.04302278-5.45955239e-02j,  0.00253837-9.77382520e-02j,
        -0.16291667-5.20830223e-02j,  0.08638506+1.05624841e-16j]]), array([[ 0.28768824+1.25860106e-15j,  0.07586463+1.59756738e-01j,
         0.0904091 -1.48656358e-01j, -0.0606667 +1.27928087e-02j],
       [ 0.07586463-1.59756738e-01j,  0.21772299-5.43270781e-15j,
         0.08433334+1.04850818e-02j, -0.10839318+5.85564308e-02j],
       [ 0.0904091 +1.48656358e-01j,  0.08433334-1.04850818e-02j,
         0.38573196+1.26932178e-14j, -0.13689938+9.23706284e-02j],
       [-0.0606667 -1.27928087e-02j, -0.10839318-5.85564308e-02j,
        -0.13689938-9.23706284e-02j,  0.10885681-4.46284366e-15j]]), array([[ 0.14748435-4.99517488e-16j,  0.22871651-1.01922739e-01j,
        -0.0759701 -9.76110952e-03j,  0.04227646-9.54893606e-02j],
       [ 0.22871651+1.01922739e-01j,  0.55873903-2.52904318e-15j,
        -0.06262101-8.40955303e-02j,  0.2128687 -1.75621818e-01j],
       [-0.0759701 +9.76110952e-03j, -0.06262101+8.40955303e-02j,
         0.10554281+7.22027416e-17j,  0.04443152+3.14367347e-02j],
       [ 0.04227646+9.54893606e-02j,  0.2128687 +1.75621818e-01j,
         0.04443152-3.14367347e-02j,  0.18823381+1.49746165e-15j]]), array([[ 0.22544292+2.32749264e-16j,  0.20399113-1.17745142e-01j,
        -0.11132801-1.98959015e-02j, -0.11791921-1.62250657e-01j],
       [ 0.20399113+1.17745142e-01j,  0.42963154+1.18564644e-15j,
        -0.04673143+2.04848150e-02j,  0.00779344-2.08196697e-01j],
       [-0.11132801+1.98959015e-02j, -0.04673143-2.04848150e-02j,
         0.14205068-1.10924160e-17j,  0.09020186+5.65972677e-02j],
       [-0.11791921+1.62250657e-01j,  0.00779344+2.08196697e-01j,
         0.09020186-5.65972677e-02j,  0.20287486+1.72205660e-16j]]), array([[ 0.09338363+3.30023660e-17j,  0.15258429+3.65674848e-02j,
        -0.05621085+8.76534072e-02j,  0.08155776-3.57524228e-02j],
       [ 0.15258429-3.65674848e-02j,  0.55406741-5.50255323e-16j,
        -0.02282091+2.15629347e-01j,  0.24916548-1.45292511e-01j],
       [-0.05621085-8.76534072e-02j, -0.02282091-2.15629347e-01j,
         0.17219185+1.96131012e-16j, -0.08151678-8.51799874e-02j],
       [ 0.08155776+3.57524228e-02j,  0.24916548+1.45292511e-01j,
        -0.08151678+8.51799874e-02j,  0.1803571 -1.77221390e-16j]]), array([[ 0.16588493-4.05729338e-16j,  0.16543623+3.00001393e-02j,
        -0.09107802+9.01290056e-02j, -0.04001094-1.26797077e-01j],
       [ 0.16543623-3.00001393e-02j,  0.46598472+1.39464853e-15j,
        -0.01339581+2.65334169e-01j,  0.00120167-2.08176578e-01j],
       [-0.09107802-9.01290056e-02j, -0.01339581-2.65334169e-01j,
         0.2092574 -2.99517986e-16j, -0.08009142+3.95878905e-02j],
       [-0.04001094+1.26797077e-01j,  0.00120167+2.08176578e-01j,
        -0.08009142-3.95878905e-02j,  0.15887295-4.40871151e-16j]]), array([[ 0.18396744+2.27136334e-16j,  0.20317838+4.31058436e-02j,
        -0.0670597 -4.05377974e-02j,  0.11689725-1.99187517e-02j],
       [ 0.20317838-4.31058436e-02j,  0.37461413+4.88526773e-17j,
        -0.03352016-1.08615779e-01j,  0.06848802-2.18012595e-01j],
       [-0.0670597 +4.05377974e-02j, -0.03352016+1.08615779e-01j,
         0.11008893+2.08720017e-16j,  0.03944945-7.16291436e-02j],
       [ 0.11689725+1.99187517e-02j,  0.06848802+2.18012595e-01j,
         0.03944945+7.16291436e-02j,  0.3313295 +6.31477031e-16j]]), array([[ 0.26368755+4.97658806e-16j,  0.22646198-1.58976192e-03j,
        -0.08624532-8.77201958e-02j, -0.09299941-1.32643708e-01j],
       [ 0.22646198+1.58976192e-03j,  0.32497089-6.92094545e-18j,
        -0.03393028-6.80859399e-02j, -0.11194616-2.63033098e-01j],
       [-0.08624532+8.77201958e-02j, -0.03393028+6.80859399e-02j,
         0.09230692-1.69129747e-16j,  0.05325589-4.23150697e-02j],
       [-0.09299941+1.32643708e-01j, -0.11194616+2.63033098e-01j,
         0.05325589+4.23150697e-02j,  0.31903463-5.05415466e-16j]]), array([[ 0.1845634 -1.64283934e-16j,  0.12180044+2.12413984e-01j,
        -0.08163684+3.74904011e-02j,  0.19102705+1.88787507e-02j],
       [ 0.12180044-2.12413984e-01j,  0.41269008+7.12064524e-16j,
         0.00391153+1.16786109e-01j,  0.15285574-2.49957677e-01j],
       [-0.08163684-3.74904011e-02j,  0.00391153-1.16786109e-01j,
         0.09999472-3.50073923e-17j, -0.10281584-8.67180393e-02j],
       [ 0.19102705-1.88787507e-02j,  0.15285574+2.49957677e-01j,
        -0.10281584+8.67180393e-02j,  0.3027518 +3.31169616e-17j]]), array([[ 0.24261899-4.09767261e-17j,  0.11831096+1.87531900e-01j,
        -0.12397096-1.62743982e-02j,  0.04360714-1.09013059e-01j],
       [ 0.11831096-1.87531900e-01j,  0.35388588-1.70073510e-17j,
        -0.03418928+1.51601831e-01j, -0.06809473-2.59491891e-01j],
       [-0.12397096+1.62743982e-02j, -0.03418928-1.51601831e-01j,
         0.11761251-7.68615661e-17j, -0.09326239+9.10713023e-03j],
       [ 0.04360714+1.09013059e-01j, -0.06809473+2.59491891e-01j,
        -0.09326239-9.10713023e-03j,  0.28588262-5.18801210e-17j]]), array([[ 0.05811921-1.30081601e-16j,  0.07195261-1.38544206e-01j,
        -0.07658771-3.88793515e-02j, -0.0254758 -2.96822782e-02j],
       [ 0.07195261+1.38544206e-01j,  0.68212538+4.12443846e-16j,
         0.03008335-2.50684093e-01j,  0.06583275-1.51179862e-01j],
       [-0.07658771+3.88793515e-02j,  0.03008335+2.50684093e-01j,
         0.20274985-5.35160299e-17j,  0.06992871+1.40587226e-02j],
       [-0.0254758 +2.96822782e-02j,  0.06583275+1.51179862e-01j,
         0.06992871-1.40587226e-02j,  0.05700556+4.69674182e-17j]]), array([[ 0.12808826+7.80958463e-14j,  0.06672648-1.68591199e-01j,
        -0.07234094-1.06044257e-01j, -0.07043317-3.47884734e-02j],
       [ 0.06672648+1.68591199e-01j,  0.55442687+2.10100900e-13j,
         0.06173097+2.96786741e-02j, -0.06947644-1.50688053e-01j],
       [-0.07234094+1.06044257e-01j,  0.06173097-2.96786741e-02j,
         0.24319084+2.30270282e-14j,  0.05509427+1.42622095e-02j],
       [-0.07043317+3.47884734e-02j, -0.06947644+1.50688053e-01j,
         0.05509427-1.42622095e-02j,  0.07429402-5.65984168e-14j]]), array([[ 0.03376339+1.71466135e-15j, -0.02854789+2.04434562e-02j,
        -0.09130391+3.24472627e-02j,  0.02563531+1.31960879e-03j],
       [-0.02854789-2.04434562e-02j,  0.62426475-5.12599501e-15j,
         0.06246568-3.89366588e-03j,  0.09447598-1.09155533e-01j],
       [-0.09130391-3.24472627e-02j,  0.06246568+3.89366588e-03j,
         0.28471464+1.68932482e-15j, -0.07055029-1.66404817e-02j],
       [ 0.02563531-1.31960879e-03j,  0.09447598+1.09155533e-01j,
        -0.07055029+1.66404817e-02j,  0.05725722-1.52668417e-15j]]), array([[ 0.04332251-1.55389371e-18j, -0.04026595+1.64801267e-03j,
        -0.05791264-3.42781615e-02j,  0.00164999+2.28174133e-03j],
       [-0.04026595-1.64801267e-03j,  0.59306741+5.14319551e-16j,
         0.1154959 +3.11331223e-01j, -0.02333012-1.72864608e-01j],
       [-0.05791264+3.42781615e-02j,  0.1154959 -3.11331223e-01j,
         0.29555433+2.49574931e-16j, -0.09404706-6.81483717e-03j],
       [ 0.00164999-2.28174133e-03j, -0.02333012+1.72864608e-01j,
        -0.09404706+6.81483717e-03j,  0.06805575-7.05071543e-17j]]), array([[ 0.08084063-4.66603279e-17j,  0.10393714-2.35837708e-02j,
        -0.06838451-5.64388836e-02j,  0.01939841+1.39067766e-02j],
       [ 0.10393714+2.35837708e-02j,  0.50221381+1.42578373e-15j,
         0.05506122-2.60219528e-01j, -0.10909639-1.66493443e-01j],
       [-0.06838451+5.64388836e-02j,  0.05506122+2.60219528e-01j,
         0.24200192-4.53768212e-17j,  0.009784  -1.36015741e-01j],
       [ 0.01939841-1.39067766e-02j, -0.10909639+1.66493443e-01j,
         0.009784  +1.36015741e-01j,  0.17494364-7.29265708e-16j]]), array([[ 0.16068746-2.18152026e-17j,  0.11422237-9.11756290e-02j,
        -0.05362517-1.67103888e-01j, -0.10162097-1.12502732e-03j],
       [ 0.11422237+9.11756290e-02j,  0.43382269-5.21452326e-16j,
         0.106388  -9.83888246e-02j, -0.19109419-1.94246330e-01j],
       [-0.05362517+1.67103888e-01j,  0.106388  +9.83888246e-02j,
         0.22390925+3.09557741e-16j, -0.00855517-1.09047094e-01j],
       [-0.10162097+1.12502732e-03j, -0.19109419+1.94246330e-01j,
        -0.00855517+1.09047094e-01j,  0.1815806 +2.17707948e-15j]]), array([[ 0.07449164+4.57155884e-16j, -0.00376034+1.37730665e-01j,
        -0.07143386-5.19568022e-03j,  0.08651881+3.59584538e-02j],
       [-0.00376034-1.37730665e-01j,  0.50054052+4.14592983e-15j,
         0.06674421-6.39804972e-02j, -0.03193271-1.68660725e-01j],
       [-0.07143386+5.19568022e-03j,  0.06674421+6.39804972e-02j,
         0.26341971-1.39220398e-15j, -0.11491488-1.10836733e-01j],
       [ 0.08651881-3.59584538e-02j, -0.03193271+1.68660725e-01j,
        -0.11491488+1.10836733e-01j,  0.16154814+2.83295339e-15j]]), array([[ 0.14766657-1.68893858e-16j, -0.05068389+1.42392756e-01j,
        -0.09660045-1.01758252e-01j,  0.06123023+4.79492606e-03j],
       [-0.05068389-1.42392756e-01j,  0.46342185-5.57684378e-16j,
         0.07440443+1.39990636e-01j, -0.1352945 -2.20238452e-01j],
       [-0.09660045+1.01758252e-01j,  0.07440443-1.39990636e-01j,
         0.22126719+1.25842819e-16j, -0.10697643-3.39364162e-02j],
       [ 0.06123023-4.79492606e-03j, -0.1352945 +2.20238452e-01j,
        -0.10697643+3.39364162e-02j,  0.16764439-7.53554373e-16j]]), array([[ 0.32627747-8.04619622e-16j,  0.20351881-1.11861710e-01j,
        -0.22347355+5.19553338e-02j,  0.07264086-6.21712085e-02j],
       [ 0.20351881+1.11861710e-01j,  0.27672966-2.08183186e-15j,
        -0.05502868-9.55322196e-02j,  0.14324906-4.18459884e-02j],
       [-0.22347355-5.19553338e-02j, -0.05502868+9.55322196e-02j,
         0.30048838-3.89332627e-16j,  0.02947492+4.09499856e-02j],
       [ 0.07264086+6.21712085e-02j,  0.14324906+4.18459884e-02j,
         0.02947492-4.09499856e-02j,  0.09650449-7.52120678e-16j]]), array([[ 0.41440066+1.29491038e-15j,  0.16878783-1.11805803e-01j,
        -0.30689489-3.60378744e-02j, -0.07212017-2.03567005e-01j],
       [ 0.16878783+1.11805803e-01j,  0.15265215+2.64607318e-16j,
        -0.09453808-7.44860079e-02j,  0.02516461-1.03689899e-01j],
       [-0.30689489+3.60378744e-02j, -0.09453808+7.44860079e-02j,
         0.29430585+2.82504646e-16j,  0.07793588+1.58029346e-01j],
       [-0.07212017+2.03567005e-01j,  0.02516461+1.03689899e-01j,
         0.07793588-1.58029346e-01j,  0.13864134-6.70285311e-16j]]), array([[ 0.27081102+1.19598570e-15j,  0.14517641+3.87243161e-02j,
        -0.21901571+2.23398596e-01j,  0.09669444-5.61958532e-02j],
       [ 0.14517641-3.87243161e-02j,  0.22218883+5.53450377e-16j,
        -0.01457787+1.28669862e-01j,  0.10195437-5.20562510e-02j],
       [-0.21901571-2.23398596e-01j, -0.01457787-1.28669862e-01j,
         0.42674666-1.26782606e-15j, -0.09499258-2.71559817e-02j],
       [ 0.09669444+5.61958532e-02j,  0.10195437+5.20562510e-02j,
        -0.09499258+2.71559817e-02j,  0.08025349-4.68242174e-17j]]), array([[ 0.35402438+3.21658301e-16j,  0.08237701+6.04345074e-02j,
        -0.31457821+1.12573287e-01j, -0.02129551-1.60920611e-01j],
       [ 0.08237701-6.04345074e-02j,  0.14996397-1.78802587e-17j,
        -0.0241842 +1.46485776e-01j, -0.01742776-8.43009792e-02j],
       [-0.31457821-1.12573287e-01j, -0.0241842 -1.46485776e-01j,
         0.38321232-1.45036192e-15j, -0.05826381+1.32390252e-01j],
       [-0.02129551+1.60920611e-01j, -0.01742776+8.43009792e-02j,
        -0.05826381-1.32390252e-01j,  0.11279934-1.52619612e-16j]]), array([[ 0.43286073-1.11250955e-17j,  0.22241576-1.16284814e-02j,
        -0.20478658-4.94063936e-02j,  0.1726943 +4.55212993e-02j],
       [ 0.22241576+1.16284814e-02j,  0.20511954-4.56510150e-16j,
        -0.04611475-9.36383488e-02j,  0.08187674-5.33579691e-02j],
       [-0.20478658+4.94063936e-02j, -0.04611475+9.36383488e-02j,
         0.19990719-5.82194260e-16j, -0.03147613-6.52844219e-02j],
       [ 0.1726943 -4.55212993e-02j,  0.08187674+5.33579691e-02j,
        -0.03147613+6.52844219e-02j,  0.16211253-4.57204139e-16j]]), array([[ 0.56596334-7.91444742e-16j,  0.21105611-3.99949761e-02j,
        -0.23895404-1.50506624e-01j, -0.00474976-5.21714912e-02j],
       [ 0.21105611+3.99949761e-02j,  0.14840035-8.24569470e-18j,
        -0.05954995-6.05960853e-02j, -0.02845619-8.91226715e-02j],
       [-0.23895404+1.50506624e-01j, -0.05954995+6.05960853e-02j,
         0.16617598+2.57518431e-16j, -0.01111034+3.93794471e-03j],
       [-0.00474976+5.21714912e-02j, -0.02845619+8.91226715e-02j,
        -0.01111034-3.93794471e-03j,  0.11946032-7.63498908e-18j]]), array([[ 0.41522122+7.82532070e-17j,  0.14001225+1.77148514e-01j,
        -0.25028452+7.74613003e-02j,  0.23201753+5.51811079e-02j],
       [ 0.14001225-1.77148514e-01j,  0.16946904-4.73522914e-18j,
        -0.034522  +1.11734821e-01j,  0.10468977-8.34181542e-02j],
       [-0.25028452-7.74613003e-02j, -0.034522  -1.11734821e-01j,
         0.24530269+1.22609102e-17j, -0.14646034-8.20006099e-02j],
       [ 0.23201753-5.51811079e-02j,  0.10468977+8.34181542e-02j,
        -0.14646034+8.20006099e-02j,  0.17000705+2.84461633e-16j]]), array([[ 0.49419772-4.71156124e-16j,  0.07471424+1.81125160e-01j,
        -0.29266098-5.20933729e-02j,  0.10930505-6.76920011e-02j],
       [ 0.07471424-1.81125160e-01j,  0.13466395+2.33592846e-16j,
        -0.05449943+1.34658909e-01j, -0.02412186-1.12843785e-01j],
       [-0.29266098+5.20933729e-02j, -0.05449943-1.34658909e-01j,
         0.22708272-1.12083025e-16j, -0.11143356+5.25004369e-02j],
       [ 0.10930505+6.76920011e-02j, -0.02412186+1.12843785e-01j,
        -0.11143356-5.25004369e-02j,  0.1440556 -1.07622373e-16j]]), array([[ 0.16476439+5.56196987e-16j,  0.06542259-1.81272991e-01j,
        -0.23242718-7.84387106e-02j,  0.00988599-5.13996667e-02j],
       [ 0.06542259+1.81272991e-01j,  0.33583867-5.85635417e-16j,
         0.04770867-3.17373706e-01j,  0.07776145-2.92572386e-02j],
       [-0.23242718+7.84387106e-02j,  0.04770867+3.17373706e-01j,
         0.46094257+3.45336999e-16j,  0.02502026+7.51295989e-02j],
       [ 0.00988599+5.13996667e-02j,  0.07776145+2.92572386e-02j,
         0.02502026-7.51295989e-02j,  0.03845437-4.51404387e-17j]]), array([[ 0.24063554+9.14849462e-15j,  0.03710557-1.76156787e-01j,
        -0.2147625 -1.53668010e-01j, -0.01718391-5.90363813e-02j],
       [ 0.03710557+1.76156787e-01j,  0.28050595-1.64876542e-15j,
         0.06313288-4.49268584e-02j, -0.0274082 -6.33152082e-02j],
       [-0.2147625 +1.53668010e-01j,  0.06313288+4.49268584e-02j,
         0.41929812+4.56674510e-14j,  0.0217895 +1.09999114e-01j],
       [-0.01718391+5.90363813e-02j, -0.0274082 +6.33152082e-02j,
         0.0217895 -1.09999114e-01j,  0.05956039+5.47171703e-16j]]), array([[ 0.10006874-4.09441220e-16j, -0.00949307-6.03770251e-03j,
        -0.21469507+8.09225928e-02j,  0.05002963-2.90420686e-02j],
       [-0.00949307+6.03770251e-03j,  0.28676305-4.82859862e-16j,
         0.10165994-4.83746218e-02j,  0.04544262-3.19163267e-02j],
       [-0.21469507-8.09225928e-02j,  0.10165994+4.83746218e-02j,
         0.56448384+9.36226986e-16j, -0.11449143+1.55096591e-02j],
       [ 0.05002963+2.90420686e-02j,  0.04544262+3.19163267e-02j,
        -0.11449143-1.55096591e-02j,  0.04868437-4.50035286e-16j]]), array([[ 0.1645258 +2.64618862e-16j, -0.06054257-8.10136871e-03j,
        -0.24900494-4.02214436e-02j,  0.02909863-4.86380646e-02j],
       [-0.06054257+8.10136871e-03j,  0.23435003+8.64089534e-17j,
         0.11944532+1.59440230e-01j, -0.03878462-6.42826162e-02j],
       [-0.24900494+4.02214436e-02j,  0.11944532-1.59440230e-01j,
         0.53456815+4.12921251e-16j, -0.10190022+9.89116276e-02j],
       [ 0.02909863+4.86380646e-02j, -0.03878462+6.42826162e-02j,
        -0.10190022-9.89116276e-02j,  0.06655603-1.31950847e-16j]]), array([[ 0.24307055+3.14109513e-16j,  0.10585849-8.39319327e-02j,
        -0.19003266-1.22157773e-01j,  0.07915728+5.95374899e-02j],
       [ 0.10585849+8.39319327e-02j,  0.24648016-3.54095609e-16j,
         0.0787248 -2.49814527e-01j, -0.0383907 -2.59180714e-02j],
       [-0.19003266+1.22157773e-01j,  0.0787248 +2.49814527e-01j,
         0.40850872+2.27068827e-15j, -0.06942714-1.06582470e-01j],
       [ 0.07915728-5.95374899e-02j, -0.0383907 +2.59180714e-02j,
        -0.06942714+1.06582470e-01j,  0.10194056-1.36275831e-16j]]), array([[ 0.3656487 +1.07956829e-17j,  0.09238401-1.35543926e-01j,
        -0.18650711-2.78716116e-01j, -0.00783006+4.63563440e-02j],
       [ 0.09238401+1.35543926e-01j,  0.20088012+1.06285059e-15j,
         0.09976979-1.05714724e-01j, -0.08161757-5.70239196e-02j],
       [-0.18650711+2.78716116e-01j,  0.09976979+1.05714724e-01j,
         0.35014878-1.25276576e-15j, -0.07444609-3.47536240e-02j],
       [-0.00783006-4.63563440e-02j, -0.08161757+5.70239196e-02j,
        -0.07444609+3.47536240e-02j,  0.08332241+1.94171552e-16j]]), array([[ 0.16972603-3.74461339e-16j,  0.02225505+7.67555025e-02j,
        -0.18603309-1.52182096e-02j,  0.11581236+4.80635709e-02j],
       [ 0.02225505-7.67555025e-02j,  0.1956271 +3.89160112e-16j,
         0.11372334-6.97342317e-02j, -0.02517227-5.30244690e-02j],
       [-0.18603309+1.52182096e-02j,  0.11372334+6.97342317e-02j,
         0.50945802+1.27506427e-15j, -0.1889984 -1.12490416e-01j],
       [ 0.11581236-4.80635709e-02j, -0.02517227+5.30244690e-02j,
        -0.1889984 +1.12490416e-01j,  0.12518885-2.40054943e-16j]]), array([[ 0.29704158+1.83019096e-15j, -0.06163515+9.30568566e-02j,
        -0.24442998-1.81697986e-01j,  0.12449414+3.17677700e-02j],
       [-0.06163515-9.30568566e-02j,  0.1688926 -4.05381075e-16j,
         0.08754798+1.23268377e-01j, -0.06987586-9.18095394e-02j],
       [-0.24442998+1.81697986e-01j,  0.08754798-1.23268377e-01j,
         0.42066568+5.27643369e-16j, -0.1746182 +1.82340456e-02j],
       [ 0.12449414-3.17677700e-02j, -0.06987586+9.18095394e-02j,
        -0.1746182 -1.82340456e-02j,  0.11340013+4.82591555e-16j]]), array([[0.17254392-9.05102807e-17j, 0.24198116-1.02431157e-01j,
        0.06831067-1.65879597e-02j, 0.12414348-7.84817489e-02j],
       [0.24198116+1.02431157e-01j, 0.55253382+6.74219911e-16j,
        0.14421969+2.74689820e-02j, 0.25259592+1.29574673e-02j],
       [0.06831067+1.65879597e-02j, 0.14421969-2.74689820e-02j,
        0.06901527-3.83836303e-17j, 0.07815393-8.94171419e-03j],
       [0.12414348+7.84817489e-02j, 0.25259592-1.29574673e-02j,
        0.07815393+8.94171419e-03j, 0.20590699+1.38986849e-16j]]), array([[ 0.24806556+1.39927769e-14j,  0.18531094-8.89220021e-02j,
         0.00815419-4.12596716e-02j, -0.04084923-1.88463098e-01j],
       [ 0.18531094+8.89220021e-02j,  0.4123317 +4.53967308e-15j,
         0.1093852 +1.00351183e-01j,  0.00991327-1.89944299e-02j],
       [ 0.00815419+4.12596716e-02j,  0.1093852 -1.00351183e-01j,
         0.10830892+1.42328607e-14j,  0.09282568+5.15821557e-02j],
       [-0.04084923+1.88463098e-01j,  0.00991327+1.89944299e-02j,
         0.09282568-5.15821557e-02j,  0.23129382-6.37214690e-15j]]), array([[ 0.15022616-9.73778115e-17j,  0.11092549+9.52139881e-02j,
        -0.00234784+1.26435060e-01j,  0.03865428-8.79169689e-02j],
       [ 0.11092549-9.52139881e-02j,  0.52321508+3.36933695e-15j,
         0.17045847+1.02965711e-01j,  0.15427025+2.71388442e-02j],
       [-0.00234784-1.26435060e-01j,  0.17045847-1.02965711e-01j,
         0.13434986+9.45637577e-16j, -0.03053439-6.20575973e-03j],
       [ 0.03865428+8.79169689e-02j,  0.15427025-2.71388442e-02j,
        -0.03053439+6.20575973e-03j,  0.1922089 -4.18026895e-16j]]), array([[ 0.21922429-2.28780983e-14j,  0.07057615+8.56640606e-02j,
        -0.06144647+7.55568001e-02j, -0.06806017-1.96048062e-01j],
       [ 0.07057615-8.56640606e-02j,  0.41782821+1.50427490e-13j,
         0.14232889+1.84003838e-01j, -0.01507968+2.44996946e-03j],
       [-0.06144647-7.55568001e-02j,  0.14232889-1.84003838e-01j,
         0.1428747 +4.24922301e-14j, -0.00327563+6.14117753e-02j],
       [-0.06806017+1.96048062e-01j, -0.01507968-2.44996946e-03j,
        -0.00327563-6.14117753e-02j,  0.2200728 +3.51464568e-14j]]), array([[0.26044158+3.14741021e-16j, 0.27619883+9.84612201e-02j,
        0.10488882-3.03912407e-02j, 0.15390188-1.32192579e-01j],
       [0.27619883-9.84612201e-02j, 0.41316323+1.13395560e-15j,
        0.10107766-9.42584175e-02j, 0.07688095-1.56118827e-01j],
       [0.10488882+3.03912407e-02j, 0.10107766+9.42584175e-02j,
        0.06766286+3.63662567e-17j, 0.06760833-5.63620293e-02j],
       [0.15390188+1.32192579e-01j, 0.07688095+1.56118827e-01j,
        0.06760833+5.63620293e-02j, 0.25873233-1.02008549e-16j]]), array([[ 0.36785276+5.51043606e-17j,  0.26679909+5.75205244e-02j,
         0.06330753-8.04457370e-02j, -0.03773436-2.62206277e-01j],
       [ 0.26679909-5.75205244e-02j,  0.29438708-7.61183632e-17j,
         0.05214436-5.64504636e-02j, -0.11854026-1.50676515e-01j],
       [ 0.06330753+8.04457370e-02j,  0.05214436+5.64504636e-02j,
         0.05410327-4.41192362e-17j,  0.05102639-3.71219651e-02j],
       [-0.03773436+2.62206277e-01j, -0.11854026+1.50676515e-01j,
         0.05102639+3.71219651e-02j,  0.2836569 +1.33289863e-16j]]), array([[ 0.25652986-1.11213770e-15j,  0.16571283+2.59383461e-01j,
         0.04909246+1.16668759e-01j,  0.10437547-9.64614347e-02j],
       [ 0.16571283-2.59383461e-01j,  0.45325778-4.75416919e-17j,
         0.13863439+1.57885194e-02j,  0.02217879-1.07922759e-01j],
       [ 0.04909246-1.16668759e-01j,  0.13863439-1.57885194e-02j,
         0.08167167-1.87359493e-16j, -0.05166347-7.80317644e-02j],
       [ 0.10437547+9.64614347e-02j,  0.02217879+1.07922759e-01j,
        -0.05166347+7.80317644e-02j,  0.2085407 -8.33879069e-17j]]), array([[ 0.33866697-3.84490258e-16j,  0.14880232+2.57485397e-01j,
        -0.01161819+7.83812725e-02j, -0.01997854-2.56776538e-01j],
       [ 0.14880232-2.57485397e-01j,  0.34386333+3.02382916e-16j,
         0.07783749+6.67006361e-02j, -0.19719818-1.19193243e-01j],
       [-0.01161819-7.83812725e-02j,  0.07783749-6.67006361e-02j,
         0.05940372+9.19653057e-17j, -0.06863438-1.40099507e-03j],
       [-0.01997854+2.56776538e-01j, -0.19719818+1.19193243e-01j,
        -0.06863438+1.40099507e-03j,  0.25806599+3.82787442e-16j]]), array([[0.06688773+1.68794461e-16j, 0.08974069-1.25283661e-01j,
        0.03025905-6.78344395e-02j, 0.03977276-2.84121450e-02j],
       [0.08974069+1.25283661e-01j, 0.70393098+1.40182400e-15j,
        0.24307365-1.28964938e-01j, 0.07986227+5.17758806e-02j],
       [0.03025905+6.78344395e-02j, 0.24307365+1.28964938e-01j,
        0.15963128+3.53932627e-16j, 0.05014164+1.64059400e-02j],
       [0.03977276+2.84121450e-02j, 0.07986227-5.17758806e-02j,
        0.05014164-1.64059400e-02j, 0.06955001-1.57865101e-17j]]), array([[ 0.14694556+3.76055121e-16j,  0.08528061-1.67678196e-01j,
         0.0643009 -1.28161269e-01j, -0.00853625-6.09948968e-02j],
       [ 0.08528061+1.67678196e-01j,  0.57211986-3.11269469e-16j,
         0.23288869+1.08097778e-01j, -0.06146364+5.26871898e-03j],
       [ 0.0643009 +1.28161269e-01j,  0.23288869-1.08097778e-01j,
         0.19122999+1.12105618e-15j,  0.05060762+1.55544200e-02j],
       [-0.00853625+6.09948968e-02j, -0.06146364-5.26871898e-03j,
         0.05060762-1.55544200e-02j,  0.08970459+4.58996795e-17j]]), array([[ 4.55869000e-02-6.51296470e-17j, -5.30572569e-02+8.92811574e-02j,
        -2.65507241e-02+6.17818591e-02j,  4.24267836e-04-2.15487312e-02j],
       [-5.30572569e-02-8.92811574e-02j,  7.26848004e-01-1.03069123e-16j,
         2.87379769e-01-5.12671130e-02j,  3.37082403e-02+6.35150723e-02j],
       [-2.65507241e-02-6.17818591e-02j,  2.87379769e-01+5.12671130e-02j,
         1.77037014e-01+2.27144391e-16j, -2.49955226e-02+2.85852339e-02j],
       [ 4.24267836e-04+2.15487312e-02j,  3.37082403e-02-6.35150723e-02j,
        -2.49955226e-02-2.85852339e-02j,  5.05280822e-02-8.84760703e-18j]]), array([[ 0.08371046+9.65219632e-17j, -0.09200287+5.54368125e-02j,
        -0.06462466-1.65529211e-02j,  0.00862926-6.42764633e-02j],
       [-0.09200287-5.54368125e-02j,  0.61768415+5.31824173e-16j,
         0.276126  +2.07595969e-01j, -0.11796909+4.91733235e-02j],
       [-0.06462466+1.65529211e-02j,  0.276126  -2.07595969e-01j,
         0.21721007+8.23570127e-16j, -0.02926363+6.62298361e-02j],
       [ 0.00862926+6.42764633e-02j, -0.11796909-4.91733235e-02j,
        -0.02926363-6.62298361e-02j,  0.08139532-6.42289084e-17j]]), array([[ 0.1227064 -5.75498259e-17j,  0.1880246 +5.75018455e-02j,
         0.12010233-6.82455456e-02j,  0.02420773-7.60766325e-02j],
       [ 0.1880246 -5.75018455e-02j,  0.54168737+2.92482066e-16j,
         0.21021495-2.56955648e-01j, -0.08463757-1.13728903e-01j],
       [ 0.12010233+6.82455456e-02j,  0.21021495+2.56955648e-01j,
         0.22700278-1.33902853e-16j,  0.03986015-9.92158877e-02j],
       [ 0.02420773+7.60766325e-02j, -0.08463757+1.13728903e-01j,
         0.03986015+9.92158877e-02j,  0.10860346+1.42687665e-16j]]), array([[ 2.11590969e-01+2.30125886e-16j,  1.27858626e-01-4.31014411e-02j,
         9.39964217e-02-1.52078316e-01j, -3.64724822e-02-1.03970370e-01j],
       [ 1.27858626e-01+4.31014411e-02j,  4.25896681e-01+2.41861911e-15j,
         1.89651105e-01-6.84733182e-02j, -1.99010972e-01-7.17683912e-02j],
       [ 9.39964217e-02+1.52078316e-01j,  1.89651105e-01+6.84733182e-02j,
         1.85401707e-01+2.17419896e-15j, -3.06896485e-04-7.05492296e-02j],
       [-3.64724822e-02+1.03970370e-01j, -1.99010972e-01+7.17683912e-02j,
        -3.06896485e-04+7.05492296e-02j,  1.77110643e-01-2.61234822e-16j]]), array([[ 0.11771904-4.90312078e-17j,  0.01569166+2.21531353e-01j,
         0.05709324+9.71359644e-02j,  0.04098321-7.17990292e-02j],
       [ 0.01569166-2.21531353e-01j,  0.57179794+1.06329927e-15j,
         0.23406105-1.53918004e-01j, -0.15510528-6.23327635e-02j],
       [ 0.05709324-9.71359644e-02j,  0.23406105+1.53918004e-01j,
         0.19484965-2.29321530e-16j, -0.08296298-8.65232438e-02j],
       [ 0.04098321+7.17990292e-02j, -0.15510528+6.23327635e-02j,
        -0.08296298+8.65232438e-02j,  0.11563336+4.39152295e-17j]]), array([[ 0.209768  -4.26423842e-16j, -0.04609218+2.10207216e-01j,
        -0.022816  -2.43466136e-02j,  0.04482439-1.32680119e-01j],
       [-0.04609218-2.10207216e-01j,  0.48831882+7.58740657e-16j,
         0.16019447+5.75429686e-02j, -0.24598262-5.92035672e-02j],
       [-0.022816  +2.43466136e-02j,  0.16019447-5.75429686e-02j,
         0.14908728+5.27195492e-17j, -0.06517343+3.49465199e-04j],
       [ 0.04482439+1.32680119e-01j, -0.24598262+5.92035672e-02j,
        -0.06517343-3.49465199e-04j,  0.1528259 -2.76258111e-16j]]), array([[ 0.33461895-7.11406870e-16j,  0.21484273-8.96877217e-02j,
        -0.03001955+2.29757675e-02j,  0.13917659-6.76973908e-02j],
       [ 0.21484273+8.96877217e-02j,  0.29508869+5.73645225e-16j,
         0.13245756-4.06064075e-02j,  0.18041757+5.03757828e-02j],
       [-0.03001955-2.29757675e-02j,  0.13245756+4.06064075e-02j,
         0.22654539+2.94393781e-16j,  0.05118329+9.47086414e-02j],
       [ 0.13917659+6.76973908e-02j,  0.18041757-5.03757828e-02j,
         0.05118329-9.47086414e-02j,  0.14374697-1.55179910e-16j]]), array([[ 0.3877768 +1.37315041e-14j,  0.14670726-7.21055620e-02j,
        -0.11783597-6.45377060e-02j,  0.02555393-1.96169708e-01j],
       [ 0.14670726+7.21055620e-02j,  0.18342046-1.18188932e-14j,
         0.09965756+1.96199530e-02j,  0.04224673+3.17998251e-02j],
       [-0.11783597+6.45377060e-02j,  0.09965756-1.96199530e-02j,
         0.23777997-1.51488260e-14j,  0.07881634+1.83332163e-01j],
       [ 0.02555393+1.96169708e-01j,  0.04224673-3.17998251e-02j,
         0.07881634-1.83332163e-01j,  0.19102277+1.17537851e-14j]]), array([[ 0.28787451+2.28993202e-13j,  0.13641773+8.20920119e-02j,
        -0.05472723+2.30353456e-01j,  0.06185396-8.53100266e-02j],
       [ 0.13641773-8.20920119e-02j,  0.28177543+4.68570839e-14j,
         0.17759247+5.40624116e-02j,  0.08097732+3.33876875e-02j],
       [-0.05472723-2.30353456e-01j,  0.17759247-5.40624116e-02j,
         0.31872139-2.01442938e-13j, -0.05935106+5.95610714e-02j],
       [ 0.06185396+8.53100266e-02j,  0.08097732-3.33876875e-02j,
        -0.05935106-5.95610714e-02j,  0.11162867+2.33346231e-14j]]), array([[ 0.36336679+2.29973500e-15j,  0.05149388+1.18325809e-01j,
        -0.18323361+1.40772822e-01j, -0.03982305-2.01978954e-01j],
       [ 0.05149388-1.18325809e-01j,  0.19568964-1.58667436e-15j,
         0.15629789+1.18664710e-01j, -0.0527024 +4.24642875e-02j],
       [-0.18323361-1.40772822e-01j,  0.15629789-1.18664710e-01j,
         0.29184374+2.10211433e-18j, -0.02554646+1.68802242e-01j],
       [-0.03982305+2.01978954e-01j, -0.0527024 -4.24642875e-02j,
        -0.02554646-1.68802242e-01j,  0.14909983+7.13550849e-17j]]), array([[0.52783495-6.22250967e-16j, 0.29446868+4.26298279e-02j,
        0.03788833-5.16992917e-02j, 0.27122058-3.35329486e-02j],
       [0.29446868-4.26298279e-02j, 0.2245887 -4.06554389e-16j,
        0.04871444-5.96268626e-02j, 0.14548458-3.51848893e-02j],
       [0.03788833+5.16992917e-02j, 0.04871444+5.96268626e-02j,
        0.07508178+5.23300890e-18j, 0.01320007+2.46656996e-02j],
       [0.27122058+3.35329486e-02j, 0.14548458+3.51848893e-02j,
        0.01320007-2.46656996e-02j, 0.17249457-2.61700527e-16j]]), array([[ 0.62871225-2.52312858e-16j,  0.25839947+3.60066254e-03j,
        -0.01363992-1.37972389e-01j,  0.0636942 -1.59485508e-01j],
       [ 0.25839947-3.60066254e-03j,  0.16376417-1.03580870e-16j,
         0.03317125-4.00959713e-02j, -0.01584693-4.66827369e-02j],
       [-0.01363992+1.37972389e-01j,  0.03317125+4.00959713e-02j,
         0.0906154 -1.84451089e-17j,  0.00500278+5.52676241e-02j],
       [ 0.0636942 +1.59485508e-01j, -0.01584693+4.66827369e-02j,
         0.00500278-5.52676241e-02j,  0.11690819+1.04592220e-16j]]), array([[ 0.43692726-8.49323886e-16j,  0.16515086+2.11647698e-01j,
        -0.01496047+1.54482223e-01j,  0.15057239-4.98543498e-02j],
       [ 0.16515086-2.11647698e-01j,  0.2318099 +1.42170105e-15j,
         0.12481696-4.17234983e-03j,  0.02123039-3.16427877e-02j],
       [-0.01496047-1.54482223e-01j,  0.12481696+4.17234983e-03j,
         0.19933992+2.89804251e-16j, -0.10911964-9.86437597e-03j],
       [ 0.15057239+4.98543498e-02j,  0.02123039+3.16427877e-02j,
        -0.10911964+9.86437597e-03j,  0.13192292-3.65588534e-16j]]), array([[ 0.57815839+1.07428716e-15j,  0.11941753+2.22035799e-01j,
        -0.11018004+6.23581798e-02j,  0.04388123-1.88003225e-01j],
       [ 0.11941753-2.22035799e-01j,  0.15767741-1.65331113e-16j,
         0.05942597+6.52959762e-02j, -0.0987725 -3.58065364e-02j],
       [-0.11018004-6.23581798e-02j,  0.05942597-6.52959762e-02j,
         0.13792219+2.08759789e-16j, -0.0825186 +7.57954031e-02j],
       [ 0.04388123+1.88003225e-01j, -0.0987725 +3.58065364e-02j,
        -0.0825186 -7.57954031e-02j,  0.12624201+2.76709717e-18j]]), array([[ 0.13689964+1.61254654e-17j,  0.06689998-1.44410596e-01j,
        -0.05298443-1.21032381e-01j,  0.08101955-4.18646294e-02j],
       [ 0.06689998+1.44410596e-01j,  0.38178782-1.64504240e-16j,
         0.27443257-2.26879451e-01j,  0.12173471+9.00616755e-02j],
       [-0.05298443+1.21032381e-01j,  0.27443257+2.26879451e-01j,
         0.39089914+2.90487868e-17j,  0.02600155+1.36079290e-01j],
       [ 0.08101955+4.18646294e-02j,  0.12173471-9.00616755e-02j,
         0.02600155-1.36079290e-01j,  0.09041339+1.34087595e-16j]]), array([[ 0.23349962-4.83103880e-16j,  0.02698699-1.71858087e-01j,
        -0.06972817-2.19592058e-01j,  0.07164932-7.42238941e-02j],
       [ 0.02698699+1.71858087e-01j,  0.29128519+1.29892614e-16j,
         0.26149402+1.59840938e-02j,  0.00043359+7.88670515e-02j],
       [-0.06972817+2.19592058e-01j,  0.26149402-1.59840938e-02j,
         0.38193106+2.90868321e-16j,  0.02756913+1.59361134e-01j],
       [ 0.07164932+7.42238941e-02j,  0.00043359-7.88670515e-02j,
         0.02756913-1.59361134e-01j,  0.09328413+7.36438683e-17j]]), array([[ 0.08097734+9.25661949e-17j, -0.04570827+4.77310646e-02j,
        -0.08902094+1.01785805e-01j,  0.01678184-4.39979375e-02j],
       [-0.04570827-4.77310646e-02j,  0.36744365+4.00694457e-16j,
         0.34412648-1.25452304e-01j, -0.00289591+8.70666910e-02j],
       [-0.08902094-1.01785805e-01j,  0.34412648+1.25452304e-01j,
         0.48798125+3.73555099e-16j, -0.08704151+9.94611842e-02j],
       [ 0.01678184+4.39979375e-02j, -0.00289591-8.70666910e-02j,
        -0.08704151-9.94611842e-02j,  0.06359776+2.93815594e-17j]]), array([[ 0.15558834-1.76307848e-16j, -0.10733261+4.38471405e-02j,
        -0.17897732-2.33408054e-02j,  0.0369781 -9.44798641e-02j],
       [-0.10733261-4.38471405e-02j,  0.28390024-6.53905820e-16j,
         0.31315671+1.24027041e-01j, -0.09371747+9.52912141e-02j],
       [-0.17897732+2.33408054e-02j,  0.31315671-1.24027041e-01j,
         0.45945336-7.74995594e-17j, -0.06147047+1.75808368e-01j],
       [ 0.0369781 +9.44798641e-02j, -0.09371747-9.52912141e-02j,
        -0.06147047-1.75808368e-01j,  0.10105806+9.37890272e-17j]]), array([[ 0.28736364+6.42090093e-16j,  0.13016288-2.57710939e-02j,
         0.03070144-1.06556374e-01j,  0.14427497-8.92945835e-03j],
       [ 0.13016288+2.57710939e-02j,  0.28350044-5.16590582e-15j,
         0.19371863-2.23810693e-01j, -0.0171352 +7.85607325e-03j],
       [ 0.03070144+1.06556374e-01j,  0.19371863+2.23810693e-01j,
         0.32164735-3.58708414e-15j, -0.04515163-1.58780475e-02j],
       [ 0.14427497+8.92945835e-03j, -0.0171352 -7.85607325e-03j,
        -0.04515163+1.58780475e-02j,  0.10748857+3.45725328e-16j]]), array([[ 0.39830279-6.60382043e-17j,  0.13235112-9.75683989e-02j,
         0.03908716-2.56911404e-01j,  0.05097686-3.77037474e-02j],
       [ 0.13235112+9.75683989e-02j,  0.23459989-8.09807914e-16j,
         0.20629956-7.58741017e-02j, -0.07773488-8.03337868e-03j],
       [ 0.03908716+2.56911404e-01j,  0.20629956+7.58741017e-02j,
         0.28267934+5.48058000e-16j, -0.05453984+2.37323112e-02j],
       [ 0.05097686+3.77037474e-02j, -0.07773488+8.03337868e-03j,
        -0.05453984-2.37323112e-02j,  0.08441797+6.78628674e-17j]]), array([[ 0.22811161-5.28894381e-16j,  0.05223662+1.37034576e-01j,
         0.00907546+6.69473046e-02j,  0.08430724-3.38162756e-02j],
       [ 0.05223662-1.37034576e-01j,  0.25906697-5.47259949e-17j,
         0.24512898-1.38109217e-01j, -0.08155648-7.08655282e-03j],
       [ 0.00907546-6.69473046e-02j,  0.24512898+1.38109217e-01j,
         0.41570651+3.33437129e-15j, -0.15654942-3.53424238e-02j],
       [ 0.08430724+3.38162756e-02j, -0.08155648+7.08655282e-03j,
        -0.15654942+3.53424238e-02j,  0.09711492-6.34072692e-16j]]), array([[ 0.34885527+3.44616284e-13j, -0.01594569+1.30409751e-01j,
        -0.05659153-9.25148232e-02j,  0.07904378-8.06419461e-02j],
       [-0.01594569-1.30409751e-01j,  0.22458949-2.81211132e-14j,
         0.19461326+3.13389698e-02j, -0.13682045-6.72072810e-03j],
       [-0.05659153+9.25148232e-02j,  0.19461326-3.13389698e-02j,
         0.32722994-1.45143794e-13j, -0.12417208+6.23257995e-02j],
       [ 0.07904378+8.06419461e-02j, -0.13682045+6.72072810e-03j,
        -0.12417208-6.23257995e-02j,  0.0993253 +1.96907118e-13j]]), array([[ 0.10351779+2.55669221e-15j, -0.01279338-1.09529519e-01j,
        -0.01737298+1.30846315e-01j, -0.03166053+1.07356204e-01j],
       [-0.01279338+1.09529519e-01j,  0.244392  +2.37688840e-14j,
        -0.16208259+2.43517166e-02j,  0.06801047+5.37045212e-02j],
       [-0.01737298-1.30846315e-01j, -0.16208259-2.43517166e-02j,
         0.20127256-4.20135289e-14j,  0.15202942-8.10874346e-02j],
       [-0.03166053-1.07356204e-01j,  0.06801047-5.37045212e-02j,
         0.15202942+8.10874346e-02j,  0.45081764-9.51080142e-15j]]), array([[ 0.14254517+7.60262859e-16j, -0.04349359-1.06287430e-01j,
        -0.01499363+6.50145282e-02j, -0.20114745+5.67413664e-02j],
       [-0.04349359+1.06287430e-01j,  0.18986376+3.60789846e-16j,
        -0.1154056 +4.66608088e-02j, -0.04969648-6.20044091e-02j],
       [-0.01499363-6.50145282e-02j, -0.1154056 -4.66608088e-02j,
         0.15925095+9.72825639e-16j,  0.19852179+6.31487897e-02j],
       [-0.20114745-5.67413664e-02j, -0.04969648+6.20044091e-02j,
         0.19852179-6.31487897e-02j,  0.50834012+1.87462413e-15j]]), array([[ 0.11508463+8.79098216e-16j, -0.11699803+1.82859431e-02j,
         0.02858881+6.33663472e-02j, -0.15090487+9.86066409e-02j],
       [-0.11699803-1.82859431e-02j,  0.30040753-9.85398561e-16j,
        -0.13374605-2.12635881e-05j,  0.28487476+1.85006578e-02j],
       [ 0.02858881-6.33663472e-02j, -0.13374605+2.12635881e-05j,
         0.15644619-2.17031013e-16j, -0.01374844-7.87478251e-04j],
       [-0.15090487-9.86066409e-02j,  0.28487476-1.85006578e-02j,
        -0.01374844+7.87478251e-04j,  0.42806166-7.03595426e-16j]]), array([[ 0.19515165-1.56142492e-15j, -0.11095953-1.95510042e-02j,
         0.02325916+1.78421167e-02j, -0.27781735+3.54873498e-02j],
       [-0.11095953+1.95510042e-02j,  0.23004489-2.67575758e-15j,
        -0.118454  +1.09199264e-01j,  0.12236219-2.99888903e-02j],
       [ 0.02325916-1.78421167e-02j, -0.118454  -1.09199264e-01j,
         0.15691849-7.44199452e-16j,  0.00468666+4.23691629e-02j],
       [-0.27781735-3.54873498e-02j,  0.12236219+2.99888903e-02j,
         0.00468666-4.23691629e-02j,  0.41788497-2.66677768e-15j]]), array([[ 0.10638908-9.45524592e-17j,  0.01328176-2.69707301e-02j,
        -0.06746864+5.60412764e-02j,  0.00847457+2.28604419e-01j],
       [ 0.01328176+2.69707301e-02j,  0.07691141+1.02173326e-16j,
        -0.0835984 -1.67040290e-02j, -0.0555155 +8.79421873e-02j],
       [-0.06746864-5.60412764e-02j, -0.0835984 +1.67040290e-02j,
         0.1618496 +9.38619153e-16j,  0.11967414-2.37535247e-01j],
       [ 0.00847457-2.28604419e-01j, -0.0555155 -8.79421873e-02j,
         0.11967414+2.37535247e-01j,  0.6548499 +7.94632536e-16j]]), array([[ 0.20067134-3.73455633e-16j,  0.00942415-4.49159905e-02j,
        -0.04185598-2.38901853e-02j, -0.23874611+1.74529144e-01j],
       [ 0.00942415+4.49159905e-02j,  0.06159048+8.43849024e-18j,
        -0.04239852-1.51961175e-02j, -0.13056293-3.15484777e-02j],
       [-0.04185598+2.38901853e-02j, -0.04239852+1.51961175e-02j,
         0.08138812-1.19578721e-16j,  0.12460371-1.01109903e-01j],
       [-0.23874611-1.74529144e-01j, -0.13056293+3.15484777e-02j,
         0.12460371+1.01109903e-01j,  0.65635005-9.93367251e-16j]]), array([[ 0.14785834-1.29336622e-15j, -0.06891764+8.63561812e-02j,
         0.00698259-2.85347500e-02j, -0.09315351+1.87155556e-01j],
       [-0.06891764-8.63561812e-02j,  0.13682515-1.25348191e-17j,
        -0.09351009+1.39992029e-02j,  0.19303538+5.85698773e-02j],
       [ 0.00698259+2.85347500e-02j, -0.09351009-1.39992029e-02j,
         0.14433352+5.06482083e-16j, -0.08982365-1.82511275e-01j],
       [-0.09315351-1.87155556e-01j,  0.19303538-5.85698773e-02j,
        -0.08982365+1.82511275e-01j,  0.57098298-1.72251852e-16j]]), array([[ 0.25691954+1.88701040e-16j, -0.07574578+3.71191259e-02j,
         0.03952367-1.19662619e-01j, -0.32093175+1.37191880e-01j],
       [-0.07574578-3.71191259e-02j,  0.08239563-8.13194894e-18j,
        -0.054028  +4.45884177e-02j,  0.09151378-6.00168655e-03j],
       [ 0.03952367+1.19662619e-01j, -0.054028  -4.45884177e-02j,
         0.10192233+1.37472836e-16j, -0.10775687-1.25801460e-01j],
       [-0.32093175-1.37191880e-01j,  0.09151378+6.00168655e-03j,
        -0.10775687+1.25801460e-01j,  0.5587625 +7.39204642e-17j]]), array([[ 0.09988253-7.71628397e-16j, -0.12059604-1.40047096e-01j,
         0.05707809+1.33032330e-01j,  0.03696804+4.65777747e-02j],
       [-0.12059604+1.40047096e-01j,  0.41437613-8.94967213e-16j,
        -0.29651474-5.89818358e-02j, -0.09209422+3.31098827e-02j],
       [ 0.05707809-1.33032330e-01j, -0.29651474+5.89818358e-02j,
         0.31088121+2.51439320e-16j,  0.14178548-9.89113007e-02j],
       [ 0.03696804-4.65777747e-02j, -0.09209422-3.31098827e-02j,
         0.14178548+9.89113007e-02j,  0.17486012-1.06159193e-15j]]), array([[ 0.15709806+9.73808232e-16j, -0.14308302-1.50078427e-01j,
         0.08474155+1.32176143e-02j, -0.04583538+6.68795379e-02j],
       [-0.14308302+1.50078427e-01j,  0.37162905+1.70595869e-15j,
        -0.20970891+9.89776877e-02j, -0.1418488 -7.43344532e-02j],
       [ 0.08474155-1.32176143e-02j, -0.20970891-9.89776877e-02j,
         0.23185082-5.32893868e-16j,  0.16300003+3.25030293e-02j],
       [-0.04583538-6.68795379e-02j, -0.1418488 +7.43344532e-02j,
         0.16300003-3.25030293e-02j,  0.23942207+1.18213636e-15j]]), array([[ 0.12879689+1.61160566e-16j, -0.21434155-2.69774128e-02j,
         0.12242682+5.87526138e-02j, -0.06668991+1.25918289e-02j],
       [-0.21434155+2.69774128e-02j,  0.45847544-1.79781626e-17j,
        -0.29241226-3.99928295e-02j,  0.14959434+6.60749984e-03j],
       [ 0.12242682-5.87526138e-02j, -0.29241226+3.99928295e-02j,
         0.28330534-3.72895089e-17j, -0.05780275-4.19392145e-02j],
       [-0.06668991-1.25918289e-02j,  0.14959434-6.60749984e-03j,
        -0.05780275+4.19392145e-02j,  0.12942233+5.75413604e-17j]]), array([[ 0.19043063+3.02902741e-16j, -0.2407444 -7.48980864e-02j,
         0.17245537-7.36145550e-02j, -0.08891306+3.58699934e-02j],
       [-0.2407444 +7.48980864e-02j,  0.42906491+1.28254127e-16j,
        -0.24462156+2.06550209e-01j,  0.06458129-7.19972665e-02j],
       [ 0.17245537+7.36145550e-02j, -0.24462156-2.06550209e-01j,
         0.27315421-4.45819302e-16j, -0.06197369+1.07681295e-02j],
       [-0.08891306-3.58699934e-02j,  0.06458129+7.19972665e-02j,
        -0.06197369-1.07681295e-02j,  0.10735025+3.31907012e-17j]]), array([[ 0.09637837+5.17876586e-17j, -0.08766781-4.59235166e-02j,
         0.018666  +5.88988134e-02j,  0.05227628+1.24353801e-01j],
       [-0.08766781+4.59235166e-02j,  0.24170251-1.19627575e-16j,
        -0.19160935-1.44804824e-01j, -0.20781998+1.95501873e-02j],
       [ 0.018666  -5.88988134e-02j, -0.19160935+1.44804824e-01j,
         0.28393422+8.77252419e-16j,  0.1117237 -2.08522400e-01j],
       [ 0.05227628-1.24353801e-01j, -0.20781998-1.95501873e-02j,
         0.1117237 +2.08522400e-01j,  0.3779849 +3.13233957e-17j]]), array([[ 0.19077139+5.34810047e-15j, -0.13049905-3.11539964e-02j,
         0.0732834 -7.89561694e-02j, -0.02135911+1.23869092e-01j],
       [-0.13049905+3.11539964e-02j,  0.24473145-1.35698291e-14j,
        -0.15479094-1.97295039e-03j, -0.21599388-1.05726884e-01j],
       [ 0.0732834 +7.89561694e-02j, -0.15479094+1.97295039e-03j,
         0.18413233+1.05029318e-14j,  0.11316148-4.30381187e-02j],
       [-0.02135911-1.23869092e-01j, -0.21599388+1.05726884e-01j,
         0.11316148+4.30381187e-02j,  0.38036483-2.10546380e-15j]]), array([[ 0.12709255+1.22032347e-14j, -0.15060535+5.10248428e-02j,
         0.08400208-2.53469312e-02j, -0.03430307+7.63803976e-02j],
       [-0.15060535-5.10248428e-02j,  0.24469795+7.91444633e-14j,
        -0.19012871-7.47809091e-02j,  0.02567169+2.19467210e-02j],
       [ 0.08400208+2.53469312e-02j, -0.19012871+7.47809091e-02j,
         0.31327241+1.14813904e-13j, -0.11140378-2.01680030e-01j],
       [-0.03430307-7.63803976e-02j,  0.02567169-2.19467210e-02j,
        -0.11140378+2.01680030e-01j,  0.31493708-5.21255341e-14j]]), array([[ 0.23073817+1.20321708e-15j, -0.19231431+4.02039716e-02j,
         0.12255423-1.56967155e-01j, -0.11377445+1.04223169e-01j],
       [-0.19231431-4.02039716e-02j,  0.2622139 -5.58619468e-16j,
        -0.15488093+7.29374087e-02j, -0.01535512-6.95122535e-02j],
       [ 0.12255423+1.56967155e-01j, -0.15488093-7.29374087e-02j,
         0.20302826-1.06878758e-15j, -0.09929242-7.98416830e-02j],
       [-0.11377445-1.04223169e-01j, -0.01535512+6.95122535e-02j,
        -0.09929242+7.98416830e-02j,  0.30401966-7.26095499e-17j]]), array([[ 0.32758525-8.97998488e-16j,  0.02864348-1.24609166e-01j,
        -0.03589633+2.87441448e-01j, -0.01048142+2.15977531e-01j],
       [ 0.02864348+1.24609166e-01j,  0.10897998-1.27801619e-16j,
        -0.13537918-1.34960291e-03j, -0.01315282+3.00117321e-02j],
       [-0.03589633-2.87441448e-01j, -0.13537918+1.34960291e-03j,
         0.2880931 -2.43979672e-16j,  0.16435607-9.67168187e-04j],
       [-0.01048142-2.15977531e-01j, -0.01315282-3.00117321e-02j,
         0.16435607+9.67168187e-04j,  0.27534167+2.57707356e-16j]]), array([[ 0.39402599-1.47595906e-16j,  0.00994109-1.50062554e-01j,
        -0.01786362+2.04516823e-01j, -0.23245169+1.94465531e-01j],
       [ 0.00994109+1.50062554e-01j,  0.08537636-1.68685614e-16j,
        -0.09511946+1.74386132e-02j, -0.09636309-7.78135153e-02j],
       [-0.01786362-2.04516823e-01j, -0.09511946-1.74386132e-02j,
         0.20342823-5.06163712e-16j,  0.16877828+1.43594835e-01j],
       [-0.23245169-1.94465531e-01j, -0.09636309+7.78135153e-02j,
         0.16877828-1.43594835e-01j,  0.31716942-1.17085835e-16j]]), array([[ 2.72272676e-01+1.81961863e-15j, -8.53448444e-02+3.29623737e-02j,
         1.06585797e-04+2.10400787e-01j, -1.41101260e-01+1.58887353e-01j],
       [-8.53448444e-02-3.29623737e-02j,  1.36572387e-01+1.97479518e-16j,
        -8.17874907e-02-7.04846986e-02j,  1.85619949e-01-3.31332937e-02j],
       [ 1.06585797e-04-2.10400787e-01j, -8.17874907e-02+7.04846986e-02j,
         2.78219920e-01+2.34851331e-16j, -2.68871240e-03+1.14980527e-01j],
       [-1.41101260e-01-1.58887353e-01j,  1.85619949e-01+3.31332937e-02j,
        -2.68871240e-03-1.14980527e-01j,  3.12935017e-01+6.26339860e-16j]]), array([[ 0.38573171+3.86070283e-17j, -0.10260014-6.22817081e-02j,
         0.07665652+1.75791579e-01j, -0.31555349+1.20778463e-01j],
       [-0.10260014+6.22817081e-02j,  0.07731789-1.17709551e-16j,
        -0.08865374+2.78194473e-03j,  0.07154614-1.06666307e-01j],
       [ 0.07665652-1.75791579e-01j, -0.08865374-2.78194473e-03j,
         0.2049532 +6.32546413e-17j, -0.04240929+1.93748668e-01j],
       [-0.31555349-1.20778463e-01j,  0.07154614+1.06666307e-01j,
        -0.04240929-1.93748668e-01j,  0.3319972 -2.31908605e-15j]]), array([[ 0.38807404+4.24341157e-16j,  0.02182437-2.16695381e-02j,
        -0.04624535+1.20411393e-01j,  0.0672199 +3.92505131e-01j],
       [ 0.02182437+2.16695381e-02j,  0.0390027 +1.03887867e-17j,
        -0.04382552-1.85047691e-02j, -0.01421024+3.32508227e-02j],
       [-0.04624535-1.20411393e-01j, -0.04382552+1.85047691e-02j,
         0.12706659+1.24705043e-16j,  0.10552297-7.75173419e-02j],
       [ 0.0672199 -3.92505131e-01j, -0.01421024-3.32508227e-02j,
         0.10552297+7.75173419e-02j,  0.44585667-7.87222485e-16j]]), array([[ 0.51946545-2.57642239e-16j,  0.02150785-9.64235977e-02j,
        -0.01352434+1.09739666e-02j, -0.18065356+3.51375856e-01j],
       [ 0.02150785+9.64235977e-02j,  0.04093606-1.64483740e-18j,
        -0.02197664-3.70552712e-03j, -0.09596852-2.20146703e-02j],
       [-0.01352434-1.09739666e-02j, -0.02197664+3.70552712e-03j,
         0.05642287+1.48419175e-17j,  0.05859121-6.72761212e-03j],
       [-0.18065356-3.51375856e-01j, -0.09596852+2.20146703e-02j,
         0.05859121+6.72761212e-03j,  0.38317563+5.86466220e-16j]]), array([[ 0.37607034+7.64819218e-16j, -0.08137361+1.25663438e-01j,
         0.02727499+5.94500782e-02j, -0.0212075 +3.19612534e-01j],
       [-0.08137361-1.25663438e-01j,  0.0991059 -5.78737077e-16j,
        -0.04877375-4.34745789e-02j,  0.17075602-4.12303510e-02j],
       [ 0.02727499-5.94500782e-02j, -0.04877375+4.34745789e-02j,
         0.13759923+4.14329408e-16j, -0.06587476+2.39358423e-02j],
       [-0.0212075 -3.19612534e-01j,  0.17075602+4.12303510e-02j,
        -0.06587476-2.39358423e-02j,  0.38722453-2.53969284e-15j]]), array([[ 0.52580682-1.22233789e-15j, -0.08366662+5.19464503e-02j,
         0.04023315-4.56484011e-02j, -0.2473171 +2.91377540e-01j],
       [-0.08366662-5.19464503e-02j,  0.04217904+4.30421763e-18j,
        -0.03053725+2.20908519e-02j,  0.07561775-4.44083324e-02j],
       [ 0.04023315+4.56484011e-02j, -0.03053725-2.20908519e-02j,
         0.08336964+1.71778772e-17j, -0.09249128+2.56659511e-02j],
       [-0.2473171 -2.91377540e-01j,  0.07561775+4.44083324e-02j,
        -0.09249128-2.56659511e-02j,  0.3486445 +9.22473485e-16j]]), array([[ 0.22953448+1.02606265e-16j, -0.10578851-1.43628307e-01j,
         0.06369675+2.53713139e-01j,  0.02254281+1.26869780e-01j],
       [-0.10578851+1.43628307e-01j,  0.19358007+1.72136967e-16j,
        -0.2260395 -1.22965500e-01j, -0.08547166-4.87540586e-02j],
       [ 0.06369675-2.53713139e-01j, -0.2260395 +1.22965500e-01j,
         0.46540883+3.65590579e-16j,  0.1590332 +3.25348584e-02j],
       [ 0.02254281-1.26869780e-01j, -0.08547166+4.87540586e-02j,
         0.1590332 -3.25348584e-02j,  0.11147662-6.31737340e-18j]]), array([[ 0.32355542-5.57473231e-16j, -0.1139878 -2.04186488e-01j,
         0.13201584+8.19007233e-02j, -0.03863038+1.83556139e-01j],
       [-0.1139878 +2.04186488e-01j,  0.20015167+6.96234511e-16j,
        -0.16136402+6.84978860e-02j, -0.12741164-1.02699877e-01j],
       [ 0.13201584-8.19007233e-02j, -0.16136402-6.84978860e-02j,
         0.31623572+4.43283165e-16j,  0.10414264+1.45469142e-01j],
       [-0.03863038-1.83556139e-01j, -0.12741164+1.02699877e-01j,
         0.10414264-1.45469142e-01j,  0.16005719+4.53727483e-16j]]), array([[ 0.2096887 -9.47669841e-17j, -0.17202493-3.45224658e-02j,
         0.12237343+1.94919448e-01j, -0.08192224+5.64321921e-02j],
       [-0.17202493+3.45224658e-02j,  0.20737624+3.53771117e-16j,
        -0.21818075-1.33366725e-01j,  0.08991334-6.03317864e-02j],
       [ 0.12237343-1.94919448e-01j, -0.21818075+1.33366725e-01j,
         0.48987868+1.86228879e-16j, -0.05933812+9.67221112e-02j],
       [-0.08192224-5.64321921e-02j,  0.08991334+6.03317864e-02j,
        -0.05933812-9.67221112e-02j,  0.09305638-1.95876911e-16j]]), array([[ 0.30610728+7.77109409e-16j, -0.17202708-1.03242252e-01j,
         0.20486434+5.14409869e-02j, -0.13478227+1.12968520e-01j],
       [-0.17202708+1.03242252e-01j,  0.16910157-3.47155331e-16j,
        -0.1744978 +1.00702690e-01j,  0.02915113-1.24407069e-01j],
       [ 0.20486434-5.14409869e-02j, -0.1744978 -1.00702690e-01j,
         0.39612392+1.88371551e-16j, -0.09103164+1.50256029e-01j],
       [-0.13478227-1.12968520e-01j,  0.02915113+1.24407069e-01j,
        -0.09103164-1.50256029e-01j,  0.12866724+3.84238949e-16j]]), array([[ 0.28768842+8.19863972e-15j, -0.07891785-4.45353566e-02j,
         0.04291414+4.13889526e-02j,  0.09763115+2.41375562e-01j],
       [-0.07891785+4.45353566e-02j,  0.1255286 +2.76760218e-15j,
        -0.12502726-1.43660713e-01j, -0.09881489-2.43111014e-02j],
       [ 0.04291414-4.13889526e-02j, -0.12502726+1.43660713e-01j,
         0.33064803+8.50544640e-15j,  0.04898998-5.74625911e-02j],
       [ 0.09763115-2.41375562e-01j, -0.09881489+2.43111014e-02j,
         0.04898998+5.74625911e-02j,  0.25613495+2.74599629e-14j]]), array([[ 0.39318261+1.53174194e-15j, -0.10512416-9.51298257e-02j,
         0.08482603-1.07871881e-01j,  0.01110834+2.63131090e-01j],
       [-0.10512416+9.51298257e-02j,  0.11598434-2.86307802e-16j,
        -0.09068791+7.41183497e-04j, -0.13112487-8.80313965e-02j],
       [ 0.08482603+1.07871881e-01j, -0.09068791-7.41183497e-04j,
         0.23620017+3.67708371e-16j,  0.04381882+3.95557315e-02j],
       [ 0.01110834-2.63131090e-01j, -0.13112487+8.80313965e-02j,
         0.04381882-3.95557315e-02j,  0.25463288-3.66560469e-16j]]), array([[ 0.3003649 -1.61702239e-15j, -0.15466402+7.52575086e-02j,
         0.08882121+1.97079202e-02j,  0.02206997+2.01970511e-01j],
       [-0.15466402-7.52575086e-02j,  0.14474461-5.52737063e-15j,
        -0.12558827-1.17019078e-01j,  0.05290024-5.31628252e-02j],
       [ 0.08882121-1.97079202e-02j, -0.12558827+1.17019078e-01j,
         0.34251648+7.48157213e-15j, -0.11039638-2.14688584e-02j],
       [ 0.02206997-2.01970511e-01j,  0.05290024+5.31628252e-02j,
        -0.11039638+2.14688584e-02j,  0.21237402-2.79857318e-17j]]), array([[ 0.43385888-6.94476340e-17j, -0.19602791+2.18397446e-02j,
         0.1614632 -1.87852119e-01j, -0.06827373+2.52628310e-01j],
       [-0.19602791-2.18397446e-02j,  0.11994974-4.07496084e-17j,
        -0.1048157 +7.65089051e-02j,  0.04260551-1.15547876e-01j],
       [ 0.1614632 +1.87852119e-01j, -0.1048157 -7.65089051e-02j,
         0.25077337+1.40260244e-16j, -0.15183583+6.72911399e-02j],
       [-0.06827373-2.52628310e-01j,  0.04260551+1.15547876e-01j,
        -0.15183583-6.72911399e-02j,  0.195418  +1.77804873e-16j]]), array([[ 0.11263829-1.47309926e-16j, -0.0163206 -9.47221295e-02j,
         0.0767132 +8.13014042e-02j,  0.09405672+1.48243448e-02j],
       [-0.0163206 +9.47221295e-02j,  0.21430183-1.53989915e-16j,
        -0.07060739+1.05287456e-01j,  0.08481187+2.66038798e-01j],
       [ 0.0767132 -8.13014042e-02j, -0.07060739-1.05287456e-01j,
         0.15773565+7.34174724e-17j,  0.18041826-8.47385033e-02j],
       [ 0.09405672-1.48243448e-02j,  0.08481187-2.66038798e-01j,
         0.18041826+8.47385033e-02j,  0.51532423+5.90632691e-16j]]), array([[ 0.16537872+2.09757096e-16j, -0.07117057-6.80516765e-02j,
         0.04003868+3.86299934e-03j, -0.07929505-6.53520065e-02j],
       [-0.07117057+6.80516765e-02j,  0.14112882-4.61370929e-16j,
        -0.0374839 +1.10140003e-01j, -0.03770039+1.60271726e-01j],
       [ 0.04003868-3.86299934e-03j, -0.0374839 -1.10140003e-01j,
         0.13658706+8.92730672e-16j,  0.20746552+7.11324202e-02j],
       [-0.07929505+6.53520065e-02j, -0.03770039-1.60271726e-01j,
         0.20746552-7.11324202e-02j,  0.5569054 -6.23702165e-17j]]), array([[ 0.15070324-1.09504402e-16j, -0.13514492+5.94006534e-02j,
         0.06579113+6.67612673e-02j, -0.13927746-2.51725595e-02j],
       [-0.13514492-5.94006534e-02j,  0.29178235+1.04923349e-15j,
        -0.03259657-2.55005722e-02j,  0.23779093+2.43785290e-01j],
       [ 0.06579113-6.67612673e-02j, -0.03259657+2.55005722e-02j,
         0.10211759-7.38054178e-17j,  0.00703962-1.46147374e-03j],
       [-0.13927746+2.51725595e-02j,  0.23779093-2.43785290e-01j,
         0.00703962+1.46147374e-03j,  0.45539682+7.40948114e-17j]]), array([[ 0.23814053-3.05985827e-16j, -0.14550774+4.51414376e-02j,
         0.03361414+2.18827641e-02j, -0.25964366-1.05143446e-01j],
       [-0.14550774-4.51414376e-02j,  0.19990644-1.05097315e-16j,
        -0.02751158+7.01361980e-02j,  0.07505443+1.94991473e-01j],
       [ 0.03361414-2.18827641e-02j, -0.02751158-7.01361980e-02j,
         0.10173798+4.05694485e-17j,  0.03645214+6.55032046e-02j],
       [-0.25964366+1.05143446e-01j,  0.07505443-1.94991473e-01j,
         0.03645214-6.55032046e-02j,  0.46021505-5.59195206e-16j]]), array([[ 0.16091736+4.64474570e-17j,  0.00063821+3.01739481e-02j,
         0.0952956 +3.61423384e-02j,  0.10640909+5.06097093e-02j],
       [ 0.00063821-3.01739481e-02j,  0.09242911+1.83550816e-16j,
        -0.05741604-1.32448854e-02j, -0.03585581+1.79303522e-01j],
       [ 0.0952956 -3.61423384e-02j, -0.05741604+1.32448854e-02j,
         0.12540753+3.68973553e-16j,  0.12819125-1.51800615e-01j],
       [ 0.10640909-5.06097093e-02j, -0.03585581-1.79303522e-01j,
         0.12819125+1.51800615e-01j,  0.621246  -2.58574039e-15j]]), array([[ 0.25110078+1.42942350e-15j, -0.02406515+2.28437869e-02j,
         0.08525219-5.21741285e-02j, -0.0722708 -3.98406034e-02j],
       [-0.02406515-2.28437869e-02j,  0.05909286-9.42879565e-16j,
        -0.05505353+1.75614661e-02j, -0.13953011+1.10386399e-01j],
       [ 0.08525219+5.21741285e-02j, -0.05505353-1.75614661e-02j,
         0.08342171+2.28213669e-16j,  0.13623099-5.32620712e-02j],
       [-0.0722708 +3.98406034e-02j, -0.13953011-1.10386399e-01j,
         0.13623099+5.32620712e-02j,  0.60638464-8.24885765e-15j]]), array([[ 0.23503431-9.58403406e-16j, -0.06038229+1.36460484e-01j,
         0.11993305+3.93462392e-02j, -0.07632473-3.70988863e-03j],
       [-0.06038229-1.36460484e-01j,  0.14781435-1.40561003e-14j,
        -0.05679079-6.07713996e-02j,  0.09377439+1.82470118e-01j],
       [ 0.11993305-3.93462392e-02j, -0.05679079+6.07713996e-02j,
         0.12101531+1.20828790e-15j, -0.06064331-1.44924535e-01j],
       [-0.07632473+3.70988863e-03j,  0.09377439-1.82470118e-01j,
        -0.06064331+1.44924535e-01j,  0.49613603-7.13787314e-15j]]), array([[ 0.3417832 +6.71343544e-16j, -0.07008346+1.17685753e-01j,
         0.12620615-5.64164204e-02j, -0.32492466-1.10764550e-01j],
       [-0.07008346-1.17685753e-01j,  0.08555406-1.05810956e-16j,
        -0.05164302-2.87414232e-02j,  0.00446473+1.62030409e-01j],
       [ 0.12620615+5.64164204e-02j, -0.05164302+2.87414232e-02j,
         0.07790808+3.70982555e-17j, -0.09308825-1.04529579e-01j],
       [-0.32492466+1.10764550e-01j,  0.00446473-1.62030409e-01j,
        -0.09308825+1.04529579e-01j,  0.49475466+2.21579743e-16j]]), array([[ 0.14232752+8.80566273e-16j, -0.12055627-1.31277614e-01j,
         0.15538447+8.07461480e-02j,  0.14645516-4.98169900e-02j],
       [-0.12055627+1.31277614e-01j,  0.35619085-7.27997399e-16j,
        -0.19334971+5.02046578e-02j, -0.05244667+2.43433869e-01j],
       [ 0.15538447-8.07461480e-02j, -0.19334971-5.02046578e-02j,
         0.26565135+1.71827755e-16j,  0.14011148-1.25682701e-01j],
       [ 0.14645516+4.98169900e-02j, -0.05244667-2.43433869e-01j,
         0.14011148+1.25682701e-01j,  0.23583028+1.58755015e-16j]]), array([[ 0.18980144+1.55072783e-17j, -0.1876069 -1.31193415e-01j,
         0.15963654-6.11852675e-02j,  0.12032362-4.80674620e-02j],
       [-0.1876069 +1.31193415e-01j,  0.35525297-1.01725843e-15j,
        -0.14321499+2.08368762e-01j, -0.15059902+1.77042739e-01j],
       [ 0.15963654+6.11852675e-02j, -0.14321499-2.08368762e-01j,
         0.2147512 -1.99426327e-16j,  0.18358063+2.19208553e-02j],
       [ 0.12032362+4.80674620e-02j, -0.15059902-1.77042739e-01j,
         0.18358063-2.19208553e-02j,  0.24019439+1.61245538e-16j]]), array([[ 0.17231872-6.33326733e-16j, -0.22721543+1.80276861e-02j,
         0.15116118+6.63688850e-02j, -0.04960666-9.89199582e-02j],
       [-0.22721543-1.80276861e-02j,  0.43374803-6.42171044e-16j,
        -0.16542817-6.29414627e-02j,  0.09158023+2.31074358e-01j],
       [ 0.15116118-6.63688850e-02j, -0.16542817+6.29414627e-02j,
         0.21911449-3.65946221e-17j, -0.03300094-5.37298728e-02j],
       [-0.04960666+9.89199582e-02j,  0.09158023-2.31074358e-01j,
        -0.03300094+5.37298728e-02j,  0.17481875-3.34270596e-16j]]), array([[ 0.24027282+9.93042275e-16j, -0.2423785 -5.79580456e-03j,
         0.14791134-4.73520033e-02j, -0.0825324 -9.57592348e-02j],
       [-0.2423785 +5.79580456e-03j,  0.36368037-1.37530874e-15j,
        -0.11922847+1.46117884e-01j, -0.00210531+1.68121012e-01j],
       [ 0.14791134+4.73520033e-02j, -0.11922847-1.46117884e-01j,
         0.20007406-1.60232504e-17j,  0.00281467+2.25556191e-02j],
       [-0.0825324 +9.57592348e-02j, -0.00210531-1.68121012e-01j,
         0.00281467-2.25556191e-02j,  0.19597275+2.21981089e-16j]]), array([[ 0.15135836+7.19420145e-17j, -0.11413281+2.05670623e-02j,
         0.16030062+4.49192795e-02j,  0.14124833-5.14659086e-02j],
       [-0.11413281-2.05670623e-02j,  0.22604131+4.13578730e-16j,
        -0.17238475-1.12043324e-01j, -0.19710349+1.55313665e-01j],
       [ 0.16030062-4.49192795e-02j, -0.17238475+1.12043324e-01j,
         0.24976579-4.23576838e-16j,  0.11779431-1.93045563e-01j],
       [ 0.14124833+5.14659086e-02j, -0.19710349-1.55313665e-01j,
         0.11779431+1.93045563e-01j,  0.37283454+8.09258705e-16j]]), array([[ 0.24427145+5.82683368e-16j, -0.15964172+3.15536411e-02j,
         0.15464307-9.42149079e-02j,  0.11796761-4.90273533e-02j],
       [-0.15964172-3.15536411e-02j,  0.20896912+1.06840045e-15j,
        -0.14680279+3.63157087e-02j, -0.2493274 +6.27980656e-02j],
       [ 0.15464307+9.42149079e-02j, -0.14680279-3.63157087e-02j,
         0.15471897+3.01146896e-16j,  0.14844806-1.12456831e-02j],
       [ 0.11796761+4.90273533e-02j, -0.2493274 -6.27980656e-02j,
         0.14844806+1.12456831e-02j,  0.39204047+8.54794203e-16j]]), array([[ 0.20202696-2.52048122e-16j, -0.16167023+1.19313200e-01j,
         0.21076481+3.20594799e-02j, -0.04979539-1.40318864e-01j],
       [-0.16167023-1.19313200e-01j,  0.24938901+2.41214965e-16j,
        -0.17378601-1.74238050e-01j, -0.05803332+1.91825152e-01j],
       [ 0.21076481-3.20594799e-02j, -0.17378601+1.74238050e-01j,
         0.28923562+4.39769818e-16j, -0.10757615-2.03324496e-01j],
       [-0.04979539+1.40318864e-01j, -0.05803332-1.91825152e-01j,
        -0.10757615+2.03324496e-01j,  0.25934841-3.32824597e-16j]]), array([[ 0.32009757+6.92141986e-16j, -0.19807335+9.83537907e-02j,
         0.19118026-1.07169869e-01j, -0.09478815-8.95405474e-02j],
       [-0.19807335-9.83537907e-02j,  0.240464  -9.18921899e-16j,
        -0.13049681+1.23508634e-02j, -0.09657911+1.08528152e-01j],
       [ 0.19118026+1.07169869e-01j, -0.13049681-1.23508634e-02j,
         0.16565414-8.64949997e-17j, -0.06333878-7.26400074e-02j],
       [-0.09478815+8.95405474e-02j, -0.09657911-1.08528152e-01j,
        -0.06333878+7.26400074e-02j,  0.27378429-3.68688595e-17j]]), array([[ 0.32861399+1.00802795e-15j,  0.04092235-9.17316119e-02j,
         0.14240068+2.12716305e-01j,  0.09337079+1.45055105e-01j],
       [ 0.04092235+9.17316119e-02j,  0.1088046 -9.62399785e-17j,
        -0.00955573+5.63970542e-02j,  0.05209138+1.41710709e-01j],
       [ 0.14240068-2.12716305e-01j, -0.00955573-5.63970542e-02j,
         0.2307553 +2.14160050e-16j,  0.16176328+6.18240108e-02j],
       [ 0.09337079-1.45055105e-01j,  0.05209138-1.41710709e-01j,
         0.16176328-6.18240108e-02j,  0.3318261 -7.63399126e-16j]]), array([[ 0.4149904 -1.83932316e-15j,  0.01445779-1.10041550e-01j,
         0.12552283+1.03127928e-01j, -0.08359249+6.27077374e-02j],
       [ 0.01445779+1.10041550e-01j,  0.0709336 +4.19097745e-16j,
         0.00610843+1.00046243e-01j, -0.03511726+8.68176469e-02j],
       [ 0.12552283-1.03127928e-01j,  0.00610843-1.00046243e-01j,
         0.18873564+2.30919497e-15j,  0.15029994+1.44340599e-01j],
       [-0.08359249-6.27077374e-02j, -0.03511726-8.68176469e-02j,
         0.15029994-1.44340599e-01j,  0.32534037+7.66528075e-16j]]), array([[ 0.31258852-3.65467351e-16j, -0.08691257+8.39394157e-02j,
         0.10850272+2.31644062e-01j, -0.14480776+7.44142754e-02j],
       [-0.08691257-8.39394157e-02j,  0.13884741-2.43498913e-16j,
         0.04475058-1.02818574e-01j,  0.16062136+1.17323044e-01j],
       [ 0.10850272-2.31644062e-01j,  0.04475058+1.02818574e-01j,
         0.22347518-2.66435562e-16j,  0.01066283+1.59149966e-01j],
       [-0.14480776-7.44142754e-02j,  0.16062136-1.17323044e-01j,
         0.01066283-1.59149966e-01j,  0.32508888+4.34371120e-17j]]), array([[ 0.43583219-1.37404535e-15j, -0.07382797+3.68430614e-02j,
         0.10268562+1.74083443e-01j, -0.27598193-9.56152420e-03j],
       [-0.07382797-3.68430614e-02j,  0.07012345+1.24604052e-16j,
         0.02639545+2.28544544e-02j,  0.02650515+8.97229169e-02j],
       [ 0.10268562-1.74083443e-01j,  0.02639545-2.28544544e-02j,
         0.20644355-2.38718036e-16j,  0.00294981+1.79328019e-01j],
       [-0.27598193+9.56152420e-03j,  0.02650515-8.97229169e-02j,
         0.00294981-1.79328019e-01j,  0.2876008 -5.46955822e-16j]]), array([[0.4290925 -1.18037051e-15j, 0.0383957 +2.19237730e-02j,
        0.17515232+7.94633460e-02j, 0.21260368+2.63152168e-01j],
       [0.0383957 -2.19237730e-02j, 0.03438015-2.46811417e-17j,
        0.01163285-6.75340591e-03j, 0.02739167+6.64684099e-02j],
       [0.17515232-7.94633460e-02j, 0.01163285+6.75340591e-03j,
        0.10368987+1.74319372e-16j, 0.13120881+4.64786388e-02j],
       [0.21260368-2.63152168e-01j, 0.02739167-6.64684099e-02j,
        0.13120881-4.64786388e-02j, 0.43283748-2.40055329e-16j]]), array([[ 0.54074267-1.92387401e-14j,  0.04117396-2.79919914e-02j,
         0.16091472-1.88795671e-02j, -0.05083479+1.33378229e-01j],
       [ 0.04117396+2.79919914e-02j,  0.0251036 -1.93852592e-16j,
        -0.00251131+2.42327796e-02j, -0.0686772 +6.39172910e-02j],
       [ 0.16091472+1.88795671e-02j, -0.00251131-2.42327796e-02j,
         0.07564942-9.32510782e-16j,  0.07296632+4.36359338e-02j],
       [-0.05083479-1.33378229e-01j, -0.0686772 -6.39172910e-02j,
         0.07296632-4.36359338e-02j,  0.35850431+2.45853733e-15j]]), array([[ 0.44546152+2.56674581e-13j, -0.04121218+1.55901466e-01j,
         0.15863458+1.25667067e-01j, -0.02900819+1.42519328e-01j],
       [-0.04121218-1.55901466e-01j,  0.09126021+4.66047665e-15j,
         0.0050558 -8.85985098e-02j,  0.09721645+8.40418195e-02j],
       [ 0.15863458-1.25667067e-01j,  0.0050558 +8.85985098e-02j,
         0.12395473-4.65946002e-14j, -0.06001219+2.37733207e-02j],
       [-0.02900819-1.42519328e-01j,  0.09721645-8.40418195e-02j,
        -0.06001219-2.37733207e-02j,  0.33932355+5.22693056e-14j]]), array([[ 0.6128291 -1.64679814e-16j, -0.01383471+9.95825163e-02j,
         0.20692894+3.69387340e-02j, -0.2868491 +7.17201409e-02j],
       [-0.01383471-9.95825163e-02j,  0.03398419-1.10088217e-17j,
         0.00307782-3.54392385e-02j,  0.00821453+6.22502535e-02j],
       [ 0.20692894-3.69387340e-02j,  0.00307782+3.54392385e-02j,
         0.09263086+8.22557069e-18j, -0.10807991+4.59403610e-02j],
       [-0.2868491 -7.17201409e-02j,  0.00821453-6.22502535e-02j,
        -0.10807991-4.59403610e-02j,  0.26055585-2.51257340e-16j]]), array([[ 0.28693418+2.38368803e-15j, -0.07749892-1.20557848e-01j,
         0.24283624+1.69306111e-01j,  0.13928756+5.88444369e-02j],
       [-0.07749892+1.20557848e-01j,  0.16191209+2.50971676e-16j,
        -0.09079265-5.93854636e-03j, -0.02984902+9.56179334e-02j],
       [ 0.24283624-1.69306111e-01j, -0.09079265+5.93854636e-03j,
         0.40991836+2.51941514e-15j,  0.13877913+2.71143267e-02j],
       [ 0.13928756-5.88444369e-02j, -0.02984902-9.56179334e-02j,
         0.13877913-2.71143267e-02j,  0.14123538+4.25242318e-16j]]), array([[ 0.34759308+1.17715989e-16j, -0.07953135-1.92472372e-01j,
         0.29249328-1.47383417e-02j,  0.10074441+9.59913820e-02j],
       [-0.07953135+1.92472372e-01j,  0.1657946 +2.23586400e-16j,
        -0.04680447+1.92320771e-01j, -0.08930806+6.11148487e-02j],
       [ 0.29249328+1.47383417e-02j, -0.04680447-1.92320771e-01j,
         0.35156958-3.34356011e-16j,  0.12006672+1.36456640e-01j],
       [ 0.10074441-9.59913820e-02j, -0.08930806-6.11148487e-02j,
         0.12006672-1.36456640e-01j,  0.13504274+4.73766377e-16j]]), array([[ 0.27256259+4.99543787e-16j, -0.15555187+2.94684013e-02j,
         0.22270342+2.13367854e-01j, -0.07046691-1.53150307e-02j],
       [-0.15555187-2.94684013e-02j,  0.18348026+1.94784666e-16j,
        -0.04751911-1.44415024e-01j,  0.05662527+8.58893724e-02j],
       [ 0.22270342-2.13367854e-01j, -0.04751911+1.44415024e-01j,
         0.44079012-4.15279229e-16j, -0.05231642+1.01735561e-01j],
       [-0.07046691+1.53150307e-02j,  0.05662527-8.58893724e-02j,
        -0.05231642-1.01735561e-01j,  0.10316703+4.12680262e-17j]]), array([[ 0.34604379-3.76411784e-16j, -0.14244794-4.57212283e-02j,
         0.2449895 +4.72570097e-02j, -0.10250502-1.55069842e-02j],
       [-0.14244794+4.57212283e-02j,  0.15111045-1.29528549e-16j,
        -0.02306354+1.06200722e-01j, -0.00359446+5.48528942e-02j],
       [ 0.2449895 -4.72570097e-02j, -0.02306354-1.06200722e-01j,
         0.3884435 -1.03448487e-16j, -0.05559372+1.25841716e-01j],
       [-0.10250502+1.55069842e-02j, -0.00359446-5.48528942e-02j,
        -0.05559372-1.25841716e-01j,  0.11440226-1.86060819e-16j]]), array([[ 0.38737758-3.70802051e-16j, -0.11056741+3.05832838e-02j,
         0.26808104+7.00944536e-02j,  0.21464325+1.30193554e-01j],
       [-0.11056741-3.05832838e-02j,  0.10211627-3.15860877e-16j,
        -0.08797898-1.04025876e-01j, -0.07903545+1.55792645e-03j],
       [ 0.26808104-7.00944536e-02j, -0.08797898+1.04025876e-01j,
         0.27428492-2.81982280e-16j,  0.12524324+9.90597103e-03j],
       [ 0.21464325-1.30193554e-01j, -0.07903545-1.55792645e-03j,
         0.12524324-9.90597103e-03j,  0.23622123-7.15272361e-16j]]), array([[ 0.51189064-6.43179250e-16j, -0.10442565-5.11513864e-02j,
         0.27375123-1.53863151e-01j,  0.16948581+1.53001722e-01j],
       [-0.10442565+5.11513864e-02j,  0.06647215-3.80547377e-17j,
        -0.05025236+5.61456976e-02j, -0.09150776+1.80706439e-03j],
       [ 0.27375123+1.53863151e-01j, -0.05025236-5.61456976e-02j,
         0.22176873-6.62325154e-16j,  0.0598294 +1.27674584e-01j],
       [ 0.16948581-1.53001722e-01j, -0.09150776-1.80706439e-03j,
         0.0598294 -1.27674584e-01j,  0.19986848-2.06795289e-17j]]), array([[ 0.38466591-1.12883589e-15j, -0.1326756 +1.26115790e-01j,
         0.26577806+8.87640024e-02j, -0.00202651+4.40809369e-02j],
       [-0.1326756 -1.26115790e-01j,  0.13599298+2.10502751e-16j,
        -0.06871777-1.82275506e-01j, -0.00219609+5.45790037e-02j],
       [ 0.26577806-8.87640024e-02j, -0.06871777+1.82275506e-01j,
         0.3242563 -4.43626329e-16j, -0.10509662-7.10291213e-03j],
       [-0.00202651-4.40809369e-02j, -0.00219609-5.45790037e-02j,
        -0.10509662+7.10291213e-03j,  0.1550848 +2.98927105e-17j]]), array([[ 0.53597338-9.31327847e-16j, -0.13905434+4.97033320e-02j,
         0.32457571-9.45915072e-02j, -0.1093872 +4.61669160e-02j],
       [-0.13905434-4.97033320e-02j,  0.07978888-6.19430080e-17j,
        -0.0676541 -5.72717059e-03j, -0.00417341+1.79008595e-02j],
       [ 0.32457571+9.45915072e-02j, -0.0676541 +5.72717059e-03j,
         0.26843097-4.65480383e-16j, -0.11952146+3.02504053e-02j],
       [-0.1093872 -4.61669160e-02j, -0.00417341-1.79008595e-02j,
        -0.11952146-3.02504053e-02j,  0.11580676+1.20470251e-18j]]), array([[ 0.1840277 +4.24567990e-15j, -0.05784538-1.81571218e-01j,
        -0.03914848+1.10102402e-01j, -0.00893358-2.45792516e-04j],
       [-0.05784538+1.81571218e-01j,  0.27820649-6.99616989e-15j,
        -0.03626815-6.90681994e-02j,  0.163332  -9.76903052e-02j],
       [-0.03914848-1.10102402e-01j, -0.03626815+6.90681994e-02j,
         0.11964884-1.22848163e-14j,  0.1168801 -6.95126960e-02j],
       [-0.00893358+2.45792516e-04j,  0.163332  +9.76903052e-02j,
         0.1168801 +6.95126960e-02j,  0.41811698+3.32662190e-14j]]), array([[ 0.28708393+6.86948817e-16j, -0.061992  -2.45094030e-01j,
        -0.04251043+1.24500817e-02j, -0.23139475-5.83437435e-02j],
       [-0.061992  +2.45094030e-01j,  0.24539948+4.93005416e-16j,
        -0.0096877 -3.87875040e-02j,  0.08681245-1.88291284e-01j],
       [-0.04251043-1.24500817e-02j, -0.0096877 +3.87875040e-02j,
         0.05857802-4.47426750e-17j,  0.11840807+3.18267904e-03j],
       [-0.23139475+5.83437435e-02j,  0.08681245+1.88291284e-01j,
         0.11840807-3.18267904e-03j,  0.40893857+3.48795327e-16j]]), array([[ 0.17382228+2.59711022e-16j, -0.1460986 -6.72514531e-02j,
        -0.01849005+9.83731990e-02j, -0.08376669-1.71831551e-02j],
       [-0.1460986 +6.72514531e-02j,  0.32591454-3.37334819e-16j,
        -0.0203112 -7.75221778e-03j,  0.30485153-9.74911005e-02j],
       [-0.01849005-9.83731990e-02j, -0.0203112 +7.75221778e-03j,
         0.10853013+4.12470950e-17j, -0.03687933-6.54732381e-02j],
       [-0.08376669+1.71831551e-02j,  0.30485153+9.74911005e-02j,
        -0.03687933+6.54732381e-02j,  0.39173305+4.88062486e-16j]]), array([[ 0.28483345+4.42285024e-16j, -0.15142167-1.61965948e-01j,
         0.03352756+5.51362591e-03j, -0.2807003 -8.88951317e-02j],
       [-0.15142167+1.61965948e-01j,  0.26247743-2.06949267e-16j,
        -0.02322535+6.70386695e-02j,  0.23232831-1.64841372e-01j],
       [ 0.03352756-5.51362591e-03j, -0.02322535-6.70386695e-02j,
         0.0617445 +1.76603288e-17j, -0.07154273-2.33634387e-02j],
       [-0.2807003 +8.88951317e-02j,  0.23232831+1.64841372e-01j,
        -0.07154273+2.33634387e-02j,  0.39094461-1.52506760e-16j]]), array([[ 0.1515154 +1.31872168e-16j, -0.04879351-3.54966184e-02j,
        -0.04176377+8.58140275e-02j,  0.1306516 +1.20777429e-01j],
       [-0.04879351+3.54966184e-02j,  0.10325603-1.91299462e-16j,
         0.03513198-4.87034843e-02j, -0.01458728-1.57551587e-01j],
       [-0.04176377-8.58140275e-02j,  0.03513198+4.87034843e-02j,
         0.1066921 +3.51077840e-16j,  0.09333262-2.08772483e-01j],
       [ 0.1306516 -1.20777429e-01j, -0.01458728+1.57551587e-01j,
         0.09333262+2.08772483e-01j,  0.63853647-1.77450693e-16j]]), array([[ 0.26503114-6.75623969e-17j, -0.03677159-1.33717126e-01j,
        -0.03223303-3.95551447e-02j, -0.15484824+4.69150307e-02j],
       [-0.03677159+1.33717126e-01j,  0.12038679-9.17288396e-17j,
         0.04535259-3.89248353e-02j, -0.05718347-2.04827705e-01j],
       [-0.03223303+3.95551447e-02j,  0.04535259+3.89248353e-02j,
         0.05089029-1.24929739e-16j,  0.07081089-1.36137363e-01j],
       [-0.15484824-4.69150307e-02j, -0.05718347+2.04827705e-01j,
         0.07081089+1.36137363e-01j,  0.56369178-3.01172537e-16j]]), array([[ 0.18192175+1.12148038e-16j, -0.10736665+3.56242309e-02j,
        -0.02170697+7.54903577e-02j,  0.03774087+6.92345972e-02j],
       [-0.10736665-3.56242309e-02j,  0.13803389+6.18074975e-16j,
         0.02032847+3.51326840e-02j,  0.14337554-1.20572616e-01j],
       [-0.02170697-7.54903577e-02j,  0.02032847-3.51326840e-02j,
         0.14709871-8.22673589e-16j, -0.09085132-2.19609142e-01j],
       [ 0.03774087-6.92345972e-02j,  0.14337554+1.20572616e-01j,
        -0.09085132+2.19609142e-01j,  0.53294565-1.31369347e-15j]]), array([[ 0.26208644+3.71850181e-16j, -0.10008038-3.99410118e-02j,
         0.01606888-6.38441970e-02j, -0.1990244 +1.35853709e-02j],
       [-0.10008038+3.99410118e-02j,  0.11885796+3.78325650e-16j,
         0.04972556+7.42754406e-02j,  0.08961985-1.85670736e-01j],
       [ 0.01606888+6.38441970e-02j,  0.04972556-7.42754406e-02j,
         0.09540502-5.00411861e-16j, -0.11544311-1.69375180e-01j],
       [-0.1990244 -1.35853709e-02j,  0.08961985+1.85670736e-01j,
        -0.11544311+1.69375180e-01j,  0.52365059+9.94266165e-16j]]), array([[ 0.17713986+2.46513144e-15j, -0.18330444-2.03255584e-01j,
        -0.02482724+1.10275351e-01j,  0.00470389+2.97931009e-02j],
       [-0.18330444+2.03255584e-01j,  0.48049396+1.97975510e-15j,
        -0.04879998-1.65520410e-01j,  0.01118636-9.76504950e-02j],
       [-0.02482724-1.10275351e-01j, -0.04879998+1.65520410e-01j,
         0.15527139+1.39385968e-15j,  0.1143457 -7.39371636e-02j],
       [ 0.00470389-2.97931009e-02j,  0.01118636+9.76504950e-02j,
         0.1143457 +7.39371636e-02j,  0.18709479-8.26115165e-16j]]), array([[ 0.28274027-1.14916826e-15j, -0.18106166-2.88805572e-01j,
         0.01621733-3.80190851e-02j, -0.09291838+3.34868535e-02j],
       [-0.18106166+2.88805572e-01j,  0.45301856+1.71634797e-15j,
        -0.00655884+1.74635051e-02j, -0.02423332-1.37563443e-01j],
       [ 0.01621733+3.80190851e-02j, -0.00655884-1.74635051e-02j,
         0.09717728-2.24947847e-16j,  0.08726423-3.73738276e-02j],
       [-0.09291838-3.34868535e-02j, -0.02423332+1.37563443e-01j,
         0.08726423+3.73738276e-02j,  0.16706388-1.82233587e-16j]]), array([[ 0.19902143+2.02342629e-16j, -0.30255206-6.37143115e-02j,
        -0.01324842+1.07507069e-01j, -0.06554994+3.34240743e-02j],
       [-0.30255206+6.37143115e-02j,  0.56076509+9.36180600e-17j,
        -0.02457002-1.32135110e-01j,  0.15406956-1.10587287e-01j],
       [-0.01324842-1.07507069e-01j, -0.02457002+1.32135110e-01j,
         0.10727539-6.28681958e-17j, -0.01648264-8.48651087e-03j],
       [-0.06554994-3.34240743e-02j,  0.15406956+1.10587287e-01j,
        -0.01648264+8.48651087e-03j,  0.13293809-4.10166509e-16j]]), array([[ 0.28187799+1.48890652e-16j, -0.30293419-1.69277491e-01j,
         0.04671775-6.85610427e-02j, -0.13269323+3.42183891e-02j],
       [-0.30293419+1.69277491e-01j,  0.50373186-5.29821381e-16j,
        -0.00599276+1.37330207e-01j,  0.12329076-1.49846232e-01j],
       [ 0.04671775+6.85610427e-02j, -0.00599276-1.37330207e-01j,
         0.09014713+6.01393690e-17j, -0.0596901 -3.08846811e-02j],
       [-0.13269323-3.42183891e-02j,  0.12329076+1.49846232e-01j,
        -0.0596901 +3.08846811e-02j,  0.12424302+1.43127697e-16j]]), array([[ 0.14771982-1.56481531e-16j, -0.17834992-5.75998569e-02j,
        -0.03582495+1.20310207e-01j,  0.12623958+1.30464780e-01j],
       [-0.17834992+5.75998569e-02j,  0.30643101+9.24648481e-17j,
         0.01633427-1.84837707e-01j, -0.21500667-1.67610917e-01j],
       [-0.03582495-1.20310207e-01j,  0.01633427+1.84837707e-01j,
         0.16726363+4.08371481e-16j,  0.1015565 -2.04002490e-01j],
       [ 0.12623958-1.30464780e-01j, -0.21500667+1.67610917e-01j,
         0.1015565 +2.04002490e-01j,  0.37858554+8.10233363e-16j]]), array([[ 0.26410839+1.32865035e-15j, -0.16829368-1.49474238e-01j,
        -0.00152606-7.43105126e-02j, -0.03068602+1.07945754e-01j],
       [-0.16829368+1.49474238e-01j,  0.29515056-7.15952316e-16j,
         0.04119661-3.74458463e-02j, -0.17374764-1.86409644e-01j],
       [-0.00152606+7.43105126e-02j,  0.04119661+3.74458463e-02j,
         0.10214326+3.02175453e-16j,  0.06087821-1.24418643e-01j],
       [-0.03068602-1.07945754e-01j, -0.17374764+1.86409644e-01j,
         0.06087821+1.24418643e-01j,  0.33859779+3.90113919e-16j]]), array([[ 1.91894649e-01-6.26909506e-16j, -2.49852059e-01+5.35290948e-02j,
        -3.55030526e-04+8.60323934e-02j,  7.05207892e-02+9.09729691e-02j],
       [-2.49852059e-01-5.35290948e-02j,  3.55507708e-01-7.37421170e-16j,
         5.26210853e-03-8.38839759e-02j, -1.91887791e-02-1.45505135e-01j],
       [-3.55030526e-04-8.60323934e-02j,  5.26210853e-03+8.38839759e-02j,
         1.58108312e-01+4.06041173e-16j, -6.51801814e-02-1.54249891e-01j],
       [ 7.05207892e-02-9.09729691e-02j, -1.91887791e-02+1.45505135e-01j,
        -6.51801814e-02+1.54249891e-01j,  2.94489331e-01-3.38382270e-15j]]), array([[ 0.2766396 -3.70340604e-17j, -0.278129  -2.02250983e-02j,
         0.00326088-9.54326377e-02j, -0.035104  +1.42846879e-01j],
       [-0.278129  +2.02250983e-02j,  0.34250506-5.25537569e-16j,
         0.04424022+8.80233101e-02j, -0.03206681-2.21040736e-01j],
       [ 0.00326088+9.54326377e-02j,  0.04424022-8.80233101e-02j,
         0.08959665+4.56321060e-17j, -0.08998864-9.68265988e-02j],
       [-0.035104  -1.42846879e-01j, -0.03206681+2.21040736e-01j,
        -0.08998864+9.68265988e-02j,  0.29125869+9.08813624e-17j]]), array([[ 0.45110306-1.30397591e-15j, -0.02124806-2.02200031e-01j,
        -0.12529712+2.48574970e-01j,  0.02881465+4.84393698e-02j],
       [-0.02124806+2.02200031e-01j,  0.14768225-8.29146263e-17j,
        -0.06601066-7.01367820e-02j,  0.06674744-2.85070316e-02j],
       [-0.12529712-2.48574970e-01j, -0.06601066+7.01367820e-02j,
         0.20721196-1.04648864e-15j,  0.08924559-5.63770514e-02j],
       [ 0.02881465-4.84393698e-02j,  0.06674744+2.85070316e-02j,
         0.08924559+5.63770514e-02j,  0.19400273+2.55810532e-18j]]), array([[ 0.60180315-1.09042717e-16j, -0.04138725-2.73705122e-01j,
        -0.13611123+1.21416252e-01j, -0.21810366+1.54127963e-02j],
       [-0.04138725+2.73705122e-01j,  0.147689  -7.49075515e-17j,
        -0.04247117-7.01094499e-02j,  0.01570061-1.05063945e-01j],
       [-0.13611123-1.21416252e-01j, -0.04247117+7.01094499e-02j,
         0.09777916+2.40814934e-16j,  0.08574141+4.50814144e-02j],
       [-0.21810366-1.54127963e-02j,  0.01570061+1.05063945e-01j,
         0.08574141-4.50814144e-02j,  0.15272869+5.17966664e-17j]]), array([[ 0.3966436 +8.26439724e-14j, -0.11349145-5.13628021e-02j,
        -0.11969368+2.74951378e-01j, -0.05023677+5.23092621e-03j],
       [-0.11349145+5.13628021e-02j,  0.13597457+1.77543731e-15j,
        -0.02903985-4.80826781e-02j,  0.14612274-5.52625310e-02j],
       [-0.11969368-2.74951378e-01j, -0.02903985+4.80826781e-02j,
         0.25666428+2.53785379e-13j, -0.04159177-1.62987581e-02j],
       [-0.05023677-5.23092621e-03j,  0.14612274+5.52625310e-02j,
        -0.04159177+1.62987581e-02j,  0.21071755-4.58551006e-14j]]), array([[ 0.52087534+4.86515337e-16j, -0.14626355-9.34664899e-02j,
        -0.1325606 +1.51175995e-01j, -0.22650461-3.77447417e-02j],
       [-0.14626355+9.34664899e-02j,  0.11575336+3.20178427e-16j,
        -0.00990585-3.05439808e-03j,  0.09011319-9.41632218e-02j],
       [-0.1325606 -1.51175995e-01j, -0.00990585+3.05439808e-03j,
         0.16993335+3.27035232e-16j, -0.03810124+7.79219495e-02j],
       [-0.22650461+3.77447417e-02j,  0.09011319+9.41632218e-02j,
        -0.03810124-7.79219495e-02j,  0.19343795-1.63420049e-16j]]), array([[ 0.49684344-1.23362220e-15j, -0.03191239-8.40856014e-02j,
        -0.14062387+1.65930181e-01j,  0.18210552+2.17013891e-01j],
       [-0.03191239+8.40856014e-02j,  0.05023784+2.21827964e-18j,
        -0.00209732-4.02966373e-02j, -0.02159874-3.74650481e-02j],
       [-0.14062387-1.65930181e-01j, -0.00209732+4.02966373e-02j,
         0.12196077+2.01620146e-17j,  0.05173509-1.59390254e-01j],
       [ 0.18210552-2.17013891e-01j, -0.02159874+3.74650481e-02j,
         0.05173509+1.59390254e-01j,  0.33095794+2.60601899e-16j]]), array([[ 0.63327471-3.72284510e-16j, -0.02663372-1.57952498e-01j,
        -0.10553888-6.66953940e-03j, -0.0768275 +1.49439212e-01j],
       [-0.02663372+1.57952498e-01j,  0.06228863+9.64650638e-17j,
         0.01803884-3.16947970e-02j, -0.04289386-8.70994777e-02j],
       [-0.10553888+6.66953940e-03j,  0.01803884+3.16947970e-02j,
         0.03242453-1.82346131e-16j,  0.0251444 -7.10110949e-02j],
       [-0.0768275 -1.49439212e-01j, -0.04289386+8.70994777e-02j,
         0.0251444 +7.10110949e-02j,  0.27201213+1.34337578e-16j]]), array([[ 0.4590822 +7.29417157e-15j, -0.11433121+5.55741127e-02j,
        -0.10854227+1.77671329e-01j,  0.08865914+1.49138177e-01j],
       [-0.11433121-5.55741127e-02j,  0.06570853-3.08219099e-15j,
         0.0128375 -5.17554279e-03j,  0.07668329-7.59503784e-02j],
       [-0.10854227-1.77671329e-01j,  0.0128375 +5.17554279e-03j,
         0.16179463-2.76244386e-15j, -0.08552974-1.06893757e-01j],
       [ 0.08865914-1.49138177e-01j,  0.07668329+7.59503784e-02j,
        -0.08552974+1.06893757e-01j,  0.31341464-4.46394191e-15j]]), array([[ 0.58864329-3.63637886e-14j, -0.12586025+3.90118165e-03j,
        -0.10444133+2.93764398e-02j, -0.09270157+9.90758829e-02j],
       [-0.12586025-3.90118165e-03j,  0.0572832 +6.30079370e-15j,
         0.02211895+3.68369419e-02j,  0.03454638-1.05059784e-01j],
       [-0.10444133-2.93764398e-02j,  0.02211895-3.68369419e-02j,
         0.07975607-4.69319757e-15j, -0.09747418-3.15642469e-02j],
       [-0.09270157-9.90758829e-02j,  0.03454638+1.05059784e-01j,
        -0.09747418+3.15642469e-02j,  0.27431743+1.13347457e-14j]]), array([[ 0.36659762-1.64475845e-16j, -0.18083072-2.43217275e-01j,
        -0.14949789+2.15240919e-01j,  0.010511  +8.02615623e-02j],
       [-0.18083072+2.43217275e-01j,  0.287559  -5.31959003e-16j,
        -0.05280664-2.34768166e-01j, -0.04848186-4.51512330e-02j],
       [-0.14949789-2.15240919e-01j, -0.05280664+2.34768166e-01j,
         0.29173942-5.00976006e-18j,  0.08065395-3.70884779e-02j],
       [ 0.010511  -8.02615623e-02j, -0.04848186+4.51512330e-02j,
         0.08065395+3.70884779e-02j,  0.05410396-1.10864215e-18j]]), array([[ 0.48543607+4.61530584e-16j, -0.17579128-3.09087516e-01j,
        -0.06537323+4.08063266e-03j, -0.063018  +8.16546465e-02j],
       [-0.17579128+3.09087516e-01j,  0.27281259+5.32999183e-16j,
         0.0051124 -3.20160489e-02j, -0.03620506-7.24773584e-02j],
       [-0.06537323-4.08063266e-03j,  0.0051124 +3.20160489e-02j,
         0.19209124-7.78863587e-17j,  0.04946237+3.37393355e-02j],
       [-0.063018  -8.16546465e-02j, -0.03620506+7.24773584e-02j,
         0.04946237-3.37393355e-02j,  0.04966011-7.58474411e-18j]]), array([[ 0.32601163-4.03688158e-16j, -0.26092275-7.66006418e-02j,
        -0.11237948+2.26060573e-01j, -0.03512735+2.39599374e-02j],
       [-0.26092275+7.66006418e-02j,  0.26743254+7.54418760e-16j,
        -0.00295283-1.66737518e-01j,  0.05144439-5.29836208e-02j],
       [-0.11237948-2.26060573e-01j, -0.00295283+1.66737518e-01j,
         0.34293528-3.65565531e-17j, -0.05211067+7.60723648e-03j],
       [-0.03512735-2.39599374e-02j,  0.05144439+5.29836208e-02j,
        -0.05211067-7.60723648e-03j,  0.06362054+1.93343020e-17j]]), array([[ 0.41642629+4.09053965e-16j, -0.2611217 -1.31269505e-01j,
        -0.08281466+3.55054730e-02j, -0.0922325 +3.06558733e-02j],
       [-0.2611217 +1.31269505e-01j,  0.2358657 -1.87213390e-16j,
         0.0247853 +3.76545339e-02j,  0.03308414-8.15736070e-02j],
       [-0.08281466-3.55054730e-02j,  0.0247853 -3.76545339e-02j,
         0.27925966+2.45890043e-15j, -0.06722938+6.38068360e-02j],
       [-0.0922325 -3.06558733e-02j,  0.03308414+8.15736070e-02j,
        -0.06722938-6.38068360e-02j,  0.06844835+1.39023348e-15j]]), array([[ 0.39973278+9.80368811e-16j, -0.1730185 -1.32489890e-01j,
        -0.13219276+1.33517043e-01j,  0.16603506+2.02853601e-01j],
       [-0.1730185 +1.32489890e-01j,  0.16618418-3.79839907e-17j,
         0.01898766-1.67107144e-01j, -0.15710411-4.61732758e-02j],
       [-0.13219276-1.33517043e-01j,  0.01898766+1.67107144e-01j,
         0.23099095-7.63488792e-17j,  0.03232694-1.58817680e-01j],
       [ 0.16603506-2.02853601e-01j, -0.15710411+4.61732758e-02j,
         0.03232694+1.58817680e-01j,  0.20309209+3.61840659e-16j]]), array([[ 0.55445415-8.83234589e-17j, -0.18321439-2.14889636e-01j,
        -0.07430217-9.98902494e-02j,  0.03235881+2.30488476e-01j],
       [-0.18321439+2.14889636e-01j,  0.17916238-7.83791212e-16j,
         0.06119435-2.91541506e-02j, -0.12364376-8.73500110e-02j],
       [-0.07430217+9.98902494e-02j,  0.06119435+2.91541506e-02j,
         0.10428078+2.81472507e-17j, -0.00668002-5.90665063e-02j],
       [ 0.03235881-2.30488476e-01j, -0.12364376+8.73500110e-02j,
        -0.00668002+5.90665063e-02j,  0.16210268+2.05412805e-16j]]), array([[ 0.3726128 -1.75584034e-15j, -0.23726726+2.70185134e-02j,
        -0.09166375+1.36632339e-01j,  0.11104489+1.40946734e-01j],
       [-0.23726726-2.70185134e-02j,  0.1656028 -9.44811993e-17j,
         0.03471725-1.00819002e-01j, -0.0432021 -8.08803588e-02j],
       [-0.09166375-1.36632339e-01j,  0.03471725+1.00819002e-01j,
         0.28550515-2.44468967e-16j, -0.10399173-1.11800882e-01j],
       [ 0.11104489-1.40946734e-01j, -0.0432021 +8.08803588e-02j,
        -0.10399173+1.11800882e-01j,  0.17627924-6.49747957e-16j]]), array([[ 0.5339736 +2.05676638e-17j, -0.29654641-1.69877011e-02j,
        -0.08152155-9.36739964e-02j,  0.04259687+1.89437025e-01j],
       [-0.29654641+1.69877011e-02j,  0.18498714+1.73832977e-16j,
         0.0527469 +6.56619679e-02j, -0.03444534-1.19238720e-01j],
       [-0.08152155+9.36739964e-02j,  0.0527469 -6.56619679e-02j,
         0.13809913-1.32152491e-16j, -0.11264636-1.55116763e-02j],
       [ 0.04259687-1.89437025e-01j, -0.03444534+1.19238720e-01j,
        -0.11264636+1.55116763e-02j,  0.14294014-1.87466170e-16j]]), array([[ 0.2537355 +2.43971224e-16j, -0.01839894-2.00773900e-01j,
         0.110106  +5.95231722e-02j,  0.16943169-1.93513617e-01j],
       [-0.01839894+2.00773900e-01j,  0.21527939-6.81059313e-17j,
        -0.02485096+8.81303563e-02j,  0.20636264+1.43228435e-01j],
       [ 0.110106  -5.95231722e-02j, -0.02485096-8.81303563e-02j,
         0.11519364+2.14566081e-16j,  0.09401522-1.49263654e-01j],
       [ 0.16943169+1.93513617e-01j,  0.20636264-1.43228435e-01j,
         0.09401522+1.49263654e-01j,  0.41579147-1.01108024e-15j]]), array([[ 0.35069982+1.14530311e-15j, -0.07821059-2.10615316e-01j,
         0.04332494-5.86636663e-02j, -0.04347464-2.55719218e-01j],
       [-0.07821059+2.10615316e-01j,  0.17370427+1.69595649e-16j,
         0.01210202+5.64004980e-02j,  0.11597014+5.88459082e-02j],
       [ 0.04332494+5.86636663e-02j,  0.01210202-5.64004980e-02j,
         0.05499608-5.60069580e-17j,  0.11422869-1.31273123e-02j],
       [-0.04347464+2.55719218e-01j,  0.11597014-5.88459082e-02j,
         0.11422869+1.31273123e-02j,  0.42059983-5.42355131e-16j]]), array([[ 0.25642539+1.06021032e-15j, -0.1367416 -3.62649706e-02j,
         0.04552107+1.28759341e-01j, -0.02295745-1.91627285e-01j],
       [-0.1367416 +3.62649706e-02j,  0.26102851+6.07891109e-16j,
         0.01392111-5.42807903e-03j,  0.23583041+1.10251289e-01j],
       [ 0.04552107-1.28759341e-01j,  0.01392111+5.42807903e-03j,
         0.11472024-3.61034012e-16j, -0.03586776-8.31756894e-02j],
       [-0.02295745+1.91627285e-01j,  0.23583041-1.10251289e-01j,
        -0.03586776+8.31756894e-02j,  0.36782586+9.48734283e-16j]]), array([[ 0.38756349-7.32683948e-16j, -0.19977985-7.04083846e-02j,
         0.00524129+1.08113221e-02j, -0.20885175-2.96798606e-01j],
       [-0.19977985+7.04083846e-02j,  0.18707367-5.81202583e-16j,
         0.00909479+2.45652154e-02j,  0.16928177+1.03483440e-01j],
       [ 0.00524129-1.08113221e-02j,  0.00909479-2.45652154e-02j,
         0.0378358 -5.51485960e-18j, -0.0187136 -1.73792283e-03j],
       [-0.20885175+2.96798606e-01j,  0.16928177-1.03483440e-01j,
        -0.0187136 +1.73792283e-03j,  0.38752704-8.32709360e-16j]]), array([[ 0.2368216 -2.28206109e-16j, -0.01718447-2.46622564e-02j,
         0.10415728+8.34041000e-02j,  0.27179267-1.49249250e-01j],
       [-0.01718447+2.46622564e-02j,  0.04101333-2.92511545e-18j,
        -0.00791819-1.70149390e-04j,  0.00759808+2.34103885e-02j],
       [ 0.10415728-8.34041000e-02j, -0.00791819+1.70149390e-04j,
         0.11782847-3.02629813e-16j,  0.09662533-2.13863772e-01j],
       [ 0.27179267+1.49249250e-01j,  0.00759808-2.34103885e-02j,
         0.09662533+2.13863772e-01j,  0.6043366 +5.98397712e-16j]]), array([[ 0.37076253+6.72115757e-16j, -0.04463032-6.04654395e-02j,
         0.07816465-5.72666076e-02j,  0.0262632 -2.13739628e-01j],
       [-0.04463032+6.04654395e-02j,  0.04938319+1.85619142e-17j,
        -0.00435043+1.52360482e-03j, -0.06053325-1.98891499e-02j],
       [ 0.07816465+5.72666076e-02j, -0.00435043-1.52360482e-03j,
         0.04460947+2.82821011e-16j,  0.08773199-9.52863778e-02j],
       [ 0.0262632 +2.13739628e-01j, -0.06053325+1.98891499e-02j,
         0.08773199+9.52863778e-02j,  0.5352448 -3.18476381e-16j]]), array([[ 0.28120757-3.18876759e-16j, -0.06233498+6.70611116e-02j,
         0.11259478+1.42782006e-01j,  0.0600669 -1.89078727e-01j],
       [-0.06233498-6.70611116e-02j,  0.08289763+5.58440673e-17j,
         0.00152584-1.06541123e-02j,  0.06376073+2.73378057e-02j],
       [ 0.11259478-1.42782006e-01j,  0.00152584+1.06541123e-02j,
         0.17445659+1.08653900e-15j, -0.09383911-2.32551240e-01j],
       [ 0.0600669 +1.89078727e-01j,  0.06376073-2.73378057e-02j,
        -0.09383911+2.32551240e-01j,  0.46143821-1.24836273e-15j]]), array([[ 0.4244666 -4.56371038e-16j, -0.07544688+3.67803749e-02j,
         0.12777933+1.44123744e-02j, -0.14653028-2.98143520e-01j],
       [-0.07544688-3.67803749e-02j,  0.05471813+1.50213856e-17j,
         0.00273789+2.07795321e-03j, -0.0031686 +4.54039957e-03j],
       [ 0.12777933-1.44123744e-02j,  0.00273789-2.07795321e-03j,
         0.08358839-1.13134292e-16j, -0.09656442-1.45209908e-01j],
       [-0.14653028+2.98143520e-01j, -0.0031686 -4.54039957e-03j,
        -0.09656442+1.45209908e-01j,  0.43722688-5.80647335e-16j]]), array([[ 0.22751586-7.53547304e-15j, -0.16578418-1.89957596e-01j,
         0.07461717+5.63771671e-02j,  0.13908535-1.09858306e-01j],
       [-0.16578418+1.89957596e-01j,  0.4112416 +2.66227538e-15j,
        -0.00261669-5.44635958e-02j,  0.03093172+1.17544219e-01j],
       [ 0.07461717-5.63771671e-02j, -0.00261669+5.44635958e-02j,
         0.15996463-6.25980608e-15j,  0.09604963-1.07970186e-01j],
       [ 0.13908535+1.09858306e-01j,  0.03093172-1.17544219e-01j,
         0.09604963+1.07970186e-01j,  0.2012779 +4.06841198e-16j]]), array([[ 0.33459019-6.20226450e-16j, -0.20109128-2.64495604e-01j,
         0.09763727-1.10926760e-01j,  0.07036636-1.37196590e-01j],
       [-0.20109128+2.64495604e-01j,  0.39674263+6.98630594e-16j,
         0.02131518+1.26732527e-01j,  0.01333189+1.09808773e-01j],
       [ 0.09763727+1.10926760e-01j,  0.02131518-1.26732527e-01j,
         0.09235644+1.58168096e-16j,  0.09656785-3.61512490e-02j],
       [ 0.07036636+1.37196590e-01j,  0.01333189-1.09808773e-01j,
         0.09656785+3.61512490e-02j,  0.17631074+1.20361559e-16j]]), array([[ 2.58129544e-01-3.93913496e-16j, -3.09067725e-01-3.15203464e-02j,
         2.23639484e-02+1.13919128e-01j, -2.22116561e-04-1.38647670e-01j],
       [-3.09067725e-01+3.15203464e-02j,  4.91338021e-01-3.11322243e-16j,
         2.05866218e-02-1.20060952e-01j,  8.83318361e-02+1.37616311e-01j],
       [ 2.23639484e-02-1.13919128e-01j,  2.05866218e-02+1.20060952e-01j,
         1.04259629e-01-1.99839757e-16j, -2.48573217e-02-4.53278785e-02j],
       [-2.22116561e-04+1.38647670e-01j,  8.83318361e-02-1.37616311e-01j,
        -2.48573217e-02+4.53278785e-02j,  1.46272805e-01+3.64184279e-16j]]), array([[ 0.38124517-1.88917687e-17j, -0.36899852-7.58289919e-02j,
         0.01039899-5.86050808e-02j, -0.04613285-1.68207995e-01j],
       [-0.36899852+7.58289919e-02j,  0.43982952-6.50240048e-16j,
         0.02175176+8.50142634e-02j,  0.05633844+1.36944713e-01j],
       [ 0.01039899+5.86050808e-02j,  0.02175176-8.50142634e-02j,
         0.05067174+1.94957048e-17j,  0.00132943-6.31411297e-03j],
       [-0.04613285+1.68207995e-01j,  0.05633844-1.36944713e-01j,
         0.00132943+6.31411297e-03j,  0.12825357+2.77894695e-16j]]), array([[ 0.24154817-2.80309984e-16j, -0.16091075-1.69600472e-02j,
         0.09635689+9.41223685e-02j,  0.24384388-9.74154185e-02j],
       [-0.16091075+1.69600472e-02j,  0.24188236-3.95839738e-16j,
        -0.01284014-1.30344866e-01j, -0.18984284+1.32269244e-02j],
       [ 0.09635689-9.41223685e-02j, -0.01284014+1.30344866e-01j,
         0.15995136+4.59864896e-16j,  0.08936485-1.92837750e-01j],
       [ 0.24384388+9.74154185e-02j, -0.18984284-1.32269244e-02j,
         0.08936485+1.92837750e-01j,  0.35661811-1.88259663e-15j]]), array([[ 0.34580214-4.48217741e-15j, -0.19012164-6.53379853e-02j,
         0.08259007-9.23807285e-02j,  0.14518407-1.22434432e-01j],
       [-0.19012164+6.53379853e-02j,  0.24057252-4.60252554e-15j,
        -0.00141024+7.69035329e-03j, -0.18330163-1.14755192e-02j],
       [ 0.08259007+9.23807285e-02j, -0.00141024-7.69035329e-03j,
         0.08111356-8.83206979e-16j,  0.09197105-7.54071140e-02j],
       [ 0.14518407+1.22434432e-01j, -0.18330163+1.14755192e-02j,
         0.09197105+7.54071140e-02j,  0.33251178-3.23040357e-15j]]), array([[ 0.27782525-6.66399840e-16j, -0.24002712+1.06032536e-01j,
         0.0925004 +1.46924616e-01j,  0.10394063-1.53883575e-01j],
       [-0.24002712-1.06032536e-01j,  0.30333913+4.30015980e-16j,
         0.0043685 -1.40113892e-01j, -0.11612496+4.25790466e-02j],
       [ 0.0925004 -1.46924616e-01j,  0.0043685 +1.40113892e-01j,
         0.16437539-3.44897539e-16j, -0.06185423-1.78898730e-01j],
       [ 0.10394063+1.53883575e-01j, -0.11612496-4.25790466e-02j,
        -0.06185423+1.78898730e-01j,  0.25446023+6.48378672e-16j]]), array([[ 4.00280366e-01-1.51883494e-15j, -2.94640145e-01+8.21439744e-02j,
         5.16692913e-02-3.53787031e-02j,  5.44173999e-02-1.50599088e-01j],
       [-2.94640145e-01-8.21439744e-02j,  3.03902601e-01-5.81720285e-16j,
         2.54578116e-04+2.56516454e-02j, -1.35029107e-01+1.84023317e-02j],
       [ 5.16692913e-02+3.53787031e-02j,  2.54578116e-04-2.56516454e-02j,
         5.08595881e-02+3.65903812e-17j, -3.97405070e-02-6.57661156e-02j],
       [ 5.44173999e-02+1.50599088e-01j, -1.35029107e-01-1.84023317e-02j,
        -3.97405070e-02+6.57661156e-02j,  2.44957445e-01+3.13774183e-16j]]), array([[ 0.52417638-3.49937986e-15j,  0.03910504-2.03170892e-01j,
         0.10165306+2.34821961e-01j,  0.17067061-7.72459678e-02j],
       [ 0.03910504+2.03170892e-01j,  0.12952932+1.66597927e-15j,
        -0.0341922 +5.67731402e-02j,  0.10009447+7.63727078e-02j],
       [ 0.10165306-2.34821961e-01j, -0.0341922 -5.67731402e-02j,
         0.19046848-1.25136304e-16j,  0.06560053-7.32754580e-02j],
       [ 0.17067061+7.72459678e-02j,  0.10009447-7.63727078e-02j,
         0.06560053+7.32754580e-02j,  0.15582581-4.52284395e-16j]]), array([[ 0.62955478-1.17756230e-15j, -0.00652193-2.34985772e-01j,
         0.0667736 +6.43886709e-02j, -0.0310375 -1.36257342e-01j],
       [-0.00652193+2.34985772e-01j,  0.11091784+5.30101927e-16j,
         0.00556413+4.91922980e-02j,  0.06660719+3.55317398e-02j],
       [ 0.0667736 -6.43886709e-02j,  0.00556413-4.91922980e-02j,
         0.09968621+2.52789513e-16j,  0.06783441+4.28259561e-02j],
       [-0.0310375 +1.36257342e-01j,  0.06660719-3.55317398e-02j,
         0.06783441-4.28259561e-02j,  0.15984118-3.64417924e-16j]]), array([[ 0.4634026 +5.96097855e-16j, -0.09037436-1.60466449e-02j,
         0.02133763+3.07278073e-01j, -0.00501273-1.38650068e-01j],
       [-0.09037436+1.60466449e-02j,  0.1184535 +7.65556002e-16j,
         0.02899313-4.80391566e-02j,  0.11777316+6.68976682e-02j],
       [ 0.02133763-3.07278073e-01j,  0.02899313+4.80391566e-02j,
         0.22938182+3.27517156e-16j, -0.03788144+1.76620830e-03j],
       [-0.00501273+1.38650068e-01j,  0.11777316-6.68976682e-02j,
        -0.03788144-1.76620830e-03j,  0.18876209-5.49397455e-16j]]), array([[ 0.61384702-5.10601865e-16j, -0.16505697-3.22578143e-02j,
        -0.06167596+1.74920498e-01j, -0.18880183-2.29920394e-01j],
       [-0.16505697+3.22578143e-02j,  0.07840792-2.99098842e-17j,
         0.03085233-3.46137290e-02j,  0.06325493+7.15319906e-02j],
       [-0.06167596-1.74920498e-01j,  0.03085233+3.46137290e-02j,
         0.11803033+1.14072169e-16j, -0.03343371+1.07857970e-01j],
       [-0.18880183+2.29920394e-01j,  0.06325493-7.15319906e-02j,
        -0.03343371-1.07857970e-01j,  0.18971473-9.73596041e-16j]]), array([[ 0.5889991 -1.95688259e-16j,  0.00619675-4.22709763e-02j,
         0.08692369+1.62548333e-01j,  0.34491419+1.86918188e-02j],
       [ 0.00619675+4.22709763e-02j,  0.02505342-8.38445929e-19j,
        -0.00698798+5.04574565e-03j,  0.01273634+2.51623160e-02j],
       [ 0.08692369-1.62548333e-01j, -0.00698798-5.04574565e-03j,
         0.08494528-7.86541846e-18j,  0.06704594-1.03954157e-01j],
       [ 0.34491419-1.86918188e-02j,  0.01273634-2.51623160e-02j,
         0.06704594+1.03954157e-01j,  0.30100221+2.29185329e-16j]]), array([[ 7.12917795e-01+1.90193709e-15j, -3.17180099e-03-1.05264789e-01j,
         7.88020254e-02-1.75552347e-02j,  6.46463732e-02-5.83048933e-02j],
       [-3.17180099e-03+1.05264789e-01j,  2.42172351e-02-1.77981476e-17j,
         2.83728563e-04+8.61722838e-03j, -2.08008759e-02-7.96333798e-04j],
       [ 7.88020254e-02+1.75552347e-02j,  2.83728563e-04-8.61722838e-03j,
         1.72962328e-02+5.03006940e-17j,  3.15109210e-02-2.13210293e-02j],
       [ 6.46463732e-02+5.83048933e-02j, -2.08008759e-02+7.96333798e-04j,
         3.15109210e-02+2.13210293e-02j,  2.45568737e-01+2.76048027e-16j]]), array([[ 0.56040955+1.28630359e-15j, -0.07004748+9.79740883e-02j,
         0.05756322+2.55033099e-01j,  0.12365573-6.94060230e-02j],
       [-0.07004748-9.79740883e-02j,  0.0418792 +7.73031626e-17j,
         0.02089179-4.14010537e-02j,  0.01777212+7.35037731e-03j],
       [ 0.05756322-2.55033099e-01j,  0.02089179+4.14010537e-02j,
         0.15064717-1.00306026e-15j, -0.08157476-9.58469252e-02j],
       [ 0.12365573+6.94060230e-02j,  0.01777212-7.35037731e-03j,
        -0.08157476+9.58469252e-02j,  0.24706407-1.92420541e-16j]]), array([[ 0.71837377+2.56959510e-16j, -0.09388943+5.79915196e-02j,
         0.05480481+9.22615812e-02j, -0.06417222-1.38457643e-01j],
       [-0.09388943-5.79915196e-02j,  0.02839506+1.36179170e-17j,
         0.00886173-9.11091406e-03j, -0.01972793+3.40595621e-03j],
       [ 0.05480481-9.22615812e-02j,  0.00886173+9.11091406e-03j,
         0.0518357 -8.46007757e-17j, -0.08948497-1.18252402e-02j],
       [-0.06417222+1.38457643e-01j, -0.01972793-3.40595621e-03j,
        -0.08948497+1.18252402e-02j,  0.20139547-1.52624983e-16j]]), array([[ 0.38601967-5.28521260e-11j, -0.13721248-1.95783712e-01j,
         0.05100415+1.19606018e-01j,  0.1560804 -4.74740390e-02j],
       [-0.13721248+1.95783712e-01j,  0.24188144-1.96575261e-11j,
         0.04186307-1.01701016e-01j,  0.01896464+9.69165853e-02j],
       [ 0.05100415-1.19606018e-01j,  0.04186307+1.01701016e-01j,
         0.27610147+7.73251896e-12j,  0.06989517-7.83579975e-03j],
       [ 0.1560804 +4.74740390e-02j,  0.01896464-9.69165853e-02j,
         0.06989517+7.83579976e-03j,  0.09599742+2.17692668e-12j]]), array([[ 0.53385213+8.77723434e-16j, -0.16277278-2.85080554e-01j,
         0.08522235-7.42319028e-02j,  0.08876106-5.31601494e-02j],
       [-0.16277278+2.85080554e-01j,  0.22899311-1.08164214e-15j,
         0.05639159+7.27970175e-02j,  0.0090882 +8.03650233e-02j],
       [ 0.08522235+7.42319028e-02j,  0.05639159-7.27970175e-02j,
         0.17920699+1.42585002e-16j,  0.05469241+5.54028391e-02j],
       [ 0.08876106+5.31601494e-02j,  0.0090882 -8.03650233e-02j,
         0.05469241-5.54028391e-02j,  0.05794776+3.79454721e-17j]]), array([[ 0.38860989-7.18949341e-16j, -0.28043906-1.24483074e-02j,
        -0.01495522+2.50976152e-01j, -0.00494174-1.13042996e-01j],
       [-0.28043906+1.24483074e-02j,  0.26637074-7.94236440e-16j,
         0.07293763-1.94851521e-01j,  0.02468065+1.04292946e-01j],
       [-0.01495522-2.50976152e-01j,  0.07293763+1.94851521e-01j,
         0.28435364+4.66300072e-16j, -0.05528668+4.20544183e-02j],
       [-0.00494174+1.13042996e-01j,  0.02468065-1.04292946e-01j,
        -0.05528668-4.20544183e-02j,  0.06066573-6.15195674e-17j]]), array([[ 0.4756096 +9.70165615e-16j, -0.28527454-7.26065834e-02j,
        -0.01991722+3.48757714e-02j, -0.02816954-1.13548074e-01j],
       [-0.28527454+7.26065834e-02j,  0.22019505-4.20854254e-16j,
         0.08248067+2.21972829e-02j,  0.00285376+8.96177219e-02j],
       [-0.01991722-3.48757714e-02j,  0.08248067-2.21972829e-02j,
         0.22710827-5.06566093e-18j, -0.04107836+1.02419146e-01j],
       [-0.02816954+1.13548074e-01j,  0.00285376-8.96177219e-02j,
        -0.04107836-1.02419146e-01j,  0.07708708+2.05897628e-16j]]), array([[ 0.46708599-1.50685194e-15j, -0.1409024 -6.38043076e-02j,
         0.08305574+9.34840764e-02j,  0.2829318 +1.65510643e-02j],
       [-0.1409024 +6.38043076e-02j,  0.14389835-5.94300902e-17j,
         0.02309106-1.20913297e-01j, -0.10763795+2.73616344e-02j],
       [ 0.08305574-9.34840764e-02j,  0.02309106+1.20913297e-01j,
         0.20520021+1.36332024e-16j,  0.04839646-8.18599761e-02j],
       [ 0.2829318 -1.65510643e-02j, -0.10763795-2.73616344e-02j,
         0.04839646+8.18599761e-02j,  0.18381544-1.86066328e-16j]]), array([[ 0.65046798+4.60457415e-16j, -0.19301707-1.22311627e-01j,
         0.08033853-1.41660358e-01j,  0.24283402+1.02888125e-03j],
       [-0.19301707+1.22311627e-01j,  0.12071899+1.59029106e-16j,
         0.0163904 +3.73112073e-02j, -0.09534921+3.02625759e-02j],
       [ 0.08033853+1.41660358e-01j,  0.0163904 -3.73112073e-02j,
         0.08541434-9.39346145e-17j,  0.03373711+2.88697219e-02j],
       [ 0.24283402-1.02888125e-03j, -0.09534921-3.02625759e-02j,
         0.03373711-2.88697219e-02j,  0.14339869-8.03012544e-18j]]), array([[ 0.48898722-2.48558063e-16j, -0.23406173+9.93816441e-02j,
         0.06475276+2.23437148e-01j,  0.15025988-5.57090798e-02j],
       [-0.23406173-9.93816441e-02j,  0.16497276-2.90804434e-16j,
         0.04309097-1.57370578e-01j, -0.10224098+1.57185578e-02j],
       [ 0.06475276-2.23437148e-01j,  0.04309097+1.57370578e-01j,
         0.23733401+5.84998896e-16j, -0.07408278-8.25597410e-02j],
       [ 0.15025988+5.57090798e-02j, -0.10224098-1.57185578e-02j,
        -0.07408278+8.25597410e-02j,  0.10870601-1.70816255e-16j]]), array([[ 0.63820252-7.25177309e-17j, -0.29492828+5.92884035e-02j,
         0.02731565-2.44258829e-02j,  0.10024612-5.15816892e-02j],
       [-0.29492828-5.92884035e-02j,  0.16820431+2.17413815e-16j,
         0.02492593+1.17169983e-02j, -0.08388114+2.13187905e-02j],
       [ 0.02731565+2.44258829e-02j,  0.02492593-1.17169983e-02j,
         0.10200908+6.17133805e-17j, -0.06680317+2.31047617e-02j],
       [ 0.10024612+5.15816892e-02j, -0.08388114-2.13187905e-02j,
        -0.06680317-2.31047617e-02j,  0.09158409-6.65684123e-17j]]), array([[ 0.11178199+9.58013991e-15j,  0.13633264-1.48368166e-01j,
        -0.06241005+9.54914597e-02j,  0.01628864+7.88512348e-02j],
       [ 0.13633264+1.48368166e-01j,  0.40941495-2.87437430e-14j,
        -0.22441449+2.60421456e-02j,  0.0294362 +1.24168489e-01j],
       [-0.06241005-9.54914597e-02j, -0.22441449-2.60421456e-02j,
         0.12816383-2.35625822e-15j,  0.00383432-4.14132464e-02j],
       [ 0.01628864-7.88512348e-02j,  0.0294362 -1.24168489e-01j,
         0.00383432+4.14132464e-02j,  0.35063924+4.39468196e-15j]]), array([[ 0.11069007-1.29573060e-15j,  0.1196696 -1.23862312e-01j,
        -0.02654816+1.01570381e-01j, -0.15959299+3.05128060e-02j],
       [ 0.1196696 +1.23862312e-01j,  0.33669833+9.40456277e-17j,
        -0.15474808+9.21152148e-02j, -0.18839441-8.36168818e-02j],
       [-0.02654816-1.01570381e-01j, -0.15474808-9.21152148e-02j,
         0.11722374+9.98312006e-16j,  0.08048436+1.45272974e-01j],
       [-0.15959299-3.05128060e-02j, -0.18839441+8.36168818e-02j,
         0.08048436-1.45272974e-01j,  0.43538786-1.14445531e-15j]]), array([[ 0.03895687+7.75545424e-17j,  0.04145293-1.11728404e-02j,
        -0.01056255+3.82700676e-02j, -0.04138897+1.60628713e-02j],
       [ 0.04145293+1.11728404e-02j,  0.38230509-6.98808819e-16j,
        -0.22285916+1.71710237e-02j,  0.25087055+6.52988346e-02j],
       [-0.01056255-3.82700676e-02j, -0.22285916-1.71710237e-02j,
         0.18250412+2.32252671e-16j, -0.16629512+3.84849050e-02j],
       [-0.04138897-1.60628713e-02j,  0.25087055-6.52988346e-02j,
        -0.16629512-3.84849050e-02j,  0.39623392+3.76344565e-16j]]), array([[ 0.07752561-1.61593198e-16j,  0.03913582-6.50592594e-03j,
         0.00803415+6.72215663e-02j, -0.1683275 -1.73605039e-02j],
       [ 0.03913582+6.50592594e-03j,  0.31042035-7.03995997e-16j,
        -0.15276926+1.45901397e-01j,  0.00575718-6.67135419e-02j],
       [ 0.00803415-6.72215663e-02j, -0.15276926-1.45901397e-01j,
         0.18691093+2.29866763e-15j, -0.09970737+1.37318041e-01j],
       [-0.1683275 +1.73605039e-02j,  0.00575718+6.67135419e-02j,
        -0.09970737-1.37318041e-01j,  0.4251431 -2.56285129e-16j]]), array([[ 0.10816815-9.37949827e-17j,  0.1410871 -6.02320181e-02j,
        -0.10125126-6.64672354e-03j,  0.02349486+1.73809685e-01j],
       [ 0.1410871 +6.02320181e-02j,  0.26756558+1.60638150e-15j,
        -0.13607846-5.74638957e-02j, -0.06367576+1.46257085e-01j],
       [-0.10125126+6.64672354e-03j, -0.13607846+5.74638957e-02j,
         0.10224965+5.37371338e-16j, -0.05519111-1.54686022e-01j],
       [ 0.02349486-1.73809685e-01j, -0.06367576-1.46257085e-01j,
        -0.05519111+1.54686022e-01j,  0.52201663-3.25073203e-15j]]), array([[ 0.14994987+1.01240771e-15j,  0.14228889-6.58002637e-02j,
        -0.0445467 -1.37201974e-02j, -0.17622309+1.45456844e-01j],
       [ 0.14228889+6.58002637e-02j,  0.2314388 -2.99018153e-16j,
        -0.0627178 -8.83837526e-03j, -0.25661563-2.49932642e-02j],
       [-0.0445467 +1.37201974e-02j, -0.0627178 +8.83837526e-03j,
         0.05204876+1.27052076e-17j, -0.00461926-1.37596134e-02j],
       [-0.17622309-1.45456844e-01j, -0.25661563+2.49932642e-02j,
        -0.00461926+1.37596134e-02j,  0.56656258+2.00913948e-16j]]), array([[ 0.05541308-8.51283785e-17j,  0.05923526+6.73086288e-02j,
        -0.03531583-6.47884145e-02j, -0.00776289+1.20999983e-01j],
       [ 0.05923526-6.73086288e-02j,  0.22270342+3.79606127e-16j,
        -0.14447541-1.04531242e-02j,  0.15435053+9.83255752e-02j],
       [-0.03531583+6.47884145e-02j, -0.14447541+1.04531242e-02j,
         0.16032374+8.06170746e-16j, -0.24266263-1.05080371e-01j],
       [-0.00776289-1.20999983e-01j,  0.15435053-9.83255752e-02j,
        -0.24266263+1.05080371e-01j,  0.56155977+2.35548023e-16j]]), array([[ 0.10889217-7.08451635e-16j,  0.05007476+5.34601955e-02j,
         0.01278895-5.27416096e-02j, -0.16587819+8.53252931e-02j],
       [ 0.05007476-5.34601955e-02j,  0.18407847-8.90367158e-16j,
        -0.07764577+6.61725841e-02j, -0.05456441-5.03944737e-02j],
       [ 0.01278895+5.27416096e-02j, -0.07764577-6.61725841e-02j,
         0.13100066-1.79375411e-16j, -0.18770943+1.83069898e-02j],
       [-0.16587819-8.53252931e-02j, -0.05456441+5.03944737e-02j,
        -0.18770943-1.83069898e-02j,  0.57602871+7.36926421e-16j]]), array([[ 0.07525168-1.37040953e-16j,  0.02664175-1.86633781e-01j,
        -0.03485932+8.02008767e-02j,  0.03528905+5.35872339e-02j],
       [ 0.02664175+1.86633781e-01j,  0.59947898+4.27041698e-16j,
        -0.28858626-9.38561335e-02j, -0.10062091+1.25898374e-01j],
       [-0.03485932-8.02008767e-02j, -0.28858626+9.38561335e-02j,
         0.20031455-9.80228900e-16j, -0.0015214 -4.71779963e-02j],
       [ 0.03528905-5.35872339e-02j, -0.10062091-1.25898374e-01j,
        -0.0015214 +4.71779963e-02j,  0.12495479+3.66683092e-16j]]), array([[ 0.07716599-7.91969631e-18j,  0.00463561-1.74892980e-01j,
         0.04258462+5.25600821e-02j, -0.02305957+9.42451880e-02j],
       [ 0.00463561+1.74892980e-01j,  0.56071627+3.41896971e-16j,
        -0.1955958 +1.32257311e-01j, -0.27812723-7.06334016e-02j],
       [ 0.04258462-5.25600821e-02j, -0.1955958 -1.32257311e-01j,
         0.15855873+7.86685667e-17j,  0.06345545+1.15610186e-01j],
       [-0.02305957-9.42451880e-02j, -0.27812723+7.06334016e-02j,
         0.06345545-1.15610186e-01j,  0.20355901-1.87375630e-17j]]), array([[ 0.01930224+6.59135715e-17j, -0.06009635-4.10574289e-02j,
         0.03228587+2.74381383e-02j, -0.01309343-9.45857264e-03j],
       [-0.06009635+4.10574289e-02j,  0.53798491+7.43031101e-16j,
        -0.2803155 -6.49067406e-02j,  0.10573318+4.94642529e-02j],
       [ 0.03228587-2.74381383e-02j, -0.2803155 +6.49067406e-02j,
         0.2786376 -5.95513939e-17j, -0.17457998+2.84883273e-02j],
       [-0.01309343+9.45857264e-03j,  0.10573318-4.94642529e-02j,
        -0.17457998-2.84883273e-02j,  0.16407525-1.33608617e-16j]]), array([[ 0.03451044+6.96404206e-17j, -0.07163924-4.95462964e-02j,
         0.07926689-2.88949281e-03j, -0.03945306+3.61661443e-02j],
       [-0.07163924+4.95462964e-02j,  0.4785882 -1.27643844e-16j,
        -0.21494459+2.04671354e-01j, -0.06998274-1.37036236e-01j],
       [ 0.07926689+2.88949281e-03j, -0.21494459-2.04671354e-01j,
         0.27630866+7.05761455e-17j, -0.12522538+1.40396332e-01j],
       [-0.03945306-3.61661443e-02j, -0.06998274+1.37036236e-01j,
        -0.12522538-1.40396332e-01j,  0.2105927 -7.10661888e-16j]]), array([[ 0.05694883+1.15376404e-16j,  0.04666524-9.61689774e-02j,
        -0.07232969-1.79998405e-02j,  0.01261842+1.30854875e-01j],
       [ 0.04666524+9.61689774e-02j,  0.38878271+7.14244565e-16j,
        -0.16236185-1.89634344e-01j, -0.2164619 +1.45440522e-01j],
       [-0.07232969+1.79998405e-02j, -0.16236185+1.89634344e-01j,
         0.22227321+2.03049439e-15j, -0.07177929-1.78342470e-01j],
       [ 0.01261842-1.30854875e-01j, -0.2164619 -1.45440522e-01j,
        -0.07177929+1.78342470e-01j,  0.33199525+3.99708218e-16j]]), array([[ 0.09394554+6.11653403e-16j,  0.01462902-7.10465106e-02j,
         0.00913233-7.61710011e-02j, -0.03147415+1.46314324e-01j],
       [ 0.01462902+7.10465106e-02j,  0.37134809-2.92193409e-15j,
        -0.1033063 -2.40791071e-02j, -0.31418709-4.41062666e-02j],
       [ 0.00913233+7.61710011e-02j, -0.1033063 +2.40791071e-02j,
         0.15632794-1.81351706e-16j, -0.02031202-7.30018433e-04j],
       [-0.03147415-1.46314324e-01j, -0.31418709+4.41062666e-02j,
        -0.02031202+7.30018433e-04j,  0.37837843-3.77844769e-16j]]), array([[ 0.0219555 +2.94649836e-15j, -0.02790904+3.22466288e-02j,
         0.00920844-5.99898910e-02j, -0.00915124+6.38591632e-02j],
       [-0.02790904-3.22466288e-02j,  0.34455504+1.19609934e-13j,
        -0.16578611-1.07773579e-01j, -0.03010406+7.44105121e-02j],
       [ 0.00920844+5.99898909e-02j, -0.16578611+1.07773579e-01j,
         0.29589318-1.19028206e-13j, -0.23721553-1.22510953e-01j],
       [-0.00915124-6.38591632e-02j, -0.03010406-7.44105121e-02j,
        -0.23721553+1.22510953e-01j,  0.33759628-1.18603965e-13j]]), array([[ 0.07577307+1.18968294e-15j, -0.06266843+5.30849436e-02j,
         0.05792501-1.13524290e-01j, -0.03699611+9.20529266e-02j],
       [-0.06266843-5.30849436e-02j,  0.34047258-5.32456294e-15j,
        -0.11586464+6.84814570e-02j, -0.14401078-7.35102956e-02j],
       [ 0.05792501+1.13524290e-01j, -0.11586464-6.84814570e-02j,
         0.21894739+2.79546847e-15j, -0.18171718+2.80514591e-02j],
       [-0.03699611-9.20529266e-02j, -0.14401078+7.35102956e-02j,
        -0.18171718-2.80514591e-02j,  0.36480695-2.79424028e-15j]]), array([[ 0.26690754-2.17152994e-14j,  0.16269992-1.59241092e-01j,
        -0.08675343+1.52013610e-01j,  0.04078639+1.36261050e-01j],
       [ 0.16269992+1.59241092e-01j,  0.23236309+5.85640649e-15j,
        -0.1840116 -1.70210271e-02j,  0.02386309+1.08910506e-01j],
       [-0.08675343-1.52013610e-01j, -0.1840116 +1.70210271e-02j,
         0.24974927+3.85195414e-15j, -0.02444914+5.67213509e-02j],
       [ 0.04078639-1.36261050e-01j,  0.02386309-1.08910506e-01j,
        -0.02444914-5.67213509e-02j,  0.25098009-1.19255941e-15j]]), array([[ 0.31796329+9.19954780e-16j,  0.16930917-1.74053055e-01j,
        -0.03912936+1.47891018e-01j, -0.12751354+1.17965035e-01j],
       [ 0.16930917+1.74053055e-01j,  0.20160753-4.23765136e-16j,
        -0.12476317+6.98543403e-02j, -0.13822299-3.19740732e-02j],
       [-0.03912936-1.47891018e-01j, -0.12476317-6.98543403e-02j,
         0.21710878+7.70716951e-17j,  0.01740332+1.80616182e-01j],
       [-0.12751354-1.17965035e-01j, -0.13822299+3.19740732e-02j,
         0.01740332-1.80616182e-01j,  0.26332039-5.95603499e-16j]]), array([[ 0.15551562+3.26458867e-16j,  0.06238486-5.89937057e-03j,
        -0.04848487+1.27336909e-01j, -0.03485844+4.62787886e-02j],
       [ 0.06238486+5.89937057e-03j,  0.15269744+5.85698192e-16j,
        -0.15756865-4.67330438e-02j,  0.17977406+2.15486766e-02j],
       [-0.04848487-1.27336909e-01j, -0.15756865+4.67330438e-02j,
         0.34938228+7.28570748e-16j, -0.16611049+1.67206995e-01j],
       [-0.03485844-4.62787886e-02j,  0.17977406-2.15486766e-02j,
        -0.16611049-1.67206995e-01j,  0.34240466+1.18923452e-15j]]), array([[ 0.17615497-3.05298509e-16j,  0.06232795-3.84905567e-02j,
        -0.01133857+1.79310843e-01j, -0.18035013-1.62638381e-02j],
       [ 0.06232795+3.84905567e-02j,  0.08801431+1.23103067e-17j,
        -0.12164376+9.14390365e-02j, -0.02211111-1.07967869e-01j],
       [-0.01133857-1.79310843e-01j, -0.12164376-9.14390365e-02j,
         0.37418744-4.74157185e-16j, -0.12788228+2.91179819e-01j],
       [-0.18035013+1.62638381e-02j, -0.02211111+1.07967869e-01j,
        -0.12788228-2.91179819e-01j,  0.36164329-6.94670667e-16j]]), array([[ 0.3308855 -1.80436539e-16j,  0.16540312-7.92704786e-02j,
        -0.12881975-3.74415223e-02j,  0.10198269+3.19035548e-01j],
       [ 0.16540312+7.92704786e-02j,  0.13342884-3.12071087e-16j,
        -0.09058536-6.28550726e-02j, -0.00305792+1.71074841e-01j],
       [-0.12881975+3.74415223e-02j, -0.09058536+6.28550726e-02j,
         0.12968182+7.49373151e-17j, -0.10974349-7.26642547e-02j],
       [ 0.10198269-3.19035548e-01j, -0.00305792-1.71074841e-01j,
        -0.10974349+7.26642547e-02j,  0.40600383-1.57540881e-16j]]), array([[ 0.39850352+2.51264392e-15j,  0.17198318-1.12412593e-01j,
        -0.05682256-4.51005816e-02j, -0.10833374+2.64802622e-01j],
       [ 0.17198318+1.12412593e-01j,  0.13281901-6.81976543e-16j,
        -0.03919547-2.75829681e-03j, -0.13989844+2.86487632e-02j],
       [-0.05682256+4.51005816e-02j, -0.03919547+2.75829681e-03j,
         0.10115112-3.32165516e-16j, -0.07797937+4.45779909e-02j],
       [-0.10833374-2.64802622e-01j, -0.13989844-2.86487632e-02j,
        -0.07797937-4.45779909e-02j,  0.36752635-2.20020905e-15j]]), array([[ 0.23081252-6.87549259e-16j,  0.06920273+7.95553599e-02j,
        -0.04643375-6.38495936e-02j,  0.07348532+2.20255488e-01j],
       [ 0.06920273-7.95553599e-02j,  0.08832478-1.57225139e-16j,
        -0.10158957-3.85954343e-02j,  0.17783129+4.53506372e-02j],
       [-0.04643375+6.38495936e-02j, -0.10158957+3.85954343e-02j,
         0.22215236+6.43283166e-16j, -0.25345878+6.16182117e-02j],
       [ 0.07348532-2.20255488e-01j,  0.17783129-4.53506372e-02j,
        -0.25345878-6.16182117e-02j,  0.45871034+7.01665396e-16j]]), array([[ 0.31218886+2.59926171e-15j,  0.06976175+4.73613110e-02j,
        -0.02268855-5.11907342e-02j, -0.10200452+1.67375571e-01j],
       [ 0.06976175-4.73613110e-02j,  0.05494972+4.27248246e-16j,
        -0.0526403 +5.76197096e-02j, -0.00800835-4.09906341e-02j],
       [-0.02268855+5.11907342e-02j, -0.0526403 -5.76197096e-02j,
         0.20800038+3.45573015e-16j, -0.21213471+1.18334907e-01j],
       [-0.10200452-1.67375571e-01j, -0.00800835+4.09906341e-02j,
        -0.21213471-1.18334907e-01j,  0.42486105-5.74738851e-15j]]), array([[ 0.14939186-1.24808709e-15j,  0.04086748-1.84277849e-01j,
        -0.04401477+5.78651209e-02j,  0.05526321+9.45922272e-02j],
       [ 0.04086748+1.84277849e-01j,  0.30224918+3.79610339e-15j,
        -0.18025471-1.49697988e-01j, -0.03948116+7.72357895e-02j],
       [-0.04401477-5.78651209e-02j, -0.18025471+1.49697988e-01j,
         0.39483159-3.24702434e-15j, -0.04754078+9.45520638e-02j],
       [ 0.05526321-9.45922272e-02j, -0.03948116-7.72357895e-02j,
        -0.04754078-9.45520638e-02j,  0.15352737+1.13715566e-15j]]), array([[ 0.18297148-2.49045400e-16j,  0.02749872-1.96344381e-01j,
         0.0085591 -8.13533523e-03j,  0.00576579+1.23197657e-01j],
       [ 0.02749872+1.96344381e-01j,  0.26329355+3.65296958e-15j,
        -0.10891208+4.67948502e-02j, -0.15082738-4.08251130e-02j],
       [ 0.0085591 +8.13533523e-03j, -0.10891208-4.67948502e-02j,
         0.36088644+1.98371861e-15j, -0.01479334+2.01178866e-01j],
       [ 0.00576579-1.23197657e-01j, -0.15082738+4.08251130e-02j,
        -0.01479334-2.01178866e-01j,  0.19284852-1.47854602e-15j]]), array([[ 0.0457775 +2.23002321e-17j, -0.03123732-4.47858662e-02j,
         0.00874808+7.51844996e-02j, -0.01679858-1.75277200e-02j],
       [-0.03123732+4.47858662e-02j,  0.18954728+1.89355840e-16j,
        -0.2129675 -1.47514402e-01j,  0.11475159+1.42181769e-02j],
       [ 0.00874808-7.51844996e-02j, -0.2129675 +1.47514402e-01j,
         0.58370092-3.74871168e-16j, -0.24328728+1.54321542e-01j],
       [-0.01679858+1.75277200e-02j,  0.11475159-1.42181769e-02j,
        -0.24328728-1.54321542e-01j,  0.1809743 -3.84684973e-17j]]), array([[ 0.06653216+5.05436171e-17j, -0.03441996-5.67610055e-02j,
         0.09095488+9.59781761e-03j, -0.03892113+5.29676304e-02j],
       [-0.03441996+5.67610055e-02j,  0.14911217-2.25982754e-17j,
        -0.12561427+1.60650260e-01j, -0.04752888-1.21104071e-01j],
       [ 0.09095488-9.59781761e-03j, -0.12561427-1.60650260e-01j,
         0.54845595+6.10928391e-16j, -0.19860921+2.64296153e-01j],
       [-0.03892113-5.29676304e-02j, -0.04752888+1.21104071e-01j,
        -0.19860921-2.64296153e-01j,  0.23589973-2.38247960e-16j]]), array([[ 0.20200766+8.59910906e-15j,  0.05809231-1.21457046e-01j,
        -0.06465157-7.18190316e-02j,  0.07855319+2.15644898e-01j],
       [ 0.05809231+1.21457046e-01j,  0.20186076+8.81058675e-15j,
        -0.10273384-1.84017069e-01j, -0.09973304+1.24756539e-01j],
       [-0.06465157+7.18190316e-02j, -0.10273384+1.84017069e-01j,
         0.33151092-8.05987447e-15j, -0.12785125-5.00778493e-02j],
       [ 0.07855319-2.15644898e-01j, -0.09973304-1.24756539e-01j,
        -0.12785125+5.00778493e-02j,  0.26462066-7.43670498e-15j]]), array([[ 0.26040699-2.44403987e-15j,  0.04445334-1.40260012e-01j,
         0.00301977-1.64144061e-01j,  0.00707775+2.49126316e-01j],
       [ 0.04445334+1.40260012e-01j,  0.18546588-1.12895692e-16j,
        -0.03550136-2.25841410e-02j, -0.1781551 -2.91357137e-03j],
       [ 0.00301977+1.64144061e-01j, -0.03550136+2.25841410e-02j,
         0.26618279+1.63462888e-15j, -0.10527238+7.23024984e-02j],
       [ 0.00707775-2.49126316e-01j, -0.1781551 +2.91357137e-03j,
        -0.10527238-7.23024984e-02j,  0.28794434+2.30516616e-15j]]), array([[ 0.08852661-2.05415250e-17j,  0.00961351+7.15339692e-03j,
        -0.01629555-1.04998975e-01j,  0.02894532+1.20328491e-01j],
       [ 0.00961351-7.15339692e-03j,  0.09846243-1.19972137e-16j,
        -0.10618007-1.42373595e-01j,  0.04962108+8.99672380e-02j],
       [-0.01629555+1.04998975e-01j, -0.10618007+1.42373595e-01j,
         0.49795897+3.19169758e-16j, -0.35125815-1.73436045e-02j],
       [ 0.02894532-1.20328491e-01j,  0.04962108-8.99672380e-02j,
        -0.35125815+1.73436045e-02j,  0.315052  +2.37172149e-16j]]), array([[ 0.17262431-3.28870473e-16j, -0.04993723-2.27535471e-03j,
         0.06987166-2.09234916e-01j,  0.01395399+2.03378204e-01j],
       [-0.04993723+2.27535471e-03j,  0.07242872-4.26827502e-17j,
        -0.03411279+8.43208040e-02j, -0.03091386-7.93197430e-02j],
       [ 0.06987166+2.09234916e-01j, -0.03411279-8.43208040e-02j,
         0.41004137+2.00604666e-17j, -0.30727099+1.43433732e-01j],
       [ 0.01395399-2.03378204e-01j, -0.03091386+7.93197430e-02j,
        -0.30727099-1.43433732e-01j,  0.3449056 +8.31753859e-16j]]), array([[ 0.07332161-8.84190337e-17j,  0.09798478-1.10450966e-01j,
         0.00507442+2.39526890e-02j,  0.1016038 +6.01131384e-02j],
       [ 0.09798478+1.10450966e-01j,  0.41388817-4.11028434e-16j,
        -0.02001513+3.83330495e-02j,  0.07913608+3.68831569e-01j],
       [ 0.00507442-2.39526890e-02j, -0.02001513-3.83330495e-02j,
         0.03563838+6.97562972e-18j,  0.03098039+1.43560331e-02j],
       [ 0.1016038 -6.01131384e-02j,  0.07913608-3.68831569e-01j,
         0.03098039-1.43560331e-02j,  0.47715184-7.34548082e-17j]]), array([[ 0.07663335+1.23048699e-16j,  0.06996858-6.95400679e-02j,
        -0.0012552 +3.86068565e-02j, -0.04806341-1.33499217e-02j],
       [ 0.06996858+6.95400679e-02j,  0.29888868-2.26109408e-16j,
         0.00095137+1.20616365e-01j, -0.1548731 +1.90565876e-01j],
       [-0.0012552 -3.86068565e-02j,  0.00095137-1.20616365e-01j,
         0.08314286-2.00304462e-16j,  0.0977952 +1.57530070e-01j],
       [-0.04806341+1.33499217e-02j, -0.1548731 -1.90565876e-01j,
         0.0977952 -1.57530070e-01j,  0.54133512+5.81155720e-16j]]), array([[ 0.03846173-4.32858115e-17j, -0.00857003+4.12921441e-02j,
         0.00595672+3.89470631e-02j, -0.07499854-2.75447319e-02j],
       [-0.00857003-4.12921441e-02j,  0.38851837-6.80044000e-16j,
        -0.00945207-6.50502862e-02j,  0.1937079 +2.98344527e-01j],
       [ 0.00595672-3.89470631e-02j, -0.00945207+6.50502862e-02j,
         0.0850224 +9.77468893e-17j, -0.12159123+9.34913040e-02j],
       [-0.07499854+2.75447319e-02j,  0.1937079 -2.98344527e-01j,
        -0.12159123-9.34913040e-02j,  0.4879975 -1.95696050e-15j]]), array([[ 0.08621605+1.86194914e-18j, -0.01001184+5.63721840e-02j,
        -0.00482697+7.57649541e-02j, -0.17225329-9.85522151e-02j],
       [-0.01001184-5.63721840e-02j,  0.29330378+4.69131589e-16j,
         0.01618171+9.50004019e-02j, -0.06644568+1.78758429e-01j],
       [-0.00482697-7.57649541e-02j,  0.01618171-9.50004019e-02j,
         0.12189389-6.23011312e-17j, -0.05905373+1.67148062e-01j],
       [-0.17225329+9.85522151e-02j, -0.06644568-1.78758429e-01j,
        -0.05905373-1.67148062e-01j,  0.49858628-4.74204412e-15j]]), array([[ 0.10798677+1.10558828e-16j,  0.10894481-1.51744576e-02j,
         0.00856928-1.58443243e-02j,  0.09233187+9.45953751e-02j],
       [ 0.10894481+1.51744576e-02j,  0.24605731-4.46949005e-16j,
        -0.01756547-6.21877826e-02j, -0.06999127+2.84873808e-01j],
       [ 0.00856928+1.58443243e-02j, -0.01756547+6.21877826e-02j,
         0.03346612+8.85424708e-17j, -0.03585929-7.65326074e-02j],
       [ 0.09233187-9.45953751e-02j, -0.06999127-2.84873808e-01j,
        -0.03585929+7.65326074e-02j,  0.6124898 +1.52115807e-15j]]), array([[ 0.1432834 -5.95822389e-17j,  0.10878695+9.47511613e-03j,
         0.02424253-2.39186446e-02j, -0.07198527+1.57521047e-02j],
       [ 0.10878695-9.47511613e-03j,  0.20429507-4.95518283e-16j,
         0.01338005+1.55406262e-03j, -0.26299646+1.55360673e-01j],
       [ 0.02424253+2.39186446e-02j,  0.01338005-1.55406262e-03j,
         0.02264008-1.35359454e-18j,  0.02099032+2.90201377e-02j],
       [-0.07198527-1.57521047e-02j, -0.26299646-1.55360673e-01j,
         0.02099032-2.90201377e-02j,  0.62978144-4.59352072e-16j]]), array([[ 0.1014417 -1.44087975e-16j,  0.04890219+1.13793309e-01j,
         0.04185317+1.79201902e-03j, -0.06341115+1.03797421e-02j],
       [ 0.04890219-1.13793309e-01j,  0.23956977+9.35468898e-16j,
        -0.01800493-1.02394091e-01j,  0.03580781+2.63495259e-01j],
       [ 0.04185317-1.79201902e-03j, -0.01800493+1.02394091e-01j,
         0.09031335+6.65831760e-16j, -0.19936531-5.84733396e-02j],
       [-0.06341115-1.03797421e-02j,  0.03580781-2.63495259e-01j,
        -0.19936531+5.84733396e-02j,  0.56867518-1.48480376e-16j]]), array([[ 0.15960036-7.43269456e-17j,  0.06509741+1.20497167e-01j,
         0.06733951+2.31490572e-02j, -0.24928738-7.30304073e-02j],
       [ 0.06509741-1.20497167e-01j,  0.16966938-1.26040658e-16j,
         0.04810474-3.01841653e-02j, -0.18852714+1.64028691e-01j],
       [ 0.06733951-2.31490572e-02j,  0.04810474+3.01841653e-02j,
         0.07632219-2.81771749e-17j, -0.16912111+2.17540045e-02j],
       [-0.24928738+7.30304073e-02j, -0.18852714-1.64028691e-01j,
        -0.16912111-2.17540045e-02j,  0.59440806-3.50304557e-16j]]), array([[ 0.05907939-2.17779543e-17j, -0.01061026-1.41757627e-01j,
         0.02959442+2.09395011e-02j,  0.09157566+3.28961018e-02j],
       [-0.01061026+1.41757627e-01j,  0.59298942+9.53811734e-16j,
        -0.08175111-4.43038824e-02j, -0.09694471+3.32154959e-01j],
       [ 0.02959442-2.09395011e-02j, -0.08175111+4.43038824e-02j,
         0.11263025-3.41195237e-18j,  0.01018824-1.67448416e-02j],
       [ 0.09157566-3.28961018e-02j, -0.09694471-3.32154959e-01j,
         0.01018824+1.67448416e-02j,  0.23530095+1.07840174e-15j]]), array([[ 6.81812548e-02-8.24847317e-17j, -3.81964719e-02-1.41839756e-01j,
         6.00066769e-02-1.67547427e-02j,  7.76202470e-02+5.86400955e-02j],
       [-3.81964719e-02+1.41839756e-01j,  5.20213119e-01-1.11418496e-16j,
        -2.34212120e-04+1.85988717e-01j, -2.79739209e-01+2.17765884e-01j],
       [ 6.00066769e-02+1.67547427e-02j, -2.34212120e-04-1.85988717e-01j,
         1.12792662e-01+2.95264344e-17j,  7.61369576e-02+1.21776201e-01j],
       [ 7.76202470e-02-5.86400955e-02j, -2.79739209e-01-2.17765884e-01j,
         7.61369576e-02-1.21776201e-01j,  2.98812964e-01-5.84940225e-17j]]), array([[ 0.03345899+1.51126148e-16j, -0.10081639+1.44647755e-02j,
         0.0435122 +4.13907059e-02j, -0.03786599-4.47403254e-02j],
       [-0.10081639-1.44647755e-02j,  0.55583946+2.08545507e-15j,
        -0.05994791-1.39436267e-01j,  0.04124594+2.90166431e-01j],
       [ 0.0435122 -4.13907059e-02j, -0.05994791+1.39436267e-01j,
         0.1798962 +1.84978076e-16j, -0.13960879+5.06700513e-02j],
       [-0.03786599+4.47403254e-02j,  0.04124594-2.90166431e-01j,
        -0.13960879-5.06700513e-02j,  0.23080535+7.87142224e-16j]]), array([[ 0.06334806+5.43217821e-14j, -0.11349979+1.21211833e-02j,
         0.06045818+9.03076746e-03j, -0.04657612-4.26704276e-02j],
       [-0.11349979-1.21211833e-02j,  0.45704129+1.24360410e-12j,
        -0.006503  +1.29565241e-01j, -0.14414322+1.68703466e-01j],
       [ 0.06045818-9.03076746e-03j, -0.006503  -1.29565241e-01j,
         0.19736627-9.50743658e-14j, -0.08579684+1.36467658e-01j],
       [-0.04657612+4.26704276e-02j, -0.14414322-1.68703466e-01j,
        -0.08579684-1.36467658e-01j,  0.28224438+1.04007291e-12j]]), array([[ 0.07843676-1.69450578e-16j,  0.02679696-3.36961836e-02j,
         0.04107508-2.17493908e-02j,  0.0680182 +4.69353226e-02j],
       [ 0.02679696+3.36961836e-02j,  0.40618346+5.23227337e-16j,
        -0.04335865-1.82970601e-01j, -0.22568337+2.72386491e-01j],
       [ 0.04107508+2.17493908e-02j, -0.04335865+1.82970601e-01j,
         0.14527944+4.19193107e-17j, -0.05057923-1.12299203e-01j],
       [ 0.0680182 -4.69353226e-02j, -0.22568337-2.72386491e-01j,
        -0.05057923+1.12299203e-01j,  0.37010034-2.70029630e-15j]]), array([[ 0.11773638+2.63651392e-17j, -0.00985412-1.73731755e-02j,
         0.07144288-8.12298854e-02j,  0.04493048+3.88815075e-02j],
       [-0.00985412+1.73731755e-02j,  0.35304026+7.92603923e-16j,
        -0.00630603-5.50542463e-03j, -0.3472675 +1.39913957e-01j],
       [ 0.07144288+8.12298854e-02j, -0.00630603+5.50542463e-03j,
         0.10942056-2.14875738e-16j,  0.00326096+2.90387574e-02j],
       [ 0.04493048-3.88815075e-02j, -0.3472675 -1.39913957e-01j,
         0.00326096-2.90387574e-02j,  0.4198028 +3.63828429e-15j]]), array([[ 0.05382747+6.07958990e-17j, -0.03706903+1.00749482e-01j,
         0.08018459+7.80497854e-03j, -0.07007384-5.36963953e-02j],
       [-0.03706903-1.00749482e-01j,  0.37271479-5.50541031e-16j,
        -0.03099372-2.40515450e-01j, -0.12887875+2.84217710e-01j],
       [ 0.08018459-7.80497854e-03j, -0.03099372+2.40515450e-01j,
         0.22326866+6.43194935e-17j, -0.2286285 -1.06908157e-01j],
       [-0.07007384+5.36963953e-02j, -0.12887875-2.84217710e-01j,
        -0.2286285 +1.06908157e-01j,  0.35018909+2.52992961e-16j]]), array([[ 0.12098643-1.10609057e-15j, -0.06491307+9.58060809e-02j,
         0.10126636-5.78986866e-02j, -0.07480823-2.63254957e-02j],
       [-0.06491307-9.58060809e-02j,  0.33462533+8.13244242e-15j,
         0.00363564+1.23932204e-03j, -0.23919927+1.25341919e-01j],
       [ 0.10126636+5.78986866e-02j,  0.00363564-1.23932204e-03j,
         0.17637819+5.97503137e-16j, -0.16140509+2.53109024e-02j],
       [-0.07480823+2.63254957e-02j, -0.23919927-1.25341919e-01j,
        -0.16140509-2.53109024e-02j,  0.36801004-8.21560825e-17j]]), array([[0.19538062+1.90405295e-16j, 0.12192688-1.04223892e-01j,
        0.03846036+5.73971659e-02j, 0.10439928+1.17809950e-01j],
       [0.12192688+1.04223892e-01j, 0.20442644+2.00518100e-15j,
        0.03808808-3.09573680e-02j, 0.10341786+2.19460452e-01j],
       [0.03846036-5.73971659e-02j, 0.03808808+3.09573680e-02j,
        0.18551974-2.10618360e-16j, 0.007662  +1.94505601e-01j],
       [0.10439928-1.17809950e-01j, 0.10341786-2.19460452e-01j,
        0.007662  -1.94505601e-01j, 0.4146732 +8.81830125e-16j]]), array([[ 0.25543433-2.11822225e-17j,  0.16363931-1.07795942e-01j,
         0.09632875+1.04310770e-01j, -0.07158378+1.56451625e-01j],
       [ 0.16363931+1.07795942e-01j,  0.18610859+9.74917922e-16j,
         0.06324975+1.26493258e-01j, -0.13845455+1.48779917e-01j],
       [ 0.09632875-1.04310770e-01j,  0.06324975-1.26493258e-01j,
         0.17910959-4.66517151e-16j,  0.04466827+2.42765919e-01j],
       [-0.07158378-1.56451625e-01j, -0.13845455-1.48779917e-01j,
         0.04466827-2.42765919e-01j,  0.37934749-6.99099993e-16j]]), array([[ 0.13384651-3.31764329e-17j,  0.02633778+5.26057828e-02j,
         0.02863536+1.17007163e-01j, -0.07215134+2.62059840e-02j],
       [ 0.02633778-5.26057828e-02j,  0.16685522-2.27587169e-16j,
         0.06462386-1.21467413e-01j,  0.1638702 +1.84019386e-01j],
       [ 0.02863536-1.17007163e-01j,  0.06462386+1.21467413e-01j,
         0.26113051-2.04740945e-15j, -0.13064819+2.56921433e-01j],
       [-0.07215134-2.62059840e-02j,  0.1638702 -1.84019386e-01j,
        -0.13064819-2.56921433e-01j,  0.43816776+2.60629000e-15j]]), array([[ 0.1881438 -1.26379224e-16j,  0.05274737+5.05965895e-02j,
         0.0448752 +1.85317832e-01j, -0.21767375-3.02397121e-02j],
       [ 0.05274737-5.05965895e-02j,  0.08133953-9.90800500e-17j,
         0.09818508+5.04452701e-02j, -0.08832878+1.03557824e-01j],
       [ 0.0448752 -1.85317832e-01j,  0.09818508-5.04452701e-02j,
         0.29981475+1.37563849e-16j, -0.11438229+3.12330348e-01j],
       [-0.21767375+3.02397121e-02j, -0.08832878-1.03557824e-01j,
        -0.11438229-3.12330348e-01j,  0.43070193-2.53231926e-16j]]), array([[ 0.30752528+3.28016820e-16j,  0.16262842-2.95968381e-02j,
         0.06521886-7.02298023e-02j,  0.19849108+2.58242016e-01j],
       [ 0.16262842+2.95968381e-02j,  0.13775146+4.86633548e-17j,
         0.04743865-5.50257881e-02j,  0.063578  +2.13958441e-01j],
       [ 0.06521886+7.02298023e-02j,  0.04743865+5.50257881e-02j,
         0.06615614+8.19631085e-17j, -0.05885596+1.03914240e-01j],
       [ 0.19849108-2.58242016e-01j,  0.063578  -2.13958441e-01j,
        -0.05885596-1.03914240e-01j,  0.48856713-1.44653310e-15j]]), array([[ 0.41869683+3.54379000e-16j,  0.19263132-6.51733217e-02j,
         0.11313299-4.22623266e-02j, -0.06776371+1.96762499e-01j],
       [ 0.19263132+6.51733217e-02j,  0.13686596-2.13326476e-16j,
         0.07730429+1.02865044e-02j, -0.14159259+1.33241198e-01j],
       [ 0.11313299+4.22623266e-02j,  0.07730429-1.02865044e-02j,
         0.05531026+3.77920857e-16j, -0.06343259+1.06468109e-01j],
       [-0.06776371-1.96762499e-01j, -0.14159259-1.33241198e-01j,
        -0.06343259-1.06468109e-01j,  0.38912695+9.70350096e-16j]]), array([[ 0.28644613-6.74995984e-16j,  0.08209786+1.19646385e-01j,
         0.07752028+3.50336766e-02j,  0.00827144+1.13873533e-01j],
       [ 0.08209786-1.19646385e-01j,  0.12437724+3.65279436e-15j,
         0.0393599 -1.05868800e-01j,  0.08244192+1.62513374e-01j],
       [ 0.07752028-3.50336766e-02j,  0.0393599 +1.05868800e-01j,
         0.1658972 -5.14682602e-15j, -0.20514186+9.05668334e-02j],
       [ 0.00827144-1.13873533e-01j,  0.08244192-1.62513374e-01j,
        -0.20514186-9.05668334e-02j,  0.42327943+1.89432198e-15j]]), array([[ 0.36509699-1.16369909e-15j,  0.12586034+7.90635995e-02j,
         0.13461515+3.06886067e-02j, -0.20460131+8.43710792e-02j],
       [ 0.12586034-7.90635995e-02j,  0.07748596-4.24210340e-16j,
         0.08430506-1.66197356e-02j, -0.0968318 +9.49466218e-02j],
       [ 0.13461515-3.06886067e-02j,  0.08430506+1.66197356e-02j,
         0.1626073 -4.89865010e-16j, -0.21062123+1.25809675e-01j],
       [-0.20460131-8.43710792e-02j, -0.0968318 -9.49466218e-02j,
        -0.21062123-1.25809675e-01j,  0.39480976+8.47452039e-16j]]), array([[ 0.1340311 +3.34135311e-15j,  0.02110362-1.48214037e-01j,
         0.07324239+6.50743401e-03j,  0.11357697+8.93954704e-02j],
       [ 0.02110362+1.48214037e-01j,  0.30707039+4.14240489e-15j,
         0.021265  -1.13603866e-01j, -0.00661888+2.15045262e-01j],
       [ 0.07324239-6.50743401e-03j,  0.021265  +1.13603866e-01j,
         0.32088361-8.76365601e-18j, -0.0299364 +1.58618536e-01j],
       [ 0.11357697-8.93954704e-02j, -0.00661888-2.15045262e-01j,
        -0.0299364 -1.58618536e-01j,  0.2380149 -8.16794445e-15j]]), array([[ 0.16311903-1.58139723e-16j,  0.01843595-1.80358079e-01j,
         0.14357346-6.59412851e-02j,  0.08984595+1.41692457e-01j],
       [ 0.01843595+1.80358079e-01j,  0.25113392-1.23191092e-17j,
         0.11407994+1.62001332e-01j, -0.16676011+1.45268183e-01j],
       [ 0.14357346+6.59412851e-02j,  0.11407994-1.62001332e-01j,
         0.30653118+1.78236358e-16j,  0.00484067+2.65283517e-01j],
       [ 0.08984595-1.41692457e-01j, -0.16676011-1.45268183e-01j,
         0.00484067-2.65283517e-01j,  0.27921587-3.39193254e-16j]]), array([[ 0.06463142-1.66147073e-17j, -0.05905677+1.21484510e-02j,
         0.07693722+9.02259321e-02j, -0.05363241-1.27167734e-02j],
       [-0.05905677-1.21484510e-02j,  0.23334361-3.64265429e-16j,
         0.06090014-2.05237899e-01j,  0.05639152+1.87662537e-01j],
       [ 0.07693722-9.02259321e-02j,  0.06090014+2.05237899e-01j,
         0.45281267+7.67722897e-16j, -0.19956001+2.16982058e-01j],
       [-0.05363241+1.27167734e-02j,  0.05639152-1.87662537e-01j,
        -0.19956001-2.16982058e-01j,  0.2492123 +4.52542149e-16j]]), array([[ 0.10288237-7.79403486e-17j, -0.03643926-3.22306605e-02j,
         0.12139618+3.38885850e-02j, -0.05200784+2.42296279e-02j],
       [-0.03643926+3.22306605e-02j,  0.17471266-4.38403721e-16j,
         0.11638234+9.42134104e-02j, -0.11292637+9.66066909e-02j],
       [ 0.12139618-3.38885850e-02j,  0.11638234-9.42134104e-02j,
         0.44778525-9.00192690e-16j, -0.16361886+2.73220968e-01j],
       [-0.05200784-2.42296279e-02j, -0.11292637-9.66066909e-02j,
        -0.16361886-2.73220968e-01j,  0.27461973-1.44257480e-16j]]), array([[ 0.22125224-3.64128334e-14j,  0.05330485-6.39300048e-02j,
         0.09844593-8.17526465e-02j,  0.14485001+1.55723495e-01j],
       [ 0.05330485+6.39300048e-02j,  0.22134124-1.36403160e-14j,
         0.03008293-1.75152330e-01j, -0.08159623+1.95903608e-01j],
       [ 0.09844593+8.17526465e-02j,  0.03008293+1.75152330e-01j,
         0.25413385-1.16019320e-15j, -0.09942781+4.30599997e-02j],
       [ 0.14485001-1.55723495e-01j, -0.08159623-1.95903608e-01j,
        -0.09942781-4.30599997e-02j,  0.30327268-9.94326301e-15j]]), array([[ 0.3295209 +7.03098767e-16j,  0.06145458-1.24714352e-01j,
         0.16045012-2.07314868e-01j,  0.09468886+2.27896202e-01j],
       [ 0.06145458+1.24714352e-01j,  0.13914963+1.53511024e-16j,
         0.11967781+1.06697519e-02j, -0.14233865+1.14776796e-01j],
       [ 0.16045012+2.07314868e-01j,  0.11967781-1.06697519e-02j,
         0.23389438+1.70394154e-16j, -0.11597165+1.69938233e-01j],
       [ 0.09468886-2.27896202e-01j, -0.14233865-1.14776796e-01j,
        -0.11597165-1.69938233e-01j,  0.2974351 +1.25989475e-16j]]), array([[ 0.14286334+3.09337455e-17j,  0.01558909+6.55609454e-02j,
         0.13378983-1.96342469e-02j, -0.03518157+5.73843744e-02j],
       [ 0.01558909-6.55609454e-02j,  0.1620013 -4.81063995e-16j,
         0.05619049-2.28786625e-01j, -0.03250854+1.87190376e-01j],
       [ 0.13378983+1.96342469e-02j,  0.05619049+2.28786625e-01j,
         0.39387622+2.70401065e-16j, -0.29476924+4.58040322e-02j],
       [-0.03518157-5.73843744e-02j, -0.03250854-1.87190376e-01j,
        -0.29476924-4.58040322e-02j,  0.30125914+1.38648532e-16j]]), array([[ 0.21750926-1.11521449e-16j,  0.03451853+8.93263600e-03j,
         0.20425613-9.18988397e-02j, -0.10810397+9.35551436e-02j],
       [ 0.03451853-8.93263600e-03j,  0.1151386 -6.37902050e-17j,
         0.13225701-1.97115187e-02j, -0.13971955+7.89032679e-02j],
       [ 0.20425613+9.18988397e-02j,  0.13225701+1.97115187e-02j,
         0.36204439+2.37339921e-16j, -0.27807382+1.11219229e-01j],
       [-0.10810397-9.35551436e-02j, -0.13971955-7.89032679e-02j,
        -0.27807382-1.11219229e-01j,  0.30530775-6.02665539e-17j]]), array([[ 0.17860644-8.86173869e-16j,  0.10336649-2.39386757e-01j,
        -0.06867006+7.21925914e-02j,  0.06120407-7.58618556e-02j],
       [ 0.10336649+2.39386757e-01j,  0.43669669-7.41218357e-18j,
        -0.13385923-5.80469982e-02j,  0.16073399-4.94208186e-02j],
       [-0.06867006-7.21925914e-02j, -0.13385923+5.80469982e-02j,
         0.06809672+8.01679110e-17j, -0.03625475-1.35467764e-02j],
       [ 0.06120407+7.58618556e-02j,  0.16073399+4.94208186e-02j,
        -0.03625475+1.35467764e-02j,  0.31660015+3.02295606e-16j]]), array([[ 0.24429729-1.06515037e-16j,  0.12327351-2.64629803e-01j,
        -0.0267127 +6.29960278e-02j, -0.14449985-9.63610146e-02j],
       [ 0.12327351+2.64629803e-01j,  0.39959234-4.42885529e-16j,
        -0.08685802+1.15938683e-02j, -0.01657973-2.26784110e-01j],
       [-0.0267127 -6.29960278e-02j, -0.08685802-1.15938683e-02j,
         0.03810293-4.20428684e-17j, -0.01187181+7.24300141e-02j],
       [-0.14449985+9.63610146e-02j, -0.01657973+2.26784110e-01j,
        -0.01187181-7.24300141e-02j,  0.31800743+1.13378588e-17j]]), array([[ 0.10303018+6.22412722e-17j,  0.06202685-1.11091543e-01j,
        -0.03002107+1.01705828e-01j,  0.04762077-1.48493185e-01j],
       [ 0.06202685+1.11091543e-01j,  0.34277399+3.72545268e-16j,
        -0.15536887+6.46671888e-02j,  0.29528688-1.00182080e-01j],
       [-0.03002107-1.01705828e-01j, -0.15536887-6.46671888e-02j,
         0.16406398-2.83517978e-17j, -0.21625217-2.14564331e-02j],
       [ 0.04762077+1.48493185e-01j,  0.29528688+1.00182080e-01j,
        -0.21625217+2.14564331e-02j,  0.39013184+1.48087163e-16j]]), array([[ 0.15191215+2.43174252e-16j,  0.0692265 -1.36571628e-01j,
         0.02969189+1.05725786e-01j, -0.12935322-1.57602161e-01j],
       [ 0.0692265 +1.36571628e-01j,  0.31351999-3.90536034e-16j,
        -0.08547381+1.56907993e-01j,  0.08303839-2.66787311e-01j],
       [ 0.02969189-1.05725786e-01j, -0.08547381-1.56907993e-01j,
         0.15771459-2.36781375e-16j, -0.19370784+7.00373047e-02j],
       [-0.12935322+1.57602161e-01j,  0.08303839+2.66787311e-01j,
        -0.19370784-7.00373047e-02j,  0.37685327+1.26683225e-16j]]), array([[ 0.14633124+2.03309055e-15j,  0.09410943-9.28833738e-02j,
        -0.08878206+2.36585183e-02j,  0.15371103+3.63486915e-02j],
       [ 0.09410943+9.28833738e-02j,  0.25900425+7.87022438e-16j,
        -0.04265107-7.30873509e-02j, -0.00518739-8.08944909e-02j],
       [-0.08878206-2.36585183e-02j, -0.04265107+7.30873509e-02j,
         0.07321247-3.77347120e-16j, -0.05935309-1.10509383e-01j],
       [ 0.15371103-3.63486915e-02j, -0.00518739+8.08944909e-02j,
        -0.05935309+1.10509383e-01j,  0.52145204+3.02131623e-15j]]), array([[ 0.17657777+3.35778103e-16j,  0.10033896-1.09267452e-01j,
        -0.04092443-1.43222936e-02j, -0.04977539-2.57923082e-02j],
       [ 0.10033896+1.09267452e-01j,  0.23972093-5.02142494e-16j,
         0.00434734-2.57365499e-02j, -0.16100703-2.23305413e-01j],
       [-0.04092443+1.43222936e-02j,  0.00434734+2.57365499e-02j,
         0.02483932-1.60342177e-17j, -0.03130877-1.92652981e-02j],
       [-0.04977539+2.57923082e-02j, -0.16100703+2.23305413e-01j,
        -0.03130877+1.92652981e-02j,  0.55886198+1.91804655e-15j]]), array([[ 0.07628968+2.59911332e-17j,  0.04668224+3.39690282e-02j,
        -0.06665866+4.96549848e-02j,  0.16356389-2.35802204e-02j],
       [ 0.04668224-3.39690282e-02j,  0.15022108-2.06663403e-16j,
        -0.03602153+7.23106834e-02j,  0.13809135-1.32334452e-01j],
       [-0.06665866-4.96549848e-02j, -0.03602153-7.23106834e-02j,
         0.16485269+3.55363024e-16j, -0.25274621-1.33315977e-01j],
       [ 0.16356389+2.35802204e-02j,  0.13809135+1.32334452e-01j,
        -0.25274621+1.33315977e-01j,  0.60863655+5.61391829e-16j]]), array([[ 0.08987435+1.50398634e-17j,  0.03736202+7.20832754e-03j,
        -0.00499159+2.12826747e-02j, -0.03306824-7.13122096e-02j],
       [ 0.03736202-7.20832754e-03j,  0.17497271+5.74611866e-17j,
         0.02829046+1.12164103e-01j, -0.06683353-2.72832960e-01j],
       [-0.00499159-2.12826747e-02j,  0.02829046-1.12164103e-01j,
         0.12257748-4.10442621e-17j, -0.23206689-1.41614813e-02j],
       [-0.03306824+7.13122096e-02j, -0.06683353+2.72832960e-01j,
        -0.23206689+1.41614813e-02j,  0.61257547+3.05230884e-16j]]), array([[ 0.14740177-2.96802376e-16j, -0.03828857-2.85614651e-01j,
        -0.08407912+5.94964461e-02j,  0.02604903-7.21105922e-03j],
       [-0.03828857+2.85614651e-01j,  0.67063805+1.10697982e-15j,
        -0.09215107-1.83266406e-01j,  0.00426908-3.67678366e-03j],
       [-0.08407912-5.94964461e-02j, -0.09215107+1.83266406e-01j,
         0.09529075-2.79921743e-17j, -0.03029389-1.59797158e-02j],
       [ 0.02604903+7.21105922e-03j,  0.00426908+3.67678366e-03j,
        -0.03029389+1.59797158e-02j,  0.08666943-2.03791726e-18j]]), array([[ 0.19252809+6.83332406e-18j, -0.01447208-3.23097592e-01j,
         0.00845359-6.56380310e-03j, -0.06072118+6.14943640e-02j],
       [-0.01447208+3.23097592e-01j,  0.64448543+5.94635103e-16j,
         0.00992834+4.29434651e-02j, -0.14296964-1.44427632e-01j],
       [ 0.00845359+6.56380310e-03j,  0.00992834-4.29434651e-02j,
         0.04364436+4.02272187e-18j, -0.02747924+2.39908651e-02j],
       [-0.06072118-6.14943640e-02j, -0.14296964+1.44427632e-01j,
        -0.02747924-2.39908651e-02j,  0.11934211+1.28466405e-16j]]), array([[ 0.07334231-4.67983753e-15j, -0.11713138-9.96401771e-02j,
        -0.05790776+7.59931619e-02j,  0.03097548-4.42371644e-02j],
       [-0.11713138+9.96401771e-02j,  0.5469484 +1.82465378e-15j,
        -0.05218008-7.30847774e-02j,  0.07484888-4.75618047e-02j],
       [-0.05790776-7.59931619e-02j, -0.05218008+7.30847774e-02j,
         0.20559179-4.67605968e-15j, -0.17415256-4.04310213e-03j],
       [ 0.03097548+4.42371644e-02j,  0.07484888+4.75618047e-02j,
        -0.17415256+4.04310213e-03j,  0.1741175 -7.26660314e-16j]]), array([[ 0.10355465+6.02245956e-17j, -0.10745602-1.47803104e-01j,
         0.01455625+8.51576261e-03j, -0.03011772-1.00656266e-02j],
       [-0.10745602+1.47803104e-01j,  0.51969647+3.08142114e-16j,
         0.01421285+1.75356277e-01j, -0.04165094-1.73408384e-01j],
       [ 0.01455625-8.51576261e-03j,  0.01421285-1.75356277e-01j,
         0.18760829-4.28543936e-16j, -0.16998663+5.47282398e-02j],
       [-0.03011772+1.00656266e-02j, -0.04165094+1.73408384e-01j,
        -0.16998663-5.47282398e-02j,  0.18914059-1.66670807e-16j]]), array([[ 0.09220379+3.93479057e-16j, -0.02006219-1.39844319e-01j,
        -0.10776344+2.92019896e-02j,  0.09546018+7.97737366e-02j],
       [-0.02006219+1.39844319e-01j,  0.42494403-2.49387782e-16j,
         0.01535787-2.02564243e-01j, -0.20016955-2.48333634e-02j],
       [-0.10776344-2.92019896e-02j,  0.01535787+2.02564243e-01j,
         0.1576541 +8.97127163e-16j, -0.08120881-1.67278168e-01j],
       [ 0.09546018-7.97737366e-02j, -0.20016955+2.48333634e-02j,
        -0.08120881+1.67278168e-01j,  0.32519808-8.83599013e-16j]]), array([[ 0.13359853+5.95545821e-17j, -0.02198794-1.91562093e-01j,
        -0.03831939-5.96365763e-02j, -0.03545013+1.39572168e-01j],
       [-0.02198794+1.91562093e-01j,  0.44303802-2.00525775e-16j,
         0.11580134-5.21194766e-02j, -0.31539941-1.66069683e-01j],
       [-0.03831939+5.96365763e-02j,  0.11580134+5.21194766e-02j,
         0.07060114-4.49990000e-17j, -0.07602641-7.86472620e-02j],
       [-0.03545013-1.39572168e-01j, -0.31539941+1.66069683e-01j,
        -0.07602641+7.86472620e-02j,  0.35276231-4.10740542e-16j]]), array([[ 0.04054345-3.22455244e-16j, -0.08692886-3.51502681e-03j,
        -0.0644866 +4.50020629e-02j,  0.09390694+2.25703741e-02j],
       [-0.08692886+3.51502681e-03j,  0.36201443+1.11975970e-15j,
         0.01761737-8.38665614e-02j, -0.08078968-6.54587520e-02j],
       [-0.0644866 -4.50020629e-02j,  0.01761737+8.38665614e-02j,
         0.25197212-3.51705989e-15j, -0.22750509-1.45507435e-01j],
       [ 0.09390694-2.25703741e-02j, -0.08078968+6.54587520e-02j,
        -0.22750509+1.45507435e-01j,  0.34547   +6.37090087e-16j]]), array([[ 0.07770548-1.54942090e-17j, -0.12469987-1.39210881e-02j,
        -0.02992741-5.35363270e-02j,  0.05566191+8.61370551e-02j],
       [-0.12469987+1.39210881e-02j,  0.36683222-3.15987173e-16j,
         0.11352788+1.34938874e-01j, -0.207557  -2.41334174e-01j],
       [-0.02992741+5.35363270e-02j,  0.11352788-1.34938874e-01j,
         0.16084569+1.89158940e-16j, -0.22072483-1.48262732e-02j],
       [ 0.05566191-8.61370551e-02j, -0.207557  +2.41334174e-01j,
        -0.22072483+1.48262732e-02j,  0.39461661+9.16473014e-18j]]), array([[ 0.43344006-5.66429390e-16j,  0.13853094-2.76795095e-01j,
        -0.19766356+1.63568004e-01j,  0.12487373-6.10030643e-02j],
       [ 0.13853094+2.76795095e-01j,  0.25617259+4.17360033e-17j,
        -0.1748405 -8.13469495e-02j,  0.09791769+4.93603029e-02j],
       [-0.19766356-1.63568004e-01j, -0.1748405 +8.13469495e-02j,
         0.18576188-4.17489362e-16j, -0.0863516 -2.43114089e-03j],
       [ 0.12487373+6.10030643e-02j,  0.09791769-4.93603029e-02j,
        -0.0863516 +2.43114089e-03j,  0.12462546-3.31851402e-18j]]), array([[ 0.47885987+9.79755097e-16j,  0.12841372-2.74645952e-01j,
        -0.12942558+9.74730961e-02j, -0.07837709-6.44915018e-02j],
       [ 0.12841372+2.74645952e-01j,  0.22058031-9.38142577e-16j,
        -0.09028589-1.37425864e-02j, -0.02456017-8.87288371e-02j],
       [-0.12942558-9.74730961e-02j, -0.09028589+1.37425864e-02j,
         0.13525496+2.98925610e-17j, -0.04675886+1.14740945e-01j],
       [-0.07837709+6.44915018e-02j, -0.02456017+8.87288371e-02j,
        -0.04675886-1.14740945e-01j,  0.16530486+1.83829156e-16j]]), array([[ 0.27572654-8.89781525e-16j,  0.06818405-1.08694355e-01j,
        -0.17513424+2.36952531e-01j,  0.09404788-1.70344243e-01j],
       [ 0.06818405+1.08694355e-01j,  0.12023389-5.05396462e-17j,
        -0.15776954-1.07736621e-02j,  0.136138  -1.78560375e-02j],
       [-0.17513424-2.36952531e-01j, -0.15776954+1.07736621e-02j,
         0.37362577-2.37077288e-16j, -0.24752748+3.92452926e-02j],
       [ 0.09404788+1.70344243e-01j,  0.136138  +1.78560375e-02j,
        -0.24752748-3.92452926e-02j,  0.2304138 -3.16111865e-16j]]), array([[ 0.33903151-5.54323581e-16j,  0.03921055-9.32305768e-02j,
        -0.14807287+1.72719345e-01j, -0.08195983-1.71802738e-01j],
       [ 0.03921055+9.32305768e-02j,  0.10078027-1.14137990e-16j,
        -0.07604913+6.30683261e-02j,  0.0132364 -1.31292348e-01j],
       [-0.14807287-1.72719345e-01j, -0.07604913-6.30683261e-02j,
         0.29274761+5.06869203e-18j, -0.17664075+1.73988288e-01j],
       [-0.08195983+1.71802738e-01j,  0.0132364 +1.31292348e-01j,
        -0.17664075-1.73988288e-01j,  0.26744061-5.41612661e-16j]]), array([[ 0.44032108-3.66387702e-17j,  0.11041119-1.40169750e-01j,
        -0.22056064+3.47627504e-02j,  0.25720591+1.30838511e-01j],
       [ 0.11041119+1.40169750e-01j,  0.11134577+3.50292044e-16j,
        -0.06538303-6.21986516e-02j,  0.02009735+6.48355965e-02j],
       [-0.22056064-3.47627504e-02j, -0.06538303+6.21986516e-02j,
         0.13042735+4.92739138e-16j, -0.12724116-9.28015512e-02j],
       [ 0.25720591-1.30838511e-01j,  0.02009735-6.48355965e-02j,
        -0.12724116+9.28015512e-02j,  0.31790581+3.19876519e-16j]]), array([[ 0.4897833 -3.41325597e-13j,  0.10646364-1.60300669e-01j,
        -0.1382785 -4.46930098e-02j,  0.02320928+7.62880718e-02j],
       [ 0.10646364+1.60300669e-01j,  0.12011989-2.77154462e-13j,
        -0.00954159-1.94320442e-02j, -0.08414589-7.29651441e-02j],
       [-0.1382785 +4.46930098e-02j, -0.00954159+1.94320442e-02j,
         0.07230588+1.94215364e-14j, -0.09961192+1.90220371e-02j],
       [ 0.02320928-7.62880718e-02j, -0.08414589+7.29651441e-02j,
        -0.09961192-1.90220371e-02j,  0.31779093-8.65721243e-14j]]), array([[ 0.29103245-5.03959895e-19j,  0.0450587 +1.52482248e-02j,
        -0.21106346+8.09033791e-02j,  0.2563718 +9.55787915e-03j],
       [ 0.0450587 -1.52482248e-02j,  0.03529381-2.36254035e-18j,
        -0.05151759+2.20070280e-02j,  0.07445797-2.01341728e-02j],
       [-0.21106346-8.09033791e-02j, -0.05151759-2.20070280e-02j,
         0.27083033-6.08963129e-17j, -0.29095752-5.85242570e-02j],
       [ 0.2563718 -9.55787915e-03j,  0.07445797+2.01341728e-02j,
        -0.29095752+5.85242570e-02j,  0.40284341+9.43995513e-17j]]), array([[ 0.40271337-9.21086445e-16j,  0.00697216+9.69168836e-03j,
        -0.14532212+8.13842107e-03j,  0.04504856+4.85786982e-03j],
       [ 0.00697216-9.69168836e-03j,  0.04435607-2.28448950e-16j,
        -0.00710389+7.54103825e-02j, -0.03168996-1.19704917e-01j],
       [-0.14532212-8.13842107e-03j, -0.00710389-7.54103825e-02j,
         0.18014404+5.69937939e-16j, -0.2178356 +6.73731738e-02j],
       [ 0.04504856-4.85786982e-03j, -0.03168996+1.19704917e-01j,
        -0.2178356 -6.73731738e-02j,  0.37278653+4.09072057e-16j]]), array([[ 2.76060293e-01+1.25055558e-16j, -3.27277782e-02-2.97143250e-01j,
        -2.28216362e-01+7.17647172e-02j,  8.37107346e-02-6.01080769e-03j],
       [-3.27277782e-02+2.97143250e-01j,  3.64347923e-01+1.48459207e-16j,
        -6.09867307e-02-2.68407903e-01j, -3.46666985e-04+8.62353980e-02j],
       [-2.28216362e-01-7.17647172e-02j, -6.09867307e-02+2.68407903e-01j,
         2.95279961e-01+4.35231013e-16j, -9.05349418e-02+1.10775046e-02j],
       [ 8.37107346e-02+6.01080769e-03j, -3.46666985e-04-8.62353980e-02j,
        -9.05349418e-02-1.10775046e-02j,  6.43118237e-02+8.24300549e-18j]]), array([[ 0.32476993-3.46935891e-15j, -0.02643258-3.02057930e-01j,
        -0.11681749-3.88721009e-02j,  0.00614396+4.17419237e-02j],
       [-0.02643258+3.02057930e-01j,  0.32402436-1.25853210e-14j,
         0.0199255 -1.92826018e-02j, -0.08470192-4.12629117e-02j],
       [-0.11681749+3.88721009e-02j,  0.0199255 +1.92826018e-02j,
         0.24761499-5.98289941e-15j, -0.07130732+1.10273674e-01j],
       [ 0.00614396-4.17419237e-02j, -0.08470192+4.12629117e-02j,
        -0.07130732-1.10273674e-01j,  0.10359071-7.47485613e-15j]]), array([[ 0.16726602+2.77347772e-16j, -0.10262769-1.22005920e-01j,
        -0.1819676 +1.42021808e-01j,  0.05800725-7.14651472e-02j],
       [-0.10262769+1.22005920e-01j,  0.23338148+1.76258930e-16j,
        -0.02766475-1.47859617e-01j,  0.03354497+2.17635360e-02j],
       [-0.1819676 -1.42021808e-01j, -0.02766475+1.47859617e-01j,
         0.46445334-1.64391235e-15j, -0.22351034+4.86018433e-02j],
       [ 0.05800725+7.14651472e-02j,  0.03354497-2.17635360e-02j,
        -0.22351034-4.86018433e-02j,  0.13489916-3.77181875e-16j]]), array([[ 0.2249996 -8.02136342e-16j, -0.11738041-1.41572227e-01j,
        -0.11940614+2.58458734e-02j,  0.00721898-2.90836368e-02j],
       [-0.11738041+1.41572227e-01j,  0.23664364-3.00436842e-15j,
         0.03624404+7.39520724e-02j, -0.04421997-7.98309058e-02j],
       [-0.11940614-2.58458734e-02j,  0.03624404-7.39520724e-02j,
         0.3776099 -1.30842967e-14j, -0.18983781+1.37943661e-01j],
       [ 0.00721898+2.90836368e-02j, -0.04421997+7.98309058e-02j,
        -0.18983781-1.37943661e-01j,  0.16074686+3.42721164e-15j]]), array([[ 0.28811767-2.95715824e-16j, -0.01900333-2.11447059e-01j,
        -0.24234201-2.30419105e-02j,  0.17000225+1.55617058e-01j],
       [-0.01900333+2.11447059e-01j,  0.21459598+1.02019596e-16j,
         0.03758616-2.12689315e-01j, -0.14111453+1.05918985e-01j],
       [-0.24234201+2.30419105e-02j,  0.03758616+2.12689315e-01j,
         0.27107913-1.40143588e-16j, -0.1633303 -1.33047528e-01j],
       [ 0.17000225-1.55617058e-01j, -0.14111453-1.05918985e-01j,
        -0.1633303 +1.33047528e-01j,  0.22620722+2.15697830e-16j]]), array([[ 0.37042812-3.21294610e-16j, -0.03002587-2.48884743e-01j,
        -0.13459494-1.77389443e-01j,  0.06137988+2.11300475e-01j],
       [-0.03002587+2.48884743e-01j,  0.22793708+2.49092879e-16j,
         0.13012129-5.23968557e-02j, -0.18262774-1.78195704e-02j],
       [-0.13459494+1.77389443e-01j,  0.13012129+5.23968557e-02j,
         0.17963086-5.35203149e-16j, -0.15719154-2.29939069e-02j],
       [ 0.06137988-2.11300475e-01j, -0.18262774+1.78195704e-02j,
        -0.15719154+2.29939069e-02j,  0.22200394-5.17165816e-16j]]), array([[ 0.15130703+4.21181342e-18j, -0.07140911-4.49642780e-02j,
        -0.20217632+3.98338167e-02j,  0.16608879+4.87194331e-02j],
       [-0.07140911+4.49642780e-02j,  0.08991588+1.15199851e-17j,
         0.06462493-1.06419707e-01j, -0.08265217+3.55769849e-02j],
       [-0.20217632-3.98338167e-02j,  0.06462493+1.06419707e-01j,
         0.45897322-4.21471998e-16j, -0.32218219-1.16671871e-01j],
       [ 0.16608879-4.87194331e-02j, -0.08265217-3.55769849e-02j,
        -0.32218219+1.16671871e-01j,  0.29980388-6.28691962e-16j]]), array([[ 0.24397259-3.04596703e-16j, -0.13590164-3.36643976e-02j,
        -0.14880266-1.35968671e-01j,  0.15501162+1.28074579e-01j],
       [-0.13590164+3.36643976e-02j,  0.1261229 -1.71775740e-16j,
         0.11471927+9.78092153e-02j, -0.13300559-9.26506558e-02j],
       [-0.14880266+1.35968671e-01j,  0.11471927-9.78092153e-02j,
         0.31407064+1.51710125e-16j, -0.2881429 +4.67425205e-02j],
       [ 0.15501162-1.28074579e-01j, -0.13300559+9.26506558e-02j,
        -0.2881429 -4.67425205e-02j,  0.31583387-7.39013403e-16j]]), array([[ 1.77398013e-01+1.22533754e-16j,  7.42438920e-02-2.11158363e-01j,
        -1.05620942e-02+4.44244031e-03j,  1.75820445e-01-1.51729422e-01j],
       [ 7.42438920e-02+2.11158363e-01j,  3.90980234e-01+1.58152722e-17j,
         2.80961207e-04-1.68848238e-02j,  2.14612110e-01+1.79434919e-01j],
       [-1.05620942e-02-4.44244031e-03j,  2.80961207e-04+1.68848238e-02j,
         1.76235934e-02+2.37677620e-18j, -2.33644344e-02+6.58877075e-03j],
       [ 1.75820445e-01+1.51729422e-01j,  2.14612110e-01-1.79434919e-01j,
        -2.33644344e-02-6.58877075e-03j,  4.13998160e-01+3.92635207e-16j]]), array([[ 0.2222058 -2.78547152e-13j,  0.04786246-1.76847746e-01j,
        -0.01230354-1.62448103e-02j,  0.01647897-2.02481155e-01j],
       [ 0.04786246+1.76847746e-01j,  0.30700097-1.10616820e-13j,
         0.03703781+5.47610064e-02j, -0.01340342+5.36356190e-02j],
       [-0.01230354+1.62448103e-02j,  0.03703781-5.47610064e-02j,
         0.03617644-1.20513412e-13j,  0.02004673+1.04594381e-01j],
       [ 0.01647897+2.02481155e-01j, -0.01340342-5.36356190e-02j,
         0.02004673-1.04594381e-01j,  0.4346168 +2.47203389e-13j]]), array([[ 0.13708857-3.34640121e-16j, -0.02796505-4.12266594e-02j,
        -0.02779539+1.03339845e-01j,  0.03904772-2.11973944e-01j],
       [-0.02796505+4.12266594e-02j,  0.34356879+1.10202732e-15j,
         0.02505527-3.44156470e-02j,  0.17601244+1.41334491e-01j],
       [-0.02779539-1.03339845e-01j,  0.02505527+3.44156470e-02j,
         0.09878863+1.87562869e-18j, -0.15530026+2.91780717e-02j],
       [ 0.03904772+2.11973944e-01j,  0.17601244-1.41334491e-01j,
        -0.15530026-2.91780717e-02j,  0.42055401-1.97514177e-15j]]), array([[ 0.19044086-1.61727390e-15j, -0.0378438 -2.65892086e-02j,
        -0.04205617+7.94215048e-02j, -0.0754794 -2.68232953e-01j],
       [-0.0378438 +2.65892086e-02j,  0.281977  +7.40409379e-16j,
         0.05750364+7.70610560e-02j, -0.00063751+5.25027409e-02j],
       [-0.04205617-7.94215048e-02j,  0.05750364-7.70610560e-02j,
         0.09710721-3.64554992e-16j, -0.10600011+1.14581936e-01j],
       [-0.0754794 +2.68232953e-01j, -0.00063751-5.25027409e-02j,
        -0.10600011-1.14581936e-01j,  0.43047492+1.68649724e-15j]]), array([[ 0.18170563-1.03215600e-16j,  0.08429032-4.20407310e-02j,
         0.00584904+9.70684806e-03j,  0.24683304-1.03444301e-01j],
       [ 0.08429032+4.20407310e-02j,  0.21759683+4.79076070e-16j,
         0.02237207-5.82701822e-02j, -0.00728568+6.82480337e-02j],
       [ 0.00584904-9.70684806e-03j,  0.02237207+5.82701822e-02j,
         0.03332315+4.91543232e-17j, -0.04091644-6.77003858e-02j],
       [ 0.24683304+1.03444301e-01j, -0.00728568-6.82480337e-02j,
        -0.04091644+6.77003858e-02j,  0.56737439+1.33539856e-15j]]), array([[ 0.22868721-3.50855022e-16j,  0.04815607-2.17500769e-02j,
        -0.01007507-4.69166678e-02j,  0.12958605-2.03720330e-01j],
       [ 0.04815607+2.17500769e-02j,  0.14565429+9.97661527e-17j,
         0.02150209+1.07666114e-04j, -0.15843151-3.02627925e-02j],
       [-0.01007507+4.69166678e-02j,  0.02150209-1.07666114e-04j,
         0.02026953-9.25586843e-18j,  0.00605336+5.53123810e-02j],
       [ 0.12958605+2.03720330e-01j, -0.15843151+3.02627925e-02j,
         0.00605336-5.53123810e-02j,  0.60538897+5.99598113e-16j]]), array([[ 0.15766053-5.13506204e-16j,  0.02195359+6.97481326e-02j,
         0.01308493+1.17503084e-01j,  0.12272084-1.85808324e-01j],
       [ 0.02195359-6.97481326e-02j,  0.18035904+7.64249870e-17j,
         0.03611883-4.61775132e-02j, -0.00303951+6.79333345e-02j],
       [ 0.01308493-1.17503084e-01j,  0.03611883+4.61775132e-02j,
         0.126533  +9.24857559e-16j, -0.20759508-1.07097292e-01j],
       [ 0.12272084+1.85808324e-01j, -0.00303951-6.79333345e-02j,
        -0.20759508+1.07097292e-01j,  0.53544743+3.08681642e-15j]]), array([[ 0.21479053+6.68206195e-17j,  0.02763844+1.00220309e-01j,
         0.01268018+9.26939020e-02j, -0.03438837-2.93563541e-01j],
       [ 0.02763844-1.00220309e-01j,  0.12055694-9.75023577e-17j,
         0.06692154+2.05886097e-02j, -0.1864904 -4.04037960e-02j],
       [ 0.01268018-9.26939020e-02j,  0.06692154-2.05886097e-02j,
         0.08785926-4.32930532e-19j, -0.18543387-4.98912375e-06j],
       [-0.03438837+2.93563541e-01j, -0.1864904 +4.04037960e-02j,
        -0.18543387+4.98912375e-06j,  0.57679327-1.93715446e-16j]]), array([[ 0.1487156 -3.24772026e-16j, -0.07223755-2.55229170e-01j,
        -0.03656069-4.39869690e-03j,  0.12561512-6.52897169e-02j],
       [-0.07223755+2.55229170e-01j,  0.63356735-2.42185753e-16j,
         0.06100442-1.07905127e-01j,  0.02500152+2.36576945e-01j],
       [-0.03656069+4.39869690e-03j,  0.06100442+1.07905127e-01j,
         0.04726577+4.28812261e-17j, -0.02986994+3.56337868e-03j],
       [ 0.12561512+6.52897169e-02j,  0.02500152-2.36576945e-01j,
        -0.02986994-3.56337868e-03j,  0.17045128-3.59922317e-16j]]), array([[ 0.18985753-1.85397519e-16j, -0.08436937-2.50498168e-01j,
         0.01546248-7.44778578e-02j,  0.08415882-4.17356386e-02j],
       [-0.08436937+2.50498168e-01j,  0.56046947+8.49087147e-16j,
         0.12657825+8.78734167e-02j, -0.13987599+1.18510813e-01j],
       [ 0.01546248+7.44778578e-02j,  0.12657825-8.78734167e-02j,
         0.05037466+5.53821067e-17j, -0.00820577+5.77901521e-02j],
       [ 0.08415882+4.17356386e-02j, -0.13987599-1.18510813e-01j,
        -0.00820577-5.77901521e-02j,  0.19929834-8.82274967e-17j]]), array([[ 0.10089443+2.12021216e-16j, -0.1701728 -4.54743288e-02j,
        -0.05471123+8.34770865e-02j,  0.03730127-1.28984218e-01j],
       [-0.1701728 +4.54743288e-02j,  0.56259418-8.26814187e-16j,
         0.09332493-1.28161111e-01j,  0.01533641+1.85662199e-01j],
       [-0.05471123-8.34770865e-02j,  0.09332493+1.28161111e-01j,
         0.1247249 +6.27073575e-16j, -0.14323644+2.84094759e-02j],
       [ 0.03730127+1.28984218e-01j,  0.01533641-1.85662199e-01j,
        -0.14323644-2.84094759e-02j,  0.21178649+3.91577513e-16j]]), array([[ 0.14356204+7.34027858e-16j, -0.18384169-5.65226637e-02j,
        -0.04435868+1.34410594e-02j,  0.0194245 -1.34072042e-01j],
       [-0.18384169+5.65226637e-02j,  0.48677207+4.68385898e-15j,
         0.12354882+9.89082550e-02j, -0.11165615+1.03616492e-01j],
       [-0.04435868-1.34410594e-02j,  0.12354882-9.89082550e-02j,
         0.12141766-2.57687366e-16j, -0.11118446+9.96137937e-02j],
       [ 0.0194245 +1.34072042e-01j, -0.11165615-1.03616492e-01j,
        -0.11118446-9.96137937e-02j,  0.24824823-1.84318595e-16j]]), array([[ 0.14240046-2.34542170e-16j, -0.02620729-8.02449510e-02j,
        -0.00230981+1.75963936e-02j,  0.1819888 -4.87012924e-02j],
       [-0.02620729+8.02449510e-02j,  0.40055773+7.15896259e-15j,
         0.07901994-1.75682109e-01j, -0.19119705+1.13934572e-01j],
       [-0.00230981-1.75963936e-02j,  0.07901994+1.75682109e-01j,
         0.10870878-2.15297713e-15j, -0.05689577-1.11764865e-01j],
       [ 0.1819888 +4.87012924e-02j, -0.19119705-1.13934572e-01j,
        -0.05689577+1.11764865e-01j,  0.34833303-2.65749036e-17j]]), array([[ 0.20263874+3.71052788e-16j, -0.06264069-8.51920356e-02j,
         0.00895928-7.83670069e-02j,  0.14075347-6.60731548e-02j],
       [-0.06264069+8.51920356e-02j,  0.36066696+1.05643306e-15j,
         0.10253444-1.57811354e-02j, -0.28884132+2.92459612e-02j],
       [ 0.00895928+7.83670069e-02j,  0.10253444+1.57811354e-02j,
         0.05745688+2.52512450e-16j, -0.0254458 +1.02787852e-04j],
       [ 0.14075347+6.60731548e-02j, -0.28884132-2.92459612e-02j,
        -0.0254458 -1.02787852e-04j,  0.37923742+1.24094989e-15j]]), array([[ 0.09290742-4.82997843e-16j, -0.11227617+7.40195266e-02j,
        -0.00528473+1.19409461e-01j,  0.09423108-1.29085300e-01j],
       [-0.11227617-7.40195266e-02j,  0.36196545-1.68499547e-17j,
         0.1122178 -1.77946286e-01j, -0.211698  +1.09127733e-01j],
       [-0.00528473-1.19409461e-01j,  0.1122178 +1.77946286e-01j,
         0.19714471+4.13876742e-16j, -0.20792818-1.27037250e-01j],
       [ 0.09423108+1.29085300e-01j, -0.211698  -1.09127733e-01j,
        -0.20792818+1.27037250e-01j,  0.34798243-8.84283636e-16j]]), array([[ 0.14631437+1.85809131e-17j, -0.15901146+9.64788724e-02j,
        -0.0473108 +2.47215432e-02j,  0.11340915-1.27455620e-01j],
       [-0.15901146-9.64788724e-02j,  0.36694506+3.66553539e-16j,
         0.13876098+3.47149089e-02j, -0.32931412+2.73265778e-02j],
       [-0.0473108 -2.47215432e-02j,  0.13876098-3.47149089e-02j,
         0.09998422+9.07773385e-17j, -0.16133031+3.00101356e-02j],
       [ 0.11340915+1.27455620e-01j, -0.32931412-2.73265778e-02j,
        -0.16133031-3.00101356e-02j,  0.38675636+7.10994570e-16j]]), array([[ 0.37170107+2.37063316e-16j,  0.08983335-2.11422181e-01j,
        -0.06471829+4.97411314e-02j,  0.21241419-1.05119602e-01j],
       [ 0.08983335+2.11422181e-01j,  0.21024904-5.25433663e-16j,
         0.01839917-6.64019065e-02j,  0.15978663+1.65790839e-01j],
       [-0.06471829-4.97411314e-02j,  0.01839917+6.64019065e-02j,
         0.13010754+7.35911243e-19j, -0.04994196+1.02052801e-01j],
       [ 0.21241419+1.05119602e-01j,  0.15978663-1.65790839e-01j,
        -0.04994196-1.02052801e-01j,  0.28794236-5.33812410e-16j]]), array([[ 0.41062995+1.44125523e-14j,  0.05686872-1.91558032e-01j,
        -0.06786809-3.54408817e-03j,  0.06147566-1.58731880e-01j],
       [ 0.05686872+1.91558032e-01j,  0.13936524+1.63066438e-15j,
         0.04476201+1.48982950e-02j,  0.01259187+7.97546106e-02j],
       [-0.06786809+3.54408817e-03j,  0.04476201-1.48982950e-02j,
         0.13172208+2.40479706e-15j, -0.01454351+1.98849868e-01j],
       [ 0.06147566+1.58731880e-01j,  0.01259187-7.97546106e-02j,
        -0.01454351-1.98849868e-01j,  0.31828274+1.56681784e-15j]]), array([[ 2.93713391e-01+1.91249049e-15j, -9.85934992e-05-3.02034002e-02j,
        -8.09733334e-02+2.06507930e-01j,  6.37502027e-02-1.86920330e-01j],
       [-9.85934992e-05+3.02034002e-02j,  1.50881896e-01-5.90776109e-16j,
         5.02761029e-02-8.46741102e-02j,  1.13833526e-01+1.27953501e-01j],
       [-8.09733334e-02-2.06507930e-01j,  5.02761029e-02+8.46741102e-02j,
         2.51192326e-01+5.86530051e-16j, -1.68734344e-01+1.17906253e-01j],
       [ 6.37502027e-02+1.86920330e-01j,  1.13833526e-01-1.27953501e-01j,
        -1.68734344e-01-1.17906253e-01j,  3.04212388e-01-1.59161394e-15j]]), array([[ 0.33953877-1.33411732e-16j, -0.05499343+8.81178743e-03j,
        -0.16076107+1.59696076e-01j, -0.05718492-2.93049654e-01j],
       [-0.05499343-8.81178743e-03j,  0.05467295-5.15037814e-17j,
         0.07133144-1.05707858e-03j, -0.03020564+8.04827109e-02j],
       [-0.16076107-1.59696076e-01j,  0.07133144+1.05707858e-03j,
         0.2429209 +9.77845845e-17j, -0.14130918+2.40584841e-01j],
       [-0.05718492+2.93049654e-01j, -0.03020564-8.04827109e-02j,
        -0.14130918-2.40584841e-01j,  0.36286737+9.97211052e-17j]]), array([[ 0.44107265+3.19449722e-18j,  0.10121321-8.60039916e-02j,
        -0.04168147-2.70198534e-02j,  0.38669663-5.07313953e-03j],
       [ 0.10121321+8.60039916e-02j,  0.08808248-1.32568209e-16j,
         0.01517065-3.91911880e-02j,  0.0742783 +1.09006420e-01j],
       [-0.04168147+2.70198534e-02j,  0.01517065+3.91911880e-02j,
         0.05098797+3.87825490e-18j, -0.07370764+3.38810211e-02j],
       [ 0.38669663+5.07313953e-03j,  0.0742783 -1.09006420e-01j,
        -0.07370764-3.38810211e-02j,  0.41985689-2.74162914e-16j]]), array([[ 0.49934537-1.72960691e-15j,  0.07427455-8.05161289e-02j,
        -0.03357173-8.02997136e-02j,  0.17220313-8.13520334e-02j],
       [ 0.07427455+8.05161289e-02j,  0.06267258+7.16210336e-16j,
         0.03368781+6.95823894e-03j, -0.06843266+3.13121791e-02j],
       [-0.03357173+8.02997136e-02j,  0.03368781-6.95823894e-03j,
         0.04992767-4.80540240e-16j, -0.06195034+1.13854617e-01j],
       [ 0.17220313+8.13520334e-02j, -0.06843266-3.13121791e-02j,
        -0.06195034-1.13854617e-01j,  0.38805438-1.37314408e-15j]]), array([[ 0.38219659+1.46227003e-15j,  0.03880703+7.44762608e-02j,
        -0.03332306+1.55828879e-01j,  0.18385905-1.01036933e-01j],
       [ 0.03880703-7.44762608e-02j,  0.07533974-2.21885976e-16j,
         0.05250749-5.53229577e-02j,  0.00678042+6.74023587e-02j],
       [-0.03332306-1.55828879e-01j,  0.05250749+5.53229577e-02j,
         0.18959449+5.20399017e-16j, -0.21417114-3.10277209e-03j],
       [ 0.18385905+1.01036933e-01j,  0.00678042-6.74023587e-02j,
        -0.21417114+3.10277209e-03j,  0.35286918-8.44930770e-16j]]), array([[ 0.46966553-3.43652127e-16j,  0.01164147+6.76551527e-02j,
        -0.04542809+6.65120123e-02j,  0.05325974-1.54904913e-01j],
       [ 0.01164147-6.76551527e-02j,  0.03695291+4.69817344e-17j,
         0.06022401+2.03410142e-02j, -0.10119917+1.12499412e-02j],
       [-0.04542809-6.65120123e-02j,  0.06022401-2.03410142e-02j,
         0.13703614+2.85504485e-16j, -0.19175683+9.89001157e-02j],
       [ 0.05325974+1.54904913e-01j, -0.10119917-1.12499412e-02j,
        -0.19175683-9.89001157e-02j,  0.35634542-1.75539113e-15j]]), array([[ 0.23682903-5.39743238e-16j, -0.044645  -2.47062951e-01j,
        -0.10956084-3.66138464e-02j,  0.17786478-4.58912781e-02j],
       [-0.044645  +2.47062951e-01j,  0.3519519 -3.18688984e-17j,
         0.12336815-1.92381444e-01j,  0.04128768+2.33075835e-01j],
       [-0.10956084+3.66138464e-02j,  0.12336815+1.92381444e-01j,
         0.22679108-2.60633679e-16j, -0.09247062+1.14631652e-01j],
       [ 0.17786478+4.58912781e-02j,  0.04128768-2.33075835e-01j,
        -0.09247062-1.14631652e-01j,  0.18442799+1.08056323e-16j]]), array([[ 0.31623403+7.76029097e-16j, -0.08361827-2.68461020e-01j,
        -0.05540631-1.28812888e-01j,  0.14849161-3.27765852e-02j],
       [-0.08361827+2.68461020e-01j,  0.29508347-1.74072905e-16j,
         0.16291103+3.36578007e-02j, -0.06223665+1.55964289e-01j],
       [-0.05540631+1.28812888e-01j,  0.16291103-3.36578007e-02j,
         0.2013041 -3.79802861e-16j, -0.04625319+1.77555586e-01j],
       [ 0.14849161+3.27765852e-02j, -0.06223665-1.55964289e-01j,
        -0.04625319-1.77555586e-01j,  0.1873784 +7.09453625e-16j]]), array([[ 0.16636278+9.81983509e-17j, -0.16551027-5.60040249e-02j,
        -0.14115661+1.38988227e-01j,  0.0478193 -1.44112063e-01j],
       [-0.16551027+5.60040249e-02j,  0.27531174-5.50694572e-16j,
         0.15667295-2.25310461e-01j,  0.0017047 +2.05365887e-01j],
       [-0.14115661-1.38988227e-01j,  0.15667295+2.25310461e-01j,
         0.36024785-4.40470585e-16j, -0.20075861+1.31846539e-01j],
       [ 0.0478193 +1.44112063e-01j,  0.0017047 -2.05365887e-01j,
        -0.20075861-1.31846539e-01j,  0.19807763+3.57695703e-16j]]), array([[ 0.23207514+2.20242063e-16j, -0.17971139-6.67938232e-02j,
        -0.12428071+1.56146248e-02j,  0.05710748-1.29539508e-01j],
       [-0.17971139+6.67938232e-02j,  0.22322113+5.79464171e-16j,
         0.17171301+3.44457335e-02j, -0.09431245+1.27639334e-01j],
       [-0.12428071-1.56146248e-02j,  0.17171301-3.44457335e-02j,
         0.31121109+1.05513878e-15j, -0.15106768+2.11148891e-01j],
       [ 0.05710748+1.29539508e-01j, -0.09431245-1.27639334e-01j,
        -0.15106768-2.11148891e-01j,  0.23349264-1.65919182e-16j]]), array([[ 0.31362882-6.81993899e-16j, -0.01581233-1.16125431e-01j,
        -0.03192137-3.53842344e-02j,  0.25686584+2.79579647e-02j],
       [-0.01581233+1.16125431e-01j,  0.22528483-1.30744282e-14j,
         0.10835311-1.73944259e-01j, -0.09643026+1.41729230e-01j],
       [-0.03192137+3.53842344e-02j,  0.10835311+1.73944259e-01j,
         0.20493503-5.66881178e-16j, -0.11060909-1.52677395e-02j],
       [ 0.25686584-2.79579647e-02j, -0.09643026-1.41729230e-01j,
        -0.11060909+1.52677395e-02j,  0.25615132-8.01382087e-16j]]), array([[ 0.40620896-5.17072880e-16j, -0.07982038-1.42560368e-01j,
        -0.04455268-1.92828124e-01j,  0.27127325+2.88167524e-02j],
       [-0.07982038+1.42560368e-01j,  0.16296015+3.86391579e-16j,
         0.12669252+9.08703298e-03j, -0.15327605+9.44229591e-02j],
       [-0.04455268+1.92828124e-01j,  0.12669252-9.08703298e-03j,
         0.1400226 +1.77399734e-16j, -0.09552781+1.17634865e-01j],
       [ 0.27127325-2.88167524e-02j, -0.15327605-9.44229591e-02j,
        -0.09552781-1.17634865e-01j,  0.29080829-2.77794089e-17j]]), array([[ 0.23773499-8.65242313e-17j, -0.08415323+3.50199479e-02j,
        -0.04044315+1.09160987e-01j,  0.14480831-6.90890013e-02j],
       [-0.08415323-3.50199479e-02j,  0.15911955+4.64724393e-16j,
         0.14438182-1.72159428e-01j, -0.12845193+1.13546865e-01j],
       [-0.04044315-1.09160987e-01j,  0.14438182+1.72159428e-01j,
         0.34216516-1.90763963e-15j, -0.25452274-2.67815504e-02j],
       [ 0.14480831+6.90890013e-02j, -0.12845193-1.13546865e-01j,
        -0.25452274+2.67815504e-02j,  0.26098029-7.07087744e-16j]]), array([[ 0.33236021-8.36567807e-16j, -0.14384309+3.46902790e-02j,
        -0.06504592-4.64692897e-02j,  0.15393219-6.21188089e-02j],
       [-0.14384309-3.46902790e-02j,  0.14800838-1.28920266e-15j,
         0.14958109+2.22803894e-02j, -0.18427247+5.92513344e-02j],
       [-0.06504592+4.64692897e-02j,  0.14958109-2.22803894e-02j,
         0.23697623-1.25677662e-15j, -0.20972519+1.08143751e-01j],
       [ 0.15393219+6.21188089e-02j, -0.18427247-5.92513344e-02j,
        -0.20972519-1.08143751e-01j,  0.28265518-1.99503326e-15j]])]

# %% [markdown]
# ## Decoding with Projective Measurements
#
# The decoding is performed by measuring the encoding states with the POVMs defined as below. The `decoding[j]` is a positive semidefinite matrix which representes the POVM used to decode the `j`-th bit from the encoding state.

# %%
decoding = [array([[ 0.46149888-4.65521063e-11j,  0.2791402 +3.27282228e-01j,
        -0.14476641-1.90543733e-01j, -0.02707437-7.28295770e-02j],
       [ 0.2791402 -3.27282228e-01j,  0.64544742+5.11375599e-12j,
         0.17177115+4.13473891e-02j,  0.08687009-7.06364802e-02j],
       [-0.14476641+1.90543733e-01j,  0.17177115-4.13473892e-02j,
         0.77238165-3.29381939e-11j,  0.27835799-9.63640008e-02j],
       [-0.02707437+7.28295771e-02j,  0.08687009+7.06364802e-02j,
         0.27835799+9.63640007e-02j,  0.11978649+7.18396158e-12j]]), array([[ 0.72447474+2.50036576e-11j, -0.3825403 +2.61241785e-02j,
         0.17657979+5.02766470e-02j, -0.12288119+6.12688079e-02j],
       [-0.3825403 -2.61241784e-02j,  0.21705522-1.89949723e-11j,
        -0.02027318+1.70304089e-02j,  0.14630857-2.76561290e-02j],
       [ 0.17657979-5.02766469e-02j, -0.02027318-1.70304090e-02j,
         0.58572557+6.12987352e-11j,  0.37681844-2.57343932e-01j],
       [-0.12288119-6.12688078e-02j,  0.14630857+2.76561290e-02j,
         0.37681844+2.57343932e-01j,  0.47284016-1.12834242e-10j]]), array([[ 0.31013366-6.07159151e-12j,  0.08611226+1.87493721e-01j,
         0.21618049-6.03868184e-02j, -0.18599469+2.93592020e-01j],
       [ 0.08611226-1.87493721e-01j,  0.43496881+5.05974574e-12j,
        -0.33841312+3.14875441e-02j, -0.06612254+2.88274896e-01j],
       [ 0.21618049+6.03868184e-02j, -0.33841312-3.14875441e-02j,
         0.71067257+5.95764848e-12j,  0.103304  +1.68966027e-01j],
       [-0.18599469-2.93592020e-01j, -0.06612254-2.88274896e-01j,
         0.103304  -1.68966027e-01j,  0.5432365 -1.64480979e-12j]]), array([[ 0.34903189-1.22362067e-11j, -0.02671535-1.28115878e-01j,
        -0.35162894-1.14242315e-02j, -0.11572532+2.70018460e-01j],
       [-0.02671535+1.28115878e-01j,  0.5216364 +9.98741451e-11j,
        -0.29693404+2.41957243e-02j,  0.05519503-3.74817527e-01j],
       [-0.35162894+1.14242315e-02j, -0.29693404-2.41957246e-02j,
         0.63149583+5.99489107e-11j, -0.09372909-1.06369358e-01j],
       [-0.11572532-2.70018460e-01j,  0.05519503+3.74817527e-01j,
        -0.09372909+1.06369358e-01j,  0.49759338+6.88473546e-10j]]), array([[ 0.0720789 -3.41572456e-12j, -0.06282683+5.09660482e-02j,
         0.06132008-7.46440203e-02j, -0.10386829-2.00338702e-01j],
       [-0.06282683-5.09660482e-02j,  0.97071954-2.36717668e-12j,
        -0.08530202+9.88873115e-02j, -0.02123968-6.49483529e-02j],
       [ 0.06132008+7.46440203e-02j, -0.08530202-9.88873116e-02j,
         0.13738688+2.33356606e-12j,  0.09292111-2.87505712e-01j],
       [-0.10386829+2.00338702e-01j, -0.02123968+6.49483529e-02j,
         0.09292111+2.87505712e-01j,  0.8198883 +2.02522356e-11j]]), array([[ 0.70886124-2.30713148e-11j,  0.33726238+8.30937678e-02j,
        -0.1536225 +2.15961122e-01j, -0.11060655-5.67225673e-02j],
       [ 0.33726238-8.30937679e-02j,  0.27312084-1.13828247e-11j,
        -0.02504508+1.34706993e-01j,  0.24307241-5.91826740e-05j],
       [-0.1536225 -2.15961122e-01j, -0.02504508-1.34706993e-01j,
         0.10600411-7.63610615e-12j,  0.0753635 +8.09646742e-03j],
       [-0.11060655+5.67225673e-02j,  0.24307241+5.91826283e-05j,
         0.0753635 -8.09646742e-03j,  0.91195499-1.75505172e-10j]]), array([[ 0.2603015 +2.61325153e-12j, -0.06200337-2.96971978e-01j,
        -0.06840545+2.50410828e-01j, -0.13482615-1.21823324e-01j],
       [-0.06200337+2.96971978e-01j,  0.73003366-2.24861212e-12j,
        -0.01767589+1.81909858e-01j,  0.23358148+1.30372808e-01j],
       [-0.06840545-2.50410828e-01j, -0.01767589-1.81909858e-01j,
         0.69912747+5.03900444e-11j,  0.1769953 +2.79484099e-01j],
       [-0.13482615+1.21823324e-01j,  0.23358148-1.30372808e-01j,
         0.1769953 -2.79484099e-01j,  0.31044174+1.30034493e-11j]]), array([[ 0.53820595+1.16293380e-11j,  0.24834878-3.67065745e-01j,
         0.02054005-1.42216796e-01j,  0.16834453+5.54245562e-02j],
       [ 0.24834878+3.67065745e-01j,  0.45573441-6.23791844e-12j,
        -0.03079714-1.75328225e-01j, -0.13997656+1.40354154e-02j],
       [ 0.02054005+1.42216796e-01j, -0.03079714+1.75328225e-01j,
         0.41454665-2.35492580e-12j,  0.43595296-7.44437576e-03j],
       [ 0.16834453-5.54245562e-02j, -0.13997656-1.40354154e-02j,
         0.43595296+7.44437574e-03j,  0.59060547-1.39946876e-11j]]), array([[ 0.27248981+2.63505335e-12j,  0.07157173+8.94006056e-02j,
         0.02445108+2.91797376e-01j,  0.28310573+1.37628068e-01j],
       [ 0.07157173-8.94006057e-02j,  0.63076089+5.59172300e-13j,
        -0.02740402-3.30131509e-01j,  0.30923856+1.19760009e-01j],
       [ 0.02445108-2.91797376e-01j, -0.02740402+3.30131509e-01j,
         0.61790877-1.09365912e-11j,  0.00972619-2.00981080e-01j],
       [ 0.28310573-1.37628068e-01j,  0.30923856-1.19760009e-01j,
         0.00972619+2.00981080e-01j,  0.47931522-2.50949088e-11j]])]

# %% [markdown]
# ## Exploring the success probabilities
#
# Now we can test the success probabilities of the newly-found $(9,2)$-QRACs.

# %%
# function to compute the success probability of observing zero
def get_prob_observe_zero(encoding, decoding):
    prob = np.abs(np.trace(np.dot(encoding, decoding))) #the probability of observing zero computed by trace
    return prob

probabilities = []
for i in range(len(decoding)):
    for j in range(len(encoding)):
        prob = get_prob_observe_zero(encoding[j], decoding[i])
        print('[Obtaining zero at {0}-th bit of {1} with. prob. {2}]'.format(format(i+1,'2'), format(j,'09b'), prob))
        probabilities.append(np.abs(prob - 1.0/2.0))
# Out:
# [Obtaining zero at  1-th bit of 000000000 with. prob. 0.6792734138319624]
# [Obtaining zero at  1-th bit of 000000001 with. prob. 0.6828437860356871]
# [Obtaining zero at  1-th bit of 000000010 with. prob. 0.7072190673054859]
# [Obtaining zero at  1-th bit of 000000011 with. prob. 0.6734677126814888]
# [Obtaining zero at  1-th bit of 000000100 with. prob. 0.675815203983642]
# [Obtaining zero at  1-th bit of 000000101 with. prob. 0.6940631725469808]
# [Obtaining zero at  1-th bit of 000000110 with. prob. 0.6799338941079152]
# [Obtaining zero at  1-th bit of 000000111 with. prob. 0.6829885065984287]
# [Obtaining zero at  1-th bit of 000001000 with. prob. 0.6749605567986083]
# [Obtaining zero at  1-th bit of 000001001 with. prob. 0.6737436733431463]
# [Obtaining zero at  1-th bit of 000001010 with. prob. 0.6731119426451536]
# [Obtaining zero at  1-th bit of 000001011 with. prob. 0.6966754061816374]
# [Obtaining zero at  1-th bit of 000001100 with. prob. 0.6867085852599547]
# ...

# %% [markdown]
# ## Computing the worst case of the success probability

# %%
#QRAC success prob.
1/2 + np.min(probabilities)
# Out:
# 0.6716050956379702

# %% [markdown]
# ## Computing the maximum success probability

# %%
#max success prob.
1/2 + np.max(probabilities)
# Out:
# 0.831858270808741

# %% [markdown]
# ## Computing the average success probability

# %%
#min success prob
1/2 + np.mean(probabilities)
# Out:
# 0.6865705289119931
